# %%
DATAPATH = "results"

# %% [markdown]
# # Installs and imports

# %%
#!pip install pingouin > /dev/null

# %%
import pingouin as pg
import pandas as pd
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc, f1_score
from sklearn import metrics
import pickle
import os
from tqdm import tqdm
import gzip
import scipy.stats as stats
import itertools
from statsmodels.stats.anova import AnovaRM
from collections import Counter

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
# Out:
# /home/kali/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/kali/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Data loading

# %%
label_names = ["human", "machine"] #0, 1
id2label = {idx:label for idx, label in enumerate(label_names)}
label2id = {v:k for k,v in id2label.items()}

# %%
multidomain = pd.read_csv(f"{DATAPATH.replace('results', 'dataset')}/multidomain.csv.gz")

# %%
temp = multidomain[(multidomain.split == 'test') & (multidomain.domain == 'social_media')]
temp['source'] = temp['source'].str.replace('multisocial_', '')
temp.groupby(['source'])['length'].describe()
# Out:
# /tmp/ipykernel_634/3072383140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#             count       mean        std  min   25%   50%   75%    max
# source
# discord   27652.0  16.213764  26.201387  3.0   5.0   9.0  15.0  197.0
# gab       30740.0  25.979538  30.708710  3.0   9.0  16.0  30.0  200.0
# telegram  44385.0  23.820390  32.579460  3.0   7.0  12.0  24.0  200.0
# twitter   25172.0  25.470563  26.693076  3.0  11.0  18.0  30.0  200.0
# whatsapp  10878.0  30.622909  33.921798  3.0   9.0  18.0  38.0  200.0

# %%
test_results = []

# %%
files = glob.glob(DATAPATH + "/pretrained/*.csv.gz")
for f in tqdm(files, total= len(files)):
   df = pd.read_csv(f)
   df = pd.concat([multidomain, df], axis=1)
   df['label'] = ['human' if 'human' in x else 'machine' for x in df['multi_label']]
   df['predictions'] = ['human' if (('human' in str(x)) or ('0' in str(x))) else 'machine' for x in df['predictions']]
   df['Category'] = 'P'

   if ('ruroberta' in f.lower()):
     df['prediction_probs'] = 1 - df['prediction_probs']
   test_results.append({f.split('/')[-1].replace('multidomain.csv_', '').replace('.csv.gz', '') : df})
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:04<00:00,  1.11it/s]

# %%
files = glob.glob(DATAPATH + "/statistical/*.csv.gz")
for f in tqdm(files, total= len(files)):
   df = pd.read_csv(f)
   df = pd.concat([multidomain, df], axis=1)
   df['label'] = ['human' if 'human' in x else 'machine' for x in df['multi_label']]
   df['predictions'] = ['human' if (('human' in str(x)) or ('0' in str(x))) else 'machine' for x in df['predictions']]
   df['Category'] = 'S'

   if ('llr' in f.lower()):
     continue
     df['prediction_probs'] = 1 - df['prediction_probs']
   if ('s5' in f.lower()):
     if ('gpt-j' not in f.lower()): continue #use only GPT-J based S5 metric
     df['ll'] = 1 - df['ll']
     temp = pd.DataFrame()
     temp[['ll', 'entropy', 'rank', 'log-rank', 'llm_deviation']] = 1 / df[['ll', 'entropy', 'rank', 'log-rank', 'llm_deviation']]
     temp = temp.fillna(0.0)
     df['prediction_probs'] = temp.prod(axis=1).fillna(0.0).replace(np.inf, 0.0)
     
     #llm_deviation
     temp = df.copy()
     temp['prediction_probs'] = 1 - temp['llm_deviation']
     test_results.append({f.split('/')[-1].replace('multidomain.csv_', '').replace('.csv.gz', '').replace('s5', 'llm_deviation') : temp})

     #lrr
     temp = df.copy()
     temp['prediction_probs'] = temp['ll'] / temp['log-rank']
     temp['prediction_probs'] = temp['prediction_probs'].fillna(0.0).replace(np.inf, 0.0)
     test_results.append({f.split('/')[-1].replace('multidomain.csv_', '').replace('.csv.gz', '').replace('s5', 'lrr') : temp})
   test_results.append({f.split('/')[-1].replace('multidomain.csv_', '').replace('.csv.gz', '') : df})
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:05<00:00,  1.70s/it]

# %%
files = glob.glob(DATAPATH + "/finetuned/*.csv.gz")
for f in tqdm(files, total= len(files)):
   #print(f)
   df = pd.read_csv(f)
   if 'prediction_probs' not in df.columns:
    df.columns.values[-1] = 'prediction_probs'
   if 'predictions' not in df.columns: df['predictions'] = 0
   df = pd.concat([multidomain, df[['predictions', 'prediction_probs']]], axis=1)
   df['prediction_probs'] = df['prediction_probs'].fillna(0.0).replace(np.inf, 0.0)
   df['label'] = ['human' if 'human' in x else 'machine' for x in df['multi_label']]
   df['predictions'] = ['human' if (('human' in str(x)) or ('0' in str(x))) else 'machine' for x in df['predictions']]
   df['Category'] = 'F'
   test_results.append({f.split('/')[-1].replace('multidomain.csv_', '').replace('.csv.gz', '') : df})
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 73/73 [00:56<00:00,  1.29it/s]

# %% [markdown]
# # Results analysis

# %% [markdown]
# ## Definitions

# %%
#https://github.com/scikit-learn/scikit-learn/issues/26808
def report_np(y_true, y_pred, n_classes):

    classes = np.arange(n_classes)[None, :]
    supp = classes == y_true[:, None]
    tmp = classes == y_pred[:, None]
    hits = (tmp & supp).sum(axis=0)
    pred = tmp.sum(axis=0)
    n = y_true.shape[0]

    supp = supp.sum(axis=0)
    #https://stackoverflow.com/questions/26248654/how-to-return-0-with-divide-by-zero
    #prec = hits / pred
    pred_inv = np.array([1/i if i!=0 else 0 for i in pred])
    prec = hits * pred_inv
    #prec = np.divide(hits, pred, out=np.zeros(hits.shape, dtype=float), where=pred!=0)
    #rec = hits / supp
    supp_inv = np.array([1/i if i!=0 else 0 for i in supp])
    rec = hits * supp_inv
    #rec = np.divide(hits, supp, out=np.zeros(hits.shape, dtype=float), where=supp!=0)
    balanced_acc = rec.mean()
    prec_rec = prec + rec
    prec_rec_mult = 2 * prec * rec
    #f1 = prec_rec_mult / prec_rec
    prec_rec_inv = np.array([1/i if i!=0 else 0 for i in prec_rec])
    f1 = prec_rec_mult * prec_rec_inv
    #f1 = np.divide(prec_rec_mult, prec_rec, out=np.zeros(prec_rec_mult.shape, dtype=float), where=prec_rec!=0)
    acc = hits.sum() / n
    stacked = np.vstack([prec, rec, f1])
    macro = stacked.mean(axis=1)
    weighted = stacked @ supp / n

    return hits, pred - hits, acc, balanced_acc, supp, prec, rec, f1 , macro, weighted

def report_todict(hits, miss, acc, balanced_acc, supp, prec, rec, f1 , macro, weighted):
  report = {}
  TN = hits[0]
  FN = miss[0]
  TP = hits[1]
  FP = miss[1]
  report['fpr'] = FP/(FP+TN) if (FP+TN) > 0 else 0
  report['fnr'] = FN/(TP+FN) if (TP+FN) > 0 else 0
  human = {}
  human['precision'] = prec[0]
  human['recall'] = rec[0]
  human['f1-score'] = f1[0]
  human['support'] = supp[0]
  report['human'] = human
  machine = {}
  machine['precision'] = prec[1]
  machine['recall'] = rec[1]
  machine['f1-score'] = f1[1]
  machine['support'] = supp[1]
  report['machine'] = machine
  report['accuracy'] = acc
  report['balanced accuracy'] = balanced_acc
  macro_avg = {}
  macro_avg['precision'] = macro[0]
  macro_avg['recall'] = macro[1]
  macro_avg['f1-score'] = macro[2]
  report['macro avg'] = macro_avg
  weighted_avg = {}
  weighted_avg['precision'] = weighted[0]
  weighted_avg['recall'] = weighted[1]
  weighted_avg['f1-score'] = weighted[2]
  report['weighted avg'] = weighted_avg
  return report

# %%
def rename_detector(detector_name):
  detector_name = (detector_name
    .lower()
    .replace('meta-', '')
    .replace('orzhan-', '')
    .replace('nealcly-', '')
    .replace('hello-simpleai-', '')
    .replace('andreas122001-', '')
    .replace('openai-community-', '')
    .replace('_threshold', '')
    .replace('metric', '')
    .replace('gpt-j-6b_', '')
    .replace('s5', 'S5')
    .replace('llm_deviation', 'LLM-Deviation')
    .replace('lrr', 'DetectLLM-LRR')
    .replace('llr', 'DetectLLM-LRR')
    .replace('-first-social-media', '-MultiSocial')
    .replace('-first-news', '-MULTITuDE')
    .replace('xlm', 'XLM')
    .replace('roberta', 'RoBERTa')
    .replace('mdeberta', 'mDeBERTa')
    .replace('bert', 'BERT')
    .replace('bloomz', 'BLOOMZ')
    .replace('falcon', 'Falcon')
    .replace('mistral', 'Mistral')
    .replace('llama', 'Llama')
    .replace('aya', 'Aya')
    .replace('opt-iml-max', 'OPT-IML-Max')
    .replace('openai', 'OpenAI')
    .replace('detection-longformer', 'Longformer Detector')
    .replace('detect', 'Detect')
    .replace('fast', 'Fast')
    .replace('chatgpt', 'ChatGPT')
    #.replace('gpt-j', 'GPT-J')
    .replace('gpt', 'GPT')
    .replace('chinese', 'Chinese')
    .replace('longformer', 'Longformer')
    .replace('binoculars', 'Binoculars')
    )

  return detector_name

# %%
rename_generators = {'opt-iml-max-30b': 'OPT-IML-Max-30b', 'Mistral-7B-Instruct-v0.2': 'Mistral-7B-Instruct-v0.2', 'vicuna-13b': 'Vicuna-13b',
       'gpt-3.5-turbo-0125': 'GPT-3.5-Turbo-0125', 'aya-101': 'Aya-101', 'v5-Eagle-7B-HF': 'v5-Eagle-7B-HF', 'gemini': 'Gemini'}

# %%
rename_platforms = {'gab': 'Gab', 'whatsapp': 'WhatsApp', 'twitter': 'Twitter', 'telegram': 'Telegram', 'discord': 'Discord', '{all}': '{all}'}

# %%
#extract_platforms = {'-cross-platform-1-cut-majority': '_all', '-cross-platform-4-cut-majority': '_Gab', '-cross-platform-6-cut-majority': '_WhatsApp', '-cross-platform-3-cut-majority': '_Twitter', '-cross-platform-2-cut-majority': '_Telegram', '-cross-platform-5-cut-majority': '_Discord'}
def extract_platform(s):
  s = (s.replace('-cross-platform-1-cut-majority-one-fifth-train-size', '_all')
        .replace('-cross-platform-1-cut-majority', '_all-x5')
        .replace('-cross-platform-4-cut-majority', '_Gab')
        .replace('-cross-platform-6-cut-majority', '_WhatsApp')
        .replace('-cross-platform-3-cut-majority', '_Twitter')
        .replace('-cross-platform-2-cut-majority', '_Telegram')
        .replace('-cross-platform-5-cut-majority', '_Discord')
  )
  return s

# %%
def extract_language(s):
  s = (s.replace('-cross-language-1-cut-majority-one-third-train-size', '_{en-es-ru}')
        .replace('-cross-language-1-cut-majority', '_{en-es-ru-x3}')
        .replace('-cross-language-2-cut-majority', '_en')
        .replace('-cross-language-3-cut-majority', '_es')
        .replace('-cross-language-4-cut-majority', '_ru')
  )
  return s

# %%
to_category = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    to_category[model] = data.Category.unique()[0]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:01<00:00, 47.80it/s]

# %%
to_language_family = {
    'el': 'Greek',
    'ar': 'Semitic', 'zh': 'Sino-Tibetan',
    'ca': 'Romance', 'es': 'Romance', 'pt': 'Romance',
    'en': 'Germanic', 'ga': 'Celtic', 'gd': 'Celtic',
    'hu': 'Uralic', 'et': 'Uralic',
    'de': 'Germanic', 'nl': 'Germanic',
    'cs': 'Slavic-Latin', 'pl': 'Slavic-Latin', 'sk': 'Slavic-Latin',
    'hr': 'Slavic-Latin', 'sl': 'Slavic-Latin',
    'ro': 'Romance',
    'bg': 'Slavic-Cyrillic', 'uk': 'Slavic-Cyrillic',  'ru': 'Slavic-Cyrillic',
}

# %%
def highlight_categories(s):
    v = s['Category']
    color = 'background-color: #b6d7a8;' if v == 'F' else 'background-color: #f9cb9c;' if v == 'S' else 'background-color: #9fc5e8;'
    return [color for v in s]

# %%
def auc_roc_reliable(fpr, tpr, labels):
    res =  auc(fpr, tpr)
    counts = Counter(labels)
    return res if (len(counts) and counts[0] >= 10 and counts[1] >= 10) else pd.NA

# %% [markdown]
# ## Benchmark Comparison

# %%
#social media test data - th calibration for macroF1 based on train data
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    train = data[(data.split == 'train') & (data.domain == 'social_media') & (~data.multi_label.str.contains('gemini'))]
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}

  train_labels = [label2id[x] for x in train['label']]
  fpr, tpr, thresholds = roc_curve(train_labels, train['prediction_probs'])
  predictions = [1 if ((x >= thresholds[fpr <= 0.05][-1])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_5'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
  predictions = [1 if ((x >= thresholds[np.argmax(tpr - fpr)])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_o'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': rename_detector(model), 'Category': to_category[model], 'AUC ROC': v['auc'], 'MacroF1@5%FPR': v['cr_5']['macro avg']['f1-score'], 'MacroF1@optim': v['cr_o']['macro avg']['f1-score']}, index=[0])
  results_all = pd.concat([results_all, temp])
results_all = results_all.sort_values(by=['AUC ROC'], ascending=False).reset_index(drop=True)
results_all.index = results_all.index + 1
results_all.style.format(na_rep=0, precision=4)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [02:05<00:00,  1.51s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 465.59it/s]
# <style type="text/css">
# </style>
# <table id="T_fb391">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb391_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_fb391_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_fb391_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_fb391_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#       <th id="T_fb391_level0_col4" class="col_heading level0 col4" >MacroF1@optim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb391_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fb391_row0_col0" class="data row0 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_fb391_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_fb391_row0_col2" class="data row0 col2" >0.9769</td>
#       <td id="T_fb391_row0_col3" class="data row0 col3" >0.8696</td>
#       <td id="T_fb391_row0_col4" class="data row0 col4" >0.8567</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fb391_row1_col0" class="data row1 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_fb391_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_fb391_row1_col2" class="data row1 col2" >0.9768</td>
#       <td id="T_fb391_row1_col3" class="data row1 col3" >0.8692</td>
#       <td id="T_fb391_row1_col4" class="data row1 col4" >0.8619</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fb391_row2_col0" class="data row2 col0" >Aya-101-MultiSocial</td>
#       <td id="T_fb391_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_fb391_row2_col2" class="data row2 col2" >0.9731</td>
#       <td id="T_fb391_row2_col3" class="data row2 col3" >0.8462</td>
#       <td id="T_fb391_row2_col4" class="data row2 col4" >0.8457</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fb391_row3_col0" class="data row3 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_fb391_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_fb391_row3_col2" class="data row3 col2" >0.9592</td>
#       <td id="T_fb391_row3_col3" class="data row3 col3" >0.7810</td>
#       <td id="T_fb391_row3_col4" class="data row3 col4" >0.8082</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fb391_row4_col0" class="data row4 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_fb391_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_fb391_row4_col2" class="data row4 col2" >0.9582</td>
#       <td id="T_fb391_row4_col3" class="data row4 col3" >0.7843</td>
#       <td id="T_fb391_row4_col4" class="data row4 col4" >0.8107</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fb391_row5_col0" class="data row5 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_fb391_row5_col1" class="data row5 col1" >F</td>
#       <td id="T_fb391_row5_col2" class="data row5 col2" >0.9553</td>
#       <td id="T_fb391_row5_col3" class="data row5 col3" >0.7840</td>
#       <td id="T_fb391_row5_col4" class="data row5 col4" >0.8075</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fb391_row6_col0" class="data row6 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_fb391_row6_col1" class="data row6 col1" >F</td>
#       <td id="T_fb391_row6_col2" class="data row6 col2" >0.9544</td>
#       <td id="T_fb391_row6_col3" class="data row6 col3" >0.7652</td>
#       <td id="T_fb391_row6_col4" class="data row6 col4" >0.7947</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fb391_row7_col0" class="data row7 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_fb391_row7_col1" class="data row7 col1" >P</td>
#       <td id="T_fb391_row7_col2" class="data row7 col2" >0.7553</td>
#       <td id="T_fb391_row7_col3" class="data row7 col3" >0.3024</td>
#       <td id="T_fb391_row7_col4" class="data row7 col4" >0.5882</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_fb391_row8_col0" class="data row8 col0" >DetectLLM-LRR</td>
#       <td id="T_fb391_row8_col1" class="data row8 col1" >S</td>
#       <td id="T_fb391_row8_col2" class="data row8 col2" >0.7464</td>
#       <td id="T_fb391_row8_col3" class="data row8 col3" >0.2523</td>
#       <td id="T_fb391_row8_col4" class="data row8 col4" >0.6580</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_fb391_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_fb391_row9_col1" class="data row9 col1" >S</td>
#       <td id="T_fb391_row9_col2" class="data row9 col2" >0.7454</td>
#       <td id="T_fb391_row9_col3" class="data row9 col3" >0.2497</td>
#       <td id="T_fb391_row9_col4" class="data row9 col4" >0.6570</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_fb391_row10_col0" class="data row10 col0" >S5</td>
#       <td id="T_fb391_row10_col1" class="data row10 col1" >S</td>
#       <td id="T_fb391_row10_col2" class="data row10 col2" >0.7418</td>
#       <td id="T_fb391_row10_col3" class="data row10 col3" >0.2465</td>
#       <td id="T_fb391_row10_col4" class="data row10 col4" >0.6531</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_fb391_row11_col0" class="data row11 col0" >Fast-Detect-GPT</td>
#       <td id="T_fb391_row11_col1" class="data row11 col1" >S</td>
#       <td id="T_fb391_row11_col2" class="data row11 col2" >0.7418</td>
#       <td id="T_fb391_row11_col3" class="data row11 col3" >0.3605</td>
#       <td id="T_fb391_row11_col4" class="data row11 col4" >0.6011</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_fb391_row12_col0" class="data row12 col0" >Binoculars</td>
#       <td id="T_fb391_row12_col1" class="data row12 col1" >S</td>
#       <td id="T_fb391_row12_col2" class="data row12 col2" >0.7248</td>
#       <td id="T_fb391_row12_col3" class="data row12 col3" >0.2815</td>
#       <td id="T_fb391_row12_col4" class="data row12 col4" >0.5525</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_fb391_row13_col0" class="data row13 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_fb391_row13_col1" class="data row13 col1" >P</td>
#       <td id="T_fb391_row13_col2" class="data row13 col2" >0.7180</td>
#       <td id="T_fb391_row13_col3" class="data row13 col3" >0.3416</td>
#       <td id="T_fb391_row13_col4" class="data row13 col4" >0.5397</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_fb391_row14_col0" class="data row14 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_fb391_row14_col1" class="data row14 col1" >P</td>
#       <td id="T_fb391_row14_col2" class="data row14 col2" >0.4817</td>
#       <td id="T_fb391_row14_col3" class="data row14 col3" >0.1711</td>
#       <td id="T_fb391_row14_col4" class="data row14 col4" >0.3425</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_fb391_row15_col0" class="data row15 col0" >Longformer Detector</td>
#       <td id="T_fb391_row15_col1" class="data row15 col1" >P</td>
#       <td id="T_fb391_row15_col2" class="data row15 col2" >0.4615</td>
#       <td id="T_fb391_row15_col3" class="data row15 col3" >0.1516</td>
#       <td id="T_fb391_row15_col4" class="data row15 col4" >0.4917</td>
#     </tr>
#     <tr>
#       <th id="T_fb391_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_fb391_row16_col0" class="data row16 col0" >RoBERTa-large-OpenAI-Detector</td>

# %%
#social media test data - th calibration for macroF1 based on train data
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    train = data[(data.split == 'train') & (data.domain == 'social_media') & (~data.multi_label.str.contains('gemini'))]
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}

  train_labels = [label2id[x] for x in train['label']]
  fpr, tpr, thresholds = roc_curve(train_labels, train['prediction_probs'])
  predictions = [1 if ((x >= thresholds[fpr <= 0.05][-1])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_5'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': rename_detector(model), 'Category': to_category[model], 'AUC ROC': v['auc'], 'MacroF1@5%FPR': v['cr_5']['macro avg']['f1-score']}, index=[0])
  results_all = pd.concat([results_all, temp])
results_all = results_all.sort_values(by=['AUC ROC'], ascending=False).reset_index(drop=True)
results_all.index = results_all.index + 1
results_all.style.format(na_rep=0, precision=4)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [01:15<00:00,  1.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 723.77it/s]
# <style type="text/css">
# </style>
# <table id="T_4108e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4108e_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_4108e_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_4108e_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_4108e_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4108e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4108e_row0_col0" class="data row0 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_4108e_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_4108e_row0_col2" class="data row0 col2" >0.9769</td>
#       <td id="T_4108e_row0_col3" class="data row0 col3" >0.8696</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4108e_row1_col0" class="data row1 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_4108e_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_4108e_row1_col2" class="data row1 col2" >0.9768</td>
#       <td id="T_4108e_row1_col3" class="data row1 col3" >0.8692</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4108e_row2_col0" class="data row2 col0" >Aya-101-MultiSocial</td>
#       <td id="T_4108e_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_4108e_row2_col2" class="data row2 col2" >0.9731</td>
#       <td id="T_4108e_row2_col3" class="data row2 col3" >0.8462</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4108e_row3_col0" class="data row3 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_4108e_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_4108e_row3_col2" class="data row3 col2" >0.9592</td>
#       <td id="T_4108e_row3_col3" class="data row3 col3" >0.7810</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4108e_row4_col0" class="data row4 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_4108e_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_4108e_row4_col2" class="data row4 col2" >0.9582</td>
#       <td id="T_4108e_row4_col3" class="data row4 col3" >0.7843</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4108e_row5_col0" class="data row5 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_4108e_row5_col1" class="data row5 col1" >F</td>
#       <td id="T_4108e_row5_col2" class="data row5 col2" >0.9553</td>
#       <td id="T_4108e_row5_col3" class="data row5 col3" >0.7840</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4108e_row6_col0" class="data row6 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_4108e_row6_col1" class="data row6 col1" >F</td>
#       <td id="T_4108e_row6_col2" class="data row6 col2" >0.9544</td>
#       <td id="T_4108e_row6_col3" class="data row6 col3" >0.7652</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4108e_row7_col0" class="data row7 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_4108e_row7_col1" class="data row7 col1" >P</td>
#       <td id="T_4108e_row7_col2" class="data row7 col2" >0.7553</td>
#       <td id="T_4108e_row7_col3" class="data row7 col3" >0.3024</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4108e_row8_col0" class="data row8 col0" >DetectLLM-LRR</td>
#       <td id="T_4108e_row8_col1" class="data row8 col1" >S</td>
#       <td id="T_4108e_row8_col2" class="data row8 col2" >0.7464</td>
#       <td id="T_4108e_row8_col3" class="data row8 col3" >0.2523</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_4108e_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_4108e_row9_col1" class="data row9 col1" >S</td>
#       <td id="T_4108e_row9_col2" class="data row9 col2" >0.7454</td>
#       <td id="T_4108e_row9_col3" class="data row9 col3" >0.2497</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_4108e_row10_col0" class="data row10 col0" >S5</td>
#       <td id="T_4108e_row10_col1" class="data row10 col1" >S</td>
#       <td id="T_4108e_row10_col2" class="data row10 col2" >0.7418</td>
#       <td id="T_4108e_row10_col3" class="data row10 col3" >0.2465</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_4108e_row11_col0" class="data row11 col0" >Fast-Detect-GPT</td>
#       <td id="T_4108e_row11_col1" class="data row11 col1" >S</td>
#       <td id="T_4108e_row11_col2" class="data row11 col2" >0.7418</td>
#       <td id="T_4108e_row11_col3" class="data row11 col3" >0.3605</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_4108e_row12_col0" class="data row12 col0" >Binoculars</td>
#       <td id="T_4108e_row12_col1" class="data row12 col1" >S</td>
#       <td id="T_4108e_row12_col2" class="data row12 col2" >0.7248</td>
#       <td id="T_4108e_row12_col3" class="data row12 col3" >0.2815</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_4108e_row13_col0" class="data row13 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_4108e_row13_col1" class="data row13 col1" >P</td>
#       <td id="T_4108e_row13_col2" class="data row13 col2" >0.7180</td>
#       <td id="T_4108e_row13_col3" class="data row13 col3" >0.3416</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_4108e_row14_col0" class="data row14 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_4108e_row14_col1" class="data row14 col1" >P</td>
#       <td id="T_4108e_row14_col2" class="data row14 col2" >0.4817</td>
#       <td id="T_4108e_row14_col3" class="data row14 col3" >0.1711</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_4108e_row15_col0" class="data row15 col0" >Longformer Detector</td>
#       <td id="T_4108e_row15_col1" class="data row15 col1" >P</td>
#       <td id="T_4108e_row15_col2" class="data row15 col2" >0.4615</td>
#       <td id="T_4108e_row15_col3" class="data row15 col3" >0.1516</td>
#     </tr>
#     <tr>
#       <th id="T_4108e_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_4108e_row16_col0" class="data row16 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_4108e_row16_col1" class="data row16 col1" >P</td>
#       <td id="T_4108e_row16_col2" class="data row16 col2" >0.3450</td>
#       <td id="T_4108e_row16_col3" class="data row16 col3" >0.1376</td>
#     </tr>
#   </tbody>
# </table>

# %%
results_all.style.apply(highlight_categories, axis=1).hide('Category', axis=1)
# Out:
# <style type="text/css">
# #T_43fdb_row0_col0, #T_43fdb_row0_col2, #T_43fdb_row0_col3, #T_43fdb_row1_col0, #T_43fdb_row1_col2, #T_43fdb_row1_col3, #T_43fdb_row2_col0, #T_43fdb_row2_col2, #T_43fdb_row2_col3, #T_43fdb_row3_col0, #T_43fdb_row3_col2, #T_43fdb_row3_col3, #T_43fdb_row4_col0, #T_43fdb_row4_col2, #T_43fdb_row4_col3, #T_43fdb_row5_col0, #T_43fdb_row5_col2, #T_43fdb_row5_col3, #T_43fdb_row6_col0, #T_43fdb_row6_col2, #T_43fdb_row6_col3 {
#   background-color: #b6d7a8;
# }
# #T_43fdb_row7_col0, #T_43fdb_row7_col2, #T_43fdb_row7_col3, #T_43fdb_row13_col0, #T_43fdb_row13_col2, #T_43fdb_row13_col3, #T_43fdb_row14_col0, #T_43fdb_row14_col2, #T_43fdb_row14_col3, #T_43fdb_row15_col0, #T_43fdb_row15_col2, #T_43fdb_row15_col3, #T_43fdb_row16_col0, #T_43fdb_row16_col2, #T_43fdb_row16_col3 {
#   background-color: #9fc5e8;
# }
# #T_43fdb_row8_col0, #T_43fdb_row8_col2, #T_43fdb_row8_col3, #T_43fdb_row9_col0, #T_43fdb_row9_col2, #T_43fdb_row9_col3, #T_43fdb_row10_col0, #T_43fdb_row10_col2, #T_43fdb_row10_col3, #T_43fdb_row11_col0, #T_43fdb_row11_col2, #T_43fdb_row11_col3, #T_43fdb_row12_col0, #T_43fdb_row12_col2, #T_43fdb_row12_col3 {
#   background-color: #f9cb9c;
# }
# </style>
# <table id="T_43fdb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43fdb_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_43fdb_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_43fdb_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43fdb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_43fdb_row0_col0" class="data row0 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_43fdb_row0_col2" class="data row0 col2" >0.976945</td>
#       <td id="T_43fdb_row0_col3" class="data row0 col3" >0.869627</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_43fdb_row1_col0" class="data row1 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_43fdb_row1_col2" class="data row1 col2" >0.976791</td>
#       <td id="T_43fdb_row1_col3" class="data row1 col3" >0.869152</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_43fdb_row2_col0" class="data row2 col0" >Aya-101-MultiSocial</td>
#       <td id="T_43fdb_row2_col2" class="data row2 col2" >0.973101</td>
#       <td id="T_43fdb_row2_col3" class="data row2 col3" >0.846166</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_43fdb_row3_col0" class="data row3 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_43fdb_row3_col2" class="data row3 col2" >0.959221</td>
#       <td id="T_43fdb_row3_col3" class="data row3 col3" >0.780969</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_43fdb_row4_col0" class="data row4 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_43fdb_row4_col2" class="data row4 col2" >0.958181</td>
#       <td id="T_43fdb_row4_col3" class="data row4 col3" >0.784282</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_43fdb_row5_col0" class="data row5 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_43fdb_row5_col2" class="data row5 col2" >0.955259</td>
#       <td id="T_43fdb_row5_col3" class="data row5 col3" >0.784015</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_43fdb_row6_col0" class="data row6 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_43fdb_row6_col2" class="data row6 col2" >0.954366</td>
#       <td id="T_43fdb_row6_col3" class="data row6 col3" >0.765163</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_43fdb_row7_col0" class="data row7 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_43fdb_row7_col2" class="data row7 col2" >0.755251</td>
#       <td id="T_43fdb_row7_col3" class="data row7 col3" >0.302403</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_43fdb_row8_col0" class="data row8 col0" >DetectLLM-LRR</td>
#       <td id="T_43fdb_row8_col2" class="data row8 col2" >0.746401</td>
#       <td id="T_43fdb_row8_col3" class="data row8 col3" >0.252282</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_43fdb_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_43fdb_row9_col2" class="data row9 col2" >0.745394</td>
#       <td id="T_43fdb_row9_col3" class="data row9 col3" >0.249699</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_43fdb_row10_col0" class="data row10 col0" >S5</td>
#       <td id="T_43fdb_row10_col2" class="data row10 col2" >0.741828</td>
#       <td id="T_43fdb_row10_col3" class="data row10 col3" >0.246517</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_43fdb_row11_col0" class="data row11 col0" >Fast-Detect-GPT</td>
#       <td id="T_43fdb_row11_col2" class="data row11 col2" >0.741762</td>
#       <td id="T_43fdb_row11_col3" class="data row11 col3" >0.360484</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_43fdb_row12_col0" class="data row12 col0" >Binoculars</td>
#       <td id="T_43fdb_row12_col2" class="data row12 col2" >0.724761</td>
#       <td id="T_43fdb_row12_col3" class="data row12 col3" >0.281492</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_43fdb_row13_col0" class="data row13 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_43fdb_row13_col2" class="data row13 col2" >0.718004</td>
#       <td id="T_43fdb_row13_col3" class="data row13 col3" >0.341555</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_43fdb_row14_col0" class="data row14 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_43fdb_row14_col2" class="data row14 col2" >0.481694</td>
#       <td id="T_43fdb_row14_col3" class="data row14 col3" >0.171067</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_43fdb_row15_col0" class="data row15 col0" >Longformer Detector</td>
#       <td id="T_43fdb_row15_col2" class="data row15 col2" >0.461508</td>
#       <td id="T_43fdb_row15_col3" class="data row15 col3" >0.151626</td>
#     </tr>
#     <tr>
#       <th id="T_43fdb_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_43fdb_row16_col0" class="data row16 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_43fdb_row16_col2" class="data row16 col2" >0.345033</td>
#       <td id="T_43fdb_row16_col3" class="data row16 col3" >0.137623</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide('Category', axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(
    axis=0).to_latex(convert_css=True))
# Out:
# \begin{tabular}{rlrr}
# \bfseries index & \bfseries Detector & \bfseries AUC ROC & MacroF1@5%FPR \\
# {\cellcolor[HTML]{B6D7A8}} 1 & {\cellcolor[HTML]{B6D7A8}} Llama-3-8b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9769 & {\cellcolor[HTML]{B6D7A8}} 0.8696 \\
# {\cellcolor[HTML]{B6D7A8}} 2 & {\cellcolor[HTML]{B6D7A8}} Mistral-7b-v0.1-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9768 & {\cellcolor[HTML]{B6D7A8}} 0.8692 \\
# {\cellcolor[HTML]{B6D7A8}} 3 & {\cellcolor[HTML]{B6D7A8}} Aya-101-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9731 & {\cellcolor[HTML]{B6D7A8}} 0.8462 \\
# {\cellcolor[HTML]{B6D7A8}} 4 & {\cellcolor[HTML]{B6D7A8}} Falcon-rw-1b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9592 & {\cellcolor[HTML]{B6D7A8}} 0.7810 \\
# {\cellcolor[HTML]{B6D7A8}} 5 & {\cellcolor[HTML]{B6D7A8}} BLOOMZ-3b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9582 & {\cellcolor[HTML]{B6D7A8}} 0.7843 \\
# {\cellcolor[HTML]{B6D7A8}} 6 & {\cellcolor[HTML]{B6D7A8}} XLM-RoBERTa-large-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9553 & {\cellcolor[HTML]{B6D7A8}} 0.7840 \\
# {\cellcolor[HTML]{B6D7A8}} 7 & {\cellcolor[HTML]{B6D7A8}} mDeBERTa-v3-base-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9544 & {\cellcolor[HTML]{B6D7A8}} 0.7652 \\
# {\cellcolor[HTML]{9FC5E8}} 8 & {\cellcolor[HTML]{9FC5E8}} BLOOMZ-3b-mixed-Detector & {\cellcolor[HTML]{9FC5E8}} 0.7553 & {\cellcolor[HTML]{9FC5E8}} 0.3024 \\
# {\cellcolor[HTML]{F9CB9C}} 9 & {\cellcolor[HTML]{F9CB9C}} DetectLLM-LRR & {\cellcolor[HTML]{F9CB9C}} 0.7464 & {\cellcolor[HTML]{F9CB9C}} 0.2523 \\
# {\cellcolor[HTML]{F9CB9C}} 10 & {\cellcolor[HTML]{F9CB9C}} LLM-Deviation & {\cellcolor[HTML]{F9CB9C}} 0.7454 & {\cellcolor[HTML]{F9CB9C}} 0.2497 \\
# {\cellcolor[HTML]{F9CB9C}} 11 & {\cellcolor[HTML]{F9CB9C}} S5 & {\cellcolor[HTML]{F9CB9C}} 0.7418 & {\cellcolor[HTML]{F9CB9C}} 0.2465 \\
# {\cellcolor[HTML]{F9CB9C}} 12 & {\cellcolor[HTML]{F9CB9C}} Fast-Detect-GPT & {\cellcolor[HTML]{F9CB9C}} 0.7418 & {\cellcolor[HTML]{F9CB9C}} 0.3605 \\
# {\cellcolor[HTML]{F9CB9C}} 13 & {\cellcolor[HTML]{F9CB9C}} Binoculars & {\cellcolor[HTML]{F9CB9C}} 0.7248 & {\cellcolor[HTML]{F9CB9C}} 0.2815 \\
# {\cellcolor[HTML]{9FC5E8}} 14 & {\cellcolor[HTML]{9FC5E8}} ChatGPT-Detector-RoBERTa-Chinese & {\cellcolor[HTML]{9FC5E8}} 0.7180 & {\cellcolor[HTML]{9FC5E8}} 0.3416 \\
# {\cellcolor[HTML]{9FC5E8}} 15 & {\cellcolor[HTML]{9FC5E8}} ruRoBERTa-ruatd-binary & {\cellcolor[HTML]{9FC5E8}} 0.4817 & {\cellcolor[HTML]{9FC5E8}} 0.1711 \\
# {\cellcolor[HTML]{9FC5E8}} 16 & {\cellcolor[HTML]{9FC5E8}} Longformer Detector & {\cellcolor[HTML]{9FC5E8}} 0.4615 & {\cellcolor[HTML]{9FC5E8}} 0.1516 \\
# {\cellcolor[HTML]{9FC5E8}} 17 & {\cellcolor[HTML]{9FC5E8}} RoBERTa-large-OpenAI-Detector & {\cellcolor[HTML]{9FC5E8}} 0.3450 & {\cellcolor[HTML]{9FC5E8}} 0.1376 \\
# \end{tabular}
# /tmp/ipykernel_634/666694371.py:1: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide('Category', axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(

# %%
#social media test data - per LLM

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
 for model,data in detector.items():
  temp_data = data[(data.split == 'test') & (data.domain == 'social_media')]
 if (to_category[model] == 'F') and ('social-media' not in model): continue
 for llm in tqdm(temp_data.multi_label.unique(), total=len(temp_data.multi_label.unique())):
  if llm == 'human': continue
  temp = temp_data[(temp_data.multi_label.str.contains(f'human|{llm}'))]
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[f"{model} {llm}"] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[f"{model} {llm}"][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Generator': model.split(' ')[1], 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Generator': model.split(' ')[1], 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Generator', 'Language']).unstack().style.format(precision=2).highlight_max(props='font-weight: bold;', axis=0).background_gradient(vmin=0.5, axis=None)
results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_all['Generator'] = results_all['Generator'].map(rename_generators)
results_perllm = results_all.copy()
# Out:
#   0%|                                                                                            | 0/83 [00:00<?, ?it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.48it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.59it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.66it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.63it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.61it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.56it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.58it/s]
#   1%|█                                                                                   | 1/83 [00:01<01:35,  1.17s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.13it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.92it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.72it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.73it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.72it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.71it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.71it/s]
#   2%|██                                                                                  | 2/83 [00:02<01:33,  1.15s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.13it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.89it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.67it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.77it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.75it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.75it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.14it/s]
#   4%|███                                                                                 | 3/83 [00:03<01:34,  1.19s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.80it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.67it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.63it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.57it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.64it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.59it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.57it/s]
#   5%|████                                                                                | 4/83 [00:04<01:32,  1.17s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.80it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.68it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.50it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.59it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.56it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.51it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.56it/s]
#   6%|█████                                                                               | 5/83 [00:05<01:31,  1.17s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.23it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.08it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.05it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  7.00it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.84it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.95it/s]
#   7%|██████                                                                              | 6/83 [00:06<01:28,  1.15s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.36it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.59it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.51it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.60it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.39it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.40it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.42it/s]
#   8%|███████                                                                             | 7/83 [00:08<01:28,  1.16s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.54it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.67it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.80it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.41it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.60it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.55it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.60it/s]
#  10%|████████                                                                            | 8/83 [00:09<01:26,  1.16s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.16it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.85it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.85it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.88it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.84it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.87it/s]
#  11%|█████████                                                                           | 9/83 [00:10<01:25,  1.15s/it]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  7.00it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.73it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.26it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  5.99it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.12it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.22it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.13it/s]
#  18%|███████████████                                                                    | 15/83 [00:12<00:23,  2.91it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.16it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.30it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.60it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.60it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.63it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.62it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.58it/s]
#  28%|███████████████████████                                                            | 23/83 [00:13<00:11,  5.16it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.07it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.93it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.95it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.97it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.84it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.83it/s]
#  36%|██████████████████████████████                                                     | 30/83 [00:15<00:08,  5.97it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.04it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.87it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.84it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.83it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.86it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.85it/s]
#  53%|████████████████████████████████████████████                                       | 44/83 [00:17<00:04,  9.11it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.32it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.02it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.96it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.95it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.78it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.70it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.80it/s]
#  72%|████████████████████████████████████████████████████████████                       | 60/83 [00:20<00:02,  9.91it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.32it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.22it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.97it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.88it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.87it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.91it/s]
#  89%|██████████████████████████████████████████████████████████████████████████         | 74/83 [00:22<00:00,  9.30it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  5.46it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:01,  5.85it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.32it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.56it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.71it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.54it/s]
#  99%|██████████████████████████████████████████████████████████████████████████████████ | 82/83 [00:24<00:00,  6.74it/s]
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.29it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.10it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.93it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.84it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.84it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.83it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:25<00:00,  3.27it/s]
#   0%|                                                                                           | 0/119 [00:00<?, ?it/s]/tmp/ipykernel_634/714514677.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_all = pd.concat([results_all, temp])
# 100%|████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 121.54it/s]

# %%
#statistical
temp = results_all[(results_all.Category == 'S')].drop(columns=['Category']).set_index(['Detector', 'Generator', 'Language']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
#styles = [dict(selector="th.row_heading.level0", props=[("writing-mode", "vertical-rl"), ('transform', 'rotateZ(180deg)')])]
display(temp)#.set_table_styles(styles)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{').replace('} &', '}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_2f6b1_row0_col0, #T_2f6b1_row1_col7, #T_2f6b1_row1_col18, #T_2f6b1_row3_col15, #T_2f6b1_row7_col22, #T_2f6b1_row11_col7, #T_2f6b1_row15_col12, #T_2f6b1_row24_col22, #T_2f6b1_row28_col21, #T_2f6b1_row29_col22, #T_2f6b1_row31_col20 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_2f6b1_row0_col1, #T_2f6b1_row1_col9, #T_2f6b1_row15_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2f6b1_row0_col2, #T_2f6b1_row11_col21, #T_2f6b1_row17_col0, #T_2f6b1_row17_col14 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_2f6b1_row0_col3, #T_2f6b1_row1_col17, #T_2f6b1_row3_col0, #T_2f6b1_row3_col7, #T_2f6b1_row5_col1, #T_2f6b1_row7_col10, #T_2f6b1_row15_col8, #T_2f6b1_row18_col7, #T_2f6b1_row21_col21, #T_2f6b1_row25_col9, #T_2f6b1_row32_col19 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_2f6b1_row0_col4, #T_2f6b1_row1_col12, #T_2f6b1_row7_col0, #T_2f6b1_row15_col0, #T_2f6b1_row18_col16, #T_2f6b1_row19_col20, #T_2f6b1_row21_col17, #T_2f6b1_row24_col17, #T_2f6b1_row24_col19, #T_2f6b1_row29_col13 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_2f6b1_row0_col5, #T_2f6b1_row8_col13, #T_2f6b1_row10_col17, #T_2f6b1_row18_col6, #T_2f6b1_row19_col19, #T_2f6b1_row21_col15, #T_2f6b1_row25_col0, #T_2f6b1_row32_col18 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_2f6b1_row0_col6, #T_2f6b1_row2_col5, #T_2f6b1_row5_col3, #T_2f6b1_row6_col8, #T_2f6b1_row7_col11, #T_2f6b1_row7_col18, #T_2f6b1_row11_col16, #T_2f6b1_row15_col21, #T_2f6b1_row24_col7, #T_2f6b1_row32_col0, #T_2f6b1_row33_col6 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_2f6b1_row0_col7, #T_2f6b1_row1_col14, #T_2f6b1_row4_col12, #T_2f6b1_row6_col0, #T_2f6b1_row15_col6, #T_2f6b1_row18_col15, #T_2f6b1_row21_col19, #T_2f6b1_row22_col1, #T_2f6b1_row28_col19, #T_2f6b1_row32_col17 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T
{
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_2f6b1_row2_col4, #T_2f6b1_row6_col21, #T_2f6b1_row8_col18, #T_2f6b1_row9_col4, #T_2f6b1_row9_col20, #T_2f6b1_row13_col9, #T_2f6b1_row13_col10, #T_2f6b1_row13_col20, #T_2f6b1_row22_col8, #T_2f6b1_row24_col5, #T_2f6b1_row26_col4, #T_2f6b1_row33_col10, #T_2f6b1_row34_col4, #T_2f6b1_row34_col9, #T_2f6b1_row34_col20 {
#   background-color: #abbfdc;
#   color: #000
# /tmp/ipykernel_634/836429760.py:5: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{').replace('} &', '}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector & Generator &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\bfseries Binoculars}} & \bfseries Aya-101 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{F1EBF4}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{F4EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\bfseries DetectLLM-LRR}} & \bfseries Aya-101 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\bfseries Fast-Detect-GPT}} & \bfseries Aya-101 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{F5EFF6}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{F4EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{F6EFF7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{F4EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{F5EFF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{F5EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\bfseries LLM-Deviation}} & \bfseries Aya-101 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\bfseries S5}} & \bfseries Aya-101 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 \\
# \end{tabular}

# %%
#pretrained
temp = results_all[(results_all.Category == 'P')].drop(columns=['Category']).set_index(['Detector', 'Generator', 'Language']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{3cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_00a67_row0_col0, #T_00a67_row0_col22, #T_00a67_row11_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_00a67_row0_col1, #T_00a67_row0_col3, #T_00a67_row13_col8 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_00a67_row0_col2, #T_00a67_row0_col5, #T_00a67_row1_col4, #T_00a67_row6_col1, #T_00a67_row6_col3, #T_00a67_row6_col4, #T_00a67_row7_col6, #T_00a67_row10_col4, #T_00a67_row11_col6, #T_00a67_row12_col7, #T_00a67_row16_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_00a67_row0_col4, #T_00a67_row0_col15, #T_00a67_row5_col12, #T_00a67_row6_col2 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_00a67_row0_col6, #T_00a67_row10_col8 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_00a67_row0_col7, #T_00a67_row0_col14, #T_00a67_row5_col2, #T_00a67_row9_col1, #T_00a67_row10_col15 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_00a67_row0_col8 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_00a67_row0_col9, #T_00a67_row1_col22, #T_00a67_row4_col7, #T_00a67_row5_col3, #T_00a67_row9_col2, #T_00a67_row9_col22, #T_00a67_row10_col2, #T_00a67_row12_col5, #T_00a67_row16_col20 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_00a67_row0_col10, #T_00a67_row8_col12, #T_00a67_row11_col12, #T_00a67_row12_col19 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_00a67_row0_col11, #T_00a67_row1_col3, #T_00a67_row6_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_00a67_row0_col12 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_00a67_row0_col13, #T_00a67_row10_col7, #T_00a67_row10_col16 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_00a67_row0_col16, #T_00a67_row3_col15, #T_00a67_row5_col9, #T_00a67_row5_col13, #T_00a67_row5_col18, #T_00a67_row7_col8, #T_00a67_row9_col13, #T_00a67_row9_col21, #T_00a67_row13_col16, #T_00a67_row34_col17 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_00a67_row0_col17, #T_00a67_row3_col7, #T_00a67_row5_col1, #T_00a67_row5_col10 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_00a67_row0_col18, #T_00a67_row1_col7, #T_00a67_row1_col11, #T_00a67_row1_col14, #T_00a67_row13_col12, #T_00a67_row25_col21 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_00a67_row0_col19, #T_00a67_row2_col12, #T_00a67_row4_col2, #T_00a67_row10_col20, #T_00a67_row10_col22 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T
_fa90d_row17_col11, #T_fa90d_row17_col15, #T_fa90d_row19_col13, #T_fa90d_row19_col22, #T_fa90d_row21_col11, #T_fa90d_row21_col13, #T_fa90d_row23_col7, #T_fa90d_row25_col3, #T_fa90d_row28_col2, #T_fa90d_row31_col10, #T_fa90d_row34_col10, #T_fa90d_row36_col5, #T_fa90d_row36_col8, #T_fa90d_row36_col16, #T_fa90d_row38_col4, #T_fa90d_row38_col8, #T_fa90d_row38_col18, #T_fa90d_row39_col1, #T_fa90d_row40_col5, #T_fa90d_row40_col7, #T_fa90d_row40_col13, #T_fa90d_row40_col22, #T_fa90d_row41_col20, #T_fa90d_row42_col1, #T_fa90d_row43_col15, #T_fa90d_row43_col22, #T_fa90d_row44_col8, #T_fa90d_row45_col0, #T_fa90d_row45_col14, #T_fa90d_row45_col17, #T_fa90d_row45_col22, #T_fa90d_row46_col12, #T_fa90d_row47_col5, #T_fa90d_row48_col20 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_fa90d_row0_col12, #T_fa90d_row1_col2, #T_fa90d_row1_col3, #T_fa90d_row1_col6, #T_fa90d_row1_col18, #T_fa90d_row3_col0, #T_fa90d_row3_col3, #T_fa90d_row3_col11, #T_fa90d_row3_col15, #T_fa90d_row3_col18, #T_fa90d_row4_col1, #T_fa90d_row5_col6, #T_fa90d_row5_col12, #T_fa90d_row5_col14, #T_fa90d_row5_col15, #T_fa90d_row5_col16, #T_fa90d_row6_col2, #T_fa90d_row6_col4, #T_fa90d_row6_col5, #T_fa90d_row6_col7, #T_fa90d_row6_col13, #T_fa90d_row6_col17, #T_fa90d_row6_col20, #T_fa90d_row6_col21, #T_
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector & Generator &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries Aya-101-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries BLOOMZ-3b-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries Falcon-rw-1b-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & N/A & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries Llama-3-8b-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries Mistral-7b-v0.1-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# ...
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{3cm}{\bfseries mDeBERTa-v3-base-MultiSocial}}} & \bfseries Aya-101 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries GPT-3.5-Turbo-0125 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Gemini & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries OPT-IML-Max-30b & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Vicuna-13b & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \end{tabular}
# /tmp/ipykernel_634/2703689501.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{3cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))

# %%
#social media test data - per platform

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
 for model,data in detector.items():
  temp_data = data[(data.split == 'test') & (data.domain == 'social_media')]
 if (to_category[model] == 'F') and ('social-media' not in model): continue
 temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
 for llm in tqdm(temp_data.source.unique(), total=len(temp_data.multi_label.unique())):
  temp = temp_data[(temp_data.source.str.contains(f'{llm}'))]
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[f"{model} {llm}"] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[f"{model} {llm}"][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Platform': model.split(' ')[1], 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Platform': model.split(' ')[1], 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Platform', 'Language']).unstack().style.format(precision=2).highlight_max(props='font-weight: bold;', axis=0).background_gradient(vmin=0.5, axis=None)
results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_all['Platform'] = results_all['Platform'].map(rename_platforms)
results_perplatform = results_all.copy()
# Out:
#   0%|                                                                                            | 0/83 [00:00<?, ?it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.46it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.56it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.38it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.18it/s]
#   1%|█                                                                                   | 1/83 [00:00<01:01,  1.34it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.36it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.48it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.28it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.43it/s]
#   2%|██                                                                                  | 2/83 [00:01<00:59,  1.36it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.08it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.45it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.25it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.14it/s]
#   4%|███                                                                                 | 3/83 [00:02<00:59,  1.35it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.08it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.39it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.13it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.20it/s]
#   5%|████                                                                                | 4/83 [00:02<00:58,  1.35it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.76it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.59it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.45it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.37it/s]
#   6%|█████                                                                               | 5/83 [00:03<00:57,  1.36it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.52it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.50it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.36it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.42it/s]
#   7%|██████                                                                              | 6/83 [00:04<00:56,  1.37it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.87it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.42it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.22it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.21it/s]
#   8%|███████                                                                             | 7/83 [00:05<00:55,  1.36it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  8.02it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.91it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.70it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.60it/s]
#  10%|████████                                                                            | 8/83 [00:05<00:54,  1.38it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.57it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.51it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.37it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.42it/s]
#  11%|█████████                                                                           | 9/83 [00:06<00:53,  1.38it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.51it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.08it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.95it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  7.99it/s]
#  19%|████████████████                                                                   | 16/83 [00:07<00:14,  4.58it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.97it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.66it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.46it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.53it/s]
#  28%|███████████████████████                                                            | 23/83 [00:09<00:09,  6.51it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.55it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.68it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.59it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.43it/s]
#  36%|██████████████████████████████                                                     | 30/83 [00:10<00:07,  7.22it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.20it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:01,  5.94it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.85it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  7.63it/s]
#  54%|█████████████████████████████████████████████                                      | 45/83 [00:12<00:03,  9.94it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.45it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:01,  5.64it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.68it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  7.76it/s]
#  72%|████████████████████████████████████████████████████████████                       | 60/83 [00:14<00:02,  9.85it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  5.97it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.09it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.00it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  7.83it/s]
#  89%|██████████████████████████████████████████████████████████████████████████         | 74/83 [00:16<00:00, 10.03it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.45it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.29it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.59it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  7.50it/s]
#  99%|██████████████████████████████████████████████████████████████████████████████████ | 82/83 [00:17<00:00,  7.82it/s]/tmp/ipykernel_634/1587289848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.35it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.58it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.40it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  8.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:18<00:00,  4.46it/s]
#   0%|                                                                                            | 0/85 [00:00<?, ?it/s]/tmp/ipykernel_634/1587289848.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_all = pd.concat([results_all, temp])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 85/85 [00:00<00:00, 122.07it/s]

# %%
#statistical
temp = results_all[(results_all.Category == 'S')].drop(columns=['Category']).set_index(['Detector', 'Platform', 'Language']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{5}{*}{', '\\multirow[c]{5}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_8d09e_row0_col0, #T_8d09e_row0_col1, #T_8d09e_row0_col5, #T_8d09e_row0_col17, #T_8d09e_row0_col19, #T_8d09e_row0_col20, #T_8d09e_row0_col21, #T_8d09e_row1_col10, #T_8d09e_row2_col10, #T_8d09e_row3_col9, #T_8d09e_row3_col10, #T_8d09e_row3_col19, #T_8d09e_row3_col20, #T_8d09e_row4_col1, #T_8d09e_row4_col5, #T_8d09e_row4_col9, #T_8d09e_row4_col10, #T_8d09e_row4_col11, #T_8d09e_row4_col12, #T_8d09e_row4_col14, #T_8d09e_row4_col18, #T_8d09e_row
{
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_1ef49_row2_col7, #T_1ef49_row2_col11, #T_1ef49_row7_col7 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_1ef49_row2_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_1ef49_row2_col9, #T_1ef49_row4_col4, #T_1ef49_row6_col21, #T_1ef49_row8_col5, #T_1ef49_row12_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_1ef49_row2_col12, #T_1ef49_row5_col2, #T_1ef49_row5_col7, #T_1ef49_row8_col17 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_1ef49_row2_col13, #T_1ef49_row6_col7, #T_1ef49_row7_col20, #T_1ef49_row8_col22, #T_1ef49_row17_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_1ef49_row2_col14, #T_1ef49_row2_col22, #T_1ef49_row3_col8, #T_1ef49_row7_col5, #T_1ef49_row8_col18, #T_1ef49_row9_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_1ef49_row2_col15, #T_1ef49_row4_col17, #T_1ef49_row7_col16, #T_1ef49_row18_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_1ef49_row2_col18, #T_1ef49_row4_col6 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_1ef49_row2_col19 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_1ef49_row3_col0, #T_1ef49_row5_col12, #T_1ef49_row7_col4 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_1ef49_row3_col5, #T_1ef49_row3_col7, #T_1ef49_row5_col18, #T_1ef49_row6_col5, #T_1ef49_row8_col12 {
# /tmp/ipykernel_634/323448539.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{5}{*}{', '\\multirow[c]{5}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector & Platform &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries BLOOMZ-3b-mixed-Detector}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & N/A & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & N/A & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & N/A & N/A & N/A & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & N/A & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & N/A & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & N/A & N/A & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & N/A & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & N/A & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & N/A & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries ChatGPT-Detector-RoBERTa-Chinese}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & N/A & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & N/A & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & N/A & N/A & N/A & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{F5EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & N/A & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & N/A & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & N/A & N/A & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & N/A & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & N/A & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & N/A & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & N/A & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Longformer Detector}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & N/A & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FEF6FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{F5EFF6}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{F6EFF7}} \color[HTML]{000000} 0.56 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FEF6FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{F9F2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{F6EFF7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & N/A & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{EFE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.24 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.22 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & N/A & {\cellcolor[HTML]{FCF4FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries RoBERTa-large-OpenAI-Detector}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.05 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.12 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.10 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.18 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{FCF4FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.12 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.09 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.09 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.07 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.09 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.09 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.22 & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.29 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{F6EFF7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.11 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.27 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.10 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.09 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.10 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.22 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.18 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.19 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.15 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.28 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.12 & N/A & N/A & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.26 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & N/A & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.18 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.07 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries ruRoBERTa-ruatd-binary}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & N/A & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.54 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.23 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.23 & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & N/A & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F4EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & N/A & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & N/A & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{FEF6FB}} \color[HTML]{000000} 0.50 \\
# \end{tabular}

# %%
#finetuned
temp = results_all[(results_all.Category == 'F')].drop(columns=['Category']).set_index(['Detector', 'Platform', 'Language']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{5}{*}{', '\\multirow[c]{5}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_078eb_row0_col0, #T_078eb_row0_col1, #T_078eb_row0_col5, #T_078eb_row0_col17, #T_078eb_row0_col19, #T_078eb_row0_col20, #T_078eb_row0_col21, #T_078eb_row1_col10, #T_078eb_row2_col10, #T_078eb_row3_col9, #T_078eb_row3_col10, #T_078eb_row3_col19, #T_078eb_row3_col20, #T_078eb_row4_col1, #T_078eb_row4_col5, #T_078eb_row4_col9, #T_078eb_row4_col10, #T_078eb_row4_col11, #T_078eb_row4_col12, #T_078eb_row4_col14, #T_078eb_row4_col18, #T_078eb_row4_col19, #T_078eb_row4_col20, #T_078eb_row4_col21, #T_078eb_row5_col0, #T_078eb_row5_col1, #T_078eb_row5_col5, #T_078eb_row5_col17, #T_078eb_row5_col19, #T_078eb_row5_col20, #T_078eb_row5_col21,
T_078eb_row30_col20, #T_078eb_row30_col21, #T_078eb_row31_col10, #T_078eb_row32_col10, #T_078eb_row33_col9, #T_078eb_row33_col10, #T_078eb_row33_col19, #T_078eb_row33_col20, #T_078eb_row34_col1, #T_078eb_row34_col5, #T_078eb_row34_col9, #T_078eb_row34_col10, #T_078eb_row34_col11, #T_078eb_row34_col12, #T_078eb_row34_col14, #T_078eb_row34_col18, #T_078eb_row34_col19, #T_078eb_row34_col20, #T_078eb_row34_col21 {
#   background-color: #000000;
#   color: #000000;
# }
# #T_078eb_row0_col2, #T_078eb_row0_col8, #T_078eb_row0_col14, #T_078eb_row0_col15, #T_078eb_row0_col16, #T_078eb_row2_col8, #T_078eb_row3_col0, #T_078eb_row3_col5, #T_078eb_row5_col15, #T_078eb_row8_col11, #T_078eb_row10_col8, #T_078eb_row10_col14, #T_078eb_row13_col18, #T_078eb_row14_col8, #T_078eb_row15_col7, #T_078eb_row15_col8, #T_078eb_row15_col13, #T_078eb_row15_col15, #T_078eb_row15_col16, #T_078eb_row17_col11, #T_078eb_row18_col7, #T_078eb_row18_col18, #T_078eb_row19_col0, #T_078eb_row20_col2, #T_078eb_row20_col14, #T_078eb_row20_col15, #T_078eb_row22_col1, #T_078eb_row22_col11, #T_078eb_row23_col0, #T_078eb_row23_col1, #T_078eb_row23_col5, #T_078eb_row23_col7, #T_078eb_row23_col18, #T_078eb_row24_col0, #T_078eb_row24_col8, #T_078eb_row25_col12, #T_078eb_row27_col12, #T_078eb_row30_col3, #T_078eb_row30_col14 {
#   background-color: #76aad0;
#   color: #000000;
# }
# #T_078eb_row0_col3, #T_078eb_row0_col12, #T_078eb_row2_col12, #T_078eb_row2_col19, #T_078eb_row3_col11, #T_078eb_row4_col8, #T_078eb_row5_col3, #T_078eb_row5_col12, #T_078eb_row7_col12, #T_078eb_row10_col3, #T_078eb_row10_col12, #T_078eb_row12_col12, #T_078eb_row15_col3, #T_078eb_row15_col12, #T_078eb_row15_col14, #T_078eb_row17_col12, #T_078eb_row17_col19, #T_078eb_row19_col8, #T_078eb_row20_col3, #T_078eb_row20_col8, #T_078eb_row20_col12, #T_078eb_row22_col12, #T_078eb_row22_col19, #T_078eb_row30_col12, #T_078eb_row32_col12, #T_078eb_row34_col8 {
#   background-color: #75a9cf;
#   color: #000000;
# }
# #T_078eb_row0_col4, #T_078eb_row2_col2, #T_078eb_row2_col7, #T_078eb_row3_col3, #T_078eb_row3_col4, #T_078eb_row4_col13, #T_078eb_row5_col9, #T_078eb_row5_col18, #T_078eb_row6_col12, #T_078eb_row7_col3, #T_078eb_row7_col11, #T_078eb_row7_col15, #T_078eb_row8_col14, #T_078eb_row9_col4, #T_078eb_row9_col17, #T_078eb_row10_col4, #T_078eb_row10_col18, #T_078eb_row11_col6, #T_078eb_row11_col12, #T_078eb_row12_col3, #T_078eb_row12_col21, #T_078eb_row13_col15, #T_078eb_row13_col22, #T_078eb_row14_col3, #T_078eb_row14_col7, #T_078eb_row16_col18, #T_078eb_row17_col0, #T_078eb_row17_col13, #T_078eb_row21_col2, #T_078eb_row21_col4, #T_078eb_row21_col7, #T_078eb_row22_col0, #T_078eb_row22_col17, #T_078eb_row24_col2, #T_078eb_row25_col15, #T_078eb_row25_col22, #T_078eb_row27_col16, #T_078eb_row28_col7, #T_078eb_row28_col12, #T_078eb_row28_col16, #T_078eb_row29_col4, #T_078eb_row29_col8, #T_078eb_row29_col16, #T_078eb_row30_col18, #T_078eb_row33_col7, #T_078eb_row33_col14, #T_078eb_row34_col7 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_078eb_row0_col6, #T_078eb_row0_col13, #T_078eb_row2_col16, #T_078eb_row2_col21, #T_078eb_row3_col7, #T_078eb_row3_col14, #T_078eb_row4_col0, #T_078eb_row5_col6, #T_078eb_row5_col7, #T_078eb_row5_col16, #T_078eb_row5_col22, #T_078eb_row8_col7, #T_078eb_row8_col21, #T_078eb_row10_col6, #T_078eb_row10_col13, #T_078eb_row10_col16, #T_078eb_row10_col22, #T_078eb_row12_col8, #T_078eb_row13_col21, #T_078eb_row14_col6, #T_078eb_row14_col16, #T_078eb_row15_col18, #T_078eb_row16_col12, #T_078eb_row18_col6, #T_078eb_row18_col11, #T_078eb_row18_col14, #T_078eb_row19_col3, #T_078eb_row20_col18, #T_078eb_row21_col12, #T_078eb_row22_col6, #T_078eb_row22_col16, #T_078eb_row23_col6, #T_078eb_row23_col11, #T_078eb_row25_col8, #T_078eb_row28_col1, #T_078eb_row30_col13, #T_078eb_row32_col1 {
#   background-color: #79abd0;
#   color: #000000;
# }
# #T_078eb_row0_col7, #T_078eb_row0_col11, #T_078eb_row0_col18, #T_078eb_row0_col22, #T_078eb_row2_col1, #T_078eb_row2_col11, #T_078eb_row3_col1, #T_078eb_row4_col16, #T_078eb_row5_col2, #T_078eb_row5_col8, #T_078eb_row5_col14, #T_078eb_row8_col0, #T_078eb_row8_col5, #T_078eb_row8_col17, #T_078eb_row9_col0, #T_078eb_row9_col8, #T_078eb_row9_col16, #T_078eb_row10_col2, #T_078eb_row10_col15, #T_078eb_row13_col5, #T_078eb_row13_col17, #T_078eb_row14_col0, #T_078eb_row15_col2, #T_078eb_row15_col6, #T_078eb_row15_col11, #T_078eb_row15_col22, #T_078eb_row17_col1, #T_078eb_row17_col3, #T_078eb_row17_col8, #T_078eb_row17_col21, #T_078eb_row18_col0, #T_078eb_row18_col1, #T_078eb_row18_col2, #T_078eb_row19_col6, #T_078eb_row19_col16, #T_078eb_row20_col6, #T_078eb_row20_col7, #T_078eb_row20_col11, #T_078eb_row20_col13, #T_078eb_row20_col16, #T_078eb_row20_col22, #T_078eb_row22_col3, #T_078eb_row22_col8, #T_078eb_row22_col21, #T_078eb_row23_col17, #T_078eb_row24_co
# /tmp/ipykernel_634/381997529.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{5}{*}{', '\\multirow[c]{5}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector & Platform &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Aya-101-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & N/A & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & N/A & N/A & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{73A9CF}} \color[HTML]{000000} 1.00 & N/A & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries BLOOMZ-3b-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & N/A & N/A & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Falcon-rw-1b-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Llama-3-8b-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & N/A & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & N/A & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & N/A & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Mistral-7b-v0.1-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & N/A & N/A & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & N/A & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries XLM-RoBERTa-large-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & N/A & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & N/A & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & N/A & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & N/A & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & N/A & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \hline
# \multirow[c]{5}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries mDeBERTa-v3-base-MultiSocial}}} & \bfseries Discord & N/A & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & N/A & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & N/A & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \end{tabular}

# %%
#social media test data - per platform per llm
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
 for model,data in detector.items():
  temp_data = data[(data.split == 'test') & (data.domain == 'social_media')]
 if (to_category[model] == 'F') and ('social-media' not in model): continue
 temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
 for llm in tqdm(temp_data.multi_label.unique(), total=len(temp_data.multi_label.unique())):
  if llm == 'human': continue
  temp = temp_data[(temp_data.multi_label.str.contains(f'{llm}') | temp_data.multi_label.str.contains(f'human'))]
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[f"{model} {llm}"] = {'auc': auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.source.unique():
    temp2 = temp[temp.source.str.contains(test_language)].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[f"{model} {llm}"][test_language] = {'auc': auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Generator': model.split(' ')[1], 'Platform': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model.split(' ')[0], 'Generator': model.split(' ')[1], 'Platform': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Platform', 'Language']).unstack().style.format(precision=2).highlight_max(props='font-weight: bold;', axis=0).background_gradient(vmin=0.5, axis=None)
results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_all['Platform'] = results_all['Platform'].map(rename_platforms)
results_perplatformperllm = results_all.copy()
# Out:
#   0%|                                                                                            | 0/83 [00:00<?, ?it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.46it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.58it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.64it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.75it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.83it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.87it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.76it/s]
#   1%|█                                                                                   | 1/83 [00:01<01:35,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.21it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.95it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.87it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.90it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.88it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.87it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.75it/s]
#   2%|██                                                                                  | 2/83 [00:02<01:34,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.19it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.00it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.96it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.89it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.71it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.41it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.62it/s]
#   4%|███                                                                                 | 3/83 [00:03<01:33,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.36it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.13it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  7.00it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.91it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.97it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.86it/s]
#   5%|████                                                                                | 4/83 [00:04<01:31,  1.16s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.25it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.61it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.66it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.67it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.77it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.73it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.68it/s]
#   6%|█████                                                                               | 5/83 [00:05<01:31,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.16it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.84it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.59it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.76it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.86it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.69it/s]
#   7%|██████                                                                              | 6/83 [00:07<01:29,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.16it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.88it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.85it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.86it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.90it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.76it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.77it/s]
#   8%|███████                                                                             | 7/83 [00:08<01:28,  1.17s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.10it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.90it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.32it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  5.96it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  5.95it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.05it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.01it/s]
#  10%|████████                                                                            | 8/83 [00:09<01:29,  1.20s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.31it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.01it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.88it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.95it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.93it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.79it/s]
#  11%|█████████                                                                           | 9/83 [00:10<01:27,  1.19s/it]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.74it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.55it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.58it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.55it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.36it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.47it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.39it/s]
#  19%|████████████████                                                                   | 16/83 [00:12<00:21,  3.19it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.09it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.84it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.43it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.54it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.65it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.56it/s]
#  28%|███████████████████████                                                            | 23/83 [00:14<00:12,  4.98it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.02it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.89it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.70it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.86it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.70it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.75it/s]
#  36%|██████████████████████████████                                                     | 30/83 [00:15<00:09,  5.73it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.12it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.76it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.19it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.30it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.34it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.53it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.29it/s]
#  54%|█████████████████████████████████████████████                                      | 45/83 [00:18<00:04,  9.40it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.33it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  7.08it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.94it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.50it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.59it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.68it/s]
#  71%|███████████████████████████████████████████████████████████                        | 59/83 [00:20<00:02,  9.22it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.81it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.58it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.38it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.35it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.38it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.55it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.43it/s]
#  90%|███████████████████████████████████████████████████████████████████████████        | 75/83 [00:23<00:00,  9.49it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:01,  6.66it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.69it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.38it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.04it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.10it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.05it/s]
#  98%|█████████████████████████████████████████████████████████████████████████████████  | 81/83 [00:24<00:00,  5.35it/s]/tmp/ipykernel_634/1194295248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
#
#   0%|                                                                                             | 0/8 [00:00<?, ?it/s]
#  12%|██████████▋                                                                          | 1/8 [00:00<00:00,  7.21it/s]
#  25%|█████████████████████▎                                                               | 2/8 [00:00<00:00,  6.78it/s]
#  38%|███████████████████████████████▉                                                     | 3/8 [00:00<00:00,  6.73it/s]
#  50%|██████████████████████████████████████████▌                                          | 4/8 [00:00<00:00,  6.32it/s]
#  62%|█████████████████████████████████████████████████████▏                               | 5/8 [00:00<00:00,  6.48it/s]
#  75%|███████████████████████████████████████████████████████████████▊                     | 6/8 [00:00<00:00,  6.65it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:26<00:00,  3.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 379.30it/s]

# %%
#statistical
temp = results_all[(results_all.Category == 'S')].drop(columns=['Category']).set_index(['Detector', 'Generator', 'Platform']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_b7ac7_row0_col0, #T_b7ac7_row6_col4, #T_b7ac7_row15_col4, #T_b7ac7_row26_col4, #T_b7ac7_row33_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_b7ac7_row0_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_b7ac7_row0_col2, #T_b7ac7_row0_col3, #T_b7ac7_row1_col5, #T_b7ac7_row25_col2, #T_b7ac7_row28_col2, #T_b7ac7_row32_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_b7ac7_row0_col4, #T_b7ac7_row11_col3, #T_b7ac7_row18_col5, #T_b7ac7_row24_col4, #T_b7ac7_row28_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_b7ac7_row0_col5, #T_b7ac7_row21_col4, #T_b7ac7_row32_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_b7ac7_row1_col0, #T_b7ac7_row5_col1, #T_b7ac7_row6_col2, #T_b7ac7_row20_col2, #T_b7ac7_row34_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_b7ac7_row1_col1, #T_b7ac7_row4_col2, #T_b7ac7_row10_col1, #T_b7ac7_row24_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_b7ac7_row1_col2, #T_b7ac7_row3_col5, #T_b7ac7_row7_col4, #T_b7ac7_row25_col5, #T_b7ac7_row31_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_b7ac7_row1_col3, #T_b7ac7_row22_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_b7ac7_row1_col4, #T_b7ac7_row10_col2, #T_b7ac7_row10_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_b7ac7_row2_col0, #T_b7ac7_row16_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_b7ac7_row2_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_b7ac7_row2_col2, #T_b7ac7_row9_col2, #T_b7ac7_row16_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_b7ac7_row2_col3, #T_b7ac7_row12_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_b7ac7_row2_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_b7ac7_row2_col5, #T_b7ac7_row9_col5, #T_b7ac7_row26_col3, #T_b7ac7_row33_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_b7ac7_row3_col0, #T_b7ac7_row15_col3, #T_b7ac7_row15_col5, #T_b7ac7_row17_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_b7ac7_row3_col1, #T_b7ac7_row8_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T
{
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_b7ac7_row13_col3, #T_b7ac7_row15_col0, #T_b7ac7_row26_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_b7ac7_row14_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_b7ac7_row14_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b7ac7_row14_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_b7ac7_row14_col4, #T_b7ac7_row32_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_b7ac7_row14_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_b7ac7_row15_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_b7ac7_row16_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_b7ac7_row16_col2, #T_b7ac7_row19_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_b7ac7_row16_col3, #T_b7ac7_row16_col5, #T_b7ac7_row19_col3, #T_b7ac7_row19_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_b7ac7_row17_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_b7ac7_row17_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_b7ac7_row18_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_b7ac7_row18_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b7ac7_row19_col2, #T_b7ac7_row19_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_b7ac7_row20_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_b7ac7_row21_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_b7ac7_row22_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_b7ac7_row22_col4, #T_b7ac7_row31_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_b7ac7_row23_col4, #T_b7ac7_row27_col5, #T_b7ac7_row34_col5 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_b7ac7_row25_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_b7ac7_row25_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_b7ac7_row26_col0 {
#   background-color: #7dacd1;
#   color: #000000;
# }
# #T_b7ac7_row26_col1, #T_b7ac7_row30_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T
# \begin{tabular}{llrrrrrr}
#  &  & \multicolumn{6}{r}{\bfseries AUC ROC} \\
#  & Platform & \bfseries Discord & \bfseries Gab & \bfseries Telegram & \bfseries Twitter & \bfseries WhatsApp & \bfseries {all} \\
# Detector & Generator &  &  &  &  &  &  \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Binoculars}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries DetectLLM-LRR}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Fast-Detect-GPT}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{EEE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries LLM-Deviation}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries S5}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 \\
# \end{tabular}
# /tmp/ipykernel_634/660990578.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))

# %%
#pretrained
temp = results_all[(results_all.Category == 'P')].drop(columns=['Category']).set_index(['Detector', 'Generator', 'Platform']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_1c6a0_row0_col0 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_1c6a0_row0_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_1c6a0_row0_col2, #T_1c6a0_row1_col1, #T_1c6a0_row3_col3, #T_1c6a0_row4_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_1c6a0_row0_col3, #T_1c6a0_row5_col1, #T_1c6a0_row8_col0, #T_1c6a0_row11_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_1c6a0_row0_col4, #T_1c6a0_row6_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_1c6a0_row0_col5 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_1c6a0_row1_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_1c6a0_row1_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_1c6a0_row1_col3 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_1c6a0_row1_col4 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_1c6a0_row1_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_1c6a0_row2_col0, #T_1c6a0_row12_col5, #T_1c6a0_row13_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_1c6a0_row2_col1, #T_1c6a0_row14_col3, #T_1c6a0_row14_col4, #T_1c6a0_row15_col0, #T_1c6a0_row15_col1, #T_1c6a0_row15_col2, #T_1c6a0_row15_col3, #T_1c6a0_row15_col4, #T_1c6a0_row15_col5, #T_1c6a0_row16_col0, #T_1c6a0_row16_col3, #T_1c6a0_row17_col0, #T_1c6a0_row17_col1, #T_1c6a0_row17_col2, #T_1c6a0_row17_col3, #T_1c6a0_row17_col4, #T_1c6a0_row17_col5, #T_1c6a0_row18_col0, #T_1c6a0_row18_col1, #T_1c6a0_row18_col2, #T_1c6a0_row18_col3, #T_1c6a0_row18_col4, #T_1c6a0_row18_col5, #T_1c6a0_row19_col3, #T_1c6a0_row20_col0, #T_1c6a0_row20_col1, #T_1c6a0_row20_col3, #T_1c6a0_row20_col4, #T_1c6a0_row20_col5, #T_1c6a0_row21_col0, #T_1c6a0_row21_col1, #T_1c6a0_row21_col2, #T_1c6a0_row21_col3, #T_1c6a0_row21_col4, #T_1c6a0_row21_col5, #T_1c6a0_row22_col0, #T_1c6a0_row22_col1, #T_1c6a0_row22_col2, #T_1c6a0_row22_col3, #T_1c6a0_row22_col5, #T_1c6a0_row23_col0, #T_1c6a0_row23_col1, #T_1c6a0_row23_col2, #T_1c6a0_row23_col3, #T_1c6a0_row23_col4, #T_1c6a0_row23_col5, #T_1c6a0_row24_col0, #T_1c6a0_row24_col1, #T_1c6a0_row24_col2, #T_1c6a0_row24_col3, #T_1c6a0_row24_col4, #T_1c6a0_row24_col5, #T_1c6a0_row25_col0, #T_1c6a0_row25_col2, #T_1c6a0_row25_col5, #T_1c6a0_row26_col0, #T_1c6a0_row26_col1, #T_1c6a0_row26_col2, #T_1c6a0_row26_col3, #T_1c6a0_row26_col4, #T_1c6a0_row26_col5, #T_1c6a0_row27_col0, #T_1c6a0_row27_col1, #T_1c6a0_row27_col2, #T_1c6a0_row27_col3, #T_1c6a0_row27_col4, #T_1c6a0_row27_col5, #T_1c6a0_row28_col0, #T_1c6a0_row29_col0, #T_1c6a0_row30_col0, #T_1c6a0_row30_col1, #T_1c6a0_row30_col2, #T_1c6a0_row30_col3, #T_1c6a0_row30_col4, #T_1c6a0_row30_col5, #T_1c6a0_row31_col0, #T_1c6a0_row31_col2, #T_1c6a0_row31_col5, #T_1c6a0_row32_col0, #T_1c6a0_row33_col0, #T_1c6a0_row33_col1, #T_1c6a0_row33_col3, #T_1c6a0_row34_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1c6a0_row2_col2, #T_1c6a0_row11_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1c6a0_row2_col3, #T_1c6a0_row14_col0, #T_1c6a0_row19_col4, #T_1c6a0_row22_col4, #T_1c6a0_row28_col1, #T_1c6a0_row31_col1, #T_1c6a0_row33_col5, #T_1c6a0_row34_col1, #T_1c6a0_row34_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1c6a0_row2_col4, #T_1c6a0_row16_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_1c6a0_row2_col5, #T_1c6a0_row32_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_1c6a0_row3_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_1c6a0_row3_col1, #T_1c6a0_row7_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_1c6a0_row3_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_1c6a0_row3_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_1c6a0_row3_col5, #T_1c6a0_row4_col4, #T_1c6a0_row9_col5, #T_1c6a0_row12_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_1c6a0_row4_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_1c6a0_row4_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_1c6a0_row4_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_1c6a0_row4_col5, #T_1c6a0_row8_col4, #T_1c6a0_row10_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_1c6a0_row5_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_1c6a0_row5_col2, #T_1c6a0_row12_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_1c6a0_row5_col3, #T_1c6a0_row9_col2 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_1c6a0_row5_col4, #T_1c6a0_row9_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_1c6a0_row5_col5, #T_1c6a0_row6_col2, #T_1c6a0_row9_col3, #T_1c6a0_row13_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_1c6a0_row6_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_1c6a0_row6_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_1c6a0_row6_col4 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_1c6a0_row6_col5 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1c6a0_row7_col0, #T_1c6a0_row7_col4 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_1c6a0_row7_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_1c6a0_row7_col3, #T_1c6a0_row12_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_1c6a0_row7_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_1c6a0_row8_col1, #T_1c6a0_row11_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_1c6a0_row8_col2, #T_1c6a0_row10_col3, #T_1c6a0_row11_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_1c6a0_row8_col3, #T_1c6a0_row12_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1c6a0_row8_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_1c6a0_row9_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_1c6a0_row9_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_1c6a0_row10_col0, #T_1c6a0_row13_col5 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1c6a0_row10_col1, #T_1c6a0_row14_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1c6a0_row10_col2 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_1c6a0_row10_col5, #T_1c6a0_row11_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_1c6a0_row11_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_1c6a0_row12_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_1c6a0_row13_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_1c6a0_row13_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_1c6a0_row13_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_1c6a0_row14_col1, #T_1c6a0_row19_col1, #T_1c6a0_row28_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1c6a0_row14_col5, #T_1c6a0_row16_col5, #T_1c6a0_row20_col2, #T_1c6a0_row28_col4, #T_1c6a0_row29_col3, #T_1c6a0_row33_col2, #T_1c6a0_row34_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1c6a0_row16_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_1c6a0_row16_col4, #T_1c6a0_row29_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1c6a0_row19_col0, #T_1c6a0_row19_col5, #T_1c6a0_row28_col5, #T_1c6a0_row33_col4, #T_1c6a0_row34_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1c6a0_row19_col2, #T_1c6a0_row32_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1c6a0_row25_col1, #T_1c6a0_row31_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1c6a0_row25_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_1c6a0_row25_col4, #T_1c6a0_row29_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_1c6a0_row28_col3, #T_1c6a0_row29_col5, #T_1c6a0_row31_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1c6a0_row29_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_1c6a0_row32_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_1c6a0_row32_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_1c6a0_row32_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_1c6a0_row34_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# </style>
# <table id="T_1c6a0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c6a0_level0_col0" class="col_
# /tmp/ipykernel_634/2287834888.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# \begin{tabular}{llrrrrrr}
#  &  & \multicolumn{6}{r}{\bfseries AUC ROC} \\
#  & Platform & \bfseries Discord & \bfseries Gab & \bfseries Telegram & \bfseries Twitter & \bfseries WhatsApp & \bfseries {all} \\
# Detector & Generator &  &  &  &  &  &  \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries BLOOMZ-3b-mixed-Detector}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{F1EBF4}} \color[HTML]{000000} 0.59 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries ChatGPT-Detector-RoBERTa-Chinese}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E2DFEE}} \color[HTML]{000000} 0.67 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.66 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Longformer Detector}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.52 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.28 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{F9F2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{F3EDF5}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FCF4FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{FAF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FAF3F9}} \color[HTML]{000000} 0.53 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries RoBERTa-large-OpenAI-Detector}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.11 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.07 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.25 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.22 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.29 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.29 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{F4EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{F5EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.11 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.31 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.13 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries ruRoBERTa-ruatd-binary}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{F8F1F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FAF3F9}} \color[HTML]{000000} 0.53 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{F4EDF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{FCF4FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{F5EEF6}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.17 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.16 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.19 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.18 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{EBE6F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{EDE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{F1EBF4}} \color[HTML]{000000} 0.59 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FAF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{FBF4F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{FAF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 \\
# \end{tabular}

# %%
#finetuned
temp = results_all[(results_all.Category == 'F')].drop(columns=['Category']).set_index(['Detector', 'Generator', 'Platform']).unstack().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_b3a6c_row0_col0, #T_b3a6c_row0_col4, #T_b3a6c_row5_col0, #T_b3a6c_row5_col2, #T_b3a6c_row5_col3, #T_b3a6c_row6_col0, #T_b3a6c_row6_col3, #T_b3a6c_row12_col0, #T_b3a6c_row19_col0, #T_b3a6c_row21_col0, #T_b3a6c_row21_col4, #T_b3a6c_row24_col3, #T_b3a6c_row24_col4, #T_b3a6c_row26_col0, #T_b3a6c_row26_col3, #T_b3a6c_row26_col4, #T_b3a6c_row27_col0, #T_b3a6c_row28_col0, #T_b3a6c_row28_col4, #T_b3a6c_row31_col4, #T_b3a6c_row33_col0, #T_b3a6c_row34_col0, #T_b3a6c_row47_col0 {
#   background-color: #75a9cf;
#   color: #000000;
# }
# #T_b3a6c_row0_col1, #T_b3a6c_row3_col1, #T_b3a6c_row7_col2, #T_b3a6c_row10_col2, #T_b3a6c_row10_col5, #T_b3a6c_row13_col2, #T_b3a6c_row14_col3, #T_b3a6c_row20_col2, #T_b3a6c_row20_col5, #T_b3a6c_row25_col3, #T_b3a6c_row31_col1, #T_b3a6c_row34_col1, #T_b3a6c_row35_col2, #T_b3a6c_row37_col0, #T_b3a6c_row41_col2, #T_b3a6c_row41_col5, #T_b3a6c_row42_col3, #T_b3a6c_row42_col5, #T_b3a6c_row43_col0, #T_b3a6c_row45_col5 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_b3a6c_row0_col2, #T_b3a6c_row0_col3, #T_b3a6c_row3_col0, #T_b3a6c_row3_col2, #T_b3a6c_row3_col3, #T_b3a6c_row3_col4, #T_b3a6c_row5_col4, #T_b3a6c_row5_col5, #T_b3a6c_row6_col4, #T_b3a6c_row7_col0, #T_b3a6c_row10_col4, #T_b3a6c_row12_col4, #T_b3a6c_row13_col0, #T_b3a6c_row13_col4, #T_b3a6c_row14_col0, #T_b3a6c_row17_col4, #T_b3a6c_row20_col0, #T_b3a6c_row21_col3, #T_b3a6c_row24_col0, #T_b3a6c_row24_col2, #T_b3a6c_row26_col2, #T_b3a6c_row26_col5, #T_b3a6c_row27_col3, #T_b3a6c_row27_col4, #T_b3a6c_row31_col0, #T_b3a6c_row31_col3, #T_b3a6c_row33_col2, #T_b3a6c_row33_col3, #T_b3a6c_row33_col4, #T_b3a6c_row33_col5, #T_b3a6c_row34_col3, #T_b3a6c_row34_col4, #T_b3a6c_row40_col0, #T_b3a6c_row48_col0 {
#   background-color: #76aad0;
#   color: #000000;
# }
# #T_b3a6c_row0_col5, #T_b3a6c_row3_col5, #T_b3a6c_row6_col2, #T_b3a6c_row6_col5, #T_b3a6c_row7_col4, #T_b3a6c_row10_col0, #T_b3a6c_row12_col3, #T_b3a6c_row17_col0, #T_b3a6c_row17_col3, #T_b3a6c_row19_col3, #T_b3a6c_row19_col4, #T_b3a6c_row21_col2, #T_b3a6c_row21_col5, #T_b3a6c_row24_col5, #T_b3a6c_row27_col2, #T_b3a6c_row27_col5, #T_b3a6c_row28_col2, #T_b3a6c_row28_col3, #T_b3a6c_row28_col5, #T_b3a6c_row30_col0, #T_b3a6c_row31_col2, #T_b3a6c_row31_col5, #T_b3a6c_row34_col2, #T_b3a6c_row34_col5, #T_b3a6c_row35_col0, #T_b3a6c_row35_col4, #T_b3a6c_row38_col3, #T_b3a6c_row38_col4, #T_b3a6c_row40_col2, #T_b3a6c_row40_col3, #T_b3a6c_row40_col4, #T_b3a6c_row41_col3, #T_b3a6c_row42_col0, #T_b3a6c_row42_col4, #T_b3a6c_row45_col4, #T_b3a6c_row47_col2, #T_b3a6c_row47_col3, #T_b3a6c_row48_col4 {
#   background-color: #78abd0;
#   color: #000000;
# }
{
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_b3a6c_row5_col1, #T_b3a6c_row15_col0, #T_b3a6c_row16_col0, #T_b3a6c_row33_col1, #T_b3a6c_row38_col0, #T_b3a6c_row45_col2, #T_b3a6c_row45_col3, #T_b3a6c_row48_col2 {
#   background-color: #7bacd1;
#   color: #000000;
# }
# #T_b3a6c_row7_col1, #T_b3a6c_row8_col5, #T_b3a6c_row9_col2, #T_b3a6c_row14_col1, #T_b3a6c_row16_col2, #T_b3a6c_row16_col3, #T_b3a6c_row36_col2, #T_b3a6c_row37_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_b3a6c_row7_col5, #T_b3a6c_row14_col5, #T_b3a6c_row22_col2, #T_b3a6c_row22_col4, #T_b3a6c_row25_col2, #T_b3a6c_row25_col4, #T_b3a6c_row28_col1, #T_b3a6c_row32_col0, #T_b3a6c_row32_col3, #T_b3a6c_row32_col4, #T_b3a6c_row35_col3, #T_b3a6c_row35_col5, #T_b3a6c_row40_col1 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_b3a6c_row8_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_b3a6c_row8_col2, #T_b3a6c_row11_col2, #T_b3a6c_row23_col3, #T_b3a6c_row37_col5, #T_b3a6c_row43_col3, #T_b3a6c_row46_col4 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_b3a6c_row9_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_b3a6c_row11_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_b3a6c_row15_col1, #T_b3a6c_row23_col1, #T_b3a6c_row46_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_b3a6c_row15_col5, #T_b3a6c_row16_col4, #T_b3a6c_row18_col2, #T_b3a6c_row42_col1, #T_b3a6c_row43_col2, #T_b3a6c_row46_col2, #T_b3a6c_row46_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_b3a6c_row16_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_b3a6c_row16_col5, #T_b3a6c_row18_col5, #T_b3a6c_row36_col5, #T_b3a6c_row43_col4, #T_b3a6c_row46_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_b3a6c_row18_col1, #T_b3a6c_row43_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_b3a6c_row29_col1, #T_b3a6c_row44_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_b3a6c_row30_col1, #T_b3a6c_row39_col0, #T_b3a6c_row39_col2 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_b3a6c_row36_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_b3a6c_row36_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_b3a6c_row37_col1, #T_b3a6c_row44_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_b3a6c_row39_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_b3a6c_row39_col5 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_b3a6c_row44_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_b3a6c_row44_col4, #T_b3a6c_row44_col5 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# </style>
# <ta
# \begin{tabular}{llrrrrrr}
#  &  & \multicolumn{6}{r}{\bfseries AUC ROC} \\
#  & Platform & \bfseries Discord & \bfseries Gab & \bfseries Telegram & \bfseries Twitter & \bfseries WhatsApp & \bfseries {all} \\
# Detector & Generator &  &  &  &  &  &  \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Aya-101-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries BLOOMZ-3b-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Falcon-rw-1b-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Llama-3-8b-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Mistral-7b-v0.1-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries XLM-RoBERTa-large-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \hline
# \multirow[c]{7}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries mDeBERTa-v3-base-MultiSocial}}} & \bfseries Mistral-7B-Instruct-v0.2 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries aya-101 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries gemini & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries gpt-3.5-turbo-0125 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 \\
# \bfseries  & \bfseries opt-iml-max-30b & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries v5-Eagle-7B-HF & {\cellcolor[HTML]{75A9CF}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 \\
# \bfseries  & \bfseries vicuna-13b & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \end{tabular}
# /tmp/ipykernel_634/2577362353.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{7}{*}{', '\\multirow[c]{7}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))

# %% [markdown]
# ## RQ1: Zero-shot MGTD

# %%
#due to low performance
to_exclude = ['ruRoBERTa-ruatd-binary', 'RoBERTa-large-OpenAI-Detector',
       'Longformer Detector']

# %%
temp_results_all = results_all.copy()
results_all = results_perplatform.copy()

# %%
results_all = results_all[~results_all.Detector.isin(to_exclude)]

# %%
#per platform mean per detector category
temp = pd.DataFrame(multidomain[multidomain.domain=='social_media'][['source', 'language']].value_counts())
temp = temp.reset_index()
temp['source'] = temp['source'].str.replace('multisocial_', '')
temp = temp.groupby(['source', 'language']).sum().unstack().fillna(0).astype(int) > 2000 #if there are enough samples (~ 250 of each generator)
enough_platform_language_samples = pd.concat([temp, temp])
enough_platform_language_samples[('count', '{all}')] = True

temp = results_all[(results_all.Category != 'F')].groupby(['Category', 'Platform', 'Language']).mean(numeric_only=True).unstack()
enough_platform_language_samples.index = temp.index
enough_platform_language_samples.columns = temp.columns
temp[~enough_platform_language_samples] = 'nan'
platforms = temp.copy()
#temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None, gmap=temp).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
#display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{5}{*}{', '\\multirow[c]{5}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# /tmp/ipykernel_634/3129301977.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp[~enough_platform_language_samples] = 'nan'

# %%
#social media test data

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model, 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model, 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_perlanguage = results_all.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:13<00:00,  6.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 120.02it/s]

# %%
temp = results_all[results_all.Category != 'F'].set_index(['Category', 'Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).sort_index().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('nan', 'N/A'))
# Out:
# /tmp/ipykernel_634/2459050323.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = results_all[results_all.Category != 'F'].set_index(['Category', 'Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).sort_index().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_44c10_row0_col0, #T_44c10_row0_col7, #T_44c10_row5_col11, #T_44c10_row6_col9, #T_44c10_row6_col13, #T_44c10_row8_col4, #T_44c10_row8_col10, #T_44c10_row8_col13, #T_44c10_row8_col21 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_44c10_row0_col1, #T_44c10_row1_col20, #T_44c10_row5_col3, #T_44c10_row5_col8, #T_44c10_row6_col10, #T_44c10_row7_col10, #T_44c10_row7_col13, #T_44c10_row7_col19, #T_44c10_row7_col21, #T_44c10_row7_col22, #T_44c10_row9_col22 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_44c10_row0_col2, #T_44c10_row0_col15, #T_44c10_row5_col5, #T_44c10_row6_col0, #T_44c10_row6_col19 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_44c10_row0_col3, #T_44c10_row1_col4, #T_44c10_row8_col6, #T_44c10_row9_col19 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_44c10_row0_col4, #T_44c10_row7_col4, #T_44c10_row7_col12 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_44c10_row0_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_44c10_row0_col6, #T_44c10_row5_col6, #T_44c10_row6_col6, #T_44c10_row7_col6, #T_44c10_row9_col0, #T_44c10_row9_col9 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T
{
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_44c10_row2_col11, #T_44c10_row3_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_44c10_row2_col20 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_44c10_row3_col0, #T_44c10_row5_col21 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_44c10_row3_col5, #T_44c10_row5_col16, #T_44c10_row6_col20, #T_44c10_row7_col7, #T_44c10_row8_col22, #T_44c10_row9_col20 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_44c10_row3_col17 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_44c10_row3_col21 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_44c10_row4_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_44c10_row4_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_44c10_row4_col17, #T_44c10_row5_col0, #T_44c10_row5_col9 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_44c10_row4_col20 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_44c10_row5_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_44c10_row5_col2, #T_44c10_row7_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_44c10_row5_col4, #T_44c10_row5_col15, #T_44c10_row7_col0, #T_44c10_row8_col20 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_44c10_row5_col10, #T_44c10_row5_col18, #T_44c10_row7_col18 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_44c10_row5_col20 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_44c10_row6_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_44c10_row6_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_44c10_row6_col3, #T_44c10_row9_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_44c10_row6_col4, #T_44c10_row9_col4, #T_44c10_row9_col10, #T_44c10_row9_col17, #T_44c10_row9_col21 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_44c10_row6_col5, #T_44c10_row6_col14, #T_44c10_row8_col16 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_44c10_row6_col7, #T_44c10_row8_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_44c10_row6_col8, #T_44c10_row6_col11, #T_44c10_row8_col14, #T_44c10_row9_col5, #T_44c10_row9_col8, #T_44c10_row9_col11 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_44c10_row6_col12 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_44c10_row6_col15 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_44c10_row6_col16 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_44c10_row6_col18 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_44c10_row7_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_44c10_row7_col9 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_44c10_row7_col20 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_44c10_row8_col0 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_44c10_row8_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_44c10_row8_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_44c10_row8_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_44c10_row8_col11 {
#   background
# /tmp/ipykernel_634/2459050323.py:3: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('nan', 'N/A'))
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Category & Detector &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{5}{*}{\bfseries P} & \bfseries BLOOMZ-3b-mixed-Detector & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{E8E4F0}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 \\
# \bfseries  & \bfseries ChatGPT-Detector-RoBERTa-Chinese & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{E3E0EE}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{ECE7F2}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{DCDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{E5E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 \\
# \bfseries  & \bfseries Longformer Detector & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{F9F2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FBF3F9}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{EFE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 \\
# \bfseries  & \bfseries RoBERTa-large-OpenAI-Detector & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.14 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{FDF5FA}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.19 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.13 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.21 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.23 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.24 & {\cellcolor[HTML]{FAF2F8}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.26 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.33 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{F0EAF4}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 \\
# \bfseries  & \bfseries ruRoBERTa-ruatd-binary & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{F6EFF7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.35 & {\cellcolor[HTML]{F7F0F7}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.43 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.34 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{F2ECF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.48 \\
# \hline
# \multirow[c]{5}{*}{\bfseries S} & \bfseries Binoculars & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DAD9EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.72 \\
# \bfseries  & \bfseries DetectLLM-LRR & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{DFDDEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 \\
# \bfseries  & \bfseries Fast-Detect-GPT & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{E6E2EF}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{E4E1EF}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DEDCEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{DBDAEB}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 \\
# \bfseries  & \bfseries LLM-Deviation & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.75 \\
# \bfseries  & \bfseries S5 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 \\
# \end{tabular}

# %%
results_all = results_all[~results_all.Detector.isin(to_exclude)]

# %%
#mean per detector category
temp = pd.DataFrame(multidomain[multidomain.domain=='social_media'][['language']].value_counts())
temp = temp.reset_index()
temp = temp.groupby(['language']).sum().unstack().fillna(0).astype(int) > 2000 #if there are enough samples (~ 250 of each generator)
enough_platform_language_samples = pd.concat([temp, temp], axis=1)
enough_platform_language_samples = enough_platform_language_samples.T
enough_platform_language_samples['{all}'] = True

temp = results_all[(results_all.Category != 'F')].groupby(['Category', 'Language']).mean(numeric_only=True).unstack()
enough_platform_language_samples.index = temp.index
enough_platform_language_samples.columns = temp.columns
temp[~enough_platform_language_samples] = 'nan'
#temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=
col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_f2b79_row1_col2, #T_f2b79_row1_col8, #T_f2b79_row2_col1, #T_f2b79_row2_col12, #T_f2b79_row2_col18, #T_f2b79_row3_col15, #T_f2b79_row3_col17, #T_f2b79_row8_col1, #T_f2b79_row9_col21, #T_f2b79_row11_col15, #T_f2b79_row11_col17, #T_f2b79_row11_col18, #T_f2b79_row11_col19, #T_f2b79_row11_col21, #T_f2b79_row12_col2, #T_f2b79_row15_col3, #T_f2b79_row15_col11, #T_f2b79_row17_col3, #T_f2b79_row17_col11, #T_f2b79_row18_col2, #T_f2b79_row18_col11, #T_f2b79_row19_col11, #T_f2b79_row19_col21, #T_f2b79_row21_col9, #T_f2b79_row21_col11, #T_f2b79_row21_col19 {
#   background-color: #76aad0;
#   color: #000000;
# }
# #T_f2b79_row1_col4, #T_f2b79_row3_col22, #T_f2b79_row4_col1, #T_f2b79_row22_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_f2b79_row1_col7, #T_f2b79_row1_col9, #T_f2b79_row3_col14, #T_f2b79_row3_col16, #T_f2b79_row7_col1, #T_f2b79_row7_col12, #T_f2b79_row8_col12, #T_f2b79_row9_col1, #T_f2b79_row9_col11, #T_f2b79_row9_col12, #T_f2b79_row9_col18, #T_f2b79_row11_col9, #T_f2b79_row11_col12, #T_f2b79_row12_col7, #T_f2b79_row12_col8, #T_f2b79_row12_col9, #T_f2b79_row12_col11, #T_f2b79_row13_col15, #T_f2b79_row13_col17, #T_f2b79_row14_col3, #T_f2b79_row14_col18, #T_f2b79_row14_col19, #T_f2b79_row15_col13, #T_f2b79_row15_col19, #T_f2b79_row16_col3, #T_f2b79_row16_col19, #T_f2b79_row17_col13, #T_f2b79_row18_col9, #T_f2b79_row18_col14, #T_f2b79_row19_col14, #T_f2b79_row19_col15, #T_f2b79_row19_col16 {
#   background-color: #78abd0;
#   color: #000000;
# }
# #T_f2b79_row1_col10, #T_f2b79_row10_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_f

# %% [markdown]
# ### Statistics

# %%
#statistical significance of per-language per-platform results between statistical and pretrained detectors
temp = results_perplatform.copy()
temp = temp[temp['Category'] != 'F'].reset_index(drop=True)
temp = temp[~temp.Detector.isin(to_exclude)]
languages = temp.Language.unique()
temp = temp.pivot(index=['Category', 'Platform', 'Detector'], columns='Language', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])

res_df = pd.DataFrame()
for (src, trg) in itertools.combinations_with_replacement(temp.Category.unique(), 2):
 if src != trg: continue
 for (psrc, ptrg) in itertools.combinations_with_replacement(temp.Platform.unique(), 2):
  if psrc == ptrg: continue
  for lang in languages[languages == '{all}']:
   try:
    print(f"\nTest language: {lang}, ({ptrg}, {psrc}), ({trg}, {src})")
    res = pg.ttest(temp[(temp["Category"] == trg) & (temp["Platform"] == ptrg)][lang], temp[(temp["Category"] == src) & (temp["Platform"] == psrc)][lang], paired=True)
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# Test language: {all}, (Gab, Discord), (P, P)
# <style type="text/css">
# #T_591b9_row0_col0, #T_591b9_row0_col1, #T_591b9_row0_col2, #T_591b9_row0_col3, #T_591b9_row0_col4, #T_591b9_row0_col5, #T_591b9_row0_col6, #T_591b9_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_591b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_591b9_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_591b9_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_591b9_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_591b9_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_591b9_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_591b9_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_591b9_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_591b9_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_591b9_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_591b9_row0_col0" class="data row0 col0" >-2.877336</td>
#       <td id="T_591b9_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_591b9_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_591b9_row0_col3" class="data row0 col3" >0.212940</td>
#       <td id="T_591b9_row0_col4" class="data row0 col4" >[-0.85  0.54]</td>
#       <td id="T_591b9_row0_col5" class="data row0 col5" >3.133956</td>
#       <td id="T_591b9_row0_col6" class="data row0 col6" >1.271</td>
#       <td id="T_591b9_row0_col7" class="data row0 col7" >0.271963</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Telegram, Discord), (P, P)
# <style type="text/css">
# #T_8aeeb_row0_col0, #T_8aeeb_row0_col1, #T_8aeeb_row0_col2, #T_8aeeb_row0_col3, #T_8aeeb_row0_col4, #T_8aeeb_row0_col5, #T_8aeeb_row0_col6, #T_8aeeb_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8aeeb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8aeeb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_8aeeb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_8aeeb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_8aeeb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_8aeeb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_8aeeb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_8aeeb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_8aeeb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aeeb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_8aeeb_row0_col0" class="data row0 col0" >-5.755065</td>
#       <td id="T_8aeeb_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_8aeeb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_8aeeb_row0_col3" class="data row0 col3" >0.109525</td>
#       <td id="T_8aeeb_row0_col4" class="data row0 col4" >[-0.26  0.1 ]</td>
#       <td id="T_8aeeb_row0_col5" class="data row0 col5" >1.296543</td>
#       <td id="T_8aeeb_row0_col6" class="data row0 col6" >1.772</td>
#       <td id="T_8aeeb_row0_col7" class="data row0 col7" >0.116036</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Discord), (P, P)
# <style type="text/css">
# #T_7e7ec_row0_col0, #T_7e7ec_row0_col1, #T_7e7ec_row0_col2, #T_7e7ec_row0_col3, #T_7e7ec_row0_col4, #T_7e7ec_row0_col5, #T_7e7ec_row0_col6, #T_7e7ec_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7e7ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e7ec_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7e7ec_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7e7ec_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7e7ec_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7e7ec_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7e7ec_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7e7ec_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7e7ec_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e7ec_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7e7ec_row0_col0" class="data row0 col0" >-1.497792</td>
#       <td id="T_7e7ec_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7e7ec_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7e7ec_row0_col3" class="data row0 col3" >0.374767</td>
#       <td id="T_7e7ec_row0_col4" class="data row0 col4" >[-0.85  0.67]</td>
#       <td id="T_7e7ec_row0_col5" class="data row0 col5" >1.757089</td>
#       <td id="T_7e7ec_row0_col6" class="data row0 col6" >0.891</td>
#       <td id="T_7e7ec_row0_col7" class="data row0 col7" >0.154842</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Discord), (P, P)
# <style type="text/css">
# #T_646df_row0_col0, #T_646df_row0_col1, #T_646df_row0_col2, #T_646df_row0_col3, #T_646df_row0_col4, #T_646df_row0_col5, #T_646df_row0_col6, #T_646df_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_646df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_646df_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_646df_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_646df_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_646df_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_646df_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_646df_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_646df_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_646df_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_646df_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_646df_row0_col0" class="data row0 col0" >-0.571369</td>
#       <td id="T_646df_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_646df_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_646df_row0_col3" class="data row0 col3" >0.669530</td>
#       <td id="T_646df_row0_col4" class="data row0 col4" >[-0.66  0.6 ]</td>
#       <td id="T_646df_row0_col5" class="data row0 col5" >0.565100</td>
#       <td id="T_646df_row0_col6" class="data row0 col6" >0.604</td>
#       <td id="T_646df_row0_col7" class="data row0 col7" >0.065096</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Telegram, Gab), (P, P)
# <style type="text/css">
# #T_cc483_row0_col0, #T_cc483_row0_col1, #T_cc483_row0_col2, #T_cc483_row0_col3, #T_cc483_row0_col4, #T_cc483_row0_col5, #T_cc483_row0_col6, #T_cc483_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_cc483">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc483_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cc483_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cc483_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cc483_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cc483_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cc483_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cc483_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cc483_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc483_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cc483_row0_col0" class="data row0 col0" >1.897459</td>
#       <td id="T_cc483_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_cc483_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cc483_row0_col3" class="data row0 col3" >0.308779</td>
#       <td id="T_cc483_row0_col4" class="data row0 col4" >[-0.44  0.6 ]</td>
#       <td id="T_cc483_row0_col5" class="data row0 col5" >2.126487</td>
#       <td id="T_cc483_row0_col6" class="data row0 col6" >1.013</td>
#       <td id="T_cc483_row0_col7" class="data row0 col7" >0.186576</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Gab), (P, P)
# <style type="text/css">
# </style>
# <table id="T_549ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_549ab_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_549ab_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_549ab_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_549ab_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_549ab_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_549ab_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_549ab_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_549ab_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_549ab_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_549ab_row0_col0" class="data row0 col0" >13.401825</td>
#       <td id="T_549ab_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_549ab_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_549ab_row0_col3" class="data row0 col3" >0.047415</td>
#       <td id="T_549ab_row0_col4" class="data row0 col4" >[0.   0.13]</td>
#       <td id="T_549ab_row0_col5" class="data row0 col5" >6.263830</td>
#       <td id="T_549ab_row0_col6" class="data row0 col6" >2.431</td>
#       <td id="T_549ab_row0_col7" class="data row0 col7" >0.512958</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Gab), (P, P)
# <style type="text/css">
# </style>
# <table id="T_a1746">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1746_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a1746_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a1746_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a1746_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a1746_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a1746_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a1746_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a1746_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1746_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a1746_row0_col0" class="data row0 col0" >24.620220</td>
#       <td id="T_a1746_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_a1746_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a1746_row0_col3" class="data row0 col3" >0.025843</td>
#       <td id="T_a1746_row0_col4" class="data row0 col4" >[0.06 0.2 ]</td>
#       <td id="T_a1746_row0_col5" class="data row0 col5" >27.295356</td>
#       <td id="T_a1746_row0_col6" class="data row0 col6" >2.914</td>
#       <td id="T_a1746_row0_col7" class="data row0 col7" >0.997543</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Telegram), (P, P)
# <style type="text/css">
# #T_599c8_row0_col0, #T_599c8_row0_col1, #T_599c8_row0_col2, #T_599c8_row0_col3, #T_599c8_row0_col4, #T_599c8_row0_col5, #T_599c8_row0_col6, #T_599c8_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_599c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_599c8_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_599c8_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_599c8_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_599c8_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_599c8_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_599c8_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_599c8_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_599c8_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_599c8_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_599c8_row0_col0" class="data row0 col0" >-0.208231</td>
#       <td id="T_599c8_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_599c8_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_599c8_row0_col3" class="data row0 col3" >0.869304</td>
#       <td id="T_599c8_row0_col4" class="data row0 col4" >[-0.59  0.57]</td>
#       <td id="T_599c8_row0_col5" class="data row0 col5" >0.255369</td>
#       <td id="T_599c8_row0_col6" class="data row0 col6" >0.535</td>
#       <td id="T_599c8_row0_col7" class="data row0 col7" >0.053212</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Telegram), (P, P)
# <style type="text/css">
# #T_5fdc5_row0_col0, #T_5fdc5_row0_col1, #T_5fdc5_row0_col2, #T_5fdc5_row0_col3, #T_5fdc5_row0_col4, #T_5fdc5_row0_col5, #T_5fdc5_row0_col6, #T_5fdc5_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5fdc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fdc5_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_5fdc5_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_5fdc5_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_5fdc5_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_5fdc5_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_5fdc5_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_5fdc5_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_5fdc5_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fdc5_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_5fdc5_row0_col0" class="data row0 col0" >1.454036</td>
#       <td id="T_5fdc5_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5fdc5_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5fdc5_row0_col3" class="data row0 col3" >0.383532</td>
#       <td id="T_5fdc5_row0_col4" class="data row0 col4" >[-0.4  0.5]</td>
#       <td id="T_5fdc5_row0_col5" class="data row0 col5" >1.431900</td>
#       <td id="T_5fdc5_row0_col6" class="data row0 col6" >0.877</td>
#       <td id="T_5fdc5_row0_col7" class="data row0 col7" >0.127233</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Twitter), (P, P)
# <style type="text/css">
# #T_a193b_row0_col0, #T_a193b_row0_col1, #T_a193b_row0_col2, #T_a193b_row0_col3, #T_a193b_row0_col4, #T_a193b_row0_col5, #T_a193b_row0_col6, #T_a193b_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a193b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a193b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a193b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a193b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a193b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a193b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a193b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a193b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a193b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a193b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a193b_row0_col0" class="data row0 col0" >5.941812</td>
#       <td id="T_a193b_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_a193b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a193b_row0_col3" class="data row0 col3" >0.106148</td>
#       <td id="T_a193b_row0_col4" class="data row0 col4" >[-0.07  0.19]</td>
#       <td id="T_a193b_row0_col5" class="data row0 col5" >6.264069</td>
#       <td id="T_a193b_row0_col6" class="data row0 col6" >1.796</td>
#       <td id="T_a193b_row0_col7" class="data row0 col7" >0.512975</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Gab, Discord), (S, S)
# <style type="text/css">
# </style>
# <table id="T_3bc57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bc57_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3bc57_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3bc57_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3bc57_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3bc57_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3bc57_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3bc57_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3bc57_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bc57_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3bc57_row0_col0" class="data row0 col0" >-5.310034</td>
#       <td id="T_3bc57_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_3bc57_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3bc57_row0_col3" class="data row0 col3" >0.006046</td>
#       <td id="T_3bc57_row0_col4" class="data row0 col4" >[-0.29 -0.09]</td>
#       <td id="T_3bc57_row0_col5" class="data row0 col5" >3.307932</td>
#       <td id="T_3bc57_row0_col6" class="data row0 col6" >10.145</td>
#       <td id="T_3bc57_row0_col7" class="data row0 col7" >0.999481</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Telegram, Discord), (S, S)
# <style type="text/css">
# </style>
# <table id="T_88f9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f9a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_88f9a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_88f9a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_88f9a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_88f9a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_88f9a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_88f9a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_88f9a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88f9a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_88f9a_row0_col0" class="data row0 col0" >-4.063327</td>
#       <td id="T_88f9a_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_88f9a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_88f9a_row0_col3" class="data row0 col3" >0.015307</td>
#       <td id="T_88f9a_row0_col4" class="data row0 col4" >[-0.24 -0.04]</td>
#       <td id="T_88f9a_row0_col5" class="data row0 col5" >2.486409</td>
#       <td id="T_88f9a_row0_col6" class="data row0 col6" >5.184</td>
#       <td id="T_88f9a_row0_col7" class="data row0 col7" >0.980799</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Discord), (S, S)
# <style type="text/css">
# </style>
# <table id="T_95787">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95787_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_95787_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_95787_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_95787_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_95787_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_95787_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_95787_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_95787_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95787_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_95787_row0_col0" class="data row0 col0" >-3.869102</td>
#       <td id="T_95787_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_95787_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_95787_row0_col3" class="data row0 col3" >0.018007</td>
#       <td id="T_95787_row0_col4" class="data row0 col4" >[-0.23 -0.04]</td>
#       <td id="T_95787_row0_col5" class="data row0 col5" >2.399520</td>
#       <td id="T_95787_row0_col6" class="data row0 col6" >4.611</td>
#       <td id="T_95787_row0_col7" class="data row0 col7" >0.973825</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Discord), (S, S)
# <style type="text/css">
# </style>
# <table id="T_532a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_532a8_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_532a8_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_532a8_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_532a8_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_532a8_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_532a8_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_532a8_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_532a8_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_532a8_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_532a8_row0_col0" class="data row0 col0" >-3.229739</td>
#       <td id="T_532a8_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_532a8_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_532a8_row0_col3" class="data row0 col3" >0.031983</td>
#       <td id="T_532a8_row0_col4" class="data row0 col4" >[-0.29 -0.02]</td>
#       <td id="T_532a8_row0_col5" class="data row0 col5" >2.582885</td>
#       <td id="T_532a8_row0_col6" class="data row0 col6" >3.052</td>
#       <td id="T_532a8_row0_col7" class="data row0 col7" >0.986607</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Telegram, Gab), (S, S)
# <style type="text/css">
# </style>
# <table id="T_f32f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f32f1_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f32f1_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f32f1_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f32f1_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f32f1_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f32f1_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f32f1_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f32f1_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f32f1_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f32f1_row0_col0" class="data row0 col0" >21.017590</td>
#       <td id="T_f32f1_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_f32f1_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f32f1_row0_col3" class="data row0 col3" >0.000030</td>
#       <td id="T_f32f1_row0_col4" class="data row0 col4" >[0.04 0.05]</td>
#       <td id="T_f32f1_row0_col5" class="data row0 col5" >8.459388</td>
#       <td id="T_f32f1_row0_col6" class="data row0 col6" >499.56</td>
#       <td id="T_f32f1_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Gab), (S, S)
# <style type="text/css">
# </style>
# <table id="T_47a29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47a29_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_47a29_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_47a29_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_47a29_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_47a29_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_47a29_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_47a29_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_47a29_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47a29_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_47a29_row0_col0" class="data row0 col0" >30.839816</td>
#       <td id="T_47a29_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_47a29_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_47a29_row0_col3" class="data row0 col3" >0.000007</td>
#       <td id="T_47a29_row0_col4" class="data row0 col4" >[0.05 0.06]</td>
#       <td id="T_47a29_row0_col5" class="data row0 col5" >10.314938</td>
#       <td id="T_47a29_row0_col6" class="data row0 col6" >1559.308</td>
#       <td id="T_47a29_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Gab), (S, S)
# <style type="text/css">
# #T_0f7bb_row0_col0, #T_0f7bb_row0_col1, #T_0f7bb_row0_col2, #T_0f7bb_row0_col3, #T_0f7bb_row0_col4, #T_0f7bb_row0_col5, #T_0f7bb_row0_col6, #T_0f7bb_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0f7bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f7bb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_0f7bb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_0f7bb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_0f7bb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_0f7bb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_0f7bb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_0f7bb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_0f7bb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f7bb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_0f7bb_row0_col0" class="data row0 col0" >2.325739</td>
#       <td id="T_0f7bb_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_0f7bb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_0f7bb_row0_col3" class="data row0 col3" >0.080628</td>
#       <td id="T_0f7bb_row0_col4" class="data row0 col4" >[-0.01  0.07]</td>
#       <td id="T_0f7bb_row0_col5" class="data row0 col5" >1.411813</td>
#       <td id="T_0f7bb_row0_col6" class="data row0 col6" >1.583</td>
#       <td id="T_0f7bb_row0_col7" class="data row0 col7" >0.661114</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (Twitter, Telegram), (S, S)
# <style type="text/css">
# </style>
# <table id="T_41937">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41937_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_41937_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_41937_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_41937_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_41937_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_41937_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_41937_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_41937_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41937_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_41937_row0_col0" class="data row0 col0" >6.616423</td>
#       <td id="T_41937_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_41937_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_41937_row0_col3" class="data row0 col3" >0.002706</td>
#       <td id="T_41937_row0_col4" class="data row0 col4" >[0.   0.01]</td>
#       <td id="T_41937_row0_col5" class="data row0 col5" >1.030571</td>
#       <td id="T_41937_row0_col6" class="data row0 col6" >18.195</td>
#       <td id="T_41937_row0_col7" class="data row0 col7" >0.420866</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Telegram), (S, S)
# <style type="text/css">
# #T_94b04_row0_col0, #T_94b04_row0_col1, #T_94b04_row0_col2, #T_94b04_row0_col3, #T_94b04_row0_col4, #T_94b04_row0_col5, #T_94b04_row0_col6, #T_94b04_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_94b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94b04_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_94b04_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_94b04_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_94b04_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_94b04_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_94b04_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_94b04_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_94b04_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94b04_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_94b04_row0_col0" class="data row0 col0" >-1.087172</td>
#       <td id="T_94b04_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_94b04_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_94b04_row0_col3" class="data row0 col3" >0.338086</td>
#       <td id="T_94b04_row0_col4" class="data row0 col4" >[-0.06  0.02]</td>
#       <td id="T_94b04_row0_col5" class="data row0 col5" >0.704080</td>
#       <td id="T_94b04_row0_col6" class="data row0 col6" >0.611</td>
#       <td id="T_94b04_row0_col7" class="data row0 col7" >0.229811</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (WhatsApp, Twitter), (S, S)
# <style type="text/css">
# #T_cfe6d_row0_col0, #T_cfe6d_row0_col1, #T_cfe6d_row0_col2, #T_cfe6d_row0_col3, #T_cfe6d_row0_col4, #T_cfe6d_row0_col5, #T_cfe6d_row0_col6, #T_cfe6d_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_cfe6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfe6d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cfe6d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cfe6d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cfe6d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cfe6d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cfe6d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cfe6d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cfe6d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfe6d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cfe6d_row0_col0" class="data row0 col0" >-1.491922</td>
#       <td id="T_cfe6d_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_cfe6d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cfe6d_row0_col3" class="data row0 col3" >0.209995</td>
#       <td id="T_cfe6d_row0_col4" class="data row0 col4" >[-0.06  0.02]</td>
#       <td id="T_cfe6d_row0_col5" class="data row0 col5" >0.938104</td>
#       <td id="T_cfe6d_row0_col6" class="data row0 col6" >0.824</td>
#       <td id="T_cfe6d_row0_col7" class="data row0 col7" >0.362619</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance of per-language results between statistical and pretrained detectors
temp = results_perlanguage.copy()
temp = temp[temp['Category'] != 'F'].reset_index(drop=True)
temp = temp[~temp.Detector.isin(to_exclude)]
languages = temp.Language.unique()
temp = temp.pivot(index=['Category', 'Detector'], columns='Language', values='AUC ROC').reset_index()

res_df = pd.DataFrame()
for (src, trg) in itertools.combinations_with_replacement(temp.Category.unique(), 2):
  for lang in languages:
   if src == trg: continue
   print(f"\nTest language: {lang}, ({trg}, {src})")
   res = pg.ttest(temp[temp["Category"] == trg][lang], temp[temp["Category"] == src][lang], paired=True)
   display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
# Out:
# Test language: {all}, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_aa7d4_row0_col0, #T_aa7d4_row0_col1, #T_aa7d4_row0_col2, #T_aa7d4_row0_col3, #T_aa7d4_row0_col4, #T_aa7d4_row0_col5, #T_aa7d4_row0_col6, #T_aa7d4_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_aa7d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa7d4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_aa7d4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_aa7d4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_aa7d4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_aa7d4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_aa7d4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_aa7d4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_aa7d4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa7d4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_aa7d4_row0_col0" class="data row0 col0" >0.178734</td>
#       <td id="T_aa7d4_row0_col1" class="data row0 col1" >1.090455</td>
#       <td id="T_aa7d4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_aa7d4_row0_col3" class="data row0 col3" >0.885510</td>
#       <td id="T_aa7d4_row0_col4" class="data row0 col4" >[-0.2  0.2]</td>
#       <td id="T_aa7d4_row0_col5" class="data row0 col5" >0.240264</td>
#       <td id="T_aa7d4_row0_col6" class="data row0 col6" >0.574</td>
#       <td id="T_aa7d4_row0_col7" class="data row0 col7" >0.056449</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ro, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_280b3_row0_col0, #T_280b3_row0_col1, #T_280b3_row0_col2, #T_280b3_row0_col3, #T_280b3_row0_col4, #T_280b3_row0_col5, #T_280b3_row0_col6, #T_280b3_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_280b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_280b3_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_280b3_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_280b3_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_280b3_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_280b3_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_280b3_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_280b3_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_280b3_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_280b3_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_280b3_row0_col0" class="data row0 col0" >2.380732</td>
#       <td id="T_280b3_row0_col1" class="data row0 col1" >2.037148</td>
#       <td id="T_280b3_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_280b3_row0_col3" class="data row0 col3" >0.137959</td>
#       <td id="T_280b3_row0_col4" class="data row0 col4" >[-0.1   0.34]</td>
#       <td id="T_280b3_row0_col5" class="data row0 col5" >1.916350</td>
#       <td id="T_280b3_row0_col6" class="data row0 col6" >1.684</td>
#       <td id="T_280b3_row0_col7" class="data row0 col7" >0.457131</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_81dfc_row0_col0, #T_81dfc_row0_col1, #T_81dfc_row0_col2, #T_81dfc_row0_col3, #T_81dfc_row0_col4, #T_81dfc_row0_col5, #T_81dfc_row0_col6, #T_81dfc_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_81dfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81dfc_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_81dfc_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_81dfc_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_81dfc_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_81dfc_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_81dfc_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_81dfc_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_81dfc_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81dfc_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_81dfc_row0_col0" class="data row0 col0" >1.762482</td>
#       <td id="T_81dfc_row0_col1" class="data row0 col1" >1.772303</td>
#       <td id="T_81dfc_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_81dfc_row0_col3" class="data row0 col3" >0.235861</td>
#       <td id="T_81dfc_row0_col4" class="data row0 col4" >[-0.24  0.51]</td>
#       <td id="T_81dfc_row0_col5" class="data row0 col5" >1.524431</td>
#       <td id="T_81dfc_row0_col6" class="data row0 col6" >1.13</td>
#       <td id="T_81dfc_row0_col7" class="data row0 col7" >0.316438</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_d4f6c_row0_col0, #T_d4f6c_row0_col1, #T_d4f6c_row0_col2, #T_d4f6c_row0_col3, #T_d4f6c_row0_col4, #T_d4f6c_row0_col5, #T_d4f6c_row0_col6, #T_d4f6c_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d4f6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4f6c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_d4f6c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_d4f6c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_d4f6c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_d4f6c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_d4f6c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_d4f6c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_d4f6c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4f6c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_d4f6c_row0_col0" class="data row0 col0" >1.531669</td>
#       <td id="T_d4f6c_row0_col1" class="data row0 col1" >1.287376</td>
#       <td id="T_d4f6c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_d4f6c_row0_col3" class="data row0 col3" >0.326203</td>
#       <td id="T_d4f6c_row0_col4" class="data row0 col4" >[-0.51  0.77]</td>
#       <td id="T_d4f6c_row0_col5" class="data row0 col5" >1.676588</td>
#       <td id="T_d4f6c_row0_col6" class="data row0 col6" >0.981</td>
#       <td id="T_d4f6c_row0_col7" class="data row0 col7" >0.369323</td>
#     </tr>
#   </tbody>
# </table>
# Test language: hr, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_98487_row0_col0, #T_98487_row0_col1, #T_98487_row0_col2, #T_98487_row0_col3, #T_98487_row0_col4, #T_98487_row0_col5, #T_98487_row0_col6, #T_98487_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_98487">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98487_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_98487_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_98487_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_98487_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_98487_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_98487_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_98487_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_98487_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98487_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_98487_row0_col0" class="data row0 col0" >1.949265</td>
#       <td id="T_98487_row0_col1" class="data row0 col1" >1.208677</td>
#       <td id="T_98487_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_98487_row0_col3" class="data row0 col3" >0.266867</td>
#       <td id="T_98487_row0_col4" class="data row0 col4" >[-0.51  0.81]</td>
#       <td id="T_98487_row0_col5" class="data row0 col5" >2.282017</td>
#       <td id="T_98487_row0_col6" class="data row0 col6" >1.272</td>
#       <td id="T_98487_row0_col7" class="data row0 col7" >0.592646</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_5c3c6_row0_col0, #T_5c3c6_row0_col1, #T_5c3c6_row0_col2, #T_5c3c6_row0_col3, #T_5c3c6_row0_col4, #T_5c3c6_row0_col5, #T_5c3c6_row0_col6, #T_5c3c6_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5c3c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c3c6_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_5c3c6_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_5c3c6_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_5c3c6_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_5c3c6_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_5c3c6_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_5c3c6_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_5c3c6_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c3c6_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_5c3c6_row0_col0" class="data row0 col0" >0.420753</td>
#       <td id="T_5c3c6_row0_col1" class="data row0 col1" >1.910227</td>
#       <td id="T_5c3c6_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5c3c6_row0_col3" class="data row0 col3" >0.716521</td>
#       <td id="T_5c3c6_row0_col4" class="data row0 col4" >[-0.15  0.19]</td>
#       <td id="T_5c3c6_row0_col5" class="data row0 col5" >0.349586</td>
#       <td id="T_5c3c6_row0_col6" class="data row0 col6" >0.598</td>
#       <td id="T_5c3c6_row0_col7" class="data row0 col7" >0.063693</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_9b52b_row0_col0, #T_9b52b_row0_col1, #T_9b52b_row0_col2, #T_9b52b_row0_col3, #T_9b52b_row0_col4, #T_9b52b_row0_col5, #T_9b52b_row0_col6, #T_9b52b_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9b52b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b52b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_9b52b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_9b52b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_9b52b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_9b52b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_9b52b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_9b52b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_9b52b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b52b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_9b52b_row0_col0" class="data row0 col0" >-1.173821</td>
#       <td id="T_9b52b_row0_col1" class="data row0 col1" >1.024218</td>
#       <td id="T_9b52b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_9b52b_row0_col3" class="data row0 col3" >0.445634</td>
#       <td id="T_9b52b_row0_col4" class="data row0 col4" >[-0.62  0.51]</td>
#       <td id="T_9b52b_row0_col5" class="data row0 col5" >1.763835</td>
#       <td id="T_9b52b_row0_col6" class="data row0 col6" >0.803</td>
#       <td id="T_9b52b_row0_col7" class="data row0 col7" >0.400804</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pt, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_2efc9_row0_col0, #T_2efc9_row0_col1, #T_2efc9_row0_col2, #T_2efc9_row0_col3, #T_2efc9_row0_col4, #T_2efc9_row0_col5, #T_2efc9_row0_col6, #T_2efc9_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2efc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2efc9_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_2efc9_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_2efc9_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_2efc9_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_2efc9_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_2efc9_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_2efc9_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_2efc9_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2efc9_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_2efc9_row0_col0" class="data row0 col0" >1.341353</td>
#       <td id="T_2efc9_row0_col1" class="data row0 col1" >1.974474</td>
#       <td id="T_2efc9_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_2efc9_row0_col3" class="data row0 col3" >0.313278</td>
#       <td id="T_2efc9_row0_col4" class="data row0 col4" >[-0.11  0.2 ]</td>
#       <td id="T_2efc9_row0_col5" class="data row0 col5" >1.096135</td>
#       <td id="T_2efc9_row0_col6" class="data row0 col6" >0.879</td>
#       <td id="T_2efc9_row0_col7" class="data row0 col7" >0.188354</td>
#     </tr>
#   </tbody>
# </table>
# Test language: de, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_a9da5_row0_col0, #T_a9da5_row0_col1, #T_a9da5_row0_col2, #T_a9da5_row0_col3, #T_a9da5_row0_col4, #T_a9da5_row0_col5, #T_a9da5_row0_col6, #T_a9da5_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a9da5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9da5_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a9da5_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a9da5_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a9da5_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a9da5_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a9da5_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a9da5_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a9da5_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9da5_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a9da5_row0_col0" class="data row0 col0" >-0.487024</td>
#       <td id="T_a9da5_row0_col1" class="data row0 col1" >1.388690</td>
#       <td id="T_a9da5_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a9da5_row0_col3" class="data row0 col3" >0.691968</td>
#       <td id="T_a9da5_row0_col4" class="data row0 col4" >[-0.11  0.1 ]</td>
#       <td id="T_a9da5_row0_col5" class="data row0 col5" >0.497627</td>
#       <td id="T_a9da5_row0_col6" class="data row0 col6" >0.607</td>
#       <td id="T_a9da5_row0_col7" class="data row0 col7" >0.077893</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_2ab78_row0_col0, #T_2ab78_row0_col1, #T_2ab78_row0_col2, #T_2ab78_row0_col3, #T_2ab78_row0_col4, #T_2ab78_row0_col5, #T_2ab78_row0_col6, #T_2ab78_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2ab78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ab78_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_2ab78_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_2ab78_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_2ab78_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_2ab78_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_2ab78_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_2ab78_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_2ab78_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ab78_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_2ab78_row0_col0" class="data row0 col0" >-0.347482</td>
#       <td id="T_2ab78_row0_col1" class="data row0 col1" >4.426025</td>
#       <td id="T_2ab78_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_2ab78_row0_col3" class="data row0 col3" >0.744133</td>
#       <td id="T_2ab78_row0_col4" class="data row0 col4" >[-0.06  0.05]</td>
#       <td id="T_2ab78_row0_col5" class="data row0 col5" >0.209105</td>
#       <td id="T_2ab78_row0_col6" class="data row0 col6" >0.588</td>
#       <td id="T_2ab78_row0_col7" class="data row0 col7" >0.054882</td>
#     </tr>
#   </tbody>
# </table>
# Test language: nl, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_244f2_row0_col0, #T_244f2_row0_col1, #T_244f2_row0_col2, #T_244f2_row0_col3, #T_244f2_row0_col4, #T_244f2_row0_col5, #T_244f2_row0_col6, #T_244f2_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_244f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_244f2_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_244f2_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_244f2_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_244f2_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_244f2_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_244f2_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_244f2_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_244f2_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_244f2_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_244f2_row0_col0" class="data row0 col0" >1.327031</td>
#       <td id="T_244f2_row0_col1" class="data row0 col1" >1.474589</td>
#       <td id="T_244f2_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_244f2_row0_col3" class="data row0 col3" >0.353245</td>
#       <td id="T_244f2_row0_col4" class="data row0 col4" >[-0.14  0.22]</td>
#       <td id="T_244f2_row0_col5" class="data row0 col5" >1.292926</td>
#       <td id="T_244f2_row0_col6" class="data row0 col6" >0.872</td>
#       <td id="T_244f2_row0_col7" class="data row0 col7" >0.242774</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ca, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# </style>
# <table id="T_f3bfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3bfd_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f3bfd_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f3bfd_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f3bfd_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f3bfd_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f3bfd_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f3bfd_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f3bfd_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3bfd_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f3bfd_row0_col0" class="data row0 col0" >-5.037530</td>
#       <td id="T_f3bfd_row0_col1" class="data row0 col1" >3.043229</td>
#       <td id="T_f3bfd_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f3bfd_row0_col3" class="data row0 col3" >0.014569</td>
#       <td id="T_f3bfd_row0_col4" class="data row0 col4" >[-0.2  -0.04]</td>
#       <td id="T_f3bfd_row0_col5" class="data row0 col5" >3.455464</td>
#       <td id="T_f3bfd_row0_col6" class="data row0 col6" >8.79</td>
#       <td id="T_f3bfd_row0_col7" class="data row0 col7" >0.905004</td>
#     </tr>
#   </tbody>
# </table>
# Test language: uk, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_cdd19_row0_col0, #T_cdd19_row0_col1, #T_cdd19_row0_col2, #T_cdd19_row0_col3, #T_cdd19_row0_col4, #T_cdd19_row0_col5, #T_cdd19_row0_col6, #T_cdd19_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_cdd19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdd19_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cdd19_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cdd19_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cdd19_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cdd19_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cdd19_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cdd19_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cdd19_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdd19_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cdd19_row0_col0" class="data row0 col0" >-0.160771</td>
#       <td id="T_cdd19_row0_col1" class="data row0 col1" >3.128454</td>
#       <td id="T_cdd19_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cdd19_row0_col3" class="data row0 col3" >0.882098</td>
#       <td id="T_cdd19_row0_col4" class="data row0 col4" >[-0.1   0.09]</td>
#       <td id="T_cdd19_row0_col5" class="data row0 col5" >0.109234</td>
#       <td id="T_cdd19_row0_col6" class="data row0 col6" >0.573</td>
#       <td id="T_cdd19_row0_col7" class="data row0 col7" >0.051330</td>
#     </tr>
#   </tbody>
# </table>
# Test language: el, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_1f9cb_row0_col0, #T_1f9cb_row0_col1, #T_1f9cb_row0_col2, #T_1f9cb_row0_col3, #T_1f9cb_row0_col4, #T_1f9cb_row0_col5, #T_1f9cb_row0_col6, #T_1f9cb_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1f9cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f9cb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_1f9cb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_1f9cb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_1f9cb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_1f9cb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_1f9cb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_1f9cb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_1f9cb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f9cb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_1f9cb_row0_col0" class="data row0 col0" >1.508357</td>
#       <td id="T_1f9cb_row0_col1" class="data row0 col1" >4.272075</td>
#       <td id="T_1f9cb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_1f9cb_row0_col3" class="data row0 col3" >0.201503</td>
#       <td id="T_1f9cb_row0_col4" class="data row0 col4" >[-0.05  0.19]</td>
#       <td id="T_1f9cb_row0_col5" class="data row0 col5" >0.766304</td>
#       <td id="T_1f9cb_row0_col6" class="data row0 col6" >0.968</td>
#       <td id="T_1f9cb_row0_col7" class="data row0 col7" >0.116890</td>
#     </tr>
#   </tbody>
# </table>
# Test language: sk, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_a8651_row0_col0, #T_a8651_row0_col1, #T_a8651_row0_col2, #T_a8651_row0_col3, #T_a8651_row0_col4, #T_a8651_row0_col5, #T_a8651_row0_col6, #T_a8651_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a8651">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8651_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a8651_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a8651_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a8651_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a8651_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a8651_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a8651_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a8651_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8651_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a8651_row0_col0" class="data row0 col0" >1.412788</td>
#       <td id="T_a8651_row0_col1" class="data row0 col1" >1.741600</td>
#       <td id="T_a8651_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a8651_row0_col3" class="data row0 col3" >0.309984</td>
#       <td id="T_a8651_row0_col4" class="data row0 col4" >[-0.25  0.45]</td>
#       <td id="T_a8651_row0_col5" class="data row0 col5" >1.234197</td>
#       <td id="T_a8651_row0_col6" class="data row0 col6" >0.915</td>
#       <td id="T_a8651_row0_col7" class="data row0 col7" >0.225677</td>
#     </tr>
#   </tbody>
# </table>
# Test language: hu, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_165a9_row0_col0, #T_165a9_row0_col1, #T_165a9_row0_col2, #T_165a9_row0_col3, #T_165a9_row0_col4, #T_165a9_row0_col5, #T_165a9_row0_col6, #T_165a9_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_165a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_165a9_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_165a9_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_165a9_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_165a9_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_165a9_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_165a9_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_165a9_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_165a9_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_165a9_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_165a9_row0_col0" class="data row0 col0" >1.339278</td>
#       <td id="T_165a9_row0_col1" class="data row0 col1" >4.690428</td>
#       <td id="T_165a9_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_165a9_row0_col3" class="data row0 col3" >0.241707</td>
#       <td id="T_165a9_row0_col4" class="data row0 col4" >[-0.06  0.19]</td>
#       <td id="T_165a9_row0_col5" class="data row0 col5" >0.785091</td>
#       <td id="T_165a9_row0_col6" class="data row0 col6" >0.878</td>
#       <td id="T_165a9_row0_col7" class="data row0 col7" >0.120265</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ga, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_db771_row0_col0, #T_db771_row0_col1, #T_db771_row0_col2, #T_db771_row0_col3, #T_db771_row0_col4, #T_db771_row0_col5, #T_db771_row0_col6, #T_db771_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_db771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db771_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_db771_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_db771_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_db771_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_db771_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_db771_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_db771_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_db771_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db771_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_db771_row0_col0" class="data row0 col0" >0.248727</td>
#       <td id="T_db771_row0_col1" class="data row0 col1" >3.540440</td>
#       <td id="T_db771_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_db771_row0_col3" class="data row0 col3" >0.817321</td>
#       <td id="T_db771_row0_col4" class="data row0 col4" >[-0.09  0.11]</td>
#       <td id="T_db771_row0_col5" class="data row0 col5" >0.162065</td>
#       <td id="T_db771_row0_col6" class="data row0 col6" >0.579</td>
#       <td id="T_db771_row0_col7" class="data row0 col7" >0.052930</td>
#     </tr>
#   </tbody>
# </table>
# Test language: et, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_c6a26_row0_col0, #T_c6a26_row0_col1, #T_c6a26_row0_col2, #T_c6a26_row0_col3, #T_c6a26_row0_col4, #T_c6a26_row0_col5, #T_c6a26_row0_col6, #T_c6a26_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c6a26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6a26_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c6a26_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c6a26_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c6a26_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c6a26_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c6a26_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c6a26_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c6a26_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6a26_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c6a26_row0_col0" class="data row0 col0" >-0.135479</td>
#       <td id="T_c6a26_row0_col1" class="data row0 col1" >4.277115</td>
#       <td id="T_c6a26_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c6a26_row0_col3" class="data row0 col3" >0.898372</td>
#       <td id="T_c6a26_row0_col4" class="data row0 col4" >[-0.13  0.11]</td>
#       <td id="T_c6a26_row0_col5" class="data row0 col5" >0.068850</td>
#       <td id="T_c6a26_row0_col6" class="data row0 col6" >0.572</td>
#       <td id="T_c6a26_row0_col7" class="data row0 col7" >0.050528</td>
#     </tr>
#   </tbody>
# </table>
# Test language: gd, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# </style>
# <table id="T_d13ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d13ed_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_d13ed_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_d13ed_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_d13ed_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_d13ed_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_d13ed_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_d13ed_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_d13ed_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d13ed_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_d13ed_row0_col0" class="data row0 col0" >5.374921</td>
#       <td id="T_d13ed_row0_col1" class="data row0 col1" >3.105213</td>
#       <td id="T_d13ed_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_d13ed_row0_col3" class="data row0 col3" >0.011535</td>
#       <td id="T_d13ed_row0_col4" class="data row0 col4" >[0.04 0.17]</td>
#       <td id="T_d13ed_row0_col5" class="data row0 col5" >3.661288</td>
#       <td id="T_d13ed_row0_col6" class="data row0 col6" >10.595</td>
#       <td id="T_d13ed_row0_col7" class="data row0 col7" >0.932711</td>
#     </tr>
#   </tbody>
# </table>
# Test language: bg, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_57820_row0_col0, #T_57820_row0_col1, #T_57820_row0_col2, #T_57820_row0_col3, #T_57820_row0_col4, #T_57820_row0_col5, #T_57820_row0_col6, #T_57820_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_57820">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57820_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_57820_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_57820_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_57820_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_57820_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_57820_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_57820_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_57820_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57820_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_57820_row0_col0" class="data row0 col0" >0.181972</td>
#       <td id="T_57820_row0_col1" class="data row0 col1" >4.759160</td>
#       <td id="T_57820_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_57820_row0_col3" class="data row0 col3" >0.863100</td>
#       <td id="T_57820_row0_col4" class="data row0 col4" >[-0.14  0.16]</td>
#       <td id="T_57820_row0_col5" class="data row0 col5" >0.105839</td>
#       <td id="T_57820_row0_col6" class="data row0 col6" >0.574</td>
#       <td id="T_57820_row0_col7" class="data row0 col7" >0.051249</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ru, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_3355c_row0_col0, #T_3355c_row0_col1, #T_3355c_row0_col2, #T_3355c_row0_col3, #T_3355c_row0_col4, #T_3355c_row0_col5, #T_3355c_row0_col6, #T_3355c_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3355c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3355c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3355c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3355c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3355c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3355c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3355c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3355c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3355c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3355c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3355c_row0_col0" class="data row0 col0" >0.949568</td>
#       <td id="T_3355c_row0_col1" class="data row0 col1" >1.279354</td>
#       <td id="T_3355c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3355c_row0_col3" class="data row0 col3" >0.486935</td>
#       <td id="T_3355c_row0_col4" class="data row0 col4" >[-0.28  0.36]</td>
#       <td id="T_3355c_row0_col5" class="data row0 col5" >1.045888</td>
#       <td id="T_3355c_row0_col6" class="data row0 col6" >0.719</td>
#       <td id="T_3355c_row0_col7" class="data row0 col7" >0.175820</td>
#     </tr>
#   </tbody>
# </table>
# Test language: sl, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# </style>
# <table id="T_7926a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7926a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7926a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7926a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7926a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7926a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7926a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7926a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7926a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7926a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7926a_row0_col0" class="data row0 col0" >6.862711</td>
#       <td id="T_7926a_row0_col1" class="data row0 col1" >4.954537</td>
#       <td id="T_7926a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7926a_row0_col3" class="data row0 col3" >0.001041</td>
#       <td id="T_7926a_row0_col4" class="data row0 col4" >[0.08 0.17]</td>
#       <td id="T_7926a_row0_col5" class="data row0 col5" >3.712047</td>
#       <td id="T_7926a_row0_col6" class="data row0 col6" >22.583</td>
#       <td id="T_7926a_row0_col7" class="data row0 col7" >0.938458</td>
#     </tr>
#   </tbody>
# </table>
# Test language: zh, (S, P)
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_a0be4_row0_col0, #T_a0be4_row0_col1, #T_a0be4_row0_col2, #T_a0be4_row0_col3, #T_a0be4_row0_col4, #T_a0be4_row0_col5, #T_a0be4_row0_col6, #T_a0be4_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a0be4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0be4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a0be4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a0be4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a0be4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a0be4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a0be4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a0be4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a0be4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0be4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a0be4_row0_col0" class="data row0 col0" >0.264622</td>
#       <td id="T_a0be4_row0_col1" class="data row0 col1" >1.067859</td>
#       <td id="T_a0be4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a0be4_row0_col3" class="data row0 col3" >0.833141</td>
#       <td id="T_a0be4_row0_col4" class="data row0 col4" >[-0.63  0.66]</td>
#       <td id="T_a0be4_row0_col5" class="data row0 col5" >0.368117</td>
#       <td id="T_a0be4_row0_col6" class="data row0 col6" >0.58</td>
#       <td id="T_a0be4_row0_col7" class="data row0 col7" >0.065193</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance of per-language results between EN and non-EN languages
temp = results_perlanguage.copy()
temp = temp[temp['Category'] != 'F'].reset_index(drop=True)
#temp = temp[~temp.Detector.isin(to_exclude)]
languages = temp.Language.unique()
display(temp.head())
#temp = temp.pivot(index=['Category', 'Detector'], columns='Language', values='AUC ROC').reset_index()
#display(temp.head())

res_df = pd.DataFrame()
for lang in languages:
   if lang == 'en': continue
   print(f"\nTest language: en vs {lang}")
   res = pg.ttest(temp[temp['Language'] == 'en']['AUC ROC'], temp[temp['Language'] == lang]['AUC ROC'], paired=True)
   display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

print(f"\nTest language: en vs others")
res = pg.ttest(temp[temp['Language'] == 'en']['AUC ROC'], temp[(temp['Language'] != 'en') & (temp['Language'] != '{all}')]['AUC ROC'], paired=True)
display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

print('*' * 10, 'pretrained')
res_df = pd.DataFrame()
for lang in languages:
   if lang == 'en': continue
   print(f"\nTest language: en vs {lang}")
   res = pg.ttest(temp[(temp.Category == 'P') & (temp['Language'] == 'en')]['AUC ROC'], temp[(temp.Category == 'P') & (temp['Language'] == lang)]['AUC ROC'], paired=True)
   display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

print(f"\nTest language: en vs others")
res = pg.ttest(temp[(temp.Category == 'P') & (temp['Language'] == 'en')]['AUC ROC'], temp[(temp.Category == 'P') & (temp['Language'] != 'en') & (temp['Language'] != '{all}')]['AUC ROC'], paired=True)
display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

print('*' * 10, 'statistical')
res_df = pd.DataFrame()
for lang in languages:
   if lang == 'en': continue
   print(f"\nTest language: en vs {lang}")
   res = pg.ttest(temp[(temp.Category == 'S') & (temp['Language'] == 'en')]['AUC ROC'], temp[(temp.Category == 'S') & (temp['Language'] == lang)]['AUC ROC'], paired=True)
   display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

print(f"\nTest language: en vs others")
res = pg.ttest(temp[(temp.Category == 'S') & (temp['Language'] == 'en')]['AUC ROC'], temp[(temp.Category == 'S') & (temp['Language'] != 'en') & (temp['Language'] != '{all}')]['AUC ROC'], paired=True)
display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
# Out:
#                    Detector Language   AUC ROC Category
# 0  BLOOMZ-3b-mixed-Detector    {all}  0.755251        P
# 1  BLOOMZ-3b-mixed-Detector       ro  0.662115        P
# 2  BLOOMZ-3b-mixed-Detector       cs  0.796334        P
# 3  BLOOMZ-3b-mixed-Detector       pl  0.782974        P
# 4  BLOOMZ-3b-mixed-Detector       hr  0.773144        P
# Test language: en vs {all}
# <style type="text/css">
# </style>
# <table id="T_122ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_122ac_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_122ac_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_122ac_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_122ac_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_122ac_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_122ac_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_122ac_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_122ac_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_122ac_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_122ac_row0_col0" class="data row0 col0" >4.923321</td>
#       <td id="T_122ac_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_122ac_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_122ac_row0_col3" class="data row0 col3" >0.000821</td>
#       <td id="T_122ac_row0_col4" class="data row0 col4" >[0.05 0.14]</td>
#       <td id="T_122ac_row0_col5" class="data row0 col5" >0.669497</td>
#       <td id="T_122ac_row0_col6" class="data row0 col6" >48.181</td>
#       <td id="T_122ac_row0_col7" class="data row0 col7" >0.472387</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ro
# <style type="text/css">
# #T_7c8de_row0_col0, #T_7c8de_row0_col1, #T_7c8de_row0_col2, #T_7c8de_row0_col3, #T_7c8de_row0_col4, #T_7c8de_row0_col5, #T_7c8de_row0_col6, #T_7c8de_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7c8de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c8de_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7c8de_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7c8de_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7c8de_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7c8de_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7c8de_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7c8de_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7c8de_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c8de_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7c8de_row0_col0" class="data row0 col0" >1.913002</td>
#       <td id="T_7c8de_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_7c8de_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7c8de_row0_col3" class="data row0 col3" >0.088037</td>
#       <td id="T_7c8de_row0_col4" class="data row0 col4" >[-0.02  0.18]</td>
#       <td id="T_7c8de_row0_col5" class="data row0 col5" >0.444895</td>
#       <td id="T_7c8de_row0_col6" class="data row0 col6" >1.158</td>
#       <td id="T_7c8de_row0_col7" class="data row0 col7" >0.242505</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs cs
# <style type="text/css">
# #T_b345b_row0_col0, #T_b345b_row0_col1, #T_b345b_row0_col2, #T_b345b_row0_col3, #T_b345b_row0_col4, #T_b345b_row0_col5, #T_b345b_row0_col6, #T_b345b_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b345b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b345b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b345b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b345b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b345b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b345b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b345b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b345b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b345b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b345b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b345b_row0_col0" class="data row0 col0" >1.027632</td>
#       <td id="T_b345b_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_b345b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b345b_row0_col3" class="data row0 col3" >0.330949</td>
#       <td id="T_b345b_row0_col4" class="data row0 col4" >[-0.07  0.18]</td>
#       <td id="T_b345b_row0_col5" class="data row0 col5" >0.276258</td>
#       <td id="T_b345b_row0_col6" class="data row0 col6" >0.475</td>
#       <td id="T_b345b_row0_col7" class="data row0 col7" >0.122760</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs pl
# <style type="text/css">
# #T_647dd_row0_col0, #T_647dd_row0_col1, #T_647dd_row0_col2, #T_647dd_row0_col3, #T_647dd_row0_col4, #T_647dd_row0_col5, #T_647dd_row0_col6, #T_647dd_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_647dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_647dd_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_647dd_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_647dd_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_647dd_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_647dd_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_647dd_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_647dd_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_647dd_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_647dd_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_647dd_row0_col0" class="data row0 col0" >1.540991</td>
#       <td id="T_647dd_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_647dd_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_647dd_row0_col3" class="data row0 col3" >0.157708</td>
#       <td id="T_647dd_row0_col4" class="data row0 col4" >[-0.03  0.18]</td>
#       <td id="T_647dd_row0_col5" class="data row0 col5" >0.388020</td>
#       <td id="T_647dd_row0_col6" class="data row0 col6" >0.766</td>
#       <td id="T_647dd_row0_col7" class="data row0 col7" >0.195824</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs hr
# <style type="text/css">
# #T_1549b_row0_col0, #T_1549b_row0_col1, #T_1549b_row0_col2, #T_1549b_row0_col3, #T_1549b_row0_col4, #T_1549b_row0_col5, #T_1549b_row0_col6, #T_1549b_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1549b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1549b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_1549b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_1549b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_1549b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_1549b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_1549b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_1549b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_1549b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1549b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_1549b_row0_col0" class="data row0 col0" >1.189933</td>
#       <td id="T_1549b_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_1549b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_1549b_row0_col3" class="data row0 col3" >0.264514</td>
#       <td id="T_1549b_row0_col4" class="data row0 col4" >[-0.05  0.16]</td>
#       <td id="T_1549b_row0_col5" class="data row0 col5" >0.304998</td>
#       <td id="T_1549b_row0_col6" class="data row0 col6" >0.544</td>
#       <td id="T_1549b_row0_col7" class="data row0 col7" >0.139101</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ar
# <style type="text/css">
# #T_8c6c9_row0_col0, #T_8c6c9_row0_col1, #T_8c6c9_row0_col2, #T_8c6c9_row0_col3, #T_8c6c9_row0_col4, #T_8c6c9_row0_col5, #T_8c6c9_row0_col6, #T_8c6c9_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8c6c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c6c9_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_8c6c9_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_8c6c9_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_8c6c9_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_8c6c9_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_8c6c9_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_8c6c9_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_8c6c9_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c6c9_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_8c6c9_row0_col0" class="data row0 col0" >1.207200</td>
#       <td id="T_8c6c9_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_8c6c9_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_8c6c9_row0_col3" class="data row0 col3" >0.258124</td>
#       <td id="T_8c6c9_row0_col4" class="data row0 col4" >[-0.05  0.15]</td>
#       <td id="T_8c6c9_row0_col5" class="data row0 col5" >0.362592</td>
#       <td id="T_8c6c9_row0_col6" class="data row0 col6" >0.553</td>
#       <td id="T_8c6c9_row0_col7" class="data row0 col7" >0.176970</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs pt
# <style type="text/css">
# #T_e58cf_row0_col0, #T_e58cf_row0_col1, #T_e58cf_row0_col2, #T_e58cf_row0_col3, #T_e58cf_row0_col4, #T_e58cf_row0_col5, #T_e58cf_row0_col6, #T_e58cf_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e58cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e58cf_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e58cf_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e58cf_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e58cf_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e58cf_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e58cf_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e58cf_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e58cf_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e58cf_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e58cf_row0_col0" class="data row0 col0" >1.966150</td>
#       <td id="T_e58cf_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_e58cf_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e58cf_row0_col3" class="data row0 col3" >0.080841</td>
#       <td id="T_e58cf_row0_col4" class="data row0 col4" >[-0.01  0.16]</td>
#       <td id="T_e58cf_row0_col5" class="data row0 col5" >0.422061</td>
#       <td id="T_e58cf_row0_col6" class="data row0 col6" >1.232</td>
#       <td id="T_e58cf_row0_col7" class="data row0 col7" >0.223038</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en v
level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_44b59_row0_col0" class="data row0 col0" >4.082358</td>
#       <td id="T_44b59_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_44b59_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_44b59_row0_col3" class="data row0 col3" >0.002748</td>
#       <td id="T_44b59_row0_col4" class="data row0 col4" >[0.04 0.13]</td>
#       <td id="T_44b59_row0_col5" class="data row0 col5" >0.680448</td>
#       <td id="T_44b59_row0_col6" class="data row0 col6" >17.693</td>
#       <td id="T_44b59_row0_col7" class="data row0 col7" >0.484598</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs el
# <style type="text/css">
# #T_30ab6_row0_col0, #T_30ab6_row0_col1, #T_30ab6_row0_col2, #T_30ab6_row0_col3, #T_30ab6_row0_col4, #T_30ab6_row0_col5, #T_30ab6_row0_col6, #T_30ab6_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_30ab6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30ab6_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_30ab6_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_30ab6_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_30ab6_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_30ab6_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_30ab6_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_30ab6_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_30ab6_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30ab6_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_30ab6_row0_col0" class="data row0 col0" >0.341213</td>
#       <td id="T_30ab6_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_30ab6_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_30ab6_row0_col3" class="data row0 col3" >0.740774</td>
#       <td id="T_30ab6_row0_col4" class="data row0 col4" >[-0.08  0.12]</td>
#       <td id="T_30ab6_row0_col5" class="data row0 col5" >0.101038</td>
#       <td id="T_30ab6_row0_col6" class="data row0 col6" >0.325</td>
#       <td id="T_30ab6_row0_col7" class="data row0 col7" >0.059485</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs sk
# <style type="text/css">
# #T_b2451_row0_col0, #T_b2451_row0_col1, #T_b2451_row0_col2, #T_b2451_row0_col3, #T_b2451_row0_col4, #T_b2451_row0_col5, #T_b2451_row0_col6, #T_b2451_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b2451">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2451_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b2451_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b2451_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b2451_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b2451_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b2451_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b2451_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b2451_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2451_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b2451_row0_col0" class="data row0 col0" >2.189165</td>
#       <td id="T_b2451_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_b2451_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b2451_row0_col3" class="data row0 col3" >0.056327</td>
#       <td id="T_b2451_row0_col4" class="data row0 col4" >[-0.    0.18]</td>
#       <td id="T_b2451_row0_col5" class="data row0 col5" >0.514225</td>
#       <td id="T_b2451_row0_col6" class="data row0 col6" >1.611</td>
#       <td id="T_b2451_row0_col7" class="data row0 col7" >0.307029</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs hu
# <style type="text/css">
# #T_fa439_row0_col0, #T_fa439_row0_col1, #T_fa439_row0_col2, #T_fa439_row0_col3, #T_fa439_row0_col4, #T_fa439_row0_col5, #T_fa439_row0_col6, #T_fa439_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_fa439">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa439_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_fa439_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_fa439_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_fa439_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_fa439_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_fa439_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_fa439_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_fa439_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa439_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_fa439_row0_col0" class="data row0 col0" >0.600040</td>
#       <td id="T_fa439_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_fa439_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_fa439_row0_col3" class="data row0 col3" >0.563280</td>
#       <td id="T_fa439_row0_col4" class="data row0 col4" >[-0.09  0.15]</td>
#       <td id="T_fa439_row0_col5" class="data row0 col5" >0.153945</td>
#       <td id="T_fa439_row0_col6" class="data row0 col6" >0.36</td>
#       <td id="T_fa439_row0_col7" class="data row0 col7" >0.072158</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ga
# <style type="text/css">
# </style>
# <table id="T_3a7d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a7d8_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3a7d8_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3a7d8_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3a7d8_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3a7d8_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3a7d8_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3a7d8_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3a7d8_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a7d8_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3a7d8_row0_col0" class="data row0 col0" >3.036760</td>
#       <td id="T_3a7d8_row0_col1" class="data row0 col1" >9</td>
#       <td id="T
row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_be065_row0_col3" class="data row0 col3" >0.155251</td>
#       <td id="T_be065_row0_col4" class="data row0 col4" >[-0.02  0.11]</td>
#       <td id="T_be065_row0_col5" class="data row0 col5" >0.399798</td>
#       <td id="T_be065_row0_col6" class="data row0 col6" >0.774</td>
#       <td id="T_be065_row0_col7" class="data row0 col7" >0.204989</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs sl
# <style type="text/css">
# </style>
# <table id="T_13800">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13800_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_13800_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_13800_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_13800_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_13800_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_13800_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_13800_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_13800_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13800_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_13800_row0_col0" class="data row0 col0" >3.367375</td>
#       <td id="T_13800_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_13800_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_13800_row0_col3" class="data row0 col3" >0.008291</td>
#       <td id="T_13800_row0_col4" class="data row0 col4" >[0.03 0.16]</td>
#       <td id="T_13800_row0_col5" class="data row0 col5" >0.666776</td>
#       <td id="T_13800_row0_col6" class="data row0 col6" >7.205</td>
#       <td id="T_13800_row0_col7" class="data row0 col7" >0.469356</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs zh
# <style type="text/css">
# </style>
# <table id="T_cb858">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb858_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cb858_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cb858_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cb858_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cb858_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cb858_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cb858_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cb858_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb858_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cb858_row0_col0" class="data row0 col0" >2.425819</td>
#       <td id="T_cb858_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_cb858_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cb858_row0_col3" class="data row0 col3" >0.038244</td>
#       <td id="T_cb858_row0_col4" class="data row0 col4" >[0.   0.11]</td>
#       <td id="T_cb858_row0_col5" class="data row0 col5" >0.442645</td>
#       <td id="T_cb858_row0_col6" class="data row0 col6" >2.162</td>
#       <td id="T_cb858_row0_col7" class="data row0 col7" >0.240544</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs others
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_83e25_row0_col0, #T_83e25_row0_col1, #T_83e25_row0_col2, #T_83e25_row0_col3, #T_83e25_row0_col4, #T_83e25_row0_col5, #T_83e25_row0_col6, #T_83e25_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_83e25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83e25_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_83e25_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_83e25_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_83e25_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_83e25_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_83e25_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_83e25_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_83e25_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83e25_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_83e25_row0_col0" class="data row0 col0" >1.673935</td>
#       <td id="T_83e25_row0_col1" class="data row0 col1" >11.008202</td>
#       <td id="T_83e25_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_83e25_row0_col3" class="data row0 col3" >0.122288</td>
#       <td id="T_83e25_row0_col4" class="data row0 col4" >[-0.02  0.16]</td>
#       <td id="T_83e25_row0_col5" class="data row0 col5" >0.377090</td>
#       <td id="T_83e25_row0_col6" class="data row0 col6" >0.946</td>
#       <td id="T_83e25_row0_col7" class="data row0 col7" >0.212747</td>
#     </tr>
#   </tbody>
# </table>
# ********** pretrained
#
# Test language: en vs {all}
# <style type="text/css">
# </style>
# <table id="T_7c5f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c5f2_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7c5f2_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7c5f2_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7c5f2_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7c5f2_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7c5f2_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7c5f2_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7c5f2_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c5f2_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7c5f2_row0_col0" class="data row0 col0" >4.572090</td>
#       <td id="T_7c5f2_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_7c5f2_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7c5f2_row0_col3" class="data row0 col3" >0.010245</td>
#       <td id="T_7c5f2_row0_col4" class="data row0 col4" >[0.05 0.21]</td>
#       <td id="T_7c5f2_row0_col5" class="data row0 col5" >0.776762</td>
#       <td id="T_7c5f2_row0_col6" class="data row0 col6" >6.926</td>
#       <td id="T_7c5f2_row0_col7" class="data row0 col7" >0.268121</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ro
# <style type="text/css">
# </style>
# <table id="T_36d8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36d8a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_36d8a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_36d8a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_36d8a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_36d8a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_36d8a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_36d8a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_36d8a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36d8a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_36d8a_row0_col0" class="data row0 col0" >8.065167</td>
#       <td id="T_36d8a_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_36d8a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_36d8a_row0_col3" class="data row0 col3" >0.001284</td>
#       <td id="T_36d8a_row0_col4" class="data row0 col4" >[0.13 0.27]</td>
#       <td id="T_36d8a_row0_col5" class="data row0 col5" >1.061897</td>
#       <td id="T_36d8a_row0_col6" class="data row0 col6" >31.353</td>
#       <td id="T_36d8a_row0_col7" class="data row0 col7" >0.440982</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs cs
# <style type="text/css">
# </style>
# <table id="T_44fd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44fd3_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_44fd3_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_44fd3_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_44fd3_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_44fd3_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_44fd3_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_44fd3_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_44fd3_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44fd3_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_44fd3_row0_col0" class="data row0 col0" >2.980614</td>
#       <td id="T_44fd3_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_44fd3_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_44fd3_row0_col3" class="data row0 col3" >0.040714</td>
#       <td id="T_44fd3_row0_col4" class="data row0 col4" >[0.01 0.35]</td>
#       <td id="T_44fd3_row0_col5" class="data row0 col5" >0.867598</td>
#       <td id="T_44fd3_row0_col6" class="data row0 col6" >2.568</td>
#       <td id="T_44fd3_row0_col7" class="data row0 col7" >0.319946</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs pl
# <style type="text/css">
# </style>
# <table id="T_46852">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46852_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_46852_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_46852_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_46852_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_46852_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_46852_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_46852_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_46852_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46852_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_46852_row0_col0" class="data row0 col0" >3.510311</td>
#       <td id="T_46852_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_46852_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_46852_row0_col3" class="data row0 col3" >0.024665</td>
#       <td id="T_46852_row0_col4" class="data row0 col4" >[0.04 0.32]</td>
#       <td id="T_46852_row0_col5" class="data row0 col5" >0.949945</td>
#       <td id="T_46852_row0_col6" class="data row0 col6" >3.677</td>
#       <td id="T_46852_row0_col7" class="data row0 col7" >0.369954</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs hr
# <style type="text/css">
# </style>
# <table id="T_2a6bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a6bf_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_2a6bf_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_2a6bf_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_2a6bf_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_2a6bf_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_2a6bf_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_2a6bf_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_2a6bf_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a6bf_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_2a6bf_row0_col0" class="data row0 col0" >2.972019</td>
#       <td id="T_2a6bf_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_2a6bf_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_2a6bf_row0_col3" class="data row0 col3" >0.041062</td>
#       <td id="T_2a6bf_row0_col4" class="data row0 col4" >[0.01 0.32]</td>
#       <td id="T_2a6bf_row0_col5" class="data row0 col5" >0.877515</td>
#       <td id="T_2a6bf_row0_col6" class="data row0 col6" >2.553</td>
#       <td id="T_2a6bf_row0_col7" class="data row0 col7" >0.325834</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ar
# <style type="text/css">
# #T_04977_row0_col0, #T_04977_row0_col1, #T_04977_row0_col2, #T_04977_row0_col3, #T_04977_row0_col4, #T_04977_row0_col5, #T_04977_row0_col6, #T_04977_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_04977">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04977_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_04977_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_04977_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_04977_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_04977_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_04977_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_04977_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_04977_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04977_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_04977_row0_col0" class="data row0 col0" >0.961611</td>
#       <td id="T_04977_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_04977_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_04977_row0_col3" class="data row0 col3" >0.390700</td>
#       <td id="T_04977_row0_col4" class="data row0 col4" >[-0.16  0.33]</td>
#       <td id="T_04977_row0_col5" class="data row0 col5" >0.456098</td>
#       <td id="T_04977_row0_col6" class="data row0 col6" >0.562</td>
#       <td id="T_04977_row0_col7" class="data row0 col7" >0.125179</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs pt
# <style type="text/css">
# </style>
# <table id="T_f25ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f25ac_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f25ac_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f25ac_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f25ac_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f25ac_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f25ac_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f25ac_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f25ac_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f25ac_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f25ac_row0_col0" class="data row0 col0" >3.510634</td>
#       <td id="T_f25ac_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_f25ac_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f25ac_row0_col3" class="data row0 col3" >0.024658</td>
#       <td id="T_f25ac_row0_col4" class="data row0 col4" >[0.03 0.29]</td>
#       <td id="T_f25ac_row0_col5" class="data row0 col5" >0.811631</td>
# ...
#       <td id="T_5ce87_row0_col0" class="data row0 col0" >-0.021877</td>
#       <td id="T_5ce87_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_5ce87_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5ce87_row0_col3" class="data row0 col3" >0.983594</td>
#       <td id="T_5ce87_row0_col4" class="data row0 col4" >[-0.11  0.11]</td>
#       <td id="T_5ce87_row0_col5" class="data row0 col5" >0.014768</td>
#       <td id="T_5ce87_row0_col6" class="data row0 col6" >0.397</td>
#       <td id="T_5ce87_row0_col7" class="data row0 col7" >0.050077</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs hu
# <style type="text/css">
# #T_00dbb_row0_col0, #T_00dbb_row0_col1, #T_00dbb_row0_col2, #T_00dbb_row0_col3, #T_00dbb_row0_col4, #T_00dbb_row0_col5, #T_00dbb_row0_col6, #T_00dbb_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_00dbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00dbb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_00dbb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_00dbb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_00dbb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_00dbb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_00dbb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_00dbb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_00dbb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00dbb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_00dbb_row0_col0" class="data row0 col0" >-1.819351</td>
#       <td id="T_00dbb_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_00dbb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_00dbb_row0_col3" class="data row0 col3" >0.142985</td>
#       <td id="T_00dbb_row0_col4" class="data row0 col4" >[-0.2   0.04]</td>
#       <td id="T_00dbb_row0_col5" class="data row0 col5" >1.220687</td>
#       <td id="T_00dbb_row0_col6" class="data row0 col6" >1.065</td>
#       <td id="T_00dbb_row0_col7" class="data row0 col7" >0.543490</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ga
# <style type="text/css">
# #T_5e7e4_row0_col0, #T_5e7e4_row0_col1, #T_5e7e4_row0_col2, #T_5e7e4_row0_col3, #T_5e7e4_row0_col4, #T_5e7e4_row0_col5, #T_5e7e4_row0_col6, #T_5e7e4_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5e7e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e7e4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_5e7e4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_5e7e4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_5e7e4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_5e7e4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_5e7e4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_5e7e4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_5e7e4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e7e4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_5e7e4_row0_col0" class="data row0 col0" >1.187866</td>
#       <td id="T_5e7e4_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_5e7e4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5e7e4_row0_col3" class="data row0 col3" >0.300599</td>
#       <td id="T_5e7e4_row0_col4" class="data row0 col4" >[-0.04  0.11]</td>
#       <td id="T_5e7e4_row0_col5" class="data row0 col5" >0.829452</td>
#       <td id="T_5e7e4_row0_col6" class="data row0 col6" >0.656</td>
#       <td id="T_5e7e4_row0_col7" class="data row0 col7" >0.297700</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs et
# <style type="text/css">
# #T_3da46_row0_col0, #T_3da46_row0_col1, #T_3da46_row0_col2, #T_3da46_row0_col3, #T_3da46_row0_col4, #T_3da46_row0_col5, #T_3da46_row0_col6, #T_3da46_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3da46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3da46_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3da46_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3da46_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3da46_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3da46_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3da46_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3da46_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3da46_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3da46_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3da46_row0_col0" class="data row0 col0" >-0.514952</td>
#       <td id="T_3da46_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_3da46_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3da46_row0_col3" class="data row0 col3" >0.633736</td>
#       <td id="T_3da46_row0_col4" class="data row0 col4" >[-0.15  0.1 ]</td>
#       <td id="T_3da46_row0_col5" class="data row0 col5" >0.344264</td>
#       <td id="T_3da46_row0_col6" class="data row0 col6" >0.443</td>
#       <td id="T_3da46_row0_col7" class="data row0 col7" >0.092587</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs gd
# <style type="text/css">
# #T_aced3_row0_col0, #T_aced3_row0_col1, #T_aced3_row0_col2, #T_aced3_row0_col3, #T_aced3_row0_col4, #T_aced3_row0_col5, #T_aced3_row0_col6, #T_aced3_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_aced3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aced3_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_aced3_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_aced3_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_aced3_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_aced3_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_aced3_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_aced3_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_aced3_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aced3_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_aced3_row0_col0" class="data row0 col0" >2.469193</td>
#       <td id="T_aced3_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_aced3_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_aced3_row0_col3" class="data row0 col3" >0.069007</td>
#       <td id="T_aced3_row0_col4" class="data row0 col4" >[-0.01  0.09]</td>
#       <td id="T_aced3_row0_col5" class="data row0 col5" >1.864327</td>
#       <td id="T_aced3_row0_col6" class="data row0 col6" >1.766</td>
#       <td id="T_aced3_row0_col7" class="data row0 col7" >0.869711</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs bg
# <style type="text/css">
# #T_9770d_row0_col0, #T_9770d_row0_col1, #T_9770d_row0_col2, #T_9770d_row0_col3, #T_9770d_row0_col4, #T_9770d_row0_col5, #T_9770d_row0_col6, #T_9770d_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9770d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9770d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_9770d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_9770d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_9770d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_9770d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_9770d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_9770d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_9770d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9770d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_9770d_row0_col0" class="data row0 col0" >0.306905</td>
#       <td id="T_9770d_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_9770d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_9770d_row0_col3" class="data row0 col3" >0.774229</td>
#       <td id="T_9770d_row0_col4" class="data row0 col4" >[-0.12  0.15]</td>
#       <td id="T_9770d_row0_col5" class="data row0 col5" >0.204056</td>
#       <td id="T_9770d_row0_col6" class="data row0 col6" >0.413</td>
#       <td id="T_9770d_row0_col7" class="data row0 col7" >0.064857</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs ru
# <style type="text/css">
# #T_8a36b_row0_col0, #T_8a36b_row0_col1, #T_8a36b_row0_col2, #T_8a36b_row0_col3, #T_8a36b_row0_col4, #T_8a36b_row0_col5, #T_8a36b_row0_col6, #T_8a36b_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8a36b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a36b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_8a36b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_8a36b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_8a36b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_8a36b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_8a36b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_8a36b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_8a36b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a36b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_8a36b_row0_col0" class="data row0 col0" >2.129397</td>
#       <td id="T_8a36b_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_8a36b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_8a36b_row0_col3" class="data row0 col3" >0.100276</td>
#       <td id="T_8a36b_row0_col4" class="data row0 col4" >[-0.01  0.08]</td>
#       <td id="T_8a36b_row0_col5" class="data row0 col5" >1.529536</td>
#       <td id="T_8a36b_row0_col6" class="data row0 col6" >1.359</td>
#       <td id="T_8a36b_row0_col7" class="data row0 col7" >0.726452</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs sl
# <style type="text/css">
# #T_97886_row0_col0, #T_97886_row0_col1, #T_97886_row0_col2, #T_97886_row0_col3, #T_97886_row0_col4, #T_97886_row0_col5, #T_97886_row0_col6, #T_97886_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_97886">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97886_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_97886_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_97886_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_97886_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_97886_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_97886_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_97886_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_97886_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97886_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_97886_row0_col0" class="data row0 col0" >1.195402</td>
#       <td id="T_97886_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_97886_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_97886_row0_col3" class="data row0 col3" >0.297954</td>
#       <td id="T_97886_row0_col4" class="data row0 col4" >[-0.03  0.08]</td>
#       <td id="T_97886_row0_col5" class="data row0 col5" >0.859886</td>
#       <td id="T_97886_row0_col6" class="data row0 col6" >0.66</td>
#       <td id="T_97886_row0_col7" class="data row0 col7" >0.315397</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs zh
# <style type="text/css">
# #T_eb459_row0_col0, #T_eb459_row0_col1, #T_eb459_row0_col2, #T_eb459_row0_col3, #T_eb459_row0_col4, #T_eb459_row0_col5, #T_eb459_row0_col6, #T_eb459_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_eb459">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb459_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_eb459_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_eb459_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_eb459_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_eb459_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_eb459_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_eb459_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_eb459_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb459_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_eb459_row0_col0" class="data row0 col0" >2.253167</td>
#       <td id="T_eb459_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_eb459_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_eb459_row0_col3" class="data row0 col3" >0.087338</td>
#       <td id="T_eb459_row0_col4" class="data row0 col4" >[-0.01  0.07]</td>
#       <td id="T_eb459_row0_col5" class="data row0 col5" >1.667215</td>
#       <td id="T_eb459_row0_col6" class="data row0 col6" >1.496</td>
#       <td id="T_eb459_row0_col7" class="data row0 col7" >0.793465</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en vs others
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_b4e5d_row0_col0, #T_b4e5d_row0_col1, #T_b4e5d_row0_col2, #T_b4e5d_row0_col3, #T_b4e5d_row0_col4, #T_b4e5d_row0_col5, #T_b4e5d_row0_col6, #T_b4e5d_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b4e5d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4e5d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b4e5d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b4e5d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b4e5d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b4e5d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b4e5d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b4e5d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b4e5d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e5d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b4e5d_row0_col0" class="data row0 col0" >0.760675</td>
#       <td id="T_b4e5d_row0_col1" class="data row0 col1" >31.236026</td>
#       <td id="T_b4e5d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b4e5d_row0_col3" class="data row0 col3" >0.452555</td>
#       <td id="T_b4e5d_row0_col4" class="data row0 col4" >[-0.01  0.02]</td>
#       <td id="T_b4e5d_row0_col5" class="data row0 col5" >0.092591</td>
#       <td id="T_b4e5d_row0_col6" class="data row0 col6" >0.491</td>
#       <td id="T_b4e5d_row0_col7" class="data row0 col7" >0.054617</td>
#     </tr>
#   </tbody>
# </table>

# %%
#based on mean AUC across detectors calculated on EN and nonEN samples
non_en = [0.7442879083629403, 0.744780307053057, 0.7420986995803567, 0.7368291096667234, 0.7171516831066395, 0.7503867288357737, 0.7074464884477927]
en = [0.7961044832461726, 0.8008579759826806, 0.7748092906493541, 0.8014880529805979, 0.8015463632661355, 0.8034267459856592, 0.8970331400804356]

print(f"\nTest language: en vs others")
res = pg.ttest(en, non_en, paired=True)
display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
# Out:
# Test language: en vs others
# <style type="text/css">
# </style>
# <table id="T_0ed56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ed56_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_0ed56_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_0ed56_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_0ed56_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_0ed56_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_0ed56_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_0ed56_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_0ed56_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ed56_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_0ed56_row0_col0" class="data row0 col0" >3.838321</td>
#       <td id="T_0ed56_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_0ed56_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_0ed56_row0_col3" class="data row0 col3" >0.008576</td>
#       <td id="T_0ed56_row0_col4" class="data row0 col4" >[0.03 0.12]</td>
#       <td id="T_0ed56_row0_col5" class="data row0 col5" >2.532048</td>
#       <td id="T_0ed56_row0_col6" class="data row0 col6" >7.562</td>
#       <td id="T_0ed56_row0_col7" class="data row0 col7" >0.999748</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## RQ2: Fine-tuned MGTD

# %%
#social media test data

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model, 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model, 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_perlanguage = results_all.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:13<00:00,  6.16it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 126.64it/s]

# %%
results_all = results_perlanguage
temp = results_all[results_all.Category == 'F'].drop(columns=['Category']).set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).sort_index().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('nan', 'N/A'))
# Out:
# /tmp/ipykernel_634/1163991209.py:2: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = results_all[results_all.Category == 'F'].drop(columns=['Category']).set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).sort_index().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_49bb0_row0_col0, #T_49bb0_row2_col2, #T_49bb0_row3_col0, #T_49bb0_row3_col5, #T_49bb0_row3_col17, #T_49bb0_row4_col0, #T_49bb0_row4_col17, #T_49bb0_row5_col6, #T_49bb0_row5_col8, #T_49bb0_row5_col11, #T_49bb0_row5_col14, #T_49bb0_row6_col11 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_49bb0_row0_col1, #T_49bb0_row1_col12, #T_49bb0_row2_col12, #T_49bb0_row3_col1, #T_49bb0_row4_col1, #T_49bb0_row4_col3, #T_49bb0_row6_col12 {
#   background-color: #78abd0;
#   color: #000000;
# }
# #T_49bb0_row0_col2, #T_49bb0_row0_col6, #T_49bb0_row0_col15, #T_49bb0_row0_col21, #T_49bb0_row0_col22, #T_49bb0_row1_col1, #T_49bb0_row1_col7, #T_49bb0_row2_col3, #T_49bb0_row3_col13, #T_49bb0_row3_col16, #T_49bb0_row3_col18, #T_49bb0_row4_col4, #T_49bb0_row4_col13, #T_49bb0_row4_col16, #T_49bb0_row4_col18, #T_49bb0_row5_col3, #T_49bb0_row6_col8 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_49bb0_row0_col3, #T_49bb0_row0_col11, #T_49bb0_row3_col2, #T_49bb0_row3_col7, #T_49bb0_row3_col14, #T_49bb0_row3_col21, #T_49bb0_row4_col7, #T_49bb0_row4_col8, #T_49bb0_row4_col14, #T_49bb0_row5_col1, #T_49bb0_row6_col1 {
#   background-color: #7bacd1;
#   color: #000000;
# }
# #T_49bb0_row0_col4, #T_49bb0_row0_col5, #T_49bb0_row0_col13, #T_49bb0_row1_col3, #T_49bb0_row1_col15, #T_49bb0_row1_col21, #T_49bb0_row4_col5, #T_49bb0_row6_col3 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T
AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_49bb0_level1_col0" class="col_heading level1 col0" >ar</th>
#       <th id="T_49bb0_level1_col1" class="col_heading level1 col1" >bg</th>
#       <th id="T_49bb0_level1_col2" class="col_heading level1 col2" >ca</th>
#       <th id="T_49bb0_level1_col3" class="col_heading level1 col3" >cs</th>
#       <th id="T_49bb0_level1_col4" class="col_heading level1 col4" >de</th>
#       <th id="T_49bb0_level1_col5" class="col_heading level1 col5" >el</th>
#       <th id="T_49bb0_level1_col6" class="col_heading level1 col6" >en</th>
#       <th id="T_49bb0_level1_col7" class="col_heading level1 col7" >es</th>
#       <th id="T_49bb0_level1_col8" class="col_heading level1 col8" >et</th>
#       <th id="T_49bb0_level1_col9" class="col_heading level1 col9" >ga</th>
#       <th id="T_49bb0_level1_col10" class="col_heading level1 col10" >gd</th>
#       <th id="T_49bb0_level1_col11" class="col_heading level1 col11" >hr</th>
#       <th id="T_49bb0_level1_col12" class="col_heading level1 col12" >hu</th>
#       <th id="T_49bb0_level1_col13" class="col_heading level1 col13" >nl</th>
#       <th id="T_49bb0_level1_col14" class="col_heading level1 col14" >pl</th>
#       <th id="T_49bb0_level1_col15" class="col_heading level1 col15" >pt</th>
#       <th id="T_49bb0_level1_col16" class="col_heading level1 col16" >ro</th>
#       <th id="T_49bb0_level1_col17" class="col_heading level1 col17" >ru</th>
#       <th id="T_49bb0_level1_col18" class="col_heading level1 col18" >sk</th>
#       <th id="T_49bb0_level1_col19" class="col_heading level1 col19" >sl</th>
#       <th id="T_49bb0_level1_col20" class="col_heading level1 col20" >uk</th>
#       <th id="T_49bb0_level1_col21" class="col_heading level1 col21" >zh</th>
#       <th id="T_49bb0_level1_col22" class="col_heading level1 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49bb0_level0_row0" class="row_heading level0 row0" >Aya-101-MultiSocial</th>
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrr}
#  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
# Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \bfseries Aya-101-MultiSocial & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 \\
# \bfseries BLOOMZ-3b-MultiSocial & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries Falcon-rw-1b-MultiSocial & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries Llama-3-8b-MultiSocial & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries Mistral-7b-v0.1-MultiSocial & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 \\
# \bfseries XLM-RoBERTa-large-MultiSocial & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries mDeBERTa-v3-base-MultiSocial & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 \\
# \end{tabular}
# /tmp/ipykernel_634/1163991209.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('nan', 'N/A'))

# %%
results_all.Language.unique()
# Out:
# array(['{all}', 'ro', 'cs', 'pl', 'hr', 'ar', 'en', 'pt', 'de', 'es',
#        'nl', 'ca', 'uk', 'el', 'sk', 'hu', 'ga', 'et', 'gd', 'bg', 'ru',
#        'sl', 'zh'], dtype=object)

# %%
sorted_languages = [
                    'el',
                    'ar', 'zh',
                    'ca', 'es', 'pt',
                    'en', 'ga', 'gd',
                    'hu', 'et',
                    'de', 'nl',
                    'cs', 'pl', 'sk',
                    'hr', 'sl',
                    'ro',
                    'bg', 'uk',  'ru',
                    ]
temp = results_all[results_all.Category == 'F'].drop(columns=['Category']).set_index(['Detector', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))
# Out:
# /tmp/ipykernel_634/1636405447.py:13: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   temp = results_all[results_all.Category == 'F'].drop(columns=['Category']).set_index(['Detector', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# /tmp/ipykernel_634/1636405447.py:13: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = results_all[results_all.Category == 'F'].drop(columns=['Category']).set_index(['Detector', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_e1736_row0_col0, #T_e1736_row1_col1, #T_e1736_row2_col2, #T_e1736_row3_col3, #T_e1736_row4_col4, #T_e1736_row5_col5, #T_e1736_row6_col6, #T_e1736_row7_col7, #T_e1736_row8_col8, #T_e1736_row9_col9, #T_e1736_row10_col10, #T_e1736_row11_col11, #T_e1736_row12_col12, #T_e1736_row13_col13, #T_e1736_row14_col14, #T_e1736_row15_col15, #T_e1736_row16_col16, #T_e1736_row17_col17, #T_e1736_row18_col18, #T_e1736_row19_col19, #T_e1736_row20_col20, #T_e1736_row21_col21 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_e1736_row0_col1, #T_e1736_row1_col0, #T_e1736_row1_col5, #T_e1736_row2_col6, #T_e1736_row2_col9, #T_e1736_row5_col1, #T_e1736_row6_col2, #T_e1736_row9_col2, #T_e1736_row13_col20, #T_e1736_row15_col19, #T_e1736_row15_col21, #T_e1736_row19_col15, #T_e1736_row20_col13, #T_e1736_row21_col15 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_e1736_row0_col2, #T_e1736_row0_col6, #T_e1736_row0_col13, #T_e1736_row1_col2, #T_e1736_row1_col13, #T_e1736_row2_col0, #T_e1736_row2_col1, #T_e1736_row2_col8, #T_e1736_row4_col6, #T_e1736_row4_col9, #T_e1736_row4_col21, #T_e1736_row6_col0, #T_e1736_row6_col4, #T_e1736_row8_col2, #T_e1736_row8_col12, #T_e1736_row9_col4, #T_e1736_row12_col8, #T_e1736_row13_col0, #T_e1736_row13_col1, #T_e1736_row21_col4 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_e1736_row0_col3, #T_e1736_row3_col0, #T_e1736_row3_col4, #T_e1736_row3_col9, #T_e1736_row4_col3, #T_e1736_row8_col10, #T_e1736_row9_col3, #T_e1736_row10_col8, #T_e1736_row11_col18, #T_e1736_row13_col19, #T_e1736_row16_col17, #T_e1736_row17_col16, #T_e1736_row18_col11, #T_e1736_row18_col21, #T_e1736_row19_col13, #T_e1736_row21_col18 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_e1736_row0_col4, #T_e1736_row0_col11, #T_e1736_row1_col11, #T_e1736_row2_col7, #T_e1736_row3_col5, #T_e1736_row4_col0, #T_e1736_row4_col11, #T_e1736_row5_col3, #T_e1736_row7_col2, #T_e1736_row7_col9, #T_e1736_row9_col7, #T_e1736_row11_col0, #T_e1736_row11_col1, #T_e1736_row11_col4, #T_e1736_row11_col19, #T_e1736_row11_col20, #T_e1736_row12_col21, #T_e1736_row19_col11, #T_e1736_row20_col11, #T_e1736_row20_col21, #T_e1736_row21_col12, #T_e1736_row21_col20 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrr}
#  & \multicolumn{22}{r}{\bfseries AUC ROC} \\
# Language & \bfseries el & \bfseries ar & \bfseries zh & \bfseries ca & \bfseries es & \bfseries pt & \bfseries en & \bfseries ga & \bfseries gd & \bfseries hu & \bfseries et & \bfseries de & \bfseries nl & \bfseries cs & \bfseries pl & \bfseries sk & \bfseries hr & \bfseries sl & \bfseries ro & \bfseries bg & \bfseries uk & \bfseries ru \\
# Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \bfseries el & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 \\
# \bfseries ar & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 \\
# \bfseries zh & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 \\
# \bfseries ca & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 \\
# \bfseries es & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 \\
# \bfseries pt & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 \\
# \bfseries en & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{BAE3B3}} \color[HTML]{000000} 0.18 & {\cellcolor[HTML]{AADDA4}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 \\
# \bfseries ga & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 \\
# \bfseries gd & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 \\
# \bfseries hu & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 \\
# \bfseries et & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 \\
# \bfseries de & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 \\
# \bfseries nl & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 \\
# \bfseries cs & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 \\
# \bfseries pl & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 \\
# \bfseries sk & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 \\
# \bfseries hr & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 \\
# \bfseries sl & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{BAE3B3}} \color[HTML]{000000} 0.18 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 \\
# \bfseries ro & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{AADDA4}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 \\
# \bfseries bg & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 \\
# \bfseries uk & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{75C477}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 \\
# \bfseries ru & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{78C679}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 \\
# \end{tabular}
# /tmp/ipykernel_634/1636405447.py:15: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))

# %%
#social media telegram test data - per language of telegram trained mono and multilingually traned EN,ES,RU detectors

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if ('cross-language' not in model): continue
  temp['source'] = temp['source'].str.replace('multisocial_', '')
  temp = temp[temp.source == 'telegram']
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  temp['prediction_probs']= temp['prediction_probs'].astype(float)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'].astype(float))
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': extract_language(model).split('_')[0], 'Train Language': extract_language(model).split('_')[1], 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': extract_language(model).split('_')[0], 'Train Language': extract_language(model).split('_')[1], 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_language = results_all.copy()
# Out:
#  12%|██████████                                                                         | 10/83 [00:00<00:06, 11.77it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  14%|████████████                                                                       | 12/83 [00:01<00:11,  6.36it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  16%|█████████████                                                                      | 13/83 [00:01<00:13,  5.28it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  19%|████████████████                                                                   | 16/83 [00:02<00:10,  6.27it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  22%|██████████████████                                                                 | 18/83 [00:02<00:10,  6.06it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  23%|███████████████████                                                                | 19/83 [00:02<00:11,  5.37it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  24%|████████████████████                                                               | 20/83 [00:03<00:13,  4.67it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  28%|███████████████████████                                                            | 23/83 [00:03<00:10,  5.53it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  30%|█████████████████████████                                                          | 25/83 [00:04<00:10,  5.55it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  31%|██████████████████████████                                                         | 26/83 [00:04<00:11,  4.99it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  33%|███████████████████████████                                                        | 27/83 [00:04<00:12,  4.59it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  36%|██████████████████████████████                                                     | 30/83 [00:04<00:09,  5.88it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  39%|████████████████████████████████                                                   | 32/83 [00:05<00:08,  5.74it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  40%|█████████████████████████████████                                                  | 33/83 [00:05<00:09,  5.14it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  41%|██████████████████████████████████                                                 | 34/83 [00:05<00:10,  4.66it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  42%|███████████████████████████████████                                                | 35/83 [00:06<00:11,  4.28it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  54%|█████████████████████████████████████████████                                      | 45/83 [00:07<00:04,  9.40it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  57%|███████████████████████████████████████████████                                    | 47/83 [00:07<00:04,  7.55it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  58%|████████████████████████████████████████████████                                   | 48/83 [00:07<00:05,  6.26it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  59%|█████████████████████████████████████████████████                                  | 49/83 [00:08<00:06,  5.44it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  60%|██████████████████████████████████████████████████                                 | 50/83 [00:08<00:06,  4.86it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  73%|█████████████████████████████████████████████████████████████                      | 61/83 [00:09<00:02,  9.99it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  76%|███████████████████████████████████████████████████████████████                    | 63/83 [00:10<00:03,  6.15it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  77%|████████████████████████████████████████████████████████████████                   | 64/83 [00:10<00:03,  5.54it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  78%|█████████████████████████████████████████████████████████████████                  | 65/83 [00:10<00:03,  5.06it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  92%|████████████████████████████████████████████████████████████████████████████       | 76/83 [00:11<00:00,  9.93it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  94%|██████████████████████████████████████████████████████████████████████████████     | 78/83 [00:12<00:00,  6.29it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  95%|███████████████████████████████████████████████████████████████████████████████    | 79/83 [00:12<00:00,  5.48it/s]/tmp/ipykernel_634/1074113524.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:13<00:00,  6.25it/s]
#   0%|                                                                                            | 0/31 [00:00<?, ?it/s]/tmp/ipykernel_634/1074113524.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_all = pd.concat([results_all, temp])
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:00<00:00, 112.92it/s]

# %%
results_all = results_language

# %%
temp = pd.DataFrame(multidomain[(multidomain.domain=='social_media') & multidomain.source.str.contains('telegram')][['language']].value_counts())
temp = temp.reset_index()
temp = temp.groupby(['language']).sum().unstack().fillna(0).astype(int) > 2000 #if there are enough samples (~ 250 of each generator)
temp.index = temp.index.droplevel(0)
temp['{all}'] = True
enough_platform_language_samples = temp

# %%
#temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()
temp = results_all[~results_all['Train Language'].str.contains('x3')].set_index(['Detector', 'Train Language', 'Language']).unstack()
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.loc[[(x,y) for x,y in temp.index if ('llama' in x.lower()) or ('mistral' in x.lower()) or ('mdeberta' in x.lower())]]
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))
# Out:
# <style type="text/css">
# #T_dfa68_row0_col0, #T_dfa68_row0_col20, #T_dfa68_row5_col3, #T_dfa68_row6_col5, #T_dfa68_row7_col13, #T_dfa68_row9_col13, #T_dfa68_row11_col21 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_dfa68_row0_col1, #T_dfa68_row3_col7, #T_dfa68_row3_col17, #T_dfa68_row8_col6, #T_dfa68_row8_col11, #T_dfa68_row8_col16, #T_dfa68_row10_col1, #T_dfa68_row10_col3, #T_dfa68_row11_col1 {
#   background-color: #83afd3;
#   color: #000000;
# }
# #T_dfa68_row0_col2, #T_dfa68_row5_col20 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T
{
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_dfa68_row1_col17, #T_dfa68_row6_col20, #T_dfa68_row7_col22, #T_dfa68_row9_col22, #T_dfa68_row11_col5 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_dfa68_row1_col21 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_dfa68_row1_col22, #T_dfa68_row2_col11, #T_dfa68_row2_col15, #T_dfa68_row8_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_dfa68_row2_col0, #T_dfa68_row6_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_dfa68_row2_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_dfa68_row2_col6, #T_dfa68_row4_col7, #T_dfa68_row9_col0, #T_dfa68_row11_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_dfa68_row2_col7 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_dfa68_row2_col8, #T_dfa68_row8_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_dfa68_row2_col13, #T_dfa68_row5_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_dfa68_row2_col16, #T_dfa68_row6_col4, #T_dfa68_row9_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_dfa68_row2_col21 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_dfa68_row2_col22 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_dfa68_row3_col0, #T_dfa68_row4_col11, #T_dfa68_row4_col12, #T_dfa68_row4_col16, #T_dfa68_row9_col7, #T_dfa68_row10_col5 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_dfa68_row3_col6, #T_dfa68_row8_col3 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_dfa68_row3_col12, #T_dfa68_row8_col12 {
#   background-color: #78abd0;
#   color: #000000;
# }
# #T_dfa68_row3_col13, #T_dfa68_row6_col3, #T_dfa68_row6_col8, #T_dfa68_row11_col20 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_dfa68_row3_col16, #T_dfa68_row7_col17, #T_dfa68_row10_col8, #T_dfa68_row11_col11, #T_dfa68_row11_col16 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_dfa68_row3_col20, #T_dfa68_row3_col22, #T_dfa68_row6_col1, #T_dfa68_row7_col7, #T_dfa68_row9_col8, #T_dfa68_row10_col16, #T_dfa68_row11_col15 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_dfa68_row4_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_dfa68_row4_col1, #T_dfa68_row4_col13, #T_dfa68_row5_col1 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_dfa68_row4_col2, #T_dfa68_row5_col22, #T_dfa68_row6_col22 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_dfa68_row4_col4, #T_dfa68_row4_col15 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_dfa68_row4_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_dfa68_row4_col14 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_dfa68_row4_col20, #T_dfa68_row5_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_dfa68_row4_col21, #T_dfa68_row6_col21 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_dfa68_row4_col22, #T_dfa68_row5_col17, #T_dfa68_row6_col6, #T_dfa68_row9_col21, #T_dfa68_row10_col2, #T_dfa68_row11_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_dfa68_row5_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_dfa68_row5_col6 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_dfa68_row5_col14 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_dfa68_row5_col16, #T_dfa68_row7_col4, #T_dfa68_row7_col20, #T_dfa68_row10_col20 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_dfa68_row5_col21 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_dfa68_row6_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_dfa68_row6_col13 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_dfa68_row6_col15, #T_dfa68_row7_col14 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_dfa68_row7_col2, #T_dfa68_row9_col5, #T_dfa68_row9_col20 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_dfa68_row7_col12 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_dfa68_row7_col21 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_dfa68_row8_col7, #T_dfa68_row11_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_dfa68_row8_col21 {
#   background-color: #d
# \begin{tabular}{llrrrrrrrrrllrrrrrrrllrrr}
#  &  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Detector & Train Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Llama-3-8b}}} & \bfseries en & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & N/A & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Mistral-7b-v0.1}}} & \bfseries en & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & N/A & N/A & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & N/A & N/A & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries mDeBER\-Ta-v3-base}}} & \bfseries en & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \end{tabular}
# /tmp/ipykernel_634/2521415468.py:7: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))

# %%
#temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()
temp = results_all[~results_all['Train Language'].str.contains('x3')].set_index(['Detector', 'Train Language', 'Language']).unstack()
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))
# Out:
# <style type="text/css">
# #T_be68d_row0_col0, #T_be68d_row4_col3, #T_be68d_row8_col15, #T_be68d_row11_col14, #T_be68d_row12_col3, #T_be68d_row12_col4, #T_be68d_row15_col2, #T_be68d_row16_col8, #T_be68d_row17_col4, #T_be68d_row17_col8, #T_be68d_row22_col4, #T_be68d_row26_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_be68d_row0_col1, #T_be68d_row1_col16, #T_be68d_row19_col12, #T_be68d_row23_col16 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_be68d_row0_col2, #T_be68d_row5_col2, #T_be68d_row10_col11, #T_be68d_row12_col13, #T_be68d_row24_col4, #T_be68d_row24_col13 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_be68d_row0_col3, #T_be68d_row0_col6, #T_be68d_row1_col1, #T_be68d_row3_col16, #T_be68d_row11_col12, #T_be68d_row12_col6, #T_be68d_row15_col11, #T_be68d_row21_col11, #T_be68d_row23_col8 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_be68d_row0_col4, #T_be68d_row2_col0, #T_be68d_row7_col7, #T_be68d_row7_col15, #T_be68d_row8_col16, #T_be68d_row11_col7, #T_be68d_row12_col14, #T_be68d_row13_col15, #T_be68d_row18_col11, #T_be68d_row20_col5, #T_be68d_row22_col6, #T_be68d_row24_col14, #T_be68d_row27_col17 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_be68d_row0_col5, #T_be68d_row1_col6, #T_be68d_row1_col17, #T_be68d_row2_col3, #T_be68d_row3_col7, #T_be68d_row4_col6, #T_be68d_row4_col12, #T_be68d_row8_col6, #T_be68d_row13_col7, #T_be68d_row14_col1, #T_be68d_row14_col17, #T_be68d_row15_col4, #T_be68d_row15_col5, #T_be68d_row15_col14, #T_be68d_row15_col15, #T_be68d_row18_col17, #T_be68d_row19_col11, #T_be68d_row21_col1, #T_be68d_row21_col8, #T_be68d_row25_col11, #T_be68d_row25_col16 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_be68d_row0_col7, #T_be68d_row2_col7, #T_be68d_row3_col0, #T_be68d_row5_col7, #T_be68d_row9_col16, #T_be68d_row12_col8, #T_be68d_row15_col21, #T_be68d_row22_col15, #T_be68d_row25_col14, #T_be68d_row26_col15 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_be68d_row0_col8, #T_be68d_row3_col8, #T_be68d_row3_col17, #T_be68d_row12_col11, #T_be68d_row16_col6, #T_be68d_row20_col6, #T_be68d_row20_col11, #T_be68d_row22_col8, #T_be68d_row22_col16, #T_be68d_row23_col5, #T_be68d_row24_col1, #T_be68d_row25_col3, #T_be68d_row27_col3 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T
{\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Falcon-rw-1b}}} & \bfseries en & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & N/A & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & N/A & N/A & {\cellcolor[HTML]{D2D3E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{D4D4E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & N/A & N/A & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & N/A & N/A & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{D9D8EA}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Llama-3-8b}}} & \bfseries en & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{E1DFED}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & N/A & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Mistral-7b-v0.1}}} & \bfseries en & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & N/A & N/A & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & N/A & N/A & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{D3D4E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries XLM-RoBERTa-large}}} & \bfseries en & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & N/A & N/A & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & N/A & N/A & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{76AAD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries mDeBER\-Ta-v3-base}}} & \bfseries en & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries es & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & N/A & N/A & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries ru & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries {en-es-ru} & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \end{tabular}
# /tmp/ipykernel_634/358942449.py:6: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))

# %%
temp = results_all[results_all['Train Language'] != '{en-es-ru-x3}']
temp['Train'] = 'monolingual'
temp.loc[temp['Train Language'] == '{en-es-ru}', 'Train'] = 'multilingual'
#temp = temp.set_index(['Train', 'Detector', 'Language']).unstack().groupby('Train').mean().style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
temp = temp.groupby(['Train', 'Language'])['AUC ROC'].mean().unstack()
temp[[x for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# /tmp/ipykernel_634/2440888058.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['Train'] = 'monolingual'
# <style type="text/css">
# #T_199c9_row0_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_199c9_row0_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_199c9_row0_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_199c9_row0_col3, #T_199c9_row1_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_199c9_row0_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_199c9_row0_col5 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_199c9_row0_col6, #T_199c9_row1_col14, #T_199c9_row1_col22 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_199c9_row0_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_199c9_row0_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_199c9_row0_col11 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_199c9_row0_col12, #T_199c9_row1_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_199c9_row0_col13 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_199c9_row0_col14 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_199c9_row0_col15, #T_199c9_row0_col17 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_199c9_row0_col16 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_199c9_row0_col20 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_199c9_row0_col21 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_199c9_row0_col22 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_199c9_row1_col2, #T_199c9_row1_col13, #T_199c9_row1_col21 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_199c9_row1_col3, #T_199c9_row1_col17 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_199c9_row1_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_199c9_row1_col5, #T_199c9_row1_col7, #T_199c9_row1_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_199c9_row1_col6 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_199c9_row1_col11, #T_199c9_row1_col15 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_199c9_row1_col12 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_199c9_row1_col16 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_199c9_row1_col20 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# </style>
# <table id="T_199c9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Language</th>
#       <th id="T_199c9_level0_col0" class="col_heading level0 col0" >ar</th>
#       <th id="T_199c9_level0_col1" class="col_heading level0 col1" >bg</th>
#       <th id="T_199c9_level0_col2" class="col_heading level0 col2" >ca</th>
#       <th id="T_199c9_level0_col3" class="col_heading level0 col3" >cs</th>
#       <th id="T_199c9_level0_col4" class="col_heading level0 col4" >de</th>
#       <th id="T_199c9_level0_col5" class="col_heading level0 col5" >el</th>
#       <th id="T_199c9_level0_col6" class="col_heading level0 col6" >en</th>
#       <th id="T_199c9_level0_col7" class="col_heading level0 col7" >es</th>
#       <th id="T_199c9_level0_col8" class="col_heading level0 col8" >et</th>
#       <th id="T_199c9_level0_col9" class="col_heading level0 col9" >ga</th>
#       <th id="T_199c9_level0_col10" class="col_heading level0 col10" >gd</th>
#       <th id="T_199c9_level0_col11" class="col_heading level0 col11" >hr</th>
#       <th id="T_199c9_level0_col12" class="col_heading level0 col12" >hu</th>
#       <th id="T_199c9_level0_col13" class="col_heading level0 col13" >nl</th>
#       <th id="T_199c9_level0_col14" class="col_heading level0 col14" >pl</th>
#       <th id="T_199c9_level0_col15" class="col_heading level0 col15" >pt</th>
#       <th id="T_199c9_level0_col16" class="col_heading level0 col16" >ro</th>
#       <th id="T_199c9_level0_col17" class="col_heading level0 col17" >ru</th>
#       <th id="T_199c9_level0_col18" class="col_heading level0 col18" >sk</th>
#       <th id="T_199c9_level0_col19" class="col_heading level0 col19" >sl</th>
#       <th id="T_199c9_level0_col20" class="col_heading level0 col20" >uk</th>
#       <th id="T_199c9_level0_col21" class="col_heading level0 col21" >zh</th>
#       <th id="T_199c9_level0_col22" class="col_heading level0 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_199c9_level0_row0" class="row_heading level0 row0" >monolingual</th>
#       <td id="T_199c9_row0_col0" class="data row0 col0" >0.81</td>
#       <td id="T_199c9_row0_col1" class="data row0 col1" >0.91</td>
#       <td id="T_199c9_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_199c9_row0_col3" class="data row0 col3" >0.89</td>
#       <td id="T_199c9_row0_col4" class="data row0 col4" >0.87</td>
#       <td id="T_199c9_row0_col5" class="data row0 col5" >0.89</td>
#       <td id="T_199c9_row0_col6" class="data row0 col6" >0.91</td>
#       <td id="T_199c9_row0_col7" class="data row0 col7" >0.88</td>
#       <td id="T_199c9_row0_col8" class="data row0 col8" >0.90</td>
#       <td id="T_199c9_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_199c9_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_199c9_row0_col11" class="data row0 col11" >0.92</td>
#       <td id="T_199c9_row0_col12" class="data row0 col12" >0.94</td>
#       <td id="T_199c9_row0_col13" class="data row0 col13" >0.82</td>
#       <td id="T_199c9_row0_col14" class="data row0 col14" >0.88</td>
#       <td id="T_199c9_row0_col15" class="data row0 col15" >0.90</td>
#       <td id="T_199c9_row0_col16" class="data row0 col16" >0.92</td>
#       <td id="T_199c9_row0_col17" class="data row0 col17" >0.90</td>
#       <td id="T_199c9_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_199c9_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_199c9_row0_col20" class="data row0 col20" >0.84</td>
#       <td id="T_199c9_row0_col21" class="data row0 col21" >0.73</td>
#       <td id="T_199c9_row0_col22" class="data row0 col22" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_199c9_level0_row1" class="row_heading level0 row1" >multilingual</th>
#       <td id="T_199c9_row1_col0" class="data row1 col0" >0.89</td>
#       <td id="T_199c9_row1_col1" class="data row1 col1" >0.94</td>
#       <td id="T_199c9_row1_col2" class="data row1 col2" >0.86</td>
#       <td id="T_199c9_row1_col3" class="data row1 col3" >0.93</td>
#       <td id="T_199c9_row1_col4" class="data row1 col4" >0.91</td>
#       <td id="T_199c9_row1_col5" class="data row1 col5" >0.93</td>
#       <td id="T_199c9_row1_col6" class="data row1 col6" >0.95</td>
#       <td id="T_199c9_row1_col7" class="data row1 col7" >0.93</td>
#       <td id="T_199c9_row1_col8" class="data row1 col8" >0.93</td>
#       <td id="T_199c9_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_199c9_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_199c9_row1_col11" class="data row1 col11" >0.94</td>
#       <td id="T_199c9_row1_col12" class="data row1 col12" >0.97</td>
#       <td id="T_199c9_row1_col13" class="data row1 col13" >0.86</td>
#       <td id="T_199c9_row1_col14" class="data row1 col14" >0.91</td>
#       <td id="T_199c9_row1_col15" class="data row1 col15" >0.94</td>
#       <td id="T_199c9_row1_col16" class="data ro

# %%
temp = results_all.set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_3b0db_row0_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_3b0db_row0_col1, #T_3b0db_row1_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_3b0db_row0_col2 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_3b0db_row0_col3, #T_3b0db_row3_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_3b0db_row0_col4, #T_3b0db_row1_col14, #T_3b0db_row2_col8 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_3b0db_row0_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_3b0db_row0_col6 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_3b0db_row0_col7, #T_3b0db_row0_col22 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_3b0db_row0_col8, #T_3b0db_row1_col11 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_3b0db_row0_col11, #T_3b0db_row0_col16, #T_3b0db_row1_col7, #T_3b0db_row2_col17, #T_3b0db_row3_col11, #T_3b0db_row3_col15 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_3b0db_row0_col12 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_3b0db_row0_col13, #T_3b0db_row2_col4, #T_3b0db_row2_col22 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_3b0db_row0_col14, #T_3b0db_row1_col1, #T_3b0db_row3_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_3b0db_row0_col15 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_3b0db_row0_col17, #T_3b0db_row1_col5, #T_3b0db_row2_col3, #T_3b0db_row2_col6, #T_3b0db_row2_col14 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_3b0db_row0_col20 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_3b0db_row0_col21 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_3b0db_row1_col0, #T_3b0db_row1_col20, #T_3b0db_row2_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_3b0db_row1_col2 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_3b0db_row1_col3, #T_3b0db_row1_col17 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3b0db_row1_col4, #T_3b0db_row2_col11, #T_3b0db_row2_col20, #T_3b0db_row3_col20 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_3b0db_row1_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_3b0db_row1_col12 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_3b0db_row1_col13 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_3b0db_row1_col15 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_3b0db_row1_col16, #T_3b0db_row2_col1, #T_3b0db_row3_col5, #T_3b0db_row3_col7, #T_3b0db_row3_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_3b0db_row1_col21, #T_3b0db_row2_col21 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_3b0db_row1_col22 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_3b0db_row2_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_3b0db_row2_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_3b0db_row2_col5, #T_3b0db_row2_col16 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_3b0db_row2_col12, #T_3b0db_row3_col14, #T_3b0db_row3_col22 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_3b0db_row2_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_3b0db_row2_col15, #T_3b0db_row3_col2, #T_3b0db_row3_col13, #T_3b0db_row3_col21 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_3b0db_row3_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_3b0db_row3_col3, #T_3b0db_row3_col17 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_3b0db_row3_col6 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_3b0db_row3_col12 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_3b0db_row3_col16 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# </style>
# <table id="T_3b0db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b0db_level0_col0" class="col_heading level0 col0" colspan="23">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_3b0db_level1_col0" class="col_heading level1 col0" >ar</th>
#       <th id="T_3b0db_level1_col1" class="col_heading level1 col1" >bg</th>
#       <th id="T_3b0db_level1_col2" class="col_heading level1 col2" >ca</th>
#       <th id="T_3b0db_level1_col3" class="col_heading level1 col3" >cs</th>
#       <th id="T_3b0db_level1_col4" class="col_heading level1 col4" >de</th>
#       <th id="T_3b0db_level1_col5" class="col_heading level1 col5" >el</th>
#       <th id="T_3b0db_level1_col6" class="col_heading level1 col6" >en</th>
#       <th id="T_3b0db_level1_col7" class="col_heading level1 col7" >es</th>
#       <th id="T_3b0db_level1_col8" class="col_heading level1 col8" >et</th>
#       <th id="T_3b0db_level1_col9" class="col_heading level1 col9" >ga</th>
#       <th id="T_3b0db_level1_col10" class="col_heading level1 col10" >gd</th>
#       <th id="T_3b0db_level1_col11" class="col_heading level1 col11" >hr</th>
#       <th id="T_3b0db_level1_col12" class="col_heading level1 col12" >hu</th>
#       <th id="T_3b0db_level1_col13" class="col_heading level1 col13" >nl</th>
#       <th id="T_3b0db_level1_col14" class="col_heading level1 col14" >pl</th>
#       <th id="T_3b0db_level1_col15" class="col_heading level1 col15" >pt</th>
#       <th id="T_3b0db_level1_col16" class="col_heading level1 col16" >ro</th>
#       <th id="T_3b0db_level1_col17" class="col_heading level1 col17" >ru</th>
#       <th id="T_3b0db_level1_col18" class="col_heading level1 col18" >sk</th>
#       <th id="T_3b0db_level1_col19" class="col_heading level1 col19" >sl</th>
#       <th id="T_3b0db_level1_col20" class="col_heading level1 col20" >uk</th>
#       <th id="T_3b0db_level1_col21" class="col_heading level1 col21" >zh</th>
#       <th id="T_3b0db_level1_col22" class="col_heading level1 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0db_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_3b0db_row0_col0" class="data row0 col0" >0.81</td>
#       <td id="T_3b0db_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_3b0db_row0_col2" class="data row0 col2" >0.78</td>
#       <td id="T_3b0db_row0_col3" class="data row0 col3" >0.91</td>
#       <td id="T_3b0db_row0_col4" class="data row0 col4" >0.88</td>
#       <td id="T_3b0db_row0_col5" class="data row0 col5" >0.90</td>
#       <td id="T_3b0db_row0_col6" class="data row0 col6" >0.96</td>
#       <td id="T_3b0db_row0_col7" class="data row0 col7" >0.87</td>
#       <td id="T_3b0db_row0_col8" class="data row0 col8" >0.92</td>
#       <td id="T_3b0db_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_3b0db_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_3b0db_row0_col11" class="data row0 col11" >0.94</td>
#       <td id="T_3b0db_row0_col12" class="data row0 col12" >0.97</td>
#       <td id="T_3b0db_row0_col13" class="data row0 col13" >0.84</td>
#       <td id="T_3b0db_row0_col14" class="data row0 col14" >0.89</td>
#       <td id="T_3b0db_row0_col15" class="data row0 col15" >0.92</td>
#       <td id="T_3b0db_row0_col16" class="data row0 col16" >0.94</td>
#       <td id="T_3b0db_row0_col17" class="data row0 col17" >0.87</td>
#       <td id="T_3b0db_row0_col18" class="d

# %%
autoregressive = [x for x in results_all.Detector.unique() if ('aya' not in x.lower()) and ('mdeberta' not in x.lower()) and ('xlm' not in x.lower())]

# %%
#autoregressive decoder-only models
temp = results_all[results_all.Detector.isin(autoregressive)].set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\
#       <th id="T_e0811_level1_col14" class="col_heading level1 col14" >pl</th>
#       <th id="T_e0811_level1_col15" class="col_heading level1 col15" >pt</th>
#       <th id="T_e0811_level1_col16" class="col_heading level1 col16" >ro</th>
#       <th id="T_e0811_level1_col17" class="col_heading level1 col17" >ru</th>
#       <th id="T_e0811_level1_col18" class="col_heading level1 col18" >sk</th>
#       <th id="T_e0811_level1_col19" class="col_heading level1 col19" >sl</th>
#       <th id="T_e0811_level1_col20" class="col_heading level1 col20" >uk</th>
#       <th id="T_e0811_level1_col21" class="col_heading level1 col21" >zh</th>
#       <th id="T_e0811_level1_col22" class="col_heading level1 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0811_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_e0811_row0_col0" class="data row0 col0" >0.78</td>
#       <td id="T_e0811_row0_col1" class="data row0 col1" >0.86</td>
#       <td id="T_e0811_row0_col2" class="data row0 col2" >0.77</td>
#       <td id="T_e0811_row0_col3" class="data row0 col3" >0.87</td>
#       <td id="T_e0811_row0_col4" class="data row0 col4" >0.88</td>
#       <td id="T_e0811_row0_col5" class="data row0 col5" >0.88</td>
#       <td id="T_e0811_row0_col6" class="data row0 col6" >0.96</td>
#       <td id="T_e0811_row0_col7" class="data row0 col7" >0.85</td>
#       <td id="T_e0811_row0_col8" class="data row0 col8" >0.89</td>
#       <td id="T_e0811_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_e0811_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_e0811_row0_col11" class="data row0 col11" >0.92</td>
#       <td id="T_e0811_row0_col12" class="data row0 col12" >0.95</td>
#       <td id="T_e0811_row0_col13" cla
# \begin{tabular}{lrrrrrrrrrllrrrrrrrllrrr}
#  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
# Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Train Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \bfseries en & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & N/A & N/A & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & N/A & N/A & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E7E3F0}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 \\
# \bfseries es & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & N/A & N/A & {\cellcolor[HTML]{C4CBE3}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries ru & {\cellcolor[HTML]{D6D6E9}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{CDD0E5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 & N/A & N/A & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{EFE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 \\
# \hline
# \bfseries {en-es-ru} & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & N/A & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & N/A & N/A & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \end{tabular}
# /tmp/ipykernel_634/2204231633.py:6: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}'))

# %%
#correlation between models
temp = results_all[(~results_all['Train Language'].str.contains('{en-es-ru-x3}'))].set_index(['Train Language', 'Language', 'Detector']).unstack().groupby('Train Language').mean()
#temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
#temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
#display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}'))

# %%
temp
# Out:
#                  AUC ROC                                                    \
# Detector         Aya-101 BLOOMZ-3b Falcon-rw-1b Llama-3-8b Mistral-7b-v0.1
# Train Language
# en              0.932335  0.843346     0.841710   0.891368        0.826079
# es              0.937753  0.820825     0.846767   0.870279        0.822502
# ru              0.935936  0.754461     0.799556   0.825385        0.827751
# {en-es-ru}      0.939851  0.871641     0.892501   0.940352        0.903409
#
#
# Detector       XLM-RoBERTa-large mDeBERTa-v3-base
# Train Language
# en                      0.897961         0.899458
# es                      0.913116         0.906526
# ru                      0.930225         0.916440
# {en-es-ru}              0.937756         0.913727

# %%
sorted_detectors = [
                    'BLOOMZ-3b', 'Falcon-rw-1b', 'Llama-3-8b', 'Mistral-7b-v0.1',
                    'Aya-101', 'XLM-RoBERTa-large', 'mDeBERTa-v3-base'
                    ]
temp[[('AUC ROC', x) for x in sorted_detectors]].corr().style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# Out:
# /tmp/ipykernel_634/2497660348.py:5: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp[[('AUC ROC', x) for x in sorted_detectors]].corr().style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_ee578_row0_col0, #T_ee578_row1_col1, #T_ee578_row2_col2, #T_ee578_row3_col3, #T_ee578_row4_col4, #T_ee578_row5_col5, #T_ee578_row6_col6 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_ee578_row0_col1, #T_ee578_row1_col0, #T_ee578_row5_col6, #T_ee578_row6_col5 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_ee578_row0_col2, #T_ee578_row1_col2, #T_ee578_row2_col0, #T_ee578_row2_col1 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_ee578_row0_col3, #T_ee578_row3_col0 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_ee578_row0_col4, #T_ee578_row4_col0 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_ee578_row0_col5, #T_ee578_row1_col6, #T_ee578_row5_col0, #T_ee578_row6_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_ee578_row0_col6, #T_ee578_row6_col0 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_ee578_row1_col3, #T_ee578_row2_col3, #T_ee578_row3_col1, #T_ee578_row3_col2, #T_ee578_row4_col5, #T_ee578_row5_col4 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_ee578_row1_col4, #T_ee578_row4_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_ee578_row1_col5, #T_ee578_row5_col1 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_ee578_row2_col4, #T_ee578_row4_col2 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_ee578_row2_col5, #T_ee578_row5_col2 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_ee578_row2_col6, #T_ee578_row6_col2 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_ee578_row3_col4, #T_ee578_row3_col5, #T_ee578_row4_col3, #T_ee578_row5_col3 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_ee578_row3_col6, #T_ee578_row6_col3 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_ee578_row4_col6, #T_ee578_row6_col4 {
#   background-color: #92d28f;
#   color: #000000;
# }
# </style>
# <table id="T_ee578">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee578_level0_col0" class="col_heading level0 col0" colspan="7">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Detector</th>
#       <th id="T_ee578_level1_col0" class="col_heading level1 col0" >BLOOMZ-3b</th>
#       <th id="T_ee578_level1_col1" class="col_heading level1 col1" >Falcon-rw-1b</th>
#       <th id="T_ee578_level1_col2" class="col_heading level1 col2" >Llama-3-8b</th>
#       <th id="T_ee578_level1_col3" class="col_heading level1 col3" >Mistral-7b-v0.1</th>
#       <th id="T_ee578_level1_col4" class="col_heading level1 col4" >Aya-101</th>
#       <th id="T_ee578_level1_col5" class="col_heading level1 col5" >XLM-RoBERTa-large</th>
#       <th id="T_ee578_level1_col6" class="col_heading level1 col6" >mDeBERTa-v3-base</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >&nbsp;</th>
#       <th class="index_name level1" >Detector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee578_level0_row0" class="row_heading level0 row0" rowspan="7">AUC ROC</th>
#       <th id="T_ee578_level1_row0" class="row_heading level1 row0" >BLOOMZ-3b</th>
#       <td id="T_ee578_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ee578_row0_col1" class="data row0 col1" >0.94</td>
#       <td id="T_ee578_row0_col2" class="data row0 col2" >0.97</td>
#       <td id="T_ee578_row0_col3" class="data row0 col3" >0.63</td>
#       <td id="T_ee578_row0_col4" class="data row0 col4" >0.24</td>
#       <td id="T_ee578_row0_col5" class="data row0 col5" >-0.10</td>
#       <td id="T_ee578_row0_col6" class="data row0 col6" >-0.41</td>
#     </tr>
#     <tr>
#       <th id="T_ee578_level1_row1" class="row_heading level1 row1" >Falcon-rw-1b</th>
#       <td id="T_ee578_row1_col0" class="data row1 col0" >0.94</td>
#       <td id="T_ee578_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_
row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#not autoregressive models (seq2seq or masked)
temp = results_all[~results_all.Detector.isin(autoregressive)].set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}'))
# Out:
# <style type="text/css">
# #T_25cf5_row0_col0, #T_25cf5_row0_col20 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_25cf5_row0_col1, #T_25cf5_row0_col8 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_25cf5_row0_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_25cf5_row0_col3, #T_25cf5_row1_col11, #T_25cf5_row2_col8, #T_25cf5_row2_col11, #T_25cf5_row3_col8 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_25cf5_row0_col4, #T_25cf5_row1_col0, #T_25cf5_row3_col13 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_25cf5_row0_col5, #T_25cf5_row2_col5, #T_25cf5_row2_col6 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_25cf5_row0_col6, #T_25cf5_row0_col11, #T_25cf5_row0_col16, #T_25cf5_row1_col16, #T_25cf5_row3_col3, #T_25cf5_row3_col11 {
#   background-color: #83afd3;
#   color: #000000;
# }
# #T_25cf5_row0_col7, #T_25cf5_row0_col17, #T_25cf5_row2_col7, #T_25cf5_row3_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_25cf5_row0_col12, #T_25cf5_row3_col12 {
#   background-color: #78abd0;
#   color: #000000;
# }
# #T_25cf5_row0_col13, #T_25cf5_row1_col2, #T_25cf5_row1_col21, #T_25cf5_row2_col13 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_25cf5_row0_col14, #T_25cf5_row1_col14, #T_25cf5_row2_col15, #T_25cf5_row2_col22, #T_25cf5_row3_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_25cf5_row0_col15, #T_25cf5_row1_col15, #T_25cf5_row2_col14, #T_25cf5_row3_col17 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_25cf5_row0_col21 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_25cf5_row0_col22, #T_25cf5_row1_col4, #T_25cf5_row3_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_25cf5_row1_col1, #T_25cf5_row1_col3, #T_25cf5_row2_col3, #T_25cf5_row2_col16, #T_25cf5_row2_col17, #T_25cf5_row3_col6 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_25cf5_row1_col5, #T_25cf5_row1_col22 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_25cf5_row1_col6, #T_25cf5_row1_col7, #T_25cf5_row3_col14 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_25cf5_row1_col8, #T_25cf5_row3_col15 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_25cf5_row1_col12, #T_25cf5_row2_col12 {
#   background-color: #79abd0;
#   color: #000000;
# }
# #T_25cf5_row1_col13 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_25cf5_row1_col17 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_25cf5_row1_col20, #T_25cf5_row3_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_25cf5_row2_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_25cf5_row2_col1 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_25cf5_row2_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_25cf5_row2_col4 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_25cf5_row2_col20 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_25cf5_row2_col21, #T_25cf5_row3_col20 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_25cf5_row3_col1 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_25cf5_row3_col5, #T_25cf5_row3_col22 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_25cf5_row3_col16 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_25cf5_row3_col21 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# </style>
# <table id="T_25cf5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25cf5_level0_col0" class="col_heading level0 col0" colspan="23">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_25cf5_level1_col0" class="col_heading level1 col0" >ar</th>
#       <th id="T_25cf5_level1_col1" class="col_heading level1 col1" >bg</th>
#       <th id="T_25cf5_level1_col2" class="col_heading level1 col2" >ca</th>
#       <th id="T_25cf5_level1_col3" class="col_heading level1 col3" >cs</th>
#       <th id="T_25cf5_level1_col4" class="col_heading level1 col4" >de</th>
#       <th id="T_25cf5_level1_col5" class="col_heading level1 col5" >el</th>
#       <th id="T_25cf5_level1_col6" class="col_heading level1 col6" >en</th>
#       <th id="T_25cf5_level1_col7" class="col_heading level1 col7" >es</th>
#       <th id="T_25cf5_level1_col8" class="col_heading level1 col8" >et</th>
#       <th id="T_25cf5_level1_col9" class="col_heading level1 col9" >ga</th>
#       <th id="T_25cf5_level1_col10" class="col_heading level1 col10" >gd</th>
#       <th id="T_25cf5_level1_col11" class="col_heading level1 col11" >hr</th>
#       <th id="T_25cf5_level1_col12" class="col_heading level1 col12" >hu</th>
#       <th id="T_25cf5_level1_col13" class="col_heading level1 col13" >nl</th>
#       <th id="T_25cf5_level1_col14" class="col_heading level1 col14" >pl</th>
#       <th id="T_25cf5_level1_col15" class="col_heading level1 col15" >pt</th>
#       <th id="T_25cf5_level1_col16" class="col_heading level1 col16" >ro</th>
#       <th id="T_25cf5_level1_col17" class="col_heading level1 col17" >ru</th>
#       <th id="T_25cf5_level1_col18" class="col_heading level1 col18" >sk</th>
#       <th id="T_25cf5_level1_col19" class="col_heading level1 col19" >sl</th>
#       <th id="T_25cf5_level1_col20" class="col_heading level1 col20" >uk</th>
#       <th id="T_25cf5_level1_col21" class="col_heading level1 col21" >zh</th>
#       <th id="T_25cf5_level1_col22" class="col_heading level1 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25cf5_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_25cf5_row0_col0" class="data row0 col0" >0.85</td>
#       <td id="T_25cf5_row0_col1" class="data row0 col1" >0.95</td>
#       <td id="T_25cf5_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_25cf5_row0_col3" class="data row0 col3" >0.96</td>
#       <td id="T_25cf5_row0_col4" class="data row0 col4" >0.88</td>
#       <td id="T_25cf5_row0_col5" class="data row0 col5" >0.93</td>
#       <td id="T_25cf5_row0_col6" class="data row0 col6" >0.96</td>
#       <td id="T_25cf5_row0_col7" class="data row0 col7" >0.90</td>
#       <td id="T_25cf5_row0_col8" class="data row0 col8" >0.95</td>
#       <td id="T_25cf5_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_25cf5_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_25cf5_row0_col11" class="data row0 col11" >0.96</td>
#       <td id="T_25cf5_row0_col12" class="data row0 col12" >0.99</td>
#       <td id="T_25cf5_row0_col13" class="data row0 col13" >0.86</td>
#       <td id="T_25cf5_row0_col14" class="data row0 col14" >0.93</td>
#       <td id="T_25cf5_row0_col15" class="data row0 col15" >0.94</td>
#       <td id="T_25cf5_row0_col16" class="data row0 col16" >0.96</td>
#       <td id="T_25cf5_row0_col17" class="data row0 col17" >0.90</td>
#       <td id="T_25cf5_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_25cf5_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_25cf5_row0_col20" class="data row0 col20" >0.85</td>
#       <td id="T_25cf5_row0_col21" class="data row0 col21" >0.83</td>
#       <td id="T_25cf5_row0_col22" class="data row0 col22" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_25cf5_level0_r
# \begin{tabular}{lrrrrrrrrrllrrrrrrrllrrr}
#  & \multicolumn{23}{r}{\bfseries AUC ROC} \\
# Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all} \\
# Train Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \bfseries en & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{C2CBE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & N/A & N/A & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 \\
# \bfseries es & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & N/A & N/A & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 \\
# \bfseries ru & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \hline
# \bfseries {en-es-ru} & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & N/A & N/A & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{78ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & N/A & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \end{tabular}
# /tmp/ipykernel_634/2127811620.py:6: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}'))

# %%
sorted_languages = [
                    'el',
                    'ar', 'zh',
                    'ca', 'es', 'pt',
                    'en', 'ga', 'gd',
                    'hu', 'et',
                    'de', 'nl',
                    'cs', 'pl', 'sk',
                    'hr', 'sl',
                    'ro',
                    'bg', 'uk',  'ru',
                    ]
temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
#temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack().corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))
# Out:
# /tmp/ipykernel_634/4163803263.py:13: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# /tmp/ipykernel_634/4163803263.py:13: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()[[('AUC ROC', x) for x in sorted_languages]].corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_f1747_row0_col0, #T_f1747_row1_col1, #T_f1747_row2_col2, #T_f1747_row3_col3, #T_f1747_row4_col4, #T_f1747_row5_col5, #T_f1747_row6_col6, #T_f1747_row7_col7, #T_f1747_row9_col9, #T_f1747_row10_col10, #T_f1747_row11_col11, #T_f1747_row12_col12, #T_f1747_row13_col13, #T_f1747_row14_col14, #T_f1747_row15_col15, #T_f1747_row16_col16, #T_f1747_row17_col17, #T_f1747_row18_col18, #T_f1747_row19_col19, #T_f1747_row20_col20, #T_f1747_row21_col21 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_f1747_row0_col1, #T_f1747_row0_col18, #T_f1747_row1_col0, #T_f1747_row2_col14, #T_f1747_row3_col12, #T_f1747_row5_col14, #T_f1747_row12_col3, #T_f1747_row14_col2, #T_f1747_row14_col5, #T_f1747_row14_col16, #T_f1747_row15_col16, #T_f1747_row16_col14, #T_f1747_row16_col15, #T_f1747_row17_col18, #T_f1747_row18_col0, #T_f1747_row18_col17 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_f1747_row0_col2, #T_f1747_row1_col11, #T_f1747_row1_col18, #T_f1747_row2_col0, #T_f1747_row5_col7, #T_f1747_row6_col18, #T_f1747_row7_col5, #T_f1747_row11_col1, #T_f1747_row18_col1, #T_f1747_row18_col6 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_f1747_row0_col3, #T_f1747_row0_col4, #T_f1747_row2_col16, #T_f1747_row3_col0, #T_f1747_row4_col0, #T_f1747_row16_col2 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_f1747_row0_col5, #T_f1747_row0_col7, #T_f1747_row0_col9, #T_f1747_row0_col13, #T_f1747_row0_col16, #T_f1747_row1_col2, #T_f1747_row2_col1, #T_f1747_row2_col7, #T_f1747_row3_col9, #T_f1747_row3_col16, #T_f1747_row5_col0, #T_f1747_row6_col7, #T_f1747_row6_col16, #T_f1747_row7_col0, #T_f1747_row7_col2, #T_f1747_row7_col6, #T_f1747_row7_col11, #T_f1747_row9_col0, #T_f1747_row9_col3, #T_f1747_row10_col14, #T_f1747_row11_col7, #T_f1747_row11_col18, #T_f1747_row13_col0, #T_f1747_row14_col10, #T_f1747_row16_col0, #T_f1747_row16_col3, #T_f1747_row16_col6, #T_f1747_row18_col11 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T
{
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_f1747_row1_col16, #T_f1747_row2_col15, #T_f1747_row5_col11, #T_f1747_row7_col15, #T_f1747_row11_col5, #T_f1747_row15_col2, #T_f1747_row15_col7, #T_f1747_row15_col19, #T_f1747_row16_col1, #T_f1747_row19_col15 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_f1747_row2_col3, #T_f1747_row2_col11, #T_f1747_row2_col21, #T_f1747_row3_col2, #T_f1747_row3_col17, #T_f1747_row11_col2, #T_f1747_row12_col20, #T_f1747_row17_col3, #T_f1747_row20_col12, #T_f1747_row21_col2 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_f1747_row2_col4, #T_f1747_row4
# /tmp/ipykernel_634/4163803263.py:16: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrr}
#  & \multicolumn{22}{r}{\bfseries AUC ROC} \\
# Language & \bfseries el & \bfseries ar & \bfseries zh & \bfseries ca & \bfseries es & \bfseries pt & \bfseries en & \bfseries ga & \bfseries gd & \bfseries hu & \bfseries et & \bfseries de & \bfseries nl & \bfseries cs & \bfseries pl & \bfseries sk & \bfseries hr & \bfseries sl & \bfseries ro & \bfseries bg & \bfseries uk & \bfseries ru \\
# Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  \\
# \bfseries el & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 \\
# \bfseries ar & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 \\
# \bfseries zh & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 \\
# \bfseries ca & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{B0DFAA}} \color[HTML]{000000} 0.30 \\
# \bfseries es & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.53 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{B6E2AF}} \color[HTML]{000000} 0.22 & {\cellcolor[HTML]{B8E3B2}} \color[HTML]{000000} 0.20 \\
# \bfseries pt & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{AFDFA8}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.27 \\
# \bfseries en & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{B0DFAA}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{B6E2AF}} \color[HTML]{000000} 0.22 \\
# \bfseries ga & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 \\
# \bfseries gd & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan \\
# \bfseries hu & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 \\
# \bfseries et & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.40 \\
# \bfseries de & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{AADDA4}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{AFDFA8}} \color[HTML]{000000} 0.32 \\
# \bfseries nl & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 \\
# \bfseries cs & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{91D28E}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.51 \\
# \bfseries pl & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 \\
# \bfseries sk & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 \\
# \bfseries hr & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9FD899}} \color[HTML]{000000} 0.52 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{83CB82}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7AC77B}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.40 \\
# \bfseries sl & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.50 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 \\
# \bfseries ro & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{7CC87C}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.65 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{7DC87E}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8BCF89}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{A8DCA2}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.28 & {\cellcolor[HTML]{B5E1AE}} \color[HTML]{000000} 0.24 \\
# \bfseries bg & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{A4DA9E}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{AADDA4}} \color[HTML]{000000} 0.38 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{A8DCA2}} \color[HTML]{000000} 0.41 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 \\
# \bfseries uk & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{A3DA9D}} \color[HTML]{000000} 0.47 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{B6E2AF}} \color[HTML]{000000} 0.22 & {\cellcolor[HTML]{AFDFA8}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{B0DFAA}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.63 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{A7DBA0}} \color[HTML]{000000} 0.42 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.36 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.48 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.55 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.60 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.28 & {\cellcolor[HTML]{7FC97F}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 \\
# \bfseries ru & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{92D28F}} \color[HTML]{000000} 0.67 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{B0DFAA}} \color[HTML]{000000} 0.30 & {\cellcolor[HTML]{B8E3B2}} \color[HTML]{000000} 0.20 & {\cellcolor[HTML]{B2E0AC}} \color[HTML]{000000} 0.27 & {\cellcolor[HTML]{B6E2AF}} \color[HTML]{000000} 0.22 & {\cellcolor[HTML]{9BD696}} \color[HTML]{000000} 0.57 & {\cellcolor[HTML]{000000}} \color[HTML]{000000} {\cellcolor{white}} nan & {\cellcolor[HTML]{ABDDA5}} \color[HTML]{000000} 0.37 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{AFDFA8}} \color[HTML]{000000} 0.32 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{A0D99B}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.40 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{B5E1AE}} \color[HTML]{000000} 0.24 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{76C578}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 \\
# \end{tabular}

# %%
#social media telegram test data - per language-family of telegram trained mono and multilingually traned EN,ES,RU detectors
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    temp = data[(data.split == 'test') & (data.domain == 'social_media')]
  if ('cross-language' not in model): continue
  temp['source'] = temp['source'].str.replace('multisocial_', '')
  temp = temp[temp.source == 'telegram']
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  temp['language'] = temp['language'].map(to_language_family)
  temp['prediction_probs']= temp['prediction_probs'].astype(float)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'].astype(float))
  auc_dict[model] = {'auc': auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc': auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': extract_language(model).split('_')[0], 'Train Language': extract_language(model).split('_')[1], 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': extract_language(model).split('_')[0], 'Train Language': extract_language(model).split('_')[1], 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_language_family = results_all.copy()
# Out:
#  12%|██████████                                                                         | 10/83 [00:00<00:06, 11.07it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  14%|████████████                                                                       | 12/83 [00:01<00:09,  7.18it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  16%|█████████████                                                                      | 13/83 [00:01<00:10,  6.37it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  19%|████████████████                                                                   | 16/83 [00:02<00:09,  7.07it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  22%|██████████████████                                                                 | 18/83 [00:02<00:09,  6.73it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  23%|███████████████████                                                                | 19/83 [00:02<00:11,  5.75it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  24%|████████████████████                                                               | 20/83 [00:02<00:12,  5.12it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  28%|███████████████████████                                                            | 23/83 [00:03<00:10,  6.00it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  30%|█████████████████████████                                                          | 25/83 [00:03<00:09,  5.98it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  31%|██████████████████████████                                                         | 26/83 [00:03<00:10,  5.57it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  33%|███████████████████████████                                                        | 27/83 [00:04<00:11,  5.04it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  36%|██████████████████████████████                                                     | 30/83 [00:04<00:08,  6.35it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  39%|████████████████████████████████                                                   | 32/83 [00:04<00:08,  6.32it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  40%|█████████████████████████████████                                                  | 33/83 [00:05<00:08,  5.76it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  41%|██████████████████████████████████                                                 | 34/83 [00:05<00:09,  5.34it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  42%|███████████████████████████████████                                                | 35/83 [00:05<00:09,  5.05it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  55%|██████████████████████████████████████████████                                     | 46/83 [00:06<00:03,  9.71it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  57%|███████████████████████████████████████████████                                    | 47/83 [00:07<00:04,  7.37it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  58%|████████████████████████████████████████████████                                   | 48/83 [00:07<00:05,  6.10it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  59%|█████████████████████████████████████████████████                                  | 49/83 [00:07<00:06,  5.36it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  60%|██████████████████████████████████████████████████                                 | 50/83 [00:07<00:06,  4.92it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  73%|█████████████████████████████████████████████████████████████                      | 61/83 [00:08<00:02, 10.28it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  76%|███████████████████████████████████████████████████████████████                    | 63/83 [00:09<00:02,  7.06it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  77%|████████████████████████████████████████████████████████████████                   | 64/83 [00:09<00:02,  6.39it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  78%|█████████████████████████████████████████████████████████████████                  | 65/83 [00:09<00:03,  5.86it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  92%|████████████████████████████████████████████████████████████████████████████       | 76/83 [00:10<00:00, 10.32it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  94%|██████████████████████████████████████████████████████████████████████████████     | 78/83 [00:11<00:00,  7.04it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
#  95%|███████████████████████████████████████████████████████████████████████████████    | 79/83 [00:11<00:00,  6.29it/s]/tmp/ipykernel_634/3236697026.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['source'] = temp['source'].str.replace('multisocial_', '')
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:12<00:00,  6.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:00<00:00, 249.75it/s]

# %%
results_all = results_language_family

# %%
temp = pd.DataFrame(multidomain[(multidomain.domain=='social_media') & multidomain.source.str.contains('telegram')][['language']].value_counts())
temp = temp.reset_index()
temp['language'] = temp['language'].map(to_language_family)
temp = temp.groupby(['language']).sum().unstack().fillna(0).astype(int) > 2000 #if there are enough samples (~ 250 of each generator)
temp.index = temp.index.droplevel(0)
temp['{all}'] = True
enough_platform_language_samples = temp

#temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack()
temp = results_all[~results_all['Train Language'].str.contains('x3')].set_index(['Detector', 'Train Language', 'Language']).unstack()
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))
# Out:
# <style type="text/css">
# #T_17300_row0_col1, #T_17300_row2_col4, #T_17300_row20_col2, #T_17300_row23_col1, #T_17300_row27_col6 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_17300_row0_col2, #T_17300_row0_col7, #T_17300_row1_col7, #T_17300_row3_col6, #T_17300_row15_col2, #T_17300_row19_col8, #T_17300_row22_col6, #T_17300_row26_col7 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_17300_row0_col3, #T_17300_row3_col4, #T_17300_row15_col5, #T_17300_row18_col6, #T_17300_row21_col3 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_17300_row0_col4, #T_17300_row7_col8, #T_17300_row21_col6, #T_17300_row24_col6, #T_17300_row26_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_17300_row0_col5, #T_17300_row1_col4, #T_17300_row9_col2, #T_17300_row12_col6, #T_17300_row13_col3, #T_17300_row17_col8, #T_17300_row21_col9, #T_17300_row22_col5, #T_17300_row23_col4, #T_17300_row25_col3, #T_17300_row27_col9 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_17300_row0_col6, #T_17300_row0_col9, #T_17300_row2_col2, #T_17300_row14_col6, #T_17300_row15_col1, #T_17300_row15_col9, #T_17300_row23_col3, #T_17300_row23_col6 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_17300_row0_col8, #T_17300_row3_col8 {
#   background-color: #7dacd1;
#   color: #000000;
# }
# #T_17300_row1_col1, #T_17300_row1_col2, #T_17300_row2_col3, #T_17300_row3_col1, #T_17300_row11_col2, #T_17300_row19_col6, #T_17300_row20_col7, #T_17300_row22_col9, #T_17300_row24_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_17300_row1_col3, #T_17300_row1_col6, #T_17300_row3_col9, #T_17300_row15_col3, #T_17300_row15_col7 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_17300_row1_col5, #T_17300_row4_col2, #T_17300_row11_col1, #T_17300_row11_col7, #T_17300_row12_col1, #T_17300_row12_col2, #T_17300_row12_col7, #T_17300_row16_col8, #T_17300_row17_col3, #T_17300_row19_col7, #T_17300_row20_col1, #T_17300_row25_col6, #T_17300_row27_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_17300_row1_col8, #T_17300_row2_col8, #T_17300_row22_col8 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_17300_row1_col9, #T_17300_row2_col9, #T_17300_row3_col2, #T_17300_row11_col8, #T_17300_row21_col2, #T_17300_row21_col7, #T_17300_row23_col9, #T_17300_row25_col7, #T_17300_row26_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_17300_row2_col1, #T_17300_row2_col5, #T_17300_row3_col5, #T_17300_row4_col8, #T_17300_row7_col2, #T_17300_row8_col8, #T_17300_row19_col2, #T_17300_row22_col3, #T_17300_row22_col4, #T_17300_row26_col9 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_17300_row2_col6, #T_17300_row25_col8 {
#   background-color: #83afd3;
#   color: #000000;
# }
# #T_17300_row2_col7, #T_17300_row3_col3, #T_17300_row3_col7, #T_17300_row24_col7, #T_17300_row27_col7 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_17300_row4_col1, #T_17300_row9_col8, #T_17300_row11_col9, #T_17300_row16_col1, #T_17300_row22_col1, #T_17300_row24_col3, #T_17300_row27_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_17300_row4_col3, #T_17300_row5_col7, #T_17300_row8_col5 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_17300_row4_col4, #T_17300_row10_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_17300_row4_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_17300_row4_col6, #T_17300_row9_col7, #T_17300_row10_col6, #T_17300_row11_col6, #T_17300_row12_col4, #T_17300_row18_col2, #T_17300_row21_col5, #T_17300_row27_col5 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_17300_row4_col7, #T_17300_row6_col6, #T_17300_row8_col7, #T_17300_row10_col2, #T_17300_row13_col7, #T_17300_row18_col7, #T_17300_row25_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_17300_row4_col9, #T_17300_row11_col4, #T_17300_row16_col9, #T_17300_row25_col5 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_17300_row5_col1, #T_17300_row7_col7 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_17300_row5_col2, #T_17300_row20_col4 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_17300_row5_col3, #T_17300_row7_col1, #T_17300_row7_col5, #T_17300_row7_col6, #T_17300_row12_col3, #T_17300_row13_col1, #T_17300_row27_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_17300_row5_col4, #T_17300_row6_col1, #T_17300_row14_col9, #T_17300_row16_col6, #T_17300_row18_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_17300_row5_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_17300_row5_col6, #T_17300_row14_col1, #T_17300_row17_col7, #T_17300_row18_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_17300_row5_col8 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_17300_row5_col9, #T_17300_row6_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_17300_row6_col2, #T_17300_row8_col6 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_17300_row6_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_17300_row6_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_17300_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_17300_row6_col7 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_17300_row6_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_17300_row7_col3, #T_17300_row13_col2, #T_17300_row14_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_17300_row7_col4, #T_17300_row8_col1, #T_17300_row11_col5, #T_17300_row12_col9, #T_17300_row20_col6, #T_17300_row21_col4, #T_17300_row26_col1, #T_17300_row26_col5 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_17300_row7_col9, #T_17300_row8_col3, #T_17300_row16_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_17300_row8_col2, #T_17300_row25_col2 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_17300_row8_col4, #T_17300_row24_col5 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_17300_row8_col9, #T_17300_row14_col8 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_17300_row9_col1, #T_17300_row16_col2 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_17300_row9_col3, #T_17300_row13_col6, #T_17300_row19_col1, #T_17300_row19_col9, #T_17300_row20_col3, #T_17300_row23_col5, #T_17300_row25_col9, #T_17300_row27_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_17300_row9_col4, #T_17300_row10_col9, #T_17300_row14_col3, #T_17300_row18_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_17300_row9_col5, #T_17300_row13_col4, #T_17300_row17_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_17300_row9_col6, #T_17300_row10_col1, #T_17300_row16_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_17300_row9_col9, #T_17300_row13_col9, #T_17300_row17_col1, #T_17300_row20_col5, #T_17300_row24_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_17300_row10_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_17300_row10_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_17300_row10_col7, #T_17300_row10_col8 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_17300_row11_col3, #T_17300_row13_col8 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_17300_row12_col5 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_17300_row12_col8, #T_17300_row22_col2, #T_17300_row22_col7 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_17300_row13_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_17300_row14_col4 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_17300_row14_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_17300_row14_col7, #T_17300_row16_col7 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_17300_row15_col4, #T_17300_row19_col3, #T_17300_row26_col2 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_17300_row15_col6, #T_17300_row23_col2, #T_17300_row23_col7 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_17300_row15_col8, #T_17300_row21_col8, #T_17300_row24_col8, #T_17300_row26_col8 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_17300_row16_col5, #T_17300_row18_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_17300_row17_col2 {
#   backgro
# \begin{tabular}{lllrrrrrrrrr}
#  &  & \multicolumn{10}{r}{\bfseries AUC ROC} \\
#  & Language & \bfseries Celtic & \bfseries Germanic & \bfseries Greek & \bfseries Romance & \bfseries Semitic & \bfseries Sino-Tibetan & \bfseries Slavic-Cyrillic & \bfseries Slavic-Latin & \bfseries Uralic & \bfseries {all} \\
# Detector & Train Language &  &  &  &  &  &  &  &  &  &  \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Aya-101}}} & \bfseries en & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries BLOOMZ-3b}}} & \bfseries en & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{EEE8F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{EFE9F3}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{EDE7F2}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{DDDBEC}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{EAE6F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C8CDE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{BCC7E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{D7D6E9}} \color[HTML]{000000} 0.72 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{B0C2DE}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Falcon-rw-1b}}} & \bfseries en & N/A & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{C1CAE2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{CCCFE5}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{BFC9E1}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{E0DEED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{D0D1E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{BDC8E1}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Llama-3-8b}}} & \bfseries en & N/A & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{D5D5E8}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{E9E5F1}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{CED0E6}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{F1EBF5}} \color[HTML]{000000} 0.59 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{B5C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries Mistral-7b-v0.1}}} & \bfseries en & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{AFC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{A9BFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{C9CEE4}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.46 & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{B1C2DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{D1D2E6}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{CACEE5}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{FEF6FA}} \color[HTML]{000000} 0.51 & {\cellcolor[HTML]{C0C9E2}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{C5CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{C6CCE3}} \color[HTML]{000000} 0.78 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 0.44 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{BBC7E0}} \color[HTML]{000000} 0.82 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{E0DDED}} \color[HTML]{000000} 0.68 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries XLM-RoBERTa-large}}} & \bfseries en & N/A & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{B9C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \hline
# \multirow[c]{4}{*}{\rotatebox{90}{\parbox{1.8cm}{\bfseries mDeBER\-Ta-v3-base}}} & \bfseries en & N/A & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{D2D2E7}} \color[HTML]{000000} 0.74 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries es & N/A & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A7BDDB}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 \\
# \bfseries  & \bfseries ru & N/A & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{A8BEDC}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.91 \\
# \bfseries  & \bfseries {en-es-ru} & N/A & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{A5BDDB}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ADC1DD}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 \\
# \end{tabular}
# /tmp/ipykernel_634/72917441.py:14: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))

# %%
temp = results_all.set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_27a05_row0_col1, #T_27a05_row2_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_27a05_row0_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_27a05_row0_col3, #T_27a05_row1_col1, #T_27a05_row1_col2 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_27a05_row0_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_27a05_row0_col5 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_27a05_row0_col6 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_27a05_row0_col7 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_27a05_row0_col8 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_27a05_row0_col9 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_27a05_row1_col3, #T_27a05_row3_col9 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_27a05_row1_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_27a05_row1_col5, #T_27a05_row2_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_27a05_row1_col6, #T_27a05_row3_col5 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_27a05_row1_col7, #T_27a05_row2_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_27a05_row1_col8, #T_27a05_row3_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_27a05_row1_col9 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_27a05_row2_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_27a05_row2_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_27a05_row2_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_27a05_row2_col6, #T_27a05_row3_col3, #T_27a05_row3_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_27a05_row2_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_27a05_row2_col9 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_27a05_row3_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_27a05_row3_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_27a05_row3_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_27a05_row3_col8 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# </style>
# <table id="T_27a05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27a05_level0_col0" class="col_heading level0 col0" colspan="10">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_27a05_level1_col0" class="col_heading level1 col0" >Celtic</th>
#       <th id="T_27a05_level1_col1" class="col_heading level1 col1" >Germanic</th>
#       <th id="T_27a05_level1_col2" class="col_heading level1 col2" >Greek</th>
#       <th id="T_27a05_level1_col3" class="col_heading level1 col3" >Romance</th>
#       <th id="T_27a05_level1_col4" class="col_heading level1 col4" >Semitic</th>
#       <th id="T_27a05_level1_col5" class="col_heading level1 col5" >Sino-Tibetan</th>
#       <th id="T_27a05_level1_col6" class="col_heading level1 col6" >Slavic-Cyrillic</th>
#       <th id="T_27a05_level1_col7" class="col_heading level1 col7" >Slavic-Latin</th>
#       <th id="T_27a05_level1_col8" class="col_heading level1 col8" >Uralic</th>
#       <th id="T_27a05_level1_col9" class="col_heading level1 col9" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27a05_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_27a05_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_27a05_row0_col1" class="data row0 col1" >0.89</td>
#       <td id="T_27a05_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_27a05_row0_col3" class="data row0 col3" >0.87</td>
#       <td id="T_27a05_row0_col4" class="data row0 col4" >0.81</td>
#       <td id="T_27a05_row0_col5" class="data row0 col5" >0.73</td>
#       <td id="T_27a05_row0_col6" class="data row0 col6" >0.86</td>
#       <td id="T_27a05_row0_col7" class="data row0 col7" >0.90</td>
#       <td id="T_27a05_row0_col8" class="data row0 col8" >0.94</td>
#       <td id="T_27a05_row0_col9" class="data row0 col9" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_27a05_level0_row1" class="row_heading level0 row1" >es</th>
#       <td id="T_27a05_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_27a05_row1_col1" class="data row1 col1" >0.87</td>
#       <td id="T_27a05_row1_col2" class="data row1 col2" >0.87</td>
#       <td id="T_27a05_row1_col3" class="data row1 col3" >0.91</td>
#       <td id="T_27a05_row1_col4" class="data row1 col4" >0.82</td>
#       <td id="T_27a05_row1_col5" class="data row1 col5" >0.73</td>
#       <td id="T_27a05_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_27a05_row1_col7" class="data row1 col7" >0.88</td>
#       <td id="T_27a05_row1_col8" class="data row1 col8" >0.92</td>
#       <td id="T_27a05_row1_col9" class="data row1 col9" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_27a05_level0_row2" class="row_heading level0 row2" >ru</th>
#       <td id="T_27a05_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_27a05_row2_col1" class="data row2 col1" >0.83</td>
#       <td id="T_27a05_row2_col2" class="data row2 col2" >0.88</td>
#       <td id="T_27a05_row2_col3" class="data row2 col3" >0.83</td>
#       <td id="T_27a05_row2_col4" class="data row2 col4" >0.81</td>
#       <td id="T_27a05_row2_col5" class="data row2 col5" >0.73</td>
#       <td id="T_27a05_row2_col6" class="data row2 col6" >0.92</td>
#       <td id="T_27a05_row2_col7" class="data row2 col7" >0.88</td>
#       <td id="T_27a05_row2_col8" class="data row2 col8" >0.89</td>
#       <td id="T_27a05_row2_col9" class="data row2 col9" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_27a05_level0_row3" class="row_heading level0 row3" >{en-es-ru}</th>
#       <td id="T_27a05_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_27a05_row3_col1" class="data row3 col1" >0.91</td>
#       <td id="T_27a05_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_27a05_row3_col3" class="data row3 col3" >0.92</td>
#       <td id="T_27a05_row3_col4" class="data row3 col4" >0.89</td>
#       <td id="T_27a05_row3_col5" class="data row3 col5" >0.86</td>
#       <td id="T_27a05_row3_col6" class="data row3 col6" >0.92</td>
#       <td id="T_27a05_row3_col7" class="data row3 col7" >0.92</td>
#       <td id="T_27a05_row3_col8" class="data row3 col8" >0.95</td>
#       <td id="T_27a05_row3_col9" class="data row3 col9" >0.91</td>
#     </tr>
#   </tbody>
# </table>

# %%
#autoregressive decoder-only models
temp = results_all[results_all.Detector.isin(autoregressive)].set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_93601_row0_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_93601_row0_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_93601_row0_col3, #T_93601_row1_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_93601_row0_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_93601_row0_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_93601_row0_col6 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_93601_row0_col7 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_93601_row0_col8 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_93601_row0_col9, #T_93601_row1_col2, #T_93601_row2_col8, #T_93601_row3_col5 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_93601_row1_col3, #T_93601_row2_col6, #T_93601_row3_col9 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_93601_row1_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_93601_row1_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_93601_row1_col6, #T_93601_row1_col9, #T_93601_row2_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_93601_row1_col7 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_93601_row1_col8 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_93601_row2_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_93601_row2_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_93601_row2_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_93601_row2_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_93601_row2_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_93601_row2_col9 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_93601_row3_col1, #T_93601_row3_col6 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_93601_row3_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_93601_row3_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_93601_row3_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_93601_row3_col7 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_93601_row3_col8 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# </style>
# <table id="T_93601">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93601_level0_col0" class="col_heading level0 col0" colspan="10">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_93601_level1_col0" class="col_heading level1 col0" >Celtic</th>
#       <th id="T_93601_level1_col1" class="col_heading level1 col1" >Germanic</th>
#       <th id="T_93601_level1_col2" class="col_heading level1 col2" >Greek</th>
#       <th id="T_93601_level1_col3" class="col_heading level1 col3" >Romance</th>
#       <th id="T_93601_level1_col4" class="col_heading level1 col4" >Semitic</th>
#       <th id="T_93601_level1_col5" class="col_heading level1 col5" >Sino-Tibetan</th>
#       <th id="T_93601_level1_col6" class="col_heading level1 col6" >Slavic-Cyrillic</th>
#       <th id="T_93601_level1_col7" class="col_heading level1 col7" >Slavic-Latin</th>
#       <th id="T_93601_level1_col8" class="col_heading level1 col8" >Uralic</th>
#       <th id="T_93601_level1_col9" class="col_heading level1 col9" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93601_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_93601_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_93601_row0_col1" class="data row0 col1" >0.89</td>
#       <td id="T_93601_row0_col2" class="data row0 col2" >0.88</td>
#       <td id="T_93601_row0_col3" class="data row0 col3" >0.85</td>
#       <td id="T_93601_row0_col4" class="data row0 col4" >0.78</td>
#       <td id="T_93601_row0_col5" class="data row0 col5" >0.65</td>
#       <td id="T_93601_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_93601_row0_col7" class="data row0 col7" >0.87</td>
#       <td id="T_93601_row0_col8" class="data row0 col8" >0.92</td>
#       <td id="T_93601_row0_col9" class="data row0 col9" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_93601_level0_row1" class="row_heading level0 row1" >es</th>
#       <td id="T_93601_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_93601_row1_col1" class="data row1 col1" >0.85</td>
#       <td id="T_93601_row1_col2" class="data row1 col2" >0.84</td>
#       <td id="T_93601_row1_col3" class="data row1 col3" >0.90</td>
#       <td id="T_93601_row1_col4" class="data row1 col4" >0.78</td>
#       <td id="T_93601_row1_col5" class="data row1 col5" >0.64</td>
#       <td id="T_93601_row1_col6" class="data row1 col6" >0.82</td>
#       <td id="T_93601_row1_col7" class="data row1 col7" >0.83</td>
#       <td id="T_93601_row1_col8" class="data row1 col8" >0.89</td>
#       <td id="T_93601_row1_col9" class="data row1 col9" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_93601_level0_row2" class="row_heading level0 row2" >ru</th>
#       <td id="T_93601_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_93601_row2_col1" class="data row2 col1" >0.79</td>
#       <td id="T_93601_row2_col2" class="data row2 col2" >0.84</td>
#       <td id="T_93601_row2_col3" class="data row2 col3" >0.76</td>
#       <td id="T_93601_row2_col4" class="data row2 col4" >0.73</td>
#       <td id="T_93601_row2_col5" class="data row2 col5" >0.61</td>
#       <td id="T_93601_row2_col6" class="data row2 col6" >0.89</td>
#       <td id="T_93601_row2_col7" class="data row2 col7" >0.82</td>
#       <td id="T_93601_row2_col8" class="data row2 col8" >0.84</td>
#       <td id="T_93601_row2_col9" class="data row2 col9" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_93601_level0_row3" class="row_heading level0 row3" >{en-es-ru}</th>
#       <td id="T_93601_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_93601_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_93601_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_93601_row3_col3" class="data row3 col3" >0.91</td>
#       <td id="T_93601_row3_col4" class="data row3 col4" >0.88</td>
#       <td id="T_93601_row3_col5" class="data row3 col5" >0.84</td>
#       <td id="T_93601_row3_col6" class="data row3 col6" >0.91</td>
#       <td id="T_93601_row3_col7" class="data row3 col7" >0.90</td>
#       <td id="T_93601_row3_col8" class="data row3 col8" >0.94</td>
#       <td id="T_93601_row3_col9" class="data row3 col9" >0.90</td>
#     </tr>
#   </tbody>
# </table>

# %%
#not autoregressive models (seq2seq or masked)
temp = results_all[~results_all.Detector.isin(autoregressive)].set_index(['Train Language', 'Detector', 'Language']).unstack().groupby('Train Language').mean().drop(index=['{en-es-ru-x3}'])
temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
display(temp)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))
# Out:
# <style type="text/css">
# #T_84c06_row0_col1, #T_84c06_row0_col3, #T_84c06_row1_col1, #T_84c06_row3_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_84c06_row0_col2, #T_84c06_row2_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_84c06_row0_col4 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_84c06_row0_col5 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_84c06_row0_col6, #T_84c06_row2_col5 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_84c06_row0_col7, #T_84c06_row1_col7 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_84c06_row0_col8, #T_84c06_row1_col8, #T_84c06_row2_col8 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_84c06_row0_col9 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_84c06_row1_col2, #T_84c06_row1_col9, #T_84c06_row3_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_84c06_row1_col3, #T_84c06_row2_col9 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_84c06_row1_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_84c06_row1_col5 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_84c06_row1_col6, #T_84c06_row2_col3, #T_84c06_row2_col4 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_84c06_row2_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_84c06_row2_col6, #T_84c06_row2_col7, #T_84c06_row3_col7 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_84c06_row3_col2, #T_84c06_row3_col3, #T_84c06_row3_col9 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_84c06_row3_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_84c06_row3_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_84c06_row3_col8 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# </style>
# <table id="T_84c06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84c06_level0_col0" class="col_heading level0 col0" colspan="10">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_84c06_level1_col0" class="col_heading level1 col0" >Celtic</th>
#       <th id="T_84c06_level1_col1" class="col_heading level1 col1" >Germanic</th>
#       <th id="T_84c06_level1_col2" class="col_heading level1 col2" >Greek</th>
#       <th id="T_84c06_level1_col3" class="col_heading level1 col3" >Romance</th>
#       <th id="T_84c06_level1_col4" class="col_heading level1 col4" >Semitic</th>
#       <th id="T_84c06_level1_col5" class="col_heading level1 col5" >Sino-Tibetan</th>
#       <th id="T_84c06_level1_col6" class="col_heading level1 col6" >Slavic-Cyrillic</th>
#       <th id="T_84c06_level1_col7" class="col_heading level1 col7" >Slavic-Latin</th>
#       <th id="T_84c06_level1_col8" class="col_heading level1 col8" >Uralic</th>
#       <th id="T_84c06_level1_col9" class="col_heading level1 col9" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84c06_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_84c06_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_84c06_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_84c06_row0_col2" class="data row0 col2" >0.93</td>
#       <td id="T_84c06_row0_col3" class="data row0 col3" >0.91</td>
#       <td id="T_84c06_row0_col4" class="data row0 col4" >0.85</td>
#       <td id="T_84c06_row0_col5" class="data row0 col5" >0.83</td>
#       <td id="T_84c06_row0_col6" class="data row0 col6" >0.90</td>
#       <td id="T_84c06_row0_col7" class="data row0 col7" >0.94</td>
#       <td id="T_84c06_row0_col8" class="data row0 col8" >0.97</td>
#       <td id="T_84c06_row0_col9" class="data row0 col9" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_84c06_level0_row1" class="row_heading level0 row1" >es</th>
#       <td id="T_84c06_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_84c06_row1_col1" class="data row1 col1" >0.90</td>
#       <td id="T_84c06_row1_col2" class="data row1 col2" >0.92</td>
#       <td id="T_84c06_row1_col3" class="data row1 col3" >0.93</td>
#       <td id="T_84c06_row1_col4" class="data row1 col4" >0.88</td>
#       <td id="T_84c06_row1_col5" class="data row1 col5" >0.86</td>
#       <td id="T_84c06_row1_col6" class="data row1 col6" >0.91</td>
#       <td id="T_84c06_row1_col7" class="data row1 col7" >0.94</td>
#       <td id="T_84c06_row1_col8" class="data row1 col8" >0.97</td>
#       <td id="T_84c06_row1_col9" class="data row1 col9" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_84c06_level0_row2" class="row_heading level0 row2" >ru</th>
#       <td id="T_84c06_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_84c06_row2_col1" class="data row2 col1" >0.89</td>
#       <td id="T_84c06_row2_col2" class="data row2 col2" >0.94</td>
#       <td id="T_84c06_row2_col3" class="data row2 col3" >0.91</td>
#       <td id="T_84c06_row2_col4" class="data row2 col4" >0.91</td>
#       <td id="T_84c06_row2_col5" class="data row2 col5" >0.90</td>
#       <td id="T_84c06_row2_col6" class="data row2 col6" >0.95</td>
#       <td id="T_84c06_row2_col7" class="data row2 col7" >0.95</td>
#       <td id="T_84c06_row2_col8" class="data row2 col8" >0.97</td>
#       <td id="T_84c06_row2_col9" class="data row2 col9" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_84c06_level0_row3" class="row_heading level0 row3" >{en-es-ru}</th>
#       <td id="T_84c06_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_84c06_row3_col1" class="data row3 col1" >0.92</td>
#       <td id="T_84c06_row3_col2" class="data row3 col2" >0.93</td>
#       <td id="T_84c06_row3_col3" class="data row3 col3" >0.93</td>
#       <td id="T_84c06_row3_col4" class="data row3 col4" >0.91</td>
#       <td id="T_84c06_row3_col5" class="data row3 col5" >0.89</td>
#       <td id="T_84c06_row3_col6" class="data row3 col6" >0.94</td>
#       <td id="T_84c06_row3_col7" class="data row3 col7" >0.95</td>
#       <td id="T_84c06_row3_col8" class="data row3 col8" >0.98</td>
#       <td id="T_84c06_row3_col9" class="data row3 col9" >0.93</td>
#     </tr>
#   </tbody>
# </table>

# %%
temp = results_all[~results_all['Train Language'].str.contains('x3')]
temp = temp[~temp.Language.isin(enough_platform_language_samples[~enough_platform_language_samples].index.tolist())]
temp = temp.set_index(['Detector', 'Train Language', 'Language']).unstack()
temp = temp.replace('nan', pd.NA).corr().reset_index().drop(columns=['level_0']).set_index('Language')
#temp[[('AUC ROC', x) for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp = temp.style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
#temp = results_all.set_index(['Detector', 'Train Language', 'Language']).unstack().corr(numeric_only=True).reset_index().drop(columns=['level_0']).set_index('Language').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))
# Out:
# /tmp/ipykernel_634/4165235407.py:4: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   temp = temp.replace('nan', pd.NA).corr().reset_index().drop(columns=['level_0']).set_index('Language')
# /tmp/ipykernel_634/4165235407.py:6: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = temp.style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_31d73_row0_col0, #T_31d73_row1_col1, #T_31d73_row2_col2, #T_31d73_row3_col3, #T_31d73_row4_col4, #T_31d73_row5_col5, #T_31d73_row6_col6, #T_31d73_row7_col7, #T_31d73_row8_col8 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_31d73_row0_col1, #T_31d73_row1_col0, #T_31d73_row1_col3, #T_31d73_row2_col6, #T_31d73_row3_col1, #T_31d73_row4_col6, #T_31d73_row6_col2, #T_31d73_row6_col4 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_31d73_row0_col2, #T_31d73_row1_col4, #T_31d73_row2_col0, #T_31d73_row4_col1, #T_31d73_row4_col8, #T_31d73_row8_col4 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_31d73_row0_col3, #T_31d73_row1_col6, #T_31d73_row3_col0, #T_31d73_row6_col1 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_31d73_row0_col4, #T_31d73_row1_col2, #T_31d73_row2_col1, #T_31d73_row4_col0 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_31d73_row0_col5, #T_31d73_row5_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_31d73_row0_col6, #T_31d73_row2_col7, #T_31d73_row6_col0, #T_31d73_row7_col2 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_31d73_row0_col7, #T_31d73_row0_col8, #T_31d73_row2_col8, #T_31d73_row7_col0, #T_31d73_row8_col0, #T_31d73_row8_col2 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_31d73_row1_col5, #T_31d73_row5_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_31d73_row1_col7, #T_31d73_row3_col4, #T_31d73_row4_col3, #T_31d73_row7_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_31d73_row1_col8, #T_31d73_row8_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_31d73_row2_col3, #T_31d73_row3_col2 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_31d73_row2_col4, #T_31d73_row4_col2 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_31d73_row2_col5, #T_31d73_row5_col2 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_31d73_row3_col5, #T_31d73_row5_col3 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_31d73_row3_col6, #T_31d73_row3_col7, #T_31d73_row6_col3, #T_31d73_row7_col3 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_31d73_row3_col8, #T_31d73_row6_col7, #T_31d73_row6_col8, #T_31d73_row7_col6, #T_31d73_row7_col8, #T_31d73_row8_col3, #T_31d73_row8_col6, #T_31d73_row8_col7 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_31d73_row4_col5, #T_31d73_row5_col4 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_31d73_row4_col7, #T_31d73_row5_col8, #T_31d73_row7_col4, #T_31d73_row8_col5 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_31d73_row5_col6, #T_31d73_row6_col5 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_31d73_row5_col7, #T_31d73_row7_col5 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# </style>
# <table id="T_31d73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31d73_level0_col0" class="col_heading level0 col0" colspan="9">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_31d73_level1_col0" class="col_heading level1 col0" >Germanic</th>
#       <th id="T_31d73_level1_col1" class="col_heading level1 col1" >Greek</th>
#       <th id="T_31d73_level1_col2" class="col_heading level1 col2" >Romance</th>
#       <th id="T_31d73_level1_col3" class="col_heading level1 col3" >Semitic</th>
#       <th id="T_31d73_level1_col4" class="col_heading level1 col4" >Sino-Tibetan</th>
#       <th id="T_31d73_level1_col5" class="col_heading level1 col5" >Slavic-Cyrillic</th>
#       <th id="T_31d73_level1_col6" class="col_heading level1 col6" >Slavic-Latin</th>
#       <th id="T_31d73_level1_col7" class="col_heading level1 col7" >Uralic</th>
#       <th id="T_31d73_level1_col8" class="col_heading level1 col8" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31
>0.77</td>
#     </tr>
#     <tr>
#       <th id="T_31d73_level0_row5" class="row_heading level0 row5" >Slavic-Cyrillic</th>
#       <td id="T_31d73_row5_col0" class="data row5 col0" >0.39</td>
#       <td id="T_31d73_row5_col1" class="data row5 col1" >0.56</td>
#       <td id="T_31d73_row5_col2" class="data row5 col2" >0.29</td>
#       <td i
# \begin{tabular}{lrrrrrrrrr}
#  & \multicolumn{9}{r}{\bfseries AUC ROC} \\
# Language & \bfseries Germanic & \bfseries Greek & \bfseries Romance & \bfseries Semitic & \bfseries Sino-Tibetan & \bfseries Slavic-Cyrillic & \bfseries Slavic-Latin & \bfseries Uralic & \bfseries {all} \\
# Language &  &  &  &  &  &  &  &  &  \\
# \bfseries Germanic & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 \\
# \bfseries Greek & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 \\
# \bfseries Romance & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.76 & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{B1E0AB}} \color[HTML]{000000} 0.29 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 \\
# \bfseries Semitic & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.73 & {\cellcolor[HTML]{88CE87}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 \\
# \bfseries Sino-Tibetan & {\cellcolor[HTML]{97D492}} \color[HTML]{000000} 0.62 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.75 & {\cellcolor[HTML]{9ED798}} \color[HTML]{000000} 0.54 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.69 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.77 \\
# \bfseries Slavic-Cyrillic & {\cellcolor[HTML]{A9DCA3}} \color[HTML]{000000} 0.39 & {\cellcolor[HTML]{9CD797}} \color[HTML]{000000} 0.56 & {\cellcolor[HTML]{B1E0AB}} \color[HTML]{000000} 0.29 & {\cellcolor[HTML]{8ED08B}} \color[HTML]{000000} 0.71 & {\cellcolor[HTML]{A5DB9F}} \color[HTML]{000000} 0.45 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 \\
# \bfseries Slavic-Latin & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{8DD08A}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{94D390}} \color[HTML]{000000} 0.66 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 \\
# \bfseries Uralic & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{90D18D}} \color[HTML]{000000} 0.70 & {\cellcolor[HTML]{87CD86}} \color[HTML]{000000} 0.79 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{A2D99C}} \color[HTML]{000000} 0.49 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 \\
# \bfseries {all} & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{81CA81}} \color[HTML]{000000} 0.85 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8ACE88}} \color[HTML]{000000} 0.77 & {\cellcolor[HTML]{98D594}} \color[HTML]{000000} 0.61 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{79C67A}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 \\
# \end{tabular}
# /tmp/ipykernel_634/4165235407.py:9: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))

# %%
#social media EN+ES test data - per platform

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
 for model,data in detector.items():
  temp_data = data[(data.split == 'test') & (data.domain == 'social_media') & (data.language.isin(['en', 'es']))]
 if ('cross-platform' not in model): continue
 temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
 temp_data['prediction_probs']= temp_data['prediction_probs'].astype(float)
 temp = temp_data
 llm = '{all}'
 labels = [label2id[x] for x in temp['label']]
 fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
 auc_dict[f"{model} {llm}"] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
 for llm in tqdm(temp_data.source.unique(), total=len(temp_data.multi_label.unique())):
  temp = temp_data[(temp_data.source.str.contains(f'{llm}'))]
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[f"{model} {llm}"] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': extract_platform(model.split(' ')[0]).split('_')[0], 'Train Platform': extract_platform(model.split(' ')[0]).split('_')[1], 'Platform': model.split(' ')[1], 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
#results_all.set_index(['Detector', 'Platform', 'Language']).unstack().style.format(precision=2).highlight_max(props='font-weight: bold;', axis=0).background_gradient(vmin=0.5, axis=None)
#results_all['Category'] = results_all['Detector'].map(to_category)
results_all['Detector'] = results_all['Detector'].apply(rename_detector)
results_all['Platform'] = results_all['Platform'].map(rename_platforms)
results_platform = results_all.copy()
# Out:
#  43%|████████████████████████████████████                                               | 36/83 [00:03<00:04,  9.95it/s]/tmp/ipykernel_634/1233827493.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['source'] = temp_data['source'].str.replace('multisocial_', '')
# /tmp/ipykernel_634/1233827493.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['prediction_probs']= temp_data['prediction_probs'].astype(float)
#
#  62%|████████████████████████████████████████████████████▌                               | 5/8 [00:00<00:00,
col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_1bf58_row0_col4, #T_1bf58_row6_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_1bf58_row0_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_1bf58_row1_col0, #T_1bf58_row1_col1, #T_1bf58_row5_col2, #T_1bf58_row10_col0, #T_1bf58_row11_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_1bf58_row1_col2, #T_1bf58_row4_col5, #T_1bf58_row7_col2, #T_1bf58_row10_col3, #T_1bf58_row13_col4, #T_1bf58_row15_col4, #T_1bf58_row15_col5 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_1bf58_row1_col3, #T_1bf58_row2_col4, #T_1bf58_row2_col5, #T_1bf58_row4_col0, #T_1bf58_row8_col2, #T_1bf58_row15_col3, #T_1bf58_row16_col4 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_1bf58_row1_col4, #T_1bf58_row15_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_1bf58_row1_col5, #T_1bf58_row2_col1, #T_1bf58_row5_col1, #T_1bf58_row7_col5, #T_1bf58_row11_col4, #T_1bf58_row11_col5, #T_1bf58_row14_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_1bf58_row2_col0, #T_1bf58_row3_col3 {
#   background-color: #7bacd1;
#   color: #000000;
# }
# #T_1bf58_row2_col2, #T_1bf58_row2_col3, #T_1bf58_row4_col4, #T_1bf58_row5_col0, #T_1bf58_row13_col0, #T_1bf58_row14_col0, #T_1bf58_row15_col0, #T_1bf58_row16_col0 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_1bf58_row3_col0, #T_1bf58_row7_col3 {
#   background-color: #83afd3;
#   color: #000000;
# }
# #T_1bf58_row3_col1, #T_1bf58_row10_col1, #T_1bf58_row14_col1, #T_1bf58_row16_col1, #T_1bf58_row16_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_1bf58_row3_col2, #T_1bf58_row10_col2, #T_1bf58_row15_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_1bf58_row3_col4, #T_1bf58_row9_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_1bf58_row3_col5, #T_1bf58_row4_col2, #T_1bf58_row10_col5, #T_1bf58_row11_col2, #T_1bf58_row13_col1, #T_1bf58_row14_col3, #T_1bf58_row16_col5 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_1bf58_row4_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_1bf58_row4_col3, #T_1bf58_row9_col5, #T_1bf58_row12_col4, #T_1bf58_row13_col2, #T_1bf58_row16_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_1bf58_row5_col3, #T_1bf58_row8_col3, #T_1bf58_row10_col4 {
#   background-color: #80aed2;
#   color: #000000;
# }
# #T_1bf58_row5_col4, #T_1bf58_row7_col0, #T_1bf58_row8_col4, #T_1bf58_row14_col2, #T_1bf58_row17_col3, #T_1bf58_row17_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_1bf58_row5_col5, #T_1bf58_row8_col5, #T_1bf58_row9_col0, #T_1bf58_row11_col0 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_1bf58_row6_col0, #T_1bf58_row8_col0, #T_1bf58_row9_col3, #T_1bf58_row17_col0 {
#   background-color: #7dacd1;
#   color: #000000;
# }
# #T_1bf58_row6_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_1bf58_row6_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_1bf58_row6_col4, #T_1bf58_row6_col5 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_1bf58_row7_col1, #T_1bf58_row14_col4, #T_1bf58_row17_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_1bf58_row7_col4, #T_1bf58_row11_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_1bf58_row8_col1, #T_1bf58_row13_col5, #T_1bf58_row17_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_1bf58_row9_col1, #T_1bf58_row9_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_1bf58_row12_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_1bf58_row12_col2, #T_1bf58_row12_col5 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_1bf58_row12_col3 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_1bf58_row13_col3 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_1bf58_row17_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# </style>
# <table id="T_1bf58">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bf58_level0_col0" class="col_heading level0 col0" colspan="6">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Platform</th>
#       <th id="T_1bf58_level1_col0" class="col_heading level1 col0" >Discord</th>
#       <th id="T_1bf58_level1_col1" class="col_heading level1 col1" >Gab</th>
#       <th id="T_1bf58_level1_col2" class="col_heading level1 col2" >Telegram</th>
#       <th id="T_1bf58_level1_col3" class="col_heading level1 col3" >Twitter</th>
#       <th id="T_1bf58_level1_col4" class="col_heading level1 col4" >WhatsApp</th>
#       <th id="T_1bf58_level1_col5" class="col_heading level1 col5" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detector</th>
#       <th class="index_name level1" >Train Platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bf58_level0_row0" class="row_heading level0 row0" rowspan="6">Llama-3-8b</th>
#       <th id="T_1bf58_level1_row0" class="row_heading level1 row0" >Discord</th>
#       <td id="T_1bf58_row0_col0" class="data row0 col0" >0.99</td>
#       <td id="T_1bf58_row0_col1" class="data row0 col1" >0.83</td>
#       <td id="T_1bf58_row0_col2" class="data row0 col2" >0.82</td>
#       <td id="T_1bf58_row0_col3" class="data row0 col3" >0.72</td>
#       <td id="T_1bf58_row0_col4" class="data row0 col4" >0.86</td>
#       <td id="T_1bf58_row0_col5" class="data row0 col5" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_1bf58_level1_row1" class="row_heading level1 row1" >Gab</th>
#       <td id="T_1bf58_row1_col0" class="data row1 col0" >0.95</td>
#       <td id="T_1bf58_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_1bf58_row1_col2" class="data row1 col2" >0.93</td>
#       <td id="T_1bf58_row1_col3" class="data row1 col3" >0.97</td>
#       <td id="T_1bf58_row1_col4" class="data row1 col4" >0.90</td>
#       <td id="T_1bf58_row1_col5" class="data row1 col5" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_1bf58_level1_row2" class="row_heading level1 row2" >Telegram</th>
#       <td id="T_1bf58_row2_col0" class="data row2 col0" >0.98</td>
#       <td id="T_1bf58_row2_col1" class="data row2 col1" >0.94</td>
#       <td id="T_1bf58_row2_col2" class="data row2 col2" >0.97</td>
#       <td id="T_1bf58_row2_col3" class="data row2 col3" >0.97</td>
#       <td id="T_1bf58_row2_col4" class="data row2 col4" >0.96</td>
#       <td id="T_1bf58_row2_col5" class="data row2 col5" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_1bf58_level1_row3" class="row_heading level1 row3" >Twitter</th>
#       <td id="T_1bf58_row3_col0" class="data row3 col0" >0.96</td>
#       <td id="T_1bf58_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_1bf58_row3_col2" class="data row3 col2" >0.92</td>
#       <td id="T_1bf58_row3_col3" class="data row3 col3" >0.98</td>
#       <td id="T_1bf58_row3_col4" class="data row3 col4" >0.91</td>
#       <td id="T_1bf58_row3_col5" class="data row3 col5" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_1bf58_level1_row4" class="row_heading level1 row4" >WhatsApp</th>
#       <td id="T_1bf58_row4_col0" class="data row4 col0" >0.97</td>
#       <td id="T_1bf58_row4_col1" class="data row4 col1" >0.89</td>
#       <td id="T_1bf58_row4_col2" class="data row4 col2" >0.93</td>
#       <td id="T_1bf58_row4_col3" class="data row4 col3" >0.93</td>
#       <td id="T_1bf58_row4_col4" class="data row4 col4" >0.98</td>
#       <td id="T_1bf58_row4_col5" class="data row4 col5" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_1bf58_level1_row5" class="row_heading level1 row5" >all</th>
#       <td id="T_1bf58_row5_col0" class="data row5 col0" >0.98</td>
#       <td id="T_1bf58_row5_col1" class="d
# \begin{tabular}{llrrrrrr}
#  &  & \multicolumn{6}{r}{\bfseries AUC ROC} \\
#  & Platform & \bfseries Discord & \bfseries Gab & \bfseries Telegram & \bfseries Twitter & \bfseries WhatsApp & \bfseries {all} \\
# Detector & Train Platform &  &  &  &  &  &  \\
# \hline
# \multirow[c]{6}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Llama-3-8b}}} & \bfseries Discord & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.83 & {\cellcolor[HTML]{B7C5DF}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{D8D7E9}} \color[HTML]{000000} 0.72 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{B4C4DF}} \color[HTML]{000000} 0.83 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{7BACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{A1BBDA}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries all & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \hline
# \multirow[c]{6}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries Mistral-7b-v0.1}}} & \bfseries Discord & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{B8C6E0}} \color[HTML]{000000} 0.82 & {\cellcolor[HTML]{A2BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{ACC0DD}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 & {\cellcolor[HTML]{A4BCDA}} \color[HTML]{000000} 0.88 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{83AFD3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{9EBAD9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{99B8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{80AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries all & {\cellcolor[HTML]{84B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{94B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{86B0D3}} \color[HTML]{000000} 0.96 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \hline
# \multirow[c]{6}{*}{\rotatebox{90}{\parbox{2cm}{\bfseries mDeBERTa-v3-base}}} & \bfseries Discord & {\cellcolor[HTML]{79ABD0}} \color[HTML]{000000} 0.99 & {\cellcolor[HTML]{ABBFDC}} \color[HTML]{000000} 0.86 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 & {\cellcolor[HTML]{B3C3DE}} \color[HTML]{000000} 0.84 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9FBAD9}} \color[HTML]{000000} 0.89 \\
# \bfseries  & \bfseries Gab & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{93B5D6}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries Telegram & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{8BB2D4}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries Twitter & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{9CB9D9}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{96B6D7}} \color[HTML]{000000} 0.92 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{8EB3D5}} \color[HTML]{000000} 0.94 \\
# \bfseries  & \bfseries WhatsApp & {\cellcolor[HTML]{7EADD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{91B5D6}} \color[HTML]{000000} 0.93 & {\cellcolor[HTML]{9AB8D8}} \color[HTML]{000000} 0.90 & {\cellcolor[HTML]{81AED2}} \color[HTML]{000000} 0.97 & {\cellcolor[HTML]{8FB4D6}} \color[HTML]{000000} 0.93 \\
# \bfseries  & \bfseries all & {\cellcolor[HTML]{7DACD1}} \color[HTML]{000000} 0.98 & {\cellcolor[HTML]{97B7D7}} \color[HTML]{000000} 0.91 & {\cellcolor[HTML]{8CB3D5}} \color[HTML]{000000} 0.94 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{88B1D4}} \color[HTML]{000000} 0.95 & {\cellcolor[HTML]{89B1D4}} \color[HTML]{000000} 0.95 \\
# \end{tabular}
# /tmp/ipykernel_634/1996549063.py:4: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('\\multirow[c]{6}{*}{', '\\multirow[c]{6}{*}{\\rotatebox{90}{\\parbox{2cm}{').replace('} &', '}}} &').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A'))

# %%
temp = results_all[results_all['Train Platform'] != 'all'].set_index(['Detector', 'Train Platform', 'Platform']).unstack()[[('AUC ROC', x) for x in ['Discord', 'WhatsApp', 'Telegram', 'Gab', 'Twitter']]].corr().reset_index().drop(columns=['level_0']).set_index('Platform').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))
# Out:
# /tmp/ipykernel_634/4010325801.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   temp = results_all[results_all['Train Platform'] != 'all'].set_index(['Detector', 'Train Platform', 'Platform']).unstack()[[('AUC ROC', x) for x in ['Discord', 'WhatsApp', 'Telegram', 'Gab', 'Twitter']]].corr().reset_index().drop(columns=['level_0']).set_index('Platform').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# /tmp/ipykernel_634/4010325801.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   temp = results_all[results_all['Train Platform'] != 'all'].set_index(['Detector', 'Train Platform', 'Platform']).unstack()[[('AUC ROC', x) for x in ['Discord', 'WhatsApp', 'Telegram', 'Gab', 'Twitter']]].corr().reset_index().drop(columns=['level_0']).set_index('Platform').style.format(precision=2).background_gradient(cmap='Greens', vmin=-1, vmax=3, text_color_threshold=0, axis=None).applymap(lambda x: 'background-color: white;' if str(x)=='nan' else '')
# <style type="text/css">
# #T_ad989_row0_col0, #T_ad989_row1_col1, #T_ad989_row2_col2, #T_ad989_row3_col3, #T_ad989_row4_col4 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_ad989_row0_col1, #T_ad989_row1_col0 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_ad989_row0_col2, #T_ad989_row2_col0 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_ad989_row0_col3, #T_ad989_row3_col0 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_ad989_row0_col4, #T_ad989_row4_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_ad989_row1_col2, #T_ad989_row2_col1, #T_ad989_row3_col4, #T_ad989_row4_col3 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_ad989_row1_col3, #T_ad989_row3_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_ad989_row1_col4, #T_ad989_row4_col1 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_ad989_row2_col3, #T_ad989_row3_col2 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_ad989_row2_col4, #T_ad989_row4_col2 {
#   background-color: #84cc83;
#   color: #000000;
# }
# </style>
# <table id="T_ad989">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad989_level0_col0" class="col_heading level0 col0" colspan="5">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Platform</th>
#       <th id="T_ad989_level1_col0" class="col_heading level1 col0" >Discord</th>
#       <th id="T_ad989_level1_col1" class="col_heading level1 col1" >WhatsApp</th>
#       <th id="T_ad989_level1_col2" class="col_heading level1 col2" >Telegram</th>
#       <th id="T_ad989_level1_col3" class="col_heading level1 col3" >Gab</th>
#       <th id="T_ad989_level1_col4" class="col_heading level1 col4" >Twitter</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad989_level0_row0" class="row_heading level0 row0" >Discord</th>
#       <td id="T_ad989_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ad989_row0_col1" class="data row0 col1" >0.19</td>
#       <td id="T_ad989_row0_col2" class="data row0 col2" >0.07</td>
#       <td id="T_ad989_row0_col3" class="data row0 col3" >-0.14</td>
#       <td id="T_ad989_row0_col4" class="data row0 col4" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_ad989_level0_row1" class="row_heading level0 row1" >WhatsApp</th>
#       <td id="T_ad989_row1_col0" class="data row1 col0" >0.19</td>
#       <td id="T_ad989_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ad989_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_ad989_row1_col3" class="data row1 col3" >0.64</td>
#       <td id="T_ad989_row1_col4" class="data row1 col4" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_ad989_level0_row2" class="row_heading level0 row2" >Telegram</th>
#       <td id="T_ad989_row2_col0" class="data row2 col0" >0.07</td>
#       <td id="T_ad989_row2_col1" class="data row2 col1" >0.80</td>
#       <td id="T_ad989_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ad989_row2_col3" class="data row2 col3" >0.87</td>
#       <td id="T_ad989_row2_col4" class="data row2 col4" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_ad989_level0_row3" class="row_heading level0 row3" >Gab</th>
#       <td id="T_ad989_row3_col0" class="data row3 col0" >-0.14</td>
#       <td id="T_ad989_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_ad989_row3_col2" class="data row3 col2" >0.87</td>
#       <td id="T_ad989_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ad989_row3_col4" class="data row3 col4" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_ad989_level0_row4" class="row_heading level0 row4" >Twitter</th>
#       <td id="T_ad989_row4_col0" class="data row4 col0" >-0.34</td>
#       <td id="T_ad989_row4_col1" class="data row4 col1" >0.58</td>
#       <td id="T_ad989_row4_col2" class="data row4 col2" >0.81</td>
#       <td id="T_ad989_row4_col3" class="data row4 col3" >0.81</td>
#       <td id="T_ad989_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrr}
#  & \multicolumn{5}{r}{\bfseries AUC ROC} \\
# Platform & \bfseries Discord & \bfseries WhatsApp & \bfseries Telegram & \bfseries Gab & \bfseries Twitter \\
# Platform &  &  &  &  &  \\
# \bfseries Discord & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{B8E3B2}} \color[HTML]{000000} 0.19 & {\cellcolor[HTML]{C2E7BB}} \color[HTML]{000000} 0.07 & {\cellcolor[HTML]{D0EDCA}} \color[HTML]{000000} -0.14 & {\cellcolor[HTML]{DCF2D7}} \color[HTML]{000000} -0.34 \\
# \bfseries WhatsApp & {\cellcolor[HTML]{B8E3B2}} \color[HTML]{000000} 0.19 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 \\
# \bfseries Telegram & {\cellcolor[HTML]{C2E7BB}} \color[HTML]{000000} 0.07 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.80 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 \\
# \bfseries Gab & {\cellcolor[HTML]{D0EDCA}} \color[HTML]{000000} -0.14 & {\cellcolor[HTML]{95D391}} \color[HTML]{000000} 0.64 & {\cellcolor[HTML]{80CA80}} \color[HTML]{000000} 0.87 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 \\
# \bfseries Twitter & {\cellcolor[HTML]{DCF2D7}} \color[HTML]{000000} -0.34 & {\cellcolor[HTML]{99D595}} \color[HTML]{000000} 0.58 & {\cellcolor[HTML]{84CC83}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{86CC85}} \color[HTML]{000000} 0.81 & {\cellcolor[HTML]{73C476}} \color[HTML]{000000} 1.00 \\
# \end{tabular}
# /tmp/ipykernel_634/4010325801.py:3: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True))

# %% [markdown]
# ### Statistics

# %%
#T-test for all combinations of train languages
temp = results_language.copy()
temp = pd.DataFrame(multidomain[(multidomain.domain=='social_media') & multidomain.source.str.contains('telegram')][['language']].value_counts())
temp = temp.reset_index()
temp = temp.groupby(['language']).sum().unstack().fillna(0).astype(int) > 2000 #if there are enough samples (~ 250 of each generator)
temp.index = temp.index.droplevel(0)
temp['{all}'] = True
enough_platform_language_samples = temp

temp = results_language.copy()
temp = temp[~temp.Language.isin(['ga', 'gd', 'sk', 'sl'])]#exclude languages with not enough samples
temp = temp[~temp['Train Language'].isin(['{en-es-ru-x3}'])]#exclude training with 3x more samples
languages = temp.Language.unique()
temp = temp.pivot(index=['Train Language', 'Detector'], columns='Language', values='AUC ROC').reset_index()

res_df = pd.DataFrame()
for lang in languages:#[languages != '{all}']:
 for (src, trg) in itertools.combinations_with_replacement(temp['Train Language'].unique(), 2):
   if src == trg: continue
   try:
    res = pg.ttest(temp[(temp["Train Language"] == trg)][lang], temp[(temp["Train Language"] == src)][lang], paired=True)
    #if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest language: {lang}, ({trg}, {src})")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))

    res = stats.ttest_rel(temp[temp["Train Language"] == trg][lang], temp[temp["Train Language"] == src][lang])
    res_df = pd.concat([res_df, pd.DataFrame({'Test Language':lang, 'Train Language':trg, '0.95 Confidence Intrval Min':stats.bayes_mvs(temp[temp["Train Language"] == trg][lang], alpha=0.95)[0].minmax[0], '0.95 Confidence Intrval Max':stats.bayes_mvs(temp[temp["Train Language"] == trg][lang], alpha=0.95)[0].minmax[1]}, index=[0])], ignore_index=True)
    res_df = pd.concat([res_df, pd.DataFrame({'Test Language':lang, 'Train Language':src, '0.95 Confidence Intrval Min':stats.bayes_mvs(temp[temp["Train Language"] == src][lang], alpha=0.95)[0].minmax[0], '0.95 Confidence Intrval Max':stats.bayes_mvs(temp[temp["Train Language"] == src][lang], alpha=0.95)[0].minmax[1]}, index=[0])], ignore_index=True)
   except:
    pass
res_df = res_df.drop_duplicates().sort_values(by=['Test Language', 'Train Language']).reset_index(drop=True)

temp_mean = temp.groupby('Train Language').mean(numeric_only=True)
#sort_key = {'en': 0, 'es': 1, 'ru': 2, 'all': 3, 'en3': 4}
#temp_mean = temp_mean.sort_index(key=lambda x: x.map(sort_key)).loc[:'all',:]
res_df['ci'] = (res_df['0.95 Confidence Intrval Max'] - res_df['0.95 Confidence Intrval Min']) / 2
res_df.drop(columns=['0.95 Confidence Intrval Max', '0.95 Confidence Intrval Min'], inplace=True)
temp_ci = res_df.set_index(['Train Language', 'Test Language']).stack().unstack(level=1).reset_index().set_index('Train Language').drop(columns=['level_1'])#.sort_index(key=lambda x: x.map(sort_key))
temp_mean_bak = temp_mean.copy()

#bg_text_color_threshold = 0.1
temp_mean = temp_mean_bak.copy()
temp = temp_mean.copy()
for col in temp_mean.columns:
  temp[col] = [f"{str('%.2f' % (x))} (±{str('%.2f' % (y))})" if y!='n.s.' else f"{str('%.2f' % (x))} (n.s.)" for x,y in zip(temp_mean[col], temp_ci[col])]

#temp = pd.concat([temp, pd.DataFrame({'Language Average': temp_mean.mean(axis=1)})], axis=1)
#temp_mean = pd.concat([temp_mean, pd.DataFrame({'Language Average': temp_mean.mean(axis=1)})], axis=1)

#temp_mean.rename(index=rename_obfuscators, inplace=True)
#temp.rename(index=rename_obfuscators, inplace=True)

temp[[x for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
temp_mean[[x for x in enough_platform_language_samples[~enough_platform_language_samples].index.tolist()]] = 'nan'
#temp = temp.style.format(precision=2).background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, axis=None)
#print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\multirow[c]{4}{*}{', '\\multirow[c]{4}{*}{\\rotatebox{90}{\\parbox{1.8cm}{').replace('} &', '}}} &').replace('{en-es-ru}}}', '{en-es-ru}').replace('mDeBERTa-v3-base', 'mDeBER\-Ta-v3-base'))
temp = temp.sort_values(by=['Language'], axis=1)
temp = temp.style.background_gradient(vmin=0.5, vmax=1.5, text_color_threshold=0, gmap=temp_mean, axis=None).format({'Language Average': '{:.2%}'.format}, precision=2)
display(temp)
print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}').replace('\\color[HTML]{000000} ', '\\textcolor{black}{').replace(') & {\\cellcolor', ')} & {\\cellcolor').replace(') & N/A', ')} & N/A').replace(' \\', '} \\').replace('&}', '&').replace('}}}', '}}'))
# Out:
# Test language: {all}, (es, en)
# <style type="text/css">
# #T_299a2_row0_col0, #T_299a2_row0_col1, #T_299a2_row0_col2, #T_299a2_row0_col3, #T_299a2_row0_col4, #T_299a2_row0_col5, #T_299a2_row0_col6, #T_299a2_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_299a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_299a2_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_299a2_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_299a2_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_299a2_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_299a2_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_299a2_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_299a2_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_299a2_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_299a2_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_299a2_row0_col0" class="data row0 col0" >-0.638733</td>
#       <td id="T_299a2_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_299a2_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_299a2_row0_col3" class="data row0 col3" >0.546590</td>
#       <td id="T_299a2_row0_col4" class="data row0 col4" >[-0.02  0.01]</td>
#       <td id="T_299a2_row0_col5" class="data row0 col5" >0.086229</td>
#       <td id="T_299a2_row0_col6" class="data row0 col6" >0.417</td>
#       <td id="T_299a2_row0_col7" class="data row0 col7" >0.054333</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (ru, en)
# <style type="text/css">
# #T_c37ac_row0_col0, #T_c37ac_row0_col1, #T_c37ac_row0_col2, #T_c37ac_row0_col3, #T_c37ac_row0_col4, #T_c37ac_row0_col5, #T_c37ac_row0_col6, #T_c37ac_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c37ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c37ac_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c37ac_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c37ac_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c37ac_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c37ac_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c37ac_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c37ac_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c37ac_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c37ac_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c37ac_row0_col0" class="data row0 col0" >-1.325776</td>
#       <td id="T_c37ac_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_c37ac_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c37ac_row0_col3" class="data row0 col3" >0.233153</td>
#       <td id="T_c37ac_row0_col4" class="data row0 col4" >[-0.08  0.02]</td>
#       <td id="T_c37ac_row0_col5" class="data row0 col5" >0.393308</td>
#       <td id="T_c37ac_row0_col6" class="data row0 col6" >0.675</td>
#       <td id="T_c37ac_row0_col7" class="data row0 col7" >0.142849</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, ({en-es-ru}, en)
# <style type="text/css">
# </style>
# <table id="T_5dacb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dacb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_5dacb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_5dacb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_5dacb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_5dacb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_5dacb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_5dacb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_5dacb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dacb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_5dacb_row0_col0" class="data row0 col0" >4.697472</td>
#       <td id="T_5dacb_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_5dacb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5dacb_row0_col3" class="data row0 col3" >0.003335</td>
#       <td id="T_5dacb_row0_col4" class="data row0 col4" >[0.02 0.07]</td>
#       <td id="T_5dacb_row0_col5" class="data row0 col5" >1.172777</td>
#       <td id="T_5dacb_row0_col6" class="data row0 col6" >15.796</td>
#       <td id="T_5dacb_row0_col7" class="data row0 col7" >0.734828</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, (ru, es)
# <style type="text/css">
# #T_a9d21_row0_col0, #T_a9d21_row0_col1, #T_a9d21_row0_col2, #T_a9d21_row0_col3, #T_a9d21_row0_col4, #T_a9d21_row0_col5, #T_a9d21_row0_col6, #T_a9d21_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a9d21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9d21_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a9d21_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a9d21_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a9d21_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a9d21_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a9d21_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a9d21_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a9d21_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9d21_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a9d21_row0_col0" class="data row0 col0" >-1.446031</td>
#       <td id="T_a9d21_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a9d21_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a9d21_row0_col3" class="data row0 col3" >0.198307</td>
#       <td id="T_a9d21_row0_col4" class="data row0 col4" >[-0.06  0.02]</td>
#       <td id="T_a9d21_row0_col5" class="data row0 col5" >0.319832</td>
#       <td id="T_a9d21_row0_col6" class="data row0 col6" >0.75</td>
#       <td id="T_a9d21_row0_col7" class="data row0 col7" >0.110912</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, ({en-es-ru}, es)
# <style type="text/css">
# </style>
# <table id="T_11b69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11b69_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_11b69_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_11b69_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_11b69_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_11b69_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_11b69_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_11b69_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_11b69_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11b69_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_11b69_row0_col0" class="data row0 col0" >3.488650</td>
#       <td id="T_11b69_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_11b69_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_11b69_row0_col3" class="data row0 col3" >0.013005</td>
#       <td id="T_11b69_row0_col4" class="data row0 col4" >[0.01 0.08]</td>
#       <td id="T_11b69_row0_col5" class="data row0 col5" >1.131194</td>
#       <td id="T_11b69_row0_col6" class="data row0 col6" >5.485</td>
#       <td id="T_11b69_row0_col7" class="data row0 col7" >0.704708</td>
#     </tr>
#   </tbody>
# </table>
# Test language: {all}, ({en-es-ru}, ru)
# <style type="text/css">
# </style>
# <table id="T_e4bb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4bb4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e4bb4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e4bb4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e4bb4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e4bb4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e4bb4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e4bb4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e4bb4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4bb4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e4bb4_row0_col0" class="data row0 col0" >2.798478</td>
#       <td id="T_e4bb4_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e4bb4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e4bb4_row0_col3" class="data row0 col3" >0.031227</td>
#       <td id="T_e4bb4_row0_col4" class="data row0 col4" >[0.01 0.13]</td>
#       <td id="T_e4bb4_row0_col5" class="data row0 col5" >1.090314</td>
#       <td id="T_e4bb4_row0_col6" class="data row0 col6" >2.818</td>
#       <td id="T_e4bb4_row0_col7" class="data row0 col7" >0.673595</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, (es, en)
# <style type="text/css">
# #T_a5c36_row0_col0, #T_a5c36_row0_col1, #T_a5c36_row0_col2, #T_a5c36_row0_col3, #T_a5c36_row0_col4, #T_a5c36_row0_col5, #T_a5c36_row0_col6, #T_a5c36_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a5c36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5c36_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a5c36_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a5c36_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a5c36_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a5c36_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a5c36_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a5c36_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a5c36_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5c36_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a5c36_row0_col0" class="data row0 col0" >-1.634649</td>
#       <td id="T_a5c36_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a5c36_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a5c36_row0_col3" class="data row0 col3" >0.153240</td>
#       <td id="T_a5c36_row0_col4" class="data row0 col4" >[-0.06  0.01]</td>
#       <td id="T_a5c36_row0_col5" class="data row0 col5" >0.403772</td>
#       <td id="T_a5c36_row0_col6" class="data row0 col6" >0.892</td>
#       <td id="T_a5c36_row0_col7" class="data row0 col7" >0.147957</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, (ru, en)
# <style type="text/css">
# #T_86ad4_row0_col0, #T_86ad4_row0_col1, #T_86ad4_row0_col2, #T_86ad4_row0_col3, #T_86ad4_row0_col4, #T_86ad4_row0_col5, #T_86ad4_row0_col6, #T_86ad4_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_86ad4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ad4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_86ad4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_86ad4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_86ad4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_86ad4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_86ad4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_86ad4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_86ad4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ad4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_86ad4_row0_col0" class="data row0 col0" >-1.748646</td>
#       <td id="T_86ad4_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_86ad4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_86ad4_row0_col3" class="data row0 col3" >0.130936</td>
#       <td id="T_86ad4_row0_col4" class="data row0 col4" >[-0.09  0.01]</td>
#       <td id="T_86ad4_row0_col5" class="data row0 col5" >0.524619</td>
#       <td id="T_86ad4_row0_col6" class="data row0 col6" >0.994</td>
#       <td id="T_86ad4_row0_col7" class="data row0 col7" >0.216777</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, ({en-es-ru}, en)
# <style type="text/css">
# #T_0da9d_row0_col0, #T_0da9d_row0_col1, #T_0da9d_row0_col2, #T_0da9d_row0_col3, #T_0da9d_row0_col4, #T_0da9d_row0_col5, #T_0da9d_row0_col6, #T_0da9d_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0da9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0da9d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_0da9d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_0da9d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_0da9d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_0da9d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_0da9d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_0da9d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_0da9d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0da9d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_0da9d_row0_col0" class="data row0 col0" >1.737926</td>
#       <td id="T_0da9d_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_0da9d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_0da9d_row0_col3" class="data row0 col3" >0.132891</td>
#       <td id="T_0da9d_row0_col4" class="data row0 col4" >[-0.01  0.06]</td>
#       <td id="T_0da9d_row0_col5" class="data row0 col5" >0.567008</td>
#       <td id="T_0da9d_row0_col6" class="data row0 col6" >0.983</td>
#       <td id="T_0da9d_row0_col7" class="data row0 col7" >0.244983</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, (ru, es)
# <style type="text/css">
# #T_f1f16_row0_col0, #T_f1f16_row0_col1, #T_f1f16_row0_col2, #T_f1f16_row0_col3, #T_f1f16_row0_col4, #T_f1f16_row0_col5, #T_f1f16_row0_col6, #T_f1f16_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f1f16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1f16_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f1f16_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f1f16_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f1f16_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f1f16_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f1f16_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f1f16_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f1f16_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1f16_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f1f16_row0_col0" class="data row0 col0" >-0.867736</td>
#       <td id="T_f1f16_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f1f16_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f1f16_row0_col3" class="data row0 col3" >0.418887</td>
#       <td id="T_f1f16_row0_col4" class="data row0 col4" >[-0.05  0.02]</td>
#       <td id="T_f1f16_row0_col5" class="data row0 col5" >0.163046</td>
#       <td id="T_f1f16_row0_col6" class="data row0 col6" >0.477</td>
#       <td id="T_f1f16_row0_col7" class="data row0 col7" >0.065573</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, ({en-es-ru}, es)
# <style type="text/css">
# </style>
# <table id="T_fd26e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd26e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_fd26e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_fd26e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_fd26e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_fd26e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_fd26e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_fd26e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_fd26e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd26e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_fd26e_row0_col0" class="data row0 col0" >2.551696</td>
#       <td id="T_fd26e_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_fd26e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_fd26e_row0_col3" class="data row0 col3" >0.043391</td>
#       <td id="T_fd26e_row0_col4" class="data row0 col4" >[0.   0.09]</td>
#       <td id="T_fd26e_row0_col5" class="data row0 col5" >0.884182</td>
#       <td id="T_fd26e_row0_col6" class="data row0 col6" >2.204</td>
#       <td id="T_fd26e_row0_col7" class="data row0 col7" >0.501279</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, ({en-es-ru}, ru)
# <style type="text/css">
# </style>
# <table id="T_94a3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94a3f_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_94a3f_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_94a3f_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_94a3f_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_94a3f_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_94a3f_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_94a3f_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_94a3f_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94a3f_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_94a3f_row0_col0" class="data row0 col0" >2.575619</td>
#       <td id="T_94a3f_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_94a3f_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_94a3f_row0_col3" class="data row0 col3" >0.042016</td>
#       <td id="T_94a3f_row0_col4" class="data row0 col4" >[0.   0.12]</td>
#       <td id="T_94a3f_row0_col5" class="data row0 col5" >0.924570</td>
#       <td id="T_94a3f_row0_col6" class="data row0 col6" >2.257</td>
#       <td id="T_94a3f_row0_col7" class="data row0 col7" >0.536261</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, (es, en)
# <style type="text/css">
# #T_adff0_row0_col0, #T_adff0_row0_col1, #T_adff0_row0_col2, #T_adff0_row0_col3, #T_adff0_row0_col4, #T_adff0_row0_col5, #T_adff0_row0_col6, #T_adff0_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_adff0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adff0_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_adff0_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_adff0_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_adff0_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_adff0_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_adff0_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_adff0_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_adff0_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adff0_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_adff0_row0_col0" class="data row0 col0" >-1.133004</td>
#       <td id="T_adff0_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_adff0_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_adff0_row0_col3" class="data row0 col3" >0.300448</td>
#       <td id="T_adff0_row0_col4" class="data row0 col4" >[-0.04  0.01]</td>
#       <td id="T_adff0_row0_col5" class="data row0 col5" >0.216914</td>
#       <td id="T_adff0_row0_col6" class="data row0 col6" >0.577</td>
#       <td id="T_adff0_row0_col7" class="data row0 col7" >0.077703</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, (ru, en)
# <style type="text/css">
# #T_b3544_row0_col0, #T_b3544_row0_col1, #T_b3544_row0_col2, #T_b3544_row0_col3, #T_b3544_row0_col4, #T_b3544_row0_col5, #T_b3544_row0_col6, #T_b3544_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b3544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3544_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b3544_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b3544_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b3544_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b3544_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b3544_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b3544_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b3544_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3544_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b3544_row0_col0" class="data row0 col0" >-0.961578</td>
#       <td id="T_b3544_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_b3544_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b3544_row0_col3" class="data row0 col3" >0.373395</td>
#       <td id="T_b3544_row0_col4" class="data row0 col4" >[-0.06  0.03]</td>
#       <td id="T_b3544_row0_col5" class="data row0 col5" >0.267915</td>
#       <td id="T_b3544_row0_col6" class="data row0 col6" >0.508</td>
#       <td id="T_b3544_row0_col7" class="data row0 col7" >0.092492</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, ({en-es-ru}, en)
# <style type="text/css">
# #T_db584_row0_col0, #T_db584_row0_col1, #T_db584_row0_col2, #T_db584_row0_col3, #T_db584_row0_col4, #T_db584_row0_col5, #T_db584_row0_col6, #T_db584_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_db584">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db584_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_db584_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_db584_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_db584_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_db584_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_db584_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_db584_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_db584_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db584_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_db584_row0_col0" class="data row0 col0" >1.950668</td>
#       <td id="T_db584_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_db584_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_db584_row0_col3" class="data row0 col3" >0.098967</td>
#       <td id="T_db584_row0_col4" class="data row0 col4" >[-0.01  0.04]</td>
#       <td id="T_db584_row0_col5" class="data row0 col5" >0.439209</td>
#       <td id="T_db584_row0_col6" class="data row0 col6" >1.209</td>
#       <td id="T_db584_row0_col7" class="data row0 col7" >0.166280</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, (ru, es)
# <style type="text/css">
# #T_b4a83_row0_col0, #T_b4a83_row0_col1, #T_b4a83_row0_col2, #T_b4a83_row0_col3, #T_b4a83_row0_col4, #T_b4a83_row0_col5, #T_b4a83_row0_col6, #T_b4a83_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b4a83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4a83_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b4a83_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b4a83_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b4a83_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b4a83_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b4a83_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b4a83_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b4a83_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4a83_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b4a83_row0_col0" class="data row0 col0" >-0.433376</td>
#       <td id="T_b4a83_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_b4a83_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b4a83_row0_col3" class="data row0 col3" >0.679889</td>
#       <td id="T_b4a83_row0_col4" class="data row0 col4" >[-0.04  0.02]</td>
#       <td id="T_b4a83_row0_col5" class="data row0 col5" >0.072476</td>
#       <td id="T_b4a83_row0_col6" class="data row0 col6" >0.382</td>
#       <td id="T_b4a83_row0_col7" class="data row0 col7" >0.053059</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, ({en-es-ru}, es)
# <style type="text/css">
# </style>
# <table id="T_93b17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93b17_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_93b17_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_93b17_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_93b17_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_93b17_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_93b17_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_93b17_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_93b17_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93b17_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_93b17_row0_col0" class="data row0 col0" >2.862210</td>
#       <td id="T_93b17_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_93b17_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_93b17_row0_col3" class="data row0 col3" >0.028718</td>
#       <td id="T_93b17_row0_col4" class="data row0 col4" >[0.   0.06]</td>
#       <td id="T_93b17_row0_col5" class="data row0 col5" >0.590470</td>
#       <td id="T_93b17_row0_col6" class="data row0 col6" >3.001</td>
#       <td id="T_93b17_row0_col7" class="data row0 col7" >0.261426</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, ({en-es-ru}, ru)
# <style type="text/css">
# #T_f72eb_row0_col0, #T_f72eb_row0_col1, #T_f72eb_row0_col2, #T_f72eb_row0_col3, #T_f72eb_row0_col4, #T_f72eb_row0_col5, #T_f72eb_row0_col6, #T_f72eb_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f72eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f72eb_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f72eb_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f72eb_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f72eb_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f72eb_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f72eb_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f72eb_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f72eb_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f72eb_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f72eb_row0_col0" class="data row0 col0" >2.249436</td>
#       <td id="T_f72eb_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f72eb_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f72eb_row0_col3" class="data row0 col3" >0.065492</td>
#       <td id="T_f72eb_row0_col4" class="data row0 col4" >[-0.    0.08]</td>
#       <td id="T_f72eb_row0_col5" class="data row0 col5" >0.587794</td>
#       <td id="T_f72eb_row0_col6" class="data row0 col6" >1.628</td>
#       <td id="T_f72eb_row0_col7" class="data row0 col7" >0.259522</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, (es, en)
# <style type="text/css">
# #T_65463_row0_col0, #T_65463_row0_col1, #T_65463_row0_col2, #T_65463_row0_col3, #T_65463_row0_col4, #T_65463_row0_col5, #T_65463_row0_col6, #T_65463_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_65463">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65463_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_65463_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_65463_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_65463_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_65463_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_65463_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_65463_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_65463_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65463_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_65463_row0_col0" class="data row0 col0" >1.124668</td>
#       <td id="T_65463_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_65463_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_65463_row0_col3" class="data row0 col3" >0.303699</td>
#       <td id="T_65463_row0_col4" class="data row0 col4" >[-0.02  0.05]</td>
#       <td id="T_65463_row0_col5" class="data row0 col5" >0.265506</td>
#       <td id="T_65463_row0_col6" class="data row0 col6" >0.573</td>
#       <td id="T_65463_row0_col7" class="data row0 col7" >0.091721</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, (ru, en)
# <style type="text/css">
# #T_93b40_row0_col0, #T_93b40_row0_col1, #T_93b40_row0_col2, #T_93b40_row0_col3, #T_93b40_row0_col4, #T_93b40_row0_col5, #T_93b40_row0_col6, #T_93b40_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_93b40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93b40_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_93b40_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_93b40_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_93b40_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_93b40_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_93b40_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_93b40_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_93b40_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93b40_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_93b40_row0_col0" class="data row0 col0" >-0.148864</td>
#       <td id="T_93b40_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_93b40_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_93b40_row0_col3" class="data row0 col3" >0.886538</td>
#       <td id="T_93b40_row0_col4" class="data row0 col4" >[-0.07  0.06]</td>
#       <td id="T_93b40_row0_col5" class="data row0 col5" >0.048266</td>
#       <td id="T_93b40_row0_col6" class="data row0 col6" >0.357</td>
#       <td id="T_93b40_row0_col7" class="data row0 col7" >0.051356</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, ({en-es-ru}, en)
# <style type="text/css">
# </style>
# <table id="T_e5f0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5f0d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e5f0d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e5f0d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e5f0d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e5f0d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e5f0d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e5f0d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e5f0d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5f0d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e5f0d_row0_col0" class="data row0 col0" >5.967275</td>
#       <td id="T_e5f0d_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e5f0d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e5f0d_row0_col3" class="data row0 col3" >0.000993</td>
#       <td id="T_e5f0d_row0_col4" class="data row0 col4" >[0.05 0.11]</td>
#       <td id="T_e5f0d_row0_col5" class="data row0 col5" >1.678484</td>
#       <td id="T_e5f0d_row0_col6" class="data row0 col6" >41.204</td>
#       <td id="T_e5f0d_row0_col7" class="data row0 col7" >0.955817</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, (ru, es)
# <style type="text/css">
# #T_1058a_row0_col0, #T_1058a_row0_col1, #T_1058a_row0_col2, #T_1058a_row0_col3, #T_1058a_row0_col4, #T_1058a_row0_col5, #T_1058a_row0_col6, #T_1058a_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1058a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1058a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_1058a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_1058a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_1058a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_1058a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_1058a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_1058a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_1058a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1058a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_1058a_row0_col0" class="data row0 col0" >-0.843288</td>
#       <td id="T_1058a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_1058a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_1058a_row0_col3" class="data row0 col3" >0.431396</td>
#       <td id="T_1058a_row0_col4" class="data row0 col4" >[-0.07  0.04]</td>
#       <td id="T_1058a_row0_col5" class="data row0 col5" >0.225316</td>
#       <td id="T_1058a_row0_col6" class="data row0 col6" >0.469</td>
#       <td id="T_1058a_row0_col7" class="data row0 col7" >0.079916</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, ({en-es-ru}, es)
# <style type="text/css">
# </style>
# <table id="T_5097d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5097d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_5097d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_5097d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_5097d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_5097d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_5097d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_5097d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_5097d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5097d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_5097d_row0_col0" class="data row0 col0" >3.611917</td>
#       <td id="T_5097d_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_5097d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5097d_row0_col3" class="data row0 col3" >0.011205</td>
#       <td id="T_5097d_row0_col4" class="data row0 col4" >[0.02 0.11]</td>
#       <td id="T_5097d_row0_col5" class="data row0 col5" >1.377878</td>
#       <td id="T_5097d_row0_col6" class="data row0 col6" >6.151</td>
#       <td id="T_5097d_row0_col7" class="data row0 col7" >0.856942</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar, ({en-es-ru}, ru)
# <style type="text/css">
# </style>
# <table id="T_a7b4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7b4c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a7b4c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a7b4c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a7b4c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a7b4c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a7b4c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a7b4c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a7b4c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7b4c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a7b4c_row0_col0" class="data row0 col0" >2.587645</td>
#       <td id="T_a7b4c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a7b4c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a7b4c_row0_col3" class="data row0 col3" >0.041342</td>
#       <td id="T_a7b4c_row0_col4" class="data row0 col4" >[0.   0.16]</td>
#       <td id="T_a7b4c_row0_col5" class="data row0 col5" >1.068175</td>
#       <td id="T_a7b4c_row0_col6" class="data row0 col6" >2.285</td>
#       <td id="T_a7b4c_row0_col7" class="data row0 col7" >0.656184</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, (es, en)
# <style type="text/css">
# </style>
# <table id="T_73484">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73484_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_73484_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_73484_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_73484_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_73484_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_73484_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_73484_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_73484_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73484_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_73484_row0_col0" class="data row0 col0" >3.194778</td>
#       <td id="T_73484_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_73484_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_73484_row0_col3" class="data row0 col3" >0.018723</td>
#       <td id="T_73484_row0_col4" class="data row0 col4" >[0.02 0.12]</td>
#       <td id="T_73484_row0_col5" class="data row0 col5" >1.477617</td>
#       <td id="T_73484_row0_col6" class="data row0 col6" >4.15</td>
#       <td id="T_73484_row0_col7" class="data row0 col7" >0.899547</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, (ru, en)
# <style type="text/css">
# #T_c719e_row0_col0, #T_c719e_row0_col1, #T_c719e_row0_col2, #T_c719e_row0_col3, #T_c719e_row0_col4, #T_c719e_row0_col5, #T_c719e_row0_col6, #T_c719e_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c719e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c719e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c719e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c719e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c719e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c719e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c719e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c719e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c719e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c719e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c719e_row0_col0" class="data row0 col0" >-1.898094</td>
#       <td id="T_c719e_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_c719e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c719e_row0_col3" class="data row0 col3" >0.106451</td>
#       <td id="T_c719e_row0_col4" class="data row0 col4" >[-0.11  0.01]</td>
#       <td id="T_c719e_row0_col5" class="data row0 col5" >0.501829</td>
#       <td id="T_c719e_row0_col6" class="data row0 col6" >1.148</td>
#       <td id="T_c719e_row0_col7" class="data row0 col7" >0.202451</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, ({en-es-ru}, en)
# <style type="text/css">
# </style>
# <table id="T_f8234">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8234_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f8234_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f8234_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f8234_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f8234_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f8234_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f8234_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f8234_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8234_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f8234_row0_col0" class="data row0 col0" >2.803569</td>
#       <td id="T_f8234_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f8234_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f8234_row0_col3" class="data row0 col3" >0.031018</td>
#       <td id="T_f8234_row0_col4" class="data row0 col4" >[0.01 0.11]</td>
#       <td id="T_f8234_row0_col5" class="data row0 col5" >1.304457</td>
#       <td id="T_f8234_row0_col6" class="data row0 col6" >2.832</td>
#       <td id="T_f8234_row0_col7" class="data row0 col7" >0.818555</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, (ru, es)
# <style type="text/css">
# </style>
# <table id="T_33b58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33b58_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_33b58_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_33b58_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_33b58_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_33b58_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_33b58_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_33b58_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_33b58_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33b58_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_33b58_row0_col0" class="data row0 col0" >-2.605750</td>
#       <td id="T_33b58_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_33b58_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_33b58_row0_col3" class="data row0 col3" >0.040350</td>
#       <td id="T_33b58_row0_col4" class="data row0 col4" >[-0.22 -0.01]</td>
#       <td id="T_33b58_row0_col5" class="data row0 col5" >1.333630</td>
#       <td id="T_33b58_row0_col6" class="data row0 col6" >2.326</td>
#       <td id="T_33b58_row0_col7" class="data row0 col7" >0.834533</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, ({en-es-ru}, es)
# <style type="text/css">
# #T_7bb4c_row0_col0, #T_7bb4c_row0_col1, #T_7bb4c_row0_col2, #T_7bb4c_row0_col3, #T_7bb4c_row0_col4, #T_7bb4c_row0_col5, #T_7bb4c_row0_col6, #T_7bb4c_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7bb4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bb4c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7bb4c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7bb4c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7bb4c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7bb4c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7bb4c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7bb4c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7bb4c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bb4c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7bb4c_row0_col0" class="data row0 col0" >-1.378571</td>
#       <td id="T_7bb4c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_7bb4c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7bb4c_row0_col3" class="data row0 col3" >0.217221</td>
#       <td id="T_7bb4c_row0_col4" class="data row0 col4" >[-0.02  0.  ]</td>
#       <td id="T_7bb4c_row0_col5" class="data row0 col5" >0.326524</td>
#       <td id="T_7bb4c_row0_col6" class="data row0 col6" >0.707</td>
#       <td id="T_7bb4c_row0_col7" class="data row0 col7" >0.113536</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, ({en-es-ru}, ru)
# <style type="text/css">
# #T_66d7a_row0_col0, #T_66d7a_row0_col1, #T_66d7a_row0_col2, #T_66d7a_row0_col3, #T_66d7a_row0_col4, #T_66d7a_row0_col5, #T_66d7a_row0_col6, #T_66d7a_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_66d7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66d7a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_66d7a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_66d7a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_66d7a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_66d7a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_66d7a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_66d7a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_66d7a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66d7a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_66d7a_row0_col0" class="data row0 col0" >2.385373</td>
#       <td id="T_66d7a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_66d7a_row0_col2" class="data row0 col2" >two-sided</td>
# ...
#       <td id="T_5ac3a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_5ac3a_row0_col3" class="data row0 col3" >0.014464</td>
#       <td id="T_5ac3a_row0_col4" class="data row0 col4" >[0.01 0.09]</td>
#       <td id="T_5ac3a_row0_col5" class="data row0 col5" >1.674619</td>
#       <td id="T_5ac3a_row0_col6" class="data row0 col6" >5.055</td>
#       <td id="T_5ac3a_row0_col7" class="data row0 col7" >0.955051</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en, ({en-es-ru}, ru)
# <style type="text/css">
# </style>
# <table id="T_d6705">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6705_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_d6705_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_d6705_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_d6705_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_d6705_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_d6705_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_d6705_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_d6705_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6705_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_d6705_row0_col0" class="data row0 col0" >3.637307</td>
#       <td id="T_d6705_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_d6705_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_d6705_row0_col3" class="data row0 col3" >0.010870</td>
#       <td id="T_d6705_row0_col4" class="data row0 col4" >[0.03 0.13]</td>
#       <td id="T_d6705_row0_col5" class="data row0 col5" >1.862422</td>
#       <td id="T_d6705_row0_col6" class="data row0 col6" >6.297</td>
#       <td id="T_d6705_row0_col7" class="data row0 col7" >0.981721</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e9ca0_row0_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e9ca0_row0_col1, #T_e9ca0_row1_col6 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e9ca0_row0_col2 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e9ca0_row0_col3, #T_e9ca0_row3_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_e9ca0_row0_col4, #T_e9ca0_row1_col14, #T_e9ca0_row2_col8 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_e9ca0_row0_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_e9ca0_row0_col6 {
#   background-color: #84b0d3;
#   color: #000000;
# }
# #T_e9ca0_row0_col7, #T_e9ca0_row0_col22 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_e9ca0_row0_col8, #T_e9ca0_row1_col11 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_e9ca0_row0_col9, #T_e9ca0_row0_col10, #T_e9ca0_row0_col18, #T_e9ca0_row0_col19, #T_e9ca0_row1_col9, #T_e9ca0_row1_col10, #T_e9ca0_row1_col18, #T_e9ca0_row1_col19, #T_e9ca0_row2_col9, #T_e9ca0_row2_col10, #T_e9ca0_row2_col18, #T_e9ca0_row2_col19, #T_e9ca0_row3_col9, #T_e9ca0_row3_col10, #T_e9ca0_row3_col18, #T_e9ca0_row3_col19 {
#   background-color: #000000;
#   color: #000000;
# }
# #T_e9ca0_row0_col11, #T_e9ca0_row0_col16, #T_e9ca0_row1_col7, #T_e9ca0_row2_col17, #T_e9ca0_row3_col11, #T_e9ca0_row3_col15 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_e9ca0_row0_col12 {
#   background-color: #81aed2;
#   color: #000000;
# }
# #T_e9ca0_row0_col13, #T_e9ca0_row2_col4, #T_e9ca0_row2_col22 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_e9ca0_row0_col14, #T_e9ca0_row1_col1, #T_e9ca0_row3_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_e9ca0_row0_col15 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_e9ca0_row0_col17, #T_e9ca0_row1_col5, #T_e9ca0_row2_col3, #T_e9ca0_row2_col6, #T_e9ca0_row2_col14 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_e9ca0_row0_col20 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_e9ca0_row0_col21 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_e9ca0_row1_col0, #T_e9ca0_row1_col20, #T_e9ca0_row2_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_e9ca0_row1_col2 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e9ca0_row1_col3, #T_e9ca0_row1_col17 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_e9ca0_row1_col4, #T_e9ca0_row2_col11, #T_e9ca0_row2_col20, #T_e9ca0_row3_col20 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e9ca0_row1_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_e9ca0_row1_col12 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_e9ca0_row1_col13 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_e9ca0_row1_col15 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e9ca0_row1_col16, #T_e9ca0_row2_col1, #T_e9ca0_row3_col5, #T_e9ca0_row3_col7, #T_e9ca0_row3_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_e9ca0_row1_col21, #T_e9ca0_row2_col21 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e9ca0_row1_col22 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_e9ca0_row2_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e9ca0_row2_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_e9ca0_row2_col5, #T_e9ca0_row2_col16 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_e9ca0_row2_col12, #T_e9ca0_row3_col14, #T_e9ca0_row3_col22 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_e9ca0_row2_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_e9ca0_row2_col15, #T_e9ca0_row3_col2, #T_e9ca0_row3_col13, #T_e9ca0_row3_col21 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_e9ca0_row3_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_e9ca0_row3_col3, #T_e9ca0_row3_col17 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_e9ca0_row3_col6 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_e9ca0_row3_col12 {
#   background-color: #7eadd1;
#   color: #000000;
# }
# #T_e9ca0_row3_col16 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# </style>
# <table id="T_e9ca0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Language</th>
#       <th id="T_e9ca0_level0_col0" class="col_heading level0 col0" >ar</th>
#       <th id="T_e9ca0_level0_col1" class="col_heading level0 col1" >bg</th>
#       <th id="T_e9ca0_level0_col2" class="col_heading level0 col2" >ca</th>
#       <th id="T_e9ca0_level0_col3" class="col_heading level0 col3" >cs</th>
#       <th id="T_e9ca0_level0_col4" class="col_heading level0 col4" >de</th>
#       <th id="T_e9ca0_level0_col5" class="col_heading level0 col5" >el</th>
#       <th id="T_e9ca0_level0_col6" class="col_heading level0 col6" >en</th>
#       <th id="T_e9ca0_level0_col7" class="col_heading level0 col7" >es</th>
#       <th id="T_e9ca0_level0_col8" class="col_heading level0 col8" >et</th>
#       <th id="T_e9ca0_level0_col9" class="col_heading level0 col9" >ga</th>
#       <th id="T_e9ca0_level0_col10" class="col_heading level0 col10" >gd</th>
#       <th id="T_e9ca0_level0_col11" class="col_heading level0 col11" >hr</th>
#       <th id="T_e9ca0_level0_col12" class="col_heading level0 col12" >hu</th>
#       <th id="T_e9ca0_level0_col13" class="col_heading level0 col13" >nl</th>
#       <th id="T_e9ca0_level0_col14" class="col_heading level0 col14" >pl</th>
#       <th id="T_e9ca0_level0_col15" class="col_heading level0 col15" >pt</th>
#       <th id="T_e9ca0_level0_col16" class="col_heading level0 col16" >ro</th>
#       <th id="T_e9ca0_level0_col17" class="col_heading level0 col17" >ru</th>
#       <th id="T_e9ca0_level0_col18" class="col_heading level0 col18" >sk</th>
#       <th id="T_e9ca0_level0_col19" class="col_heading level0 col19" >sl</th>
#       <th id="T_e9ca0_level0_col20" class="col_heading level0 col20" >uk</th>
#       <th id="T_e9ca0_level0_col21" class="col_heading level0 col21" >zh</th>
#       <th id="T_e9ca0_level0_col22" class="col_heading level0 col22" >{all}</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9ca0_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_e9ca0_row0_col0" class="data row0 col0" >0.81 (±0.05)</td>
#       <td id="T_e9ca0_row0_col1" class="data row0 col1" >0.90 (±0.08)</td>
#       <td id="T_e9ca0_row0_col2" class="data row0 col2" >0.78 (±0.03)</td>
#       <td id="T_e9ca0_row0_col3" class="data row0 col3" >0.91 (±0.05)</td>
#       <td id="T_e9ca0_row0_col4" class="data row0 col4" >0.88 (±0.02)</td>
#       <td id="T_e9ca0_row0_col5" class="data row0 col5" >0.90 (±0.03)</td>
#       <td id="T_e9ca0_row0_col6" class="data row0 col6" >0.96 (±0.01)</td>
#       <td id="T_e9ca0_row0_col7" class="data row0 col7" >0.87 (±0.06)</td>
#       <td id="T_e9ca0_row0_col8" class="data row0 col8" >0.92 (±0.03)</td>
#       <td id="T_e9ca0_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_e9ca0_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_e9ca0_row0_col11" class="data row0 col11" >0.94 (±0.03)</td>
#       <td id="T_e9ca0_row0_col12" class="data row0 col12" >0.97 (±0.03)</td>
#       <td id="T_e9ca0_row0_col13" class="data row0 col13" >0.84 (±0.02)</
# \begin{tabular}{llllllllllllllllllllllll}
# Language & \bfseries ar & \bfseries bg & \bfseries ca & \bfseries cs & \bfseries de & \bfseries el & \bfseries en & \bfseries es & \bfseries et & \bfseries ga & \bfseries gd & \bfseries hr & \bfseries hu & \bfseries nl & \bfseries pl & \bfseries pt & \bfseries ro & \bfseries ru & \bfseries sk & \bfseries sl & \bfseries uk & \bfseries zh & \bfseries {all}} \\
# Train Language &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  &  & } \\
# \bfseries en & {\cellcolor[HTML]{BCC7E1}} \textcolor{black}{0.81 (±0.05)} & {\cellcolor[HTML]{9CB9D9}} \textcolor{black}{0.90 (±0.08)} & {\cellcolor[HTML]{C6CCE3}} \textcolor{black}{0.78 (±0.03)} & {\cellcolor[HTML]{99B8D8}} \textcolor{black}{0.91 (±0.05)} & {\cellcolor[HTML]{A5BDDB}} \textcolor{black}{0.88 (±0.02)} & {\cellcolor[HTML]{9AB8D8}} \textcolor{black}{0.90 (±0.03)} & {\cellcolor[HTML]{84B0D3}} \textcolor{black}{0.96 (±0.01)} & {\cellcolor[HTML]{A8BEDC}} \textcolor{black}{0.87 (±0.06)} & {\cellcolor[HTML]{96B6D7}} \textcolor{black}{0.92 (±0.03)} & N/A & N/A & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.03)} & {\cellcolor[HTML]{81AED2}} \textcolor{black}{0.97 (±0.03)} & {\cellcolor[HTML]{B1C2DE}} \textcolor{black}{0.84 (±0.02)} & {\cellcolor[HTML]{A1BBDA}} \textcolor{black}{0.89 (±0.05)} & {\cellcolor[HTML]{94B6D7}} \textcolor{black}{0.92 (±0.02)} & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.02)} & {\cellcolor[HTML]{A7BDDB}} \textcolor{black}{0.87 (±0.05)} & N/A & N/A & {\cellcolor[HTML]{BBC7E0}} \textcolor{black}{0.81 (±0.05)} & {\cellcolor[HTML]{D5D5E8}} \textcolor{black}{0.73 (±0.14)} & {\cellcolor[HTML]{A8BEDC}} \textcolor{black}{0.87 (±0.04)} \\
# \bfseries es & {\cellcolor[HTML]{B8C6E0}} \textcolor{black}{0.82 (±0.05)} & {\cellcolor[HTML]{A1BBDA}} \textcolor{black}{0.89 (±0.08)} & {\cellcolor[HTML]{B0C2DE}} \textcolor{black}{0.85 (±0.03)} & {\cellcolor[HTML]{A2BCDA}} \textcolor{black}{0.89 (±0.06)} & {\cellcolor[HTML]{9FBAD9}} \textcolor{black}{0.89 (±0.03)} & {\cellcolor[HTML]{A7BDDB}} \textcolor{black}{0.87 (±0.06)} & {\cellcolor[HTML]{9CB9D9}} \textcolor{black}{0.90 (±0.04)} & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.01)} & {\cellcolor[HTML]{9EBAD9}} \textcolor{black}{0.90 (±0.05)} & N/A & N/A & {\cellcolor[HTML]{96B6D7}} \textcolor{black}{0.92 (±0.05)} & {\cellcolor[HTML]{88B1D4}} \textcolor{black}{0.95 (±0.04)} & {\cellcolor[HTML]{B3C3DE}} \textcolor{black}{0.84 (±0.03)} & {\cellcolor[HTML]{A5BDDB}} \textcolor{black}{0.88 (±0.06)} & {\cellcolor[HTML]{93B5D6}} \textcolor{black}{0.93 (±0.02)} & {\cellcolor[HTML]{8FB4D6}} \textcolor{black}{0.93 (±0.03)} & {\cellcolor[HTML]{A2BCDA}} \textcolor{black}{0.88 (±0.04)} & N/A & N/A & {\cellcolor[HTML]{B8C6E0}} \textcolor{black}{0.82 (±0.05)} & {\cellcolor[HTML]{D4D4E8}} \textcolor{black}{0.73 (±0.14)} & {\cellcolor[HTML]{A9BFDC}} \textcolor{black}{0.86 (±0.05)} \\
# \bfseries ru & {\cellcolor[HTML]{BDC8E1}} \textcolor{black}{0.81 (±0.10)} & {\cellcolor[HTML]{8FB4D6}} \textcolor{black}{0.93 (±0.05)} & {\cellcolor[HTML]{CED0E6}} \textcolor{black}{0.76 (±0.10)} & {\cellcolor[HTML]{A7BDDB}} \textcolor{black}{0.87 (±0.08)} & {\cellcolor[HTML]{B1C2DE}} \textcolor{black}{0.84 (±0.04)} & {\cellcolor[HTML]{A4BCDA}} \textcolor{black}{0.88 (±0.06)} & {\cellcolor[HTML]{A7BDDB}} \textcolor{black}{0.87 (±0.06)} & {\cellcolor[HTML]{B8C6E0}} \textcolor{black}{0.82 (±0.11)} & {\cellcolor[HTML]{A5BDDB}} \textcolor{black}{0.88 (±0.08)} & N/A & N/A & {\cellcolor[HTML]{9FBAD9}} \textcolor{black}{0.89 (±0.07)} & {\cellcolor[HTML]{97B7D7}} \textcolor{black}{0.91 (±0.07)} & {\cellcolor[HTML]{C1CAE2}} \textcolor{black}{0.79 (±0.06)} & {\cellcolor[HTML]{A7BDDB}} \textcolor{black}{0.87 (±0.07)} & {\cellcolor[HTML]{ABBFDC}} \textcolor{black}{0.86 (±0.07)} & {\cellcolor[HTML]{A4BCDA}} \textcolor{black}{0.88 (±0.07)} & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.02)} & N/A & N/A & {\cellcolor[HTML]{9FBAD9}} \textcolor{black}{0.89 (±0.04)} & {\cellcolor[HTML]{D4D4E8}} \textcolor{black}{0.73 (±0.17)} & {\cellcolor[HTML]{B1C2DE}} \textcolor{black}{0.84 (±0.08)} \\
# \hline
# \bfseries {en-es-ru} & {\cellcolor[HTML]{A1BBDA}} \textcolor{black}{0.89 (±0.03)} & {\cellcolor[HTML]{8BB2D4}} \textcolor{black}{0.94 (±0.04)} & {\cellcolor[HTML]{ABBFDC}} \textcolor{black}{0.86 (±0.03)} & {\cellcolor[HTML]{8EB3D5}} \textcolor{black}{0.93 (±0.03)} & {\cellcolor[HTML]{99B8D8}} \textcolor{black}{0.91 (±0.03)} & {\cellcolor[HTML]{8FB4D6}} \textcolor{black}{0.93 (±0.02)} & {\cellcolor[HTML]{86B0D3}} \textcolor{black}{0.95 (±0.01)} & {\cellcolor[HTML]{8FB4D6}} \textcolor{black}{0.93 (±0.02)} & {\cellcolor[HTML]{8FB4D6}} \textcolor{black}{0.93 (±0.03)} & N/A & N/A & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.04)} & {\cellcolor[HTML]{7EADD1}} \textcolor{black}{0.97 (±0.02)} & {\cellcolor[HTML]{ABBFDC}} \textcolor{black}{0.86 (±0.03)} & {\cellcolor[HTML]{97B7D7}} \textcolor{black}{0.91 (±0.04)} & {\cellcolor[HTML]{8CB3D5}} \textcolor{black}{0.94 (±0.01)} & {\cellcolor[HTML]{89B1D4}} \textcolor{black}{0.95 (±0.02)} & {\cellcolor[HTML]{8EB3D5}} \textcolor{black}{0.93 (±0.03)} & N/A & N/A & {\cellcolor[HTML]{9FBAD9}} \textcolor{black}{0.89 (±0.03)} & {\cellcolor[HTML]{ABBFDC}} \textcolor{black}{0.86 (±0.08)} & {\cellcolor[HTML]{97B7D7}} \textcolor{black}{0.91 (±0.03)} \\
# \end{tabular}
# /tmp/ipykernel_634/757126828.py:60: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(temp.applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).to_latex(convert_css=True).replace('\\multirow', '\\hline\n\\multirow').replace('{\\cellcolor[HTML]{000000}} \\color[HTML]{000000} nan', 'N/A').replace('nan', 'N/A').replace('\\bfseries {en-es-ru}', '\hline\n\\bfseries {en-es-ru}').replace('\\color[HTML]{000000} ', '\\textcolor{black}{').replace(') & {\\cellcolor', ')} & {\\cellcolor').replace(') & N/A', ')} & N/A').replace(' \\', '} \\').replace('&}', '&').replace('}}}', '}}'))

# %%
temp_mean.astype(float).style.highlight_max(props='font-weight: bold;', axis=0)
# Out:
# <style type="text/css">
# #T_4cf13_row0_col6, #T_4cf13_row1_col7, #T_4cf13_row2_col15, #T_4cf13_row3_col0, #T_4cf13_row3_col1, #T_4cf13_row3_col2, #T_4cf13_row3_col3, #T_4cf13_row3_col4, #T_4cf13_row3_col5, #T_4cf13_row3_col8, #T_4cf13_row3_col9, #T_4cf13_row3_col10, #T_4cf13_row3_col11, #T_4cf13_row3_col12, #T_4cf13_row3_col13, #T_4cf13_row3_col14, #T_4cf13_row3_col16, #T_4cf13_row3_col17, #T_4cf13_row3_col18 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4cf13">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Language</th>
#       <th id="T_4cf13_level0_col0" class="col_heading level0 col0" >ar</th>
#       <th id="T_4cf13_level0_col1" class="col_heading level0 col1" >bg</th>
#       <th id="T_4cf13_level0_col2" class="col_heading level0 col2" >ca</th>
#       <th id="T_4cf13_level0_col3" class="col_heading level0 col3" >cs</th>
#       <th id="T_4cf13_level0_col4" class="col_heading level0 col4" >de</th>
#       <th id="T_4cf13_level0_col5" class="col_heading level0 col5" >el</th>
#       <th id="T_4cf13_level0_col6" class="col_heading level0 col6" >en</th>
#       <th id="T_4cf13_level0_col7" class="col_heading level0 col7" >es</th>
#       <th id="T_4cf13_level0_col8" class="col_heading level0 col8" >et</th>
#       <th id="T_4cf13_level0_col9" class="col_heading level0 col9" >hr</th>
#       <th id="T_4cf13_level0_col10" class="col_heading level0 col10" >hu</th>
#       <th id="T_4cf13_level0_col11" class="col_heading level0 col11" >nl</th>
#       <th id="T_4cf13_level0_col12" class="col_heading level0 col12" >pl</th>
#       <th id="T_4cf13_level0_col13" class="col_heading level0 col13" >pt</th>
#       <th id="T_4cf13_level0_col14" class="col_heading level0 col14" >ro</th>
#       <th id="T_4cf13_level0_col15" class="col_heading level0 col15" >ru</th>
#       <th id="T_4cf13_level0_col16" class="col_heading level0 col16" >uk</th>
#       <th id="T_4cf13_level0_col17" class="col_heading level0 col17" >zh</th>
#       <th id="T_4cf13_level0_col18" class="col_heading level0 col18" >{all}</th>
#       <th id="T_4cf13_level0_col19" class="col_heading level0 col19" >ga</th>
#       <th id="T_4cf13_level0_col20" class="col_heading level0 col20" >gd</th>
#       <th id="T_4cf13_level0_col21" class="col_heading level0 col21" >sk</th>
#       <th id="T_4cf13_level0_col22" class="col_heading level0 col22" >sl</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Train Language</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cf13_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_4cf13_row0_col0" class="data row0 col0" >0.809295</td>
#       <td id="T_4cf13_row0_col1" class="data row0 col1" >0.899167</td>
#       <td id="T_4cf13_row0_col2" class="data row0 col2" >0.779832</td>
#       <td id="T_4cf13_row0_col3" class="data row0 col3" >0.909984</td>
#       <td id="T_4cf13_row0_col4" class="data row0 col4" >0.878790</td>
#       <td id="T_4cf13_row0_col5" class="data row0 col5" >0.904746</td>
#       <td id="T_4cf13_row0_col6" class="data row0 col6" >0.960253</td>
>nan</td>
#     </tr>
#     <tr>
#       <th id="T_4cf13_level0_row2" class="row_heading level0 row2" >ru</th>
#       <td id="T_4cf13_row2_col0" class="data row2 col0" >0.805230</td>
#       <td id="T_4cf13_row2_col1" class="data row2 col1" >0.930442</td>
#       <td id="T_4cf13_row2_col2" class="data row2 col2" >0.755730</td>
#       <td id="T_4cf13_row2_col3" class="data row2 col3" >0.872877</td>
#       <td id="T_4cf13_row2_col4" class="data row2 col4" >0.841072</td>
#       <td id="T_4cf13_row2_col5" class="data row2 col5" >0.881664</td>
#       <td id="T_4cf13_row2_col6" class="data row2 col6" >0.874709</td>
#       <td id="T_4cf13_row2_col7" class="data row2 col7" >0.821996</td>
#       <td id="T_4cf13_row2_col8" class="data row2 col8" >0.877180</td>
#       <td id="T_4cf13_row2_col9" class="data row2 col9" >0.892345</td>
#       <td id="T_4cf13_row2_col10" class="data row2 col10" >0.911441</td>
#       <td id="T_4cf13_row2_col11" class="data row2 col11" >0.794452</td>
#       <td id="T_4cf13_row2_col12" class="data row2 col12" >0.872687</td>
#       <td id="T_4cf13_row2_col13" class="data row2 col13" >0.861349</td>
#       <td id="T_4cf13_row2_col14" class="data

# %%
#statistical significance between language-differently finetuned detectors
temp = results_language.copy()
temp = temp[~temp.Language.isin(['ga', 'gd', 'sk', 'sl'])]#exclude languages with not enough samples
temp = temp[~temp['Train Language'].isin(['{en-es-ru-x3}'])]#exclude training with 3x more samples
languages = temp.Language.unique()
temp = temp.pivot(index=['Train Language', 'Detector'], columns='Language', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])

res_df = pd.DataFrame()
for lang in languages[languages != '{all}']:
 for (src, trg) in itertools.combinations_with_replacement(temp['Train Language'].unique(), 2):
   if src == trg: continue
   try:
    res = pg.ttest(temp[(temp["Train Language"] == trg)][lang], temp[(temp["Train Language"] == src)][lang], paired=True)
    if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest language: {lang}, ({trg}, {src})")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# Test language: cs, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_0b25a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b25a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_0b25a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_0b25a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_0b25a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_0b25a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_0b25a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_0b25a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_0b25a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b25a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_0b25a_row0_col0" class="data row0 col0" >2.551696</td>
#       <td id="T_0b25a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_0b25a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_0b25a_row0_col3" class="data row0 col3" >0.043391</td>
#       <td id="T_0b25a_row0_col4" class="data row0 col4" >[0.   0.09]</td>
#       <td id="T_0b25a_row0_col5" class="data row0 col5" >0.884182</td>
#       <td id="T_0b25a_row0_col6" class="data row0 col6" >2.204</td>
#       <td id="T_0b25a_row0_col7" class="data row0 col7" >0.501279</td>
#     </tr>
#   </tbody>
# </table>
# Test language: cs, ({en-es-ru}, ru)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_86453">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86453_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_86453_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_86453_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_86453_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_86453_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_86453_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_86453_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_86453_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86453_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_86453_row0_col0" class="data row0 col0" >2.575619</td>
#       <td id="T_86453_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_86453_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_86453_row0_col3" class="data row0 col3" >0.042016</td>
#       <td id="T_86453_row0_col4" class="data row0 col4" >[0.   0.12]</td>
#       <td id="T_86453_row0_col5" class="data row0 col5" >0.924570</td>
#       <td id="T_86453_row0_col6" class="data row0 col6" >2.257</td>
#       <td id="T_86453_row0_col7" class="data row0 col7" >0.536261</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pl, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_5775c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5775c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T
level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_d6f16_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_d6f16_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6f16_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_d6f16_row0_col0" class="data row0 col0" >2.803569</td>
#       <td id="T_d6f16_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_d6f16_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_d6f16_row0_col3" class="data row0 col3" >0.031018</td>
#       <td id="T_d6f16_row0_col4" class="data row0 col4" >[0.01 0.11]</td>
#       <td id="T_d6f16_row0_col5" class="data row0 col5" >1.304457</td>
#       <td id="T_d6f16_row0_col6" class="data row0 col6" >2.832</td>
#       <td id="T_d6f16_row0_col7" class="data row0 col7" >0.818555</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es, (ru, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_7ebaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ebaa_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7ebaa_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7ebaa_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7ebaa_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7ebaa_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7ebaa_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7ebaa_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7ebaa_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ebaa_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7ebaa_row0_col0" class="data row0 col0" >-2.605750</td>
#       <td id="T_7ebaa_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_7ebaa_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7ebaa_row0_col3" class="data row0 col3" >0.040350</td>
#       <td id="T_7ebaa_row0_col4" class="data row0 col4" >[-0.22 -0.01]</td>
#       <td id="T_7ebaa_row0_col5" class="data row0 col5" >1.333630</td>
#       <td id="T_7ebaa_row0_col6" class="data row0 col6" >2.326</td>
#       <td id="T_7ebaa_row0_col7" class="data row0 col7" >0.834533</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: uk, (ru, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_cfb9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfb9e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cfb9e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cfb9e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cfb9e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cfb9e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cfb9e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cfb9e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cfb9e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfb9e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cfb9e_row0_col0" class="data row0 col0" >4.417097</td>
#       <td id="T_cfb9e_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_cfb9e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cfb9e_row0_col3" class="data row0 col3" >0.004485</td>
#       <td id="T_cfb9e_row0_col4" class="data row0 col4" >[0.03 0.12]</td>
#       <td id="T_cfb9e_row0_col5" class="data row0 col5" >1.574611</td>
#       <td id="T_cfb9e_row0_col6" class="data row0 col6" >12.523</td>
#       <td id="T_cfb9e_row0_col7" class="data row0 col7" >0.931181</td>
#     </tr>
#   </tbody>
# </table>
# Test language: uk, ({en-es-ru}, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_a7988">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7988_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a7988_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a7988_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a7988_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a7988_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a7988_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a7988_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a7988_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7988_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a7988_row0_col0" class="data row0 col0" >4.302046</td>
#       <td id="T_a7988_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a7988_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a7988_row0_col3" class="data row0 col3" >0.005081</td>
#       <td id="T_a7988_row0_col4" class="data row0 col4" >[0.03 0.12]</td>
#       <td id="T_a7988_row0_col5" class="data row0 col5" >1.654814</td>
#       <td id="T_a7988_row0_col6" class="data row0 col6" >11.359</td>
#       <td id="T_a7988_row0_col7" class="data row0 col7" >0.950952</td>
#     </tr>
#   </tbody>
# </table>
# Test language: uk, (ru, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_321c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_321c3_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_321c3_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_321c3_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_321c3_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_321c3_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_321c3_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_321c3_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_321c3_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_321c3_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_321c3_row0_col0" class="data row0 col0" >4.736560</td>
#       <td id="T_321c3_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_321c3_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_321c3_row0_col3" class="data row0 col3" >0.003203</td>
#       <td id="T_321c3_row0_col4" class="data row0 col4" >[0.03 0.1 ]</td>
#       <td id="T_321c3_row0_col5" class="data row0 col5" >1.362947</td>
#       <td id="T_321c3_row0_col6" class="data row0 col6" >16.305</td>
#       <td id="T_321c3_row0_col7" class="data row0 col7" >0.849625</td>
#     </tr>
#   </tbody>
# </table>
# Test language: uk, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_c79fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c79fe_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c79fe_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c79fe_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c79fe_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c79fe_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c79fe_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c79fe_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c79fe_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c79fe_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c79fe_row0_col0" class="data row0 col0" >3.990462</td>
#       <td id="T_c79fe_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_c79fe_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c79fe_row0_col3" class="data row0 col3" >0.007197</td>
#       <td id="T_c79fe_row0_col4" class="data row0 col4" >[0.03 0.11]</td>
#       <td id="T_c79fe_row0_col5" class="data row0 col5" >1.430763</td>
#       <td id="T_c79fe_row0_col6" class="data row0 col6" >8.663</td>
#       <td id="T_c79fe_row0_col7" class="data row0 col7" >0.880870</td>
#     </tr>
#   </tbody>
# </table>
# Test language: nl, (ru, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_f733c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f733c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f733c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f733c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f733c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f733c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f733c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f733c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f733c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f733c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f733c_row0_col0" class="data row0 col0" >-2.590386</td>
#       <td id="T_f733c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f733c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f733c_row0_col3" class="data row0 col3" >0.041191</td>
#       <td id="T_f733c_row0_col4" class="data row0 col4" >[-0.09 -0.  ]</td>
#       <td id="T_f733c_row0_col5" class="data row0 col5" >0.867628</td>
#       <td id="T_f733c_row0_col6" class="data row0 col6" >2.291</td>
#       <td id="T_f733c_row0_col7" class="data row0 col7" >0.486906</td>
#     </tr>
#   </tbody>
# </table>
# Test language: nl, (ru, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_70bde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70bde_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_70bde_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_70bde_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_70bde_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_70bde_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_70bde_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_70bde_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_70bde_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70bde_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_70bde_row0_col0" class="data row0 col0" >-3.159160</td>
#       <td id="T_70bde_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_70bde_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_70bde_row0_col3" class="data row0 col3" >0.019586</td>
#       <td id="T_70bde_row0_col4" class="data row0 col4" >[-0.08 -0.01]</td>
#       <td id="T_70bde_row0_col5" class="data row0 col5" >0.766069</td>
#       <td id="T_70bde_row0_col6" class="data row0 col6" >4.011</td>
#       <td id="T_70bde_row0_col7" class="data row0 col7" >0.399597</td>
#     </tr>
#   </tbody>
# </table>
# Test language: nl, ({en-es-ru}, ru)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_87efd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87efd_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_87efd_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_87efd_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_87efd_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_87efd_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_87efd_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_87efd_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_87efd_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87efd_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_87efd_row0_col0" class="data row0 col0" >3.420671</td>
#       <td id="T_87efd_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_87efd_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_87efd_row0_col3" class="data row0 col3" >0.014132</td>
#       <td id="T_87efd_row0_col4" class="data row0 col4" >[0.02 0.11]</td>
#       <td id="T_87efd_row0_col5" class="data row0 col5" >1.177693</td>
#       <td id="T_87efd_row0_col6" class="data row0 col6" >5.146</td>
#       <td id="T_87efd_row0_col7" class="data row0 col7" >0.738280</td>
#     </tr>
#   </tbody>
# </table>
# Test language: el, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_10dd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10dd4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_10dd4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_10dd4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_10dd4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_10dd4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_10dd4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_10dd4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_10dd4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10dd4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_10dd4_row0_col0" class="data row0 col0" >2.643051</td>
#       <td id="T_10dd4_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_10dd4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_10dd4_row0_col3" class="data row0 col3" >0.038384</td>
#       <td id="T_10dd4_row0_col4" class="data row0 col4" >[0.   0.11]</td>
#       <td id="T_10dd4_row0_col5" class="data row0 col5" >1.163117</td>
#       <td id="T_10dd4_row0_col6" class="data row0 col6" >2.415</td>
#       <td id="T_10dd4_row0_col7" class="data row0 col7" >0.727977</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ca, (es, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_b413c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b413c_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b413c_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b413c_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b413c_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b413c_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b413c_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b413c_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b413c_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b413c_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b413c_row0_col0" class="data row0 col0" >5.490707</td>
#       <td id="T_b413c_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_b413c_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b413c_row0_col3" class="data row0 col3" >0.001528</td>
#       <td id="T_b413c_row0_col4" class="data row0 col4" >[0.04 0.09]</td>
#       <td id="T_b413c_row0_col5" class="data row0 col5" >1.829579</td>
#       <td id="T_b413c_row0_col6" class="data row0 col6" >29.243</td>
#       <td id="T_b413c_row0_col7" class="data row0 col7" >0.978402</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ca, ({en-es-ru}, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_7e68a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e68a_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7e68a_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7e68a_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7e68a_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7e68a_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7e68a_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7e68a_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7e68a_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e68a_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7e68a_row0_col0" class="data row0 col0" >7.193571</td>
#       <td id="T_7e68a_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_7e68a_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7e68a_row0_col3" class="data row0 col3" >0.000365</td>
#       <td id="T_7e68a_row0_col4" class="data row0 col4" >[0.05 0.11]</td>
#       <td id="T_7e68a_row0_col5" class="data row0 col5" >2.347866</td>
#       <td id="T_7e68a_row0_col6" class="data row0 col6" >91.774</td>
#       <td id="T_7e68a_row0_col7" class="data row0 col7" >0.999031</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: ca, ({en-es-ru}, ru)
# <style type="text/css">
# </style>
# <table id="T_9e9bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e9bf_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_9e9bf_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_9e9bf_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_9e9bf_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_9e9bf_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_9e9bf_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_9e9bf_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_9e9bf_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e9bf_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_9e9bf_row0_col0" class="data row0 col0" >2.679957</td>
#       <td id="T_9e9bf_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_9e9bf_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_9e9bf_row0_col3" class="data row0 col3" >0.036538</td>
#       <td id="T_9e9bf_row0_col4" class="data row0 col4" >[0.01 0.2 ]</td>
#       <td id="T_9e9bf_row0_col5" class="data row0 col5" >1.272657</td>
#       <td id="T_9e9bf_row0_col6" class="data row0 col6" >2.505</td>
#       <td id="T_9e9bf_row0_col7" class="data row0 col7" >0.800054</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: ro, (ru, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_23a60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23a60_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_23a60_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_23a60_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_23a60_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_23a60_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_23a60_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_23a60_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_23a60_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23a60_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_23a60_row0_col0" class="data row0 col0" >-2.611057</td>
#       <td id="T_23a60_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_23a60_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_23a60_row0_col3" class="data row0 col3" >0.040064</td>
#       <td id="T_23a60_row0_col4" class="data row0 col4" >[-0.09 -0.  ]</td>
#       <td id="T_23a60_row0_col5" class="data row0 col5" >0.785325</td>
#       <td id="T_23a60_row0_col6" class="data row0 col6" >2.339</td>
#       <td id="T_23a60_row0_col7" class="data row0 col7" >0.415930</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: ro, ({en-es-ru}, es)
# <style type="text/css">
# </style>
# <table id="T_b8b2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...
# <style type="text/css">
# </style>
# <table id="T_c6d6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6d6e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c6d6e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c6d6e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c6d6e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c6d6e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c6d6e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c6d6e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c6d6e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6d6e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c6d6e_row0_col0" class="data row0 col0" >3.250023</td>
#       <td id="T_c6d6e_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_c6d6e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c6d6e_row0_col3" class="data row0 col3" >0.017466</td>
#       <td id="T_c6d6e_row0_col4" class="data row0 col4" >[0.01 0.04]</td>
#       <td id="T_c6d6e_row0_col5" class="data row0 col5" >0.731369</td>
#       <td id="T_c6d6e_row0_col6" class="data row0 col6" >4.376</td>
#       <td id="T_c6d6e_row0_col7" class="data row0 col7" >0.370598</td>
#     </tr>
#   </tbody>
# </table>
# Test language: hu, ({en-es-ru}, ru)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_eba86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eba86_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_eba86_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_eba86_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_eba86_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_eba86_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_eba86_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_eba86_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_eba86_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eba86_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_eba86_row0_col0" class="data row0 col0" >2.715377</td>
#       <td id="T_eba86_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_eba86_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_eba86_row0_col3" class="data row0 col3" >0.034856</td>
#       <td id="T_eba86_row0_col4" class="data row0 col4" >[0.01 0.12]</td>
#       <td id="T_eba86_row0_col5" class="data row0 col5" >1.093902</td>
#       <td id="T_eba86_row0_col6" class="data row0 col6" >2.595</td>
#       <td id="T_eba86_row0_col7" class="data row0 col7" >0.676381</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: hr, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_40f05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40f05_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_40f05_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_40f05_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_40f05_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_40f05_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_40f05_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_40f05_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_40f05_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40f05_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_40f05_row0_col0" class="data row0 col0" >2.590828</td>
#       <td id="T_40f05_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_40f05_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_40f05_row0_col3" class="data row0 col3" >0.041166</td>
#       <td id="T_40f05_row0_col4" class="data row0 col4" >[0.   0.05]</td>
#       <td id="T_40f05_row0_col5" class="data row0 col5" >0.540801</td>
#       <td id="T_40f05_row0_col6" class="data row0 col6" >2.292</td>
#       <td id="T_40f05_row0_col7" class="data row0 col7" >0.227310</td>
#     </tr>
#   </tbody>
# </table>
# Test language: hr, ({en-es-ru}, ru)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_adc99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adc99_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_adc99_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_adc99_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_adc99_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_adc99_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_adc99_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_adc99_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_adc99_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adc99_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_adc99_row0_col0" class="data row0 col0" >2.470639</td>
#       <td id="T_adc99_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_adc99_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_adc99_row0_col3" class="data row0 col3" >0.048416</td>
#       <td id="T_adc99_row0_col4" class="data row0 col4" >[0.  0.1]</td>
#       <td id="T_adc99_row0_col5" class="data row0 col5" >0.804265</td>
#       <td id="T_adc99_row0_col6" class="data row0 col6" >2.032</td>
#       <td id="T_adc99_row0_col7" class="data row0 col7" >0.432126</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en, (es, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_f3f20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3f20_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f3f20_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f3f20_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f3f20_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f3f20_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f3f20_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f3f20_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f3f20_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f20_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f3f20_row0_col0" class="data row0 col0" >-3.901944</td>
#       <td id="T_f3f20_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_f3f20_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f3f20_row0_col3" class="data row0 col3" >0.007966</td>
#       <td id="T_f3f20_row0_col4" class="data row0 col4" >[-0.1  -0.02]</td>
#       <td id="T_f3f20_row0_col5" class="data row0 col5" >1.861041</td>
#       <td id="T_f3f20_row0_col6" class="data row0 col6" >8.006</td>
#       <td id="T_f3f20_row0_col7" class="data row0 col7" >0.981591</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en, (ru, en)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_e76a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e76a6_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e76a6_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e76a6_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e76a6_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e76a6_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e76a6_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e76a6_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e76a6_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e76a6_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e76a6_row0_col0" class="data row0 col0" >-4.070857</td>
#       <td id="T_e76a6_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e76a6_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e76a6_row0_col3" class="data row0 col3" >0.006569</td>
#       <td id="T_e76a6_row0_col4" class="data row0 col4" >[-0.14 -0.03]</td>
#       <td id="T_e76a6_row0_col5" class="data row0 col5" >1.998118</td>
#       <td id="T_e76a6_row0_col6" class="data row0 col6" >9.299</td>
#       <td id="T_e76a6_row0_col7" class="data row0 col7" >0.991209</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: en, ({en-es-ru}, es)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_ef2c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef2c4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_ef2c4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_ef2c4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_ef2c4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_ef2c4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_ef2c4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_ef2c4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_ef2c4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef2c4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_ef2c4_row0_col0" class="data row0 col0" >3.401772</td>
#       <td id="T_ef2c4_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_ef2c4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_ef2c4_row0_col3" class="data row0 col3" >0.014464</td>
#       <td id="T_ef2c4_row0_col4" class="data row0 col4" >[0.01 0.09]</td>
#       <td id="T_ef2c4_row0_col5" class="data row0 col5" >1.674619</td>
#       <td id="T_ef2c4_row0_col6" class="data row0 col6" >5.055</td>
#       <td id="T_ef2c4_row0_col7" class="data row0 col7" >0.955051</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en, ({en-es-ru}, ru)
# /tmp/ipykernel_634/2093459691.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_e5f21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5f21_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e5f21_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e5f21_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e5f21_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e5f21_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e5f21_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e5f21_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e5f21_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5f21_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e5f21_row0_col0" class="data row0 col0" >3.637307</td>
#       <td id="T_e5f21_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e5f21_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e5f21_row0_col3" class="data row0 col3" >0.010870</td>
#       <td id="T_e5f21_row0_col4" class="data row0 col4" >[0.03 0.13]</td>
#       <td id="T_e5f21_row0_col5" class="data row0 col5" >1.862422</td>
#       <td id="T_e5f21_row0_col6" class="data row0 col6" >6.297</td>
#       <td id="T_e5f21_row0_col7" class="data row0 col7" >0.981721</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance between monolingually and multilingually finetuned detectors
temp = results_language.copy()
temp = temp[~temp.Language.isin(['ga', 'gd', 'sk', 'sl'])]#exclude languages with not enough samples
temp = temp[~temp['Train Language'].isin(['{en-es-ru-x3}'])]#exclude training with 3x more samples
languages = temp.Language.unique()
temp = temp.pivot(index=['Train Language', 'Detector'], columns='Language', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])

res_df = pd.DataFrame()
#for (src, trg) in itertools.combinations_with_replacement(temp['Train Language'].unique(), 2):
#  if src == trg: continue
for lang in languages[languages != '{all}']:
   try:
    res = pg.ttest(temp[(temp["Train Language"] == '{en-es-ru}')][lang], temp[(temp["Train Language"] != '{en-es-ru}')][lang], paired=True)
    #res = pg.ttest(temp[(temp["Train Language"] == '{en-es-ru}')][lang], temp[(temp["Train Language"] != '{en-es-ru}')].groupby('Detector')[lang].mean(), paired=True)
    if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest language: {lang}")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test language: cs
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_6c8da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c8da_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_6c8da_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_6c8da_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_6c8da_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_6c8da_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_6c8da_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_6c8da_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_6c8da_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c8da_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_6c8da_row0_col0" class="data row0 col0" >2.252330</td>
#       <td id="T_6c8da_row0_col1" class="data row0 col1" >21.336179</td>
#       <td id="T_6c8da_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_6c8da_row0_col3" class="data row0 col3" >0.034949</td>
#       <td id="T_6c8da_row0_col4" class="data row0 col4" >[0.   0.09]</td>
#       <td id="T_6c8da_row0_col5" class="data row0 col5" >0.714576</td>
#       <td id="T_6c8da_row0_col6" class="data row0 col6" >2.177</td>
#       <td id="T_6c8da_row0_col7" class="data row0 col7" >0.351051</td>
#     </tr>
#   </tbody>
# </table>
# Test language: ar
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_7b719">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b719_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7b719_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7b719_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7b719_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7b719_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7b719_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7b719_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7b719_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b719_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7b719_row0_col0" class="data row0 col0" >3.615912</td>
#       <td id="T_7b719_row0_col1" class="data row0 col1" >20.867671</td>
#       <td id="T_7b719_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7b719_row0_col3" class="data row0 col3" >0.001634</td>
#       <td id="T_7b719_row0_col4" class="data row0 col4" >[0.03 0.12]</td>
#       <td id="T_7b719_row0_col5" class="data row0 col5" >1.157363</td>
#       <td id="T_7b719_row0_col6" class="data row0 col6" >24.078</td>
#       <td id="T_7b719_row0_col7" class="data row0 col7" >0.723386</td>
#     </tr>
#   </tbody>
# </table>
# Test language: es
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_e012f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e012f_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e012f_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e012f_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e012f_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e012f_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e012f_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e012f_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e012f_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e012f_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e012f_row0_col0" class="data row0 col0" >2.591790</td>
#       <td id="T_e012f_row0_col1" class="data row0 col1" >25.031569</td>
#       <td id="T_e012f_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e012f_row0_col3" class="data row0 col3" >0.015708</td>
#       <td id="T_e012f_row0_col4" class="data row0 col4" >[0.01 0.1 ]</td>
#       <td id="T_e012f_row0_col5" class="data row0 col5" >0.692595</td>
#       <td id="T_e012f_row0_col6" class="data row0 col6" >3.673</td>
#       <td id="T_e012f_row0_col7" class="data row0 col7" >0.333293</td>
#     </tr>
#   </tbody>
# </table>
# Test language: uk
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_3b238">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b238_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3b238_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3b238_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3b238_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3b238_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3b238_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3b238_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3b238_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b238_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3b238_row0_col0" class="data row0 col0" >2.629753</td>
#       <td id="T_3b238_row0_col1" class="data row0 col1" >18.806776</td>
#       <td id="T_3b238_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3b238_row0_col3" class="data row0 col3" >0.016594</td>
#       <td id="T_3b238_row0_col4" class="data row0 col4" >[0.01 0.09]</td>
#       <td id="T_3b238_row0_col5" class="data row0 col5" >0.876071</td>
#       <td id="T_3b238_row0_col6" class="data row0 col6" >3.908</td>
#       <td id="T_3b238_row0_col7" class="data row0 col7" >0.489291</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test language: el
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_b65d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b65d4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b65d4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b65d4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b65d4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b65d4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b65d4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b65d4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b65d4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b65d4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b65d4_row0_col0" class="data row0 col0" >3.093797</td>
#       <td id="T_b65d4_row0_col1" class="data row0 col1" >25.670038</td>
#       <td id="T_b65d4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b65d4_row0_col3" class="data row0 col3" >0.004724</td>
#       <td id="T_b65d4_row0_col4" class="data row0 col4" >[0.02 0.08]</td>
#       <td id="T_b65d4_row0_col5" class="data row0 col5" >0.889244</td>
#       <td id="T_b65d4_row0_col6" class="data row0 col6" >8.782</td>
#       <td id="T_b65d4_row0_col7" class="data row0 col7" >0.500869</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: ca
# <style type="text/css">
# </style>
# <table id="T_15aa3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15aa3_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_15aa3_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_15aa3_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_15aa3_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_15aa3_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_15aa3_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_15aa3_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_15aa3_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15aa3_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T
py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/2830034179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_84899">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84899_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_84899_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_84899_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_84899_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_84899_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_84899_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_84899_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_84899_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84899_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_84899_row0_col0" class="data row0 col0" >3.413493</td>
#       <td id="T_84899_row0_col1" class="data row0 col1" >22.678633</td>
#       <td id="T_84899_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_84899_row0_col3" class="data row0 col3" >0.002414</td>
#       <td id="T_84899_row0_col4" class="data row0 col4" >[0.02 0.07]</td>
#       <td id="T_84899_row0_col5" class="data row0 col5" >0.877190</td>
#       <td id="T_84899_row0_col6" class="data row0 col6" >16.111</td>
#       <td id="T_84899_row0_col7" class="data row0 col7" >0.490274</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance between monolingually and multilingually finetuned detectors autoregressive-only
temp = results_language.copy()
temp = temp[~temp.Language.isin(['ga', 'gd', 'sk', 'sl'])]#exclude languages with not enough samples
temp = temp[~temp['Train Language'].isin(['{en-es-ru-x3}'])]#exclude training with 3x more samples
temp = temp[temp.Detector.isin(autoregressive)]#exclude not autoregressive models
languages = temp.Language.unique()
temp = temp.pivot(index=['Train Language', 'Detector'], columns='Language', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])

res_df = pd.DataFrame()
#for (src, trg) in itertools.combinations_with_replacement(temp['Train Language'].unique(), 2):
#  if src == trg: continue
for lang in languages[languages != '{all}']:
   try:
    res = pg.ttest(temp[(temp["Train Language"] == '{en-es-ru}')][lang], temp[(temp["Train Language"] != '{en-es-ru}')][lang], paired=True)
    #res = pg.ttest(temp[(temp["Train Language"] == '{en-es-ru}')][lang], temp[(temp["Train Language"] != '{en-es-ru}')].groupby('Detector')[lang].mean(), paired=True)
    if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest language: {lang}")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test language: cs
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_148f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_148f4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_148f4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_148f4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_148f4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_148f4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_148f4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_148f4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_148f4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_148f4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_148f4_row0_col0" class="data row0 col0" >3.843354</td>
#       <td id="T_148f4_row0_col1" class="data row0 col1" >8.174722</td>
#       <td id="T_148f4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_148f4_row0_col3" class="data row0 col3" >0.004727</td>
#       <td id="T_148f4_row0_col4" class="data row0 col4" >[0.03 0.12]</td>
#       <td id="T_148f4_row0_col5" class="data row0 col5" >1.787533</td>
#       <td id="T_148f4_row0_col6" class="data row0 col6" >17.195</td>
#       <td id="T_148f4_row0_col7" class="data row0 col7" >0.820757</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: ar
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_7aa6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aa6d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_7aa6d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_7aa6d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_7aa6d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_7aa6d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_7aa6d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_7aa6d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_7aa6d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aa6d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_7aa6d_row0_col0" class="data row0 col0" >4.535370</td>
#       <td id="T_7aa6d_row0_col1" class="data row0 col1" >5.521700</td>
#       <td id="T_7aa6d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_7aa6d_row0_col3" class="data row0 col3" >0.004858</td>
#       <td id="T_7aa6d_row0_col4" class="data row0 col4" >[0.05 0.18]</td>
#       <td id="T_7aa6d_row0_col5" class="data row0 col5" >2.522101</td>
#       <td id="T_7aa6d_row0_col6" class="data row0 col6" >48.563</td>
#       <td id="T_7aa6d_row0_col7" class="data row0 col7" >0.981821</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_be431_row0_col3" class="data row0 col3" >0.028324</td>
#       <td id="T_be431_row0_col4" class="data row0 col4" >[0.01 0.09]</td>
#       <td id="T_be431_row0_col5" class="data row0 col5" >0.957138</td>
#       <td id="T_be431_row0_col6" class="data row0 col6" >2.563</td>
#       <td id="T_be431_row0_col7" class="data row0 col7" >0.339186</td>
#     </tr>
#   </tbody>
# </table>
# Test language: pt
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_8a4a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a4a2_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_8a4a2_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_8a4a2_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_8a4a2_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_8a4a2_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_8a4a2_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_8a4a2_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_8a4a2_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a4a2_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_8a4a2_row0_col0" class="data row0 col0" >3.098480</td>
#       <td id="T_8a4a2_row0_col1" class="data row0 col1" >13.795759</td>
#       <td id="T_8a4a2_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_8a4a2_row0_col3" class="data row0 col3" >0.007973</td>
#       <td id="T_8a4a2_row0_col4" class="data row0 col4" >[0.02 0.09]</td>
#       <td id="T_8a4a2_row0_col5" class="data row0 col5" >1.094127</td>
#       <td id="T_8a4a2_row0_col6" class="data row0 col6" >5.885</td>
#       <td id="T_8a4a2_row0_col7" class="data row0 col7" >0.422837</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test language: de
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_cc8cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc8cf_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_cc8cf_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_cc8cf_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_cc8cf_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_cc8cf_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_cc8cf_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_cc8cf_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_cc8cf_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc8cf_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_cc8cf_row0_col0" class="data row0 col0" >3.018914</td>
#       <td id="T_cc8cf_row0_col1" class="data row0 col1" >7.660714</td>
#       <td id="T_cc8cf_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_cc8cf_row0_col3" class="data row0 col3" >0.017446</td>
#       <td id="T_cc8cf_row0_col4" class="data row0 col4" >[0.01 0.1 ]</td>
#       <td id="T_cc8cf_row0_col5" class="data row0 col5" >1.440448</td>
#       <td id="T_cc8cf_row0_col6" class="data row0 col6" >5.275</td>
#       <td id="T_cc8cf_row0_col7" class="data row0 col7" >0.641183</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test language: zh
# <style type="text/css">
# </style>
# <table id="T_c0cf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0cf4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c0cf4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c0cf4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c0cf4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c0cf4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c0cf4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c0cf4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c0cf4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cf4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c0cf4_row0_col0" class="data row0 col0" >3.204484</td>
#       <td id="T_c0cf4_row0_col1" class="data row0 col1" >5.692791</td>
#       <td id="T_c0cf4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c0cf4_row0_col3" class="data row0 col3" >0.019898</td>
#       <td id="T_c0cf4_row0_col4" class="data row0 col4" >[0.05 0.37]</td>
#       <td id="T_c0cf4_row0_col5" class="data row0 col5" >1.752570</td>
#       <td id="T_c0cf4_row0_col6" class="data row0 col6" >6.822</td>
#       <td id="T_c0cf4_row0_col7" class="data row0 col7" >0.805719</td>
#     </tr>
#   </tbody>
# </table>
# Test language: hu
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_0195b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0195b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_0195b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_0195b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_0195b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_0195b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_0195b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_0195b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_0195b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0195b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_0195b_row0_col0" class="data row0 col0" >2.459010</td>
#       <td id="T_0195b_row0_col1" class="data row0 col1" >9.126779</td>
#       <td id="T_0195b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_0195b_row0_col3" class="data row0 col3" >0.035870</td>
#       <td id="T_0195b_row0_col4" class="data row0 col4" >[0.  0.1]</td>
#       <td id="T_0195b_row0_col5" class="data row0 col5" >1.097308</td>
#       <td id="T_0195b_row0_col6" class="data row0 col6" >2.543</td>
#       <td id="T_0195b_row0_col7" class="data row0 col7" >0.424839</td>
#     </tr>
#   </tbody>
# </table>
# Test language: en
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# /tmp/ipykernel_634/779534088.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_23368">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23368_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_23368_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_23368_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_23368_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_23368_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_23368_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_23368_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_23368_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23368_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_23368_row0_col0" class="data row0 col0" >3.686266</td>
#       <td id="T_23368_row0_col1" class="data row0 col1" >12.589695</td>
#       <td id="T_23368_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_23368_row0_col3" class="data row0 col3" >0.002883</td>
#       <td id="T_23368_row0_col4" class="data row0 col4" >[0.03 0.11]</td>
#       <td id="T_23368_row0_col5" class="data row0 col5" >1.244836</td>
#       <td id="T_23368_row0_col6" class="data row0 col6" >13.639</td>
#       <td id="T_23368_row0_col7" class="data row0 col7" >0.518943</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance between platform-differently finetuned detectors
temp = results_platform.copy()
temp = temp[~temp['Train Platform'].str.contains('x5')]#exclude training with 5x more samples
platforms = temp.Platform.unique()
temp = temp.pivot(index=['Train Platform', 'Detector'], columns='Platform', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])
#display(temp)

res_df = pd.DataFrame()
for (src, trg) in itertools.combinations_with_replacement(temp['Train Platform'].unique(), 2):
  if src == trg: continue
  for lang in platforms[platforms != '{all}']:
   try:
    res = pg.ttest(temp[(temp["Train Platform"] == trg)][lang], temp[(temp["Train Platform"] == src)][lang], paired=True)
    if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest platform: {lang}, ({trg}, {src})")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Gab, (Gab, Discord)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_90f6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90f6e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_90f6e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_90f6e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_90f6e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_90f6e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_90f6e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_90f6e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_90f6e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90f6e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_90f6e_row0_col0" class="data row0 col0" >5.825367</td>
#       <td id="T_90f6e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_90f6e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_90f6e_row0_col3" class="data row0 col3" >0.028226</td>
#       <td id="T_90f6e_row0_col4" class="data row0 col4" >[0.03 0.19]</td>
#       <td id="T_90f6e_row0_col5" class="data row0 col5" >6.274932</td>
#       <td id="T_90f6e_row0_col6" class="data row0 col6" >3.576</td>
#       <td id="T_90f6e_row0_col7" class="data row0 col7" >0.997002</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Discord, (Twitter, Discord)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_2b7ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b7ef_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_2b7ef_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_2b7ef_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_2b7ef_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_2b7ef_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_2b7ef_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_2b7ef_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_2b7ef_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b7ef_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_2b7ef_row0_col0" class="data row0 col0" >-4.501344</td>
#       <td id="T_2b7ef_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2b7ef_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_2b7ef_row0_col3" class="data row0 col3" >0.045976</td>
#       <td id="T_2b7ef_row0_col4" class="data row0 col4" >[-0.04 -0.  ]</td>
#       <td id="T_2b7ef_row0_col5" class="data row0 col5" >3.116960</td>
#       <td id="T_2b7ef_row0_col6" class="data row0 col6" >2.688</td>
#       <td id="T_2b7ef_row0_col7" class="data row0 col7" >0.770574</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Gab, (Twitter, Discord)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_84b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84b04_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_84b04_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_84b04_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_84b04_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_84b04_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_84b04_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_84b04_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_84b04_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84b04_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_84b04_row0_col0" class="data row0 col0" >5.235296</td>
#       <td id="T_84b04_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_84b04_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T
_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_d906b_row0_col3" class="data row0 col3" >0.023836</td>
#       <td id="T_d906b_row0_col4" class="data row0 col4" >[0.01 0.05]</td>
#       <td id="T_d906b_row0_col5" class="data row0 col5" >3.726769</td>
#       <td id="T_d906b_row0_col6" class="data row0 col6" >3.939</td>
#       <td id="T_d906b_row0_col7" class="data row0 col7" >0.875386</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Gab, (Twitter, Gab)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_3e7b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e7b6_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3e7b6_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3e7b6_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3e7b6_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3e7b6_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3e7b6_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3e7b6_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3e7b6_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e7b6_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3e7b6_row0_col0" class="data row0 col0" >-6.960058</td>
#       <td id="T_3e7b6_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_3e7b6_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3e7b6_row0_col3" class="data row0 col3" >0.020025</td>
#       <td id="T_3e7b6_row0_col4" class="data row0 col4" >[-0.07 -0.02]</td>
#       <td id="T_3e7b6_row0_col5" class="data row0 col5" >5.123404</td>
#       <td id="T_3e7b6_row0_col6" class="data row0 col6" >4.346</td>
#       <td id="T_3e7b6_row0_col7" class="data row0 col7" >0.979560</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Twitter, (WhatsApp, Gab)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_a6c99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6c99_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a6c99_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a6c99_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a6c99_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a6c99_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a6c99_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a6c99_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a6c99_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6c99_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a6c99_row0_col0" class="data row0 col0" >-5.137992</td>
#       <td id="T_a6c99_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_a6c99_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a6c99_row0_col3" class="data row0 col3" >0.035855</td>
#       <td id="T_a6c99_row0_col4" class="data row0 col4" >[-0.05 -0.  ]</td>
#       <td id="T_a6c99_row0_col5" class="data row0 col5" >1.310183</td>
#       <td id="T_a6c99_row0_col6" class="data row0 col6" >3.113</td>
#       <td id="T_a6c99_row0_col7" class="data row0 col7" >0.260916</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Gab, (all, Gab)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_69e5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69e5f_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_69e5f_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_69e5f_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_69e5f_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_69e5f_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_69e5f_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_69e5f_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_69e5f_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69e5f_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_69e5f_row0_col0" class="data row0 col0" >-4.919427</td>
#       <td id="T_69e5f_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_69e5f_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_69e5f_row0_col3" class="data row0 col3" >0.038924</td>
#       <td id="T_69e5f_row0_col4" class="data row0 col4" >[-0.04 -0.  ]</td>
#       <td id="T_69e5f_row0_col5" class="data row0 col5" >1.376226</td>
#       <td id="T_69e5f_row0_col6" class="data row0 col6" >2.967</td>
#       <td id="T_69e5f_row0_col7" class="data row0 col7" >0.279846</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Telegram, (Twitter, Telegram)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_6f179">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f179_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_6f179_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_6f179_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_6f179_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_6f179_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_6f179_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_6f179_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_6f179_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f179_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_6f179_row0_col0" class="data row0 col0" >-5.815158</td>
#       <td id="T_6f179_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_6f179_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_6f179_row0_col3" class="data row0 col3" >0.028321</td>
#       <td id="T_6f179_row0_col4" class="data row0 col4" >[-0.09 -0.01]</td>
#       <td id="T_6f179_row0_col5" class="data row0 col5" >4.959048</td>
#       <td id="T_6f179_row0_col6" class="data row0 col6" >3.569</td>
#       <td id="T_6f179_row0_col7" class="data row0 col7" >0.973954</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Twitter, (WhatsApp, Telegram)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_c3a6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3a6b_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c3a6b_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_c3a6b_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_c3a6b_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_c3a6b_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_c3a6b_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_c3a6b_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_c3a6b_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3a6b_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_c3a6b_row0_col0" class="data row0 col0" >-6.776219</td>
#       <td id="T_c3a6b_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_c3a6b_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_c3a6b_row0_col3" class="data row0 col3" >0.021092</td>
#       <td id="T_c3a6b_row0_col4" class="data row0 col4" >[-0.06 -0.01]</td>
#       <td id="T_c3a6b_row0_col5" class="data row0 col5" >1.646238</td>
#       <td id="T_c3a6b_row0_col6" class="data row0 col6" >4.221</td>
#       <td id="T_c3a6b_row0_col7" class="data row0 col7" >0.360869</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Telegram, (WhatsApp, Telegram)
# <style type="text/css">
# </style>
# <table id="T_abd21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abd21_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_abd21_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_abd21_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_abd21_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_abd21_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_abd21_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_abd21_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_abd21_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abd21_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_abd21_row0_col0" class="data row0 col0" >-5.096585</td>
#       <td id="T_abd21_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_abd21_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_abd21_row0_col3" class="data row0 col3" >0.036409</td>
#       <td id="T_abd21_row0_col4" class="data row0 col4" >[-0.07 -0.01]</td>
#       <td id="T_abd21_row0_col5" class="data row0 col5" >3.965144</td>
#       <td id="T_abd21_row0_col6" class="data row0 col6" >3.085</td>
#       <td id="T_abd21_row0_col7" class="data row0 col7" >0.904697</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: WhatsApp, (WhatsApp, Telegram)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_3b162">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b162_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3b162_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3b162_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3b162_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3b162_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3b162_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3b162_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3b162_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b162_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3b162_row0_col0" class="data row0 col0" >5.495194</td>
#       <td id="T_3b162_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_3b162_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3b162_row0_col3" class="data row0 col3" >0.031557</td>
#       <td id="T_3b162_row0_col4" class="data row0 col4" >[0.   0.03]</td>
#       <td id="T_3b162_row0_col5" class="data row0 col5" >2.346384</td>
#       <td id="T_3b162_row0_col6" class="data row0 col6" >3.353</td>
#       <td id="T_3b162_row0_col7" class="data row0 col7" >0.575344</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Twitter, (WhatsApp, Twitter)
# <style type="text/css">
# </style>
# <table id="T_1816f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1816f_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_1816f_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_1816f_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_1816f_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_1816f_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_1816f_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_1816f_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_1816f_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1816f_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_1816f_row0_col0" class="data row0 col0" >-9.512343</td>
#       <td id="T_1816f_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_1816f_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_1816f_row0_col3" class="data row0 col3" >0.010872</td>
#       <td id="T_1816f_row0_col4" class="data row0 col4" >[-0.08 -0.03]</td>
#       <td id="T_1816f_row0_col5" class="data row0 col5" >3.875337</td>
#       <td id="T_1816f_row0_col6" class="data row0 col6" >6.094</td>
#       <td id="T_1816f_row0_col7" class="data row0 col7" >0.894359</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Telegram, (WhatsApp, Twitter)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_12d17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12d17_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_12d17_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_12d17_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_12d17_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_12d17_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_12d17_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_12d17_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_12d17_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12d17_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_12d17_row0_col0" class="data row0 col0" >9.255128</td>
#       <td id="T_12d17_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_12d17_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_12d17_row0_col3" class="data row0 col3" >0.011474</td>
#       <td id="T_12d17_row0_col4" class="data row0 col4" >[0.01 0.02]</td>
#       <td id="T_12d17_row0_col5" class="data row0 col5" >1.546771</td>
#       <td id="T_12d17_row0_col6" class="data row0 col6" >5.917</td>
#       <td id="T_12d17_row0_col7" class="data row0 col7" >0.330482</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: WhatsApp, (WhatsApp, Twitter)
# <style type="text/css">
# </style>
# <table id="T_f497e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f497e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f497e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f497e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f497e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f497e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f497e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f497e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f497e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f497e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f497e_row0_col0" class="data row0 col0" >4.764757</td>
#       <td id="T_f497e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_f497e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f497e_row0_col3" class="data row0 col3" >0.041335</td>
#       <td id="T_f497e_row0_col4" class="data row0 col4" >[0.01 0.1 ]</td>
#       <td id="T_f497e_row0_col5" class="data row0 col5" >4.515875</td>
#       <td id="T_f497e_row0_col6" class="data row0 col6" >2.864</td>
#       <td id="T_f497e_row0_col7" class="data row0 col7" >0.951867</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Twitter, (all, Twitter)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_b39b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b39b7_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b39b7_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b39b7_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b39b7_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b39b7_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b39b7_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b39b7_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b39b7_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b39b7_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b39b7_row0_col0" class="data row0 col0" >-4.573857</td>
#       <td id="T_b39b7_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_b39b7_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b39b7_row0_col3" class="data row0 col3" >0.044625</td>
#       <td id="T_b39b7_row0_col4" class="data row0 col4" >[-0.03 -0.  ]</td>
#       <td id="T_b39b7_row0_col5" class="data row0 col5" >1.670475</td>
#       <td id="T_b39b7_row0_col6" class="data row0 col6" >2.737</td>
#       <td id="T_b39b7_row0_col7" class="data row0 col7" >0.368339</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Telegram, (all, Twitter)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_90b8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90b8e_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_90b8e_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_90b8e_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_90b8e_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_90b8e_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_90b8e_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_90b8e_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_90b8e_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90b8e_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_90b8e_row0_col0" class="data row0 col0" >8.394854</td>
#       <td id="T_90b8e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_90b8e_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_90b8e_row0_col3" class="data row0 col3" >0.013895</td>
#       <td id="T_90b8e_row0_col4" class="data row0 col4" >[0.02 0.05]</td>
#       <td id="T_90b8e_row0_col5" class="data row0 col5" >3.017736</td>
#       <td id="T_90b8e_row0_col6" class="data row0 col6" >5.327</td>
#       <td id="T_90b8e_row0_col7" class="data row0 col7" >0.749213</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Twitter, (all, WhatsApp)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_2b4ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b4ac_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_2b4ac_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_2b4ac_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_2b4ac_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_2b4ac_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_2b4ac_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_2b4ac_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_2b4ac_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b4ac_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_2b4ac_row0_col0" class="data row0 col0" >4.361766</td>
#       <td id="T_2b4ac_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2b4ac_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_2b4ac_row0_col3" class="data row0 col3" >0.048751</td>
#       <td id="T_2b4ac_row0_col4" class="data row0 col4" >[0.   0.07]</td>
#       <td id="T_2b4ac_row0_col5" class="data row0 col5" >2.457330</td>
#       <td id="T_2b4ac_row0_col6" class="data row0 col6" >2.596</td>
#       <td id="T_2b4ac_row0_col7" class="data row0 col7" >0.607186</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: Telegram, (all, WhatsApp)
# <style type="text/css">
# </style>
# <table id="T_9a0db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a0db_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_9a0db_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_9a0db_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_9a0db_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_9a0db_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_9a0db_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_9a0db_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_9a0db_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a0db_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_9a0db_row0_col0" class="data row0 col0" >6.093870</td>
#       <td id="T_9a0db_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_9a0db_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_9a0db_row0_col3" class="data row0 col3" >0.025887</td>
#       <td id="T_9a0db_row0_col4" class="data row0 col4" >[0.01 0.03]</td>
#       <td id="T_9a0db_row0_col5" class="data row0 col5" >1.834795</td>
#       <td id="T_9a0db_row0_col6" class="data row0 col6" >3.758</td>
#       <td id="T_9a0db_row0_col7" class="data row0 col7" >0.419369</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# Test platform: WhatsApp, (all, WhatsApp)
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# /tmp/ipykernel_634/970638343.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (res['p-val'][0] >= 0.05): continue
# <style type="text/css">
# </style>
# <table id="T_4d10d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d10d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_4d10d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_4d10d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_4d10d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_4d10d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_4d10d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_4d10d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_4d10d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d10d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_4d10d_row0_col0" class="data row0 col0" >-5.799327</td>
#       <td id="T_4d10d_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_4d10d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_4d10d_row0_col3" class="data row0 col3" >0.028470</td>
#       <td id="T_4d10d_row0_col4" class="data row0 col4" >[-0.04 -0.01]</td>
#       <td id="T_4d10d_row0_col5" class="data row0 col5" >4.667736</td>
#       <td id="T_4d10d_row0_col6" class="data row0 col6" >3.558</td>
#       <td id="T_4d10d_row0_col7" class="data row0 col7" >0.960748</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance between monoplatform and multiplatform finetuning of detectors
temp = results_platform.copy()
temp = temp[~temp['Train Platform'].str.contains('x5')]#exclude training with 5x more samples
platforms = temp.Platform.unique()
temp = temp.pivot(index=['Train Platform', 'Detector'], columns='Platform', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])
#display(temp)

res_df = pd.DataFrame()
#for (src, trg) in itertools.combinations_with_replacement(temp['Train Platform'].unique(), 2):
#  if src == trg: continue
for lang in platforms[platforms != '{all}']:
   try:
    res = pg.ttest(temp[(temp["Train Platform"] == 'all')][lang], temp[(temp["Train Platform"] != 'all')][lang], paired=True)
    #if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest platform: {lang}")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test platform: Twitter
# <style type="text/css">
# #T_e8cfc_row0_col0, #T_e8cfc_row0_col1, #T_e8cfc_row0_col2, #T_e8cfc_row0_col3, #T_e8cfc_row0_col4, #T_e8cfc_row0_col5, #T_e8cfc_row0_col6, #T_e8cfc_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e8cfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8cfc_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e8cfc_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e8cfc_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e8cfc_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e8cfc_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e8cfc_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e8cfc_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e8cfc_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8cfc_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e8cfc_row0_col0" class="data row0 col0" >1.877462</td>
#       <td id="T_e8cfc_row0_col1" class="data row0 col1" >15.985249</td>
#       <td id="T_e8cfc_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e8cfc_row0_col3" class="data row0 col3" >0.078826</td>
#       <td id="T_e8cfc_row0_col4" class="data row0 col4" >[-0.    0.08]</td>
#       <td id="T_e8cfc_row0_col5" class="data row0 col5" >0.549837</td>
#       <td id="T_e8cfc_row0_col6" class="data row0 col6" >1.336</td>
#       <td id="T_e8cfc_row0_col7" class="data row0 col7" >0.129492</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Telegram
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_3dc1d_row0_col0, #T_3dc1d_row0_col1, #T_3dc1d_row0_col2, #T_3dc1d_row0_col3, #T_3dc1d_row0_col4, #T_3dc1d_row0_col5, #T_3dc1d_row0_col6, #T_3dc1d_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3dc1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dc1d_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_3dc1d_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_3dc1d_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_3dc1d_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_3dc1d_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_3dc1d_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_3dc1d_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_3dc1d_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dc1d_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_3dc1d_row0_col0" class="data row0 col0" >2.009185</td>
#       <td id="T_3dc1d_row0_col1" class="data row0 col1" >11.791828</td>
#       <td id="T_3dc1d_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_3dc1d_row0_col3" class="data row0 col3" >0.067972</td>
#       <td id="T_3dc1d_row0_col4" class="data row0 col4" >[-0.    0.05]</td>
#       <td id="T_3dc1d_row0_col5" class="data row0 col5" >0.669272</td>
#       <td id="T_3dc1d_row0_col6" class="data row0 col6" >1.533</td>
#       <td id="T_3dc1d_row0_col7" class="data row0 col7" >0.168999</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Discord
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_516d4_row0_col0, #T_516d4_row0_col1, #T_516d4_row0_col2, #T_516d4_row0_col3, #T_516d4_row0_col4, #T_516d4_row0_col5, #T_516d4_row0_col6, #T_516d4_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_516d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_516d4_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_516d4_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_516d4_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_516d4_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_516d4_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_516d4_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_516d4_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_516d4_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_516d4_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_516d4_row0_col0" class="data row0 col0" >0.058547</td>
#       <td id="T_516d4_row0_col1" class="data row0 col1" >2.797362</td>
#       <td id="T_516d4_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_516d4_row0_col3" class="data row0 col3" >0.957241</td>
#       <td id="T_516d4_row0_col4" class="data row0 col4" >[-0.02  0.03]</td>
#       <td id="T_516d4_row0_col5" class="data row0 col5" >0.038025</td>
#       <td id="T_516d4_row0_col6" class="data row0 col6" >0.493</td>
#       <td id="T_516d4_row0_col7" class="data row0 col7" >0.050367</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Gab
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_de882_row0_col0, #T_de882_row0_col1, #T_de882_row0_col2, #T_de882_row0_col3, #T_de882_row0_col4, #T_de882_row0_col5, #T_de882_row0_col6, #T_de882_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_de882">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de882_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_de882_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_de882_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_de882_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_de882_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_de882_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_de882_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_de882_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de882_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_de882_row0_col0" class="data row0 col0" >1.604018</td>
#       <td id="T_de882_row0_col1" class="data row0 col1" >7.800241</td>
#       <td id="T_de882_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_de882_row0_col3" class="data row0 col3" >0.148343</td>
#       <td id="T_de882_row0_col4" class="data row0 col4" >[-0.01  0.06]</td>
#       <td id="T_de882_row0_col5" class="data row0 col5" >0.597453</td>
#       <td id="T_de882_row0_col6" class="data row0 col6" >1.031</td>
#       <td id="T_de882_row0_col7" class="data row0 col7" >0.144262</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: WhatsApp
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_86be7_row0_col0, #T_86be7_row0_col1, #T_86be7_row0_col2, #T_86be7_row0_col3, #T_86be7_row0_col4, #T_86be7_row0_col5, #T_86be7_row0_col6, #T_86be7_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_86be7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86be7_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_86be7_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_86be7_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_86be7_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_86be7_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_86be7_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_86be7_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_86be7_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86be7_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_86be7_row0_col0" class="data row0 col0" >1.941411</td>
#       <td id="T_86be7_row0_col1" class="data row0 col1" >15.978352</td>
#       <td id="T_86be7_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_86be7_row0_col3" class="data row0 col3" >0.070056</td>
#       <td id="T_86be7_row0_col4" class="data row0 col4" >[-0.    0.04]</td>
#       <td id="T_86be7_row0_col5" class="data row0 col5" >0.567905</td>
#       <td id="T_86be7_row0_col6" class="data row0 col6" >1.427</td>
#       <td id="T_86be7_row0_col7" class="data row0 col7" >0.134943</td>
#     </tr>
#   </tbody>
# </table>

# %%
#statistical significance between monoplatform and multiplatform finetuning of detectors without mdeberta
temp = results_platform.copy()
temp = temp[~temp['Train Platform'].str.contains('x5')]#exclude training with 5x more samples
temp = temp[~temp.Detector.str.contains('mDeBERTa')]#exclude the small mdeberta model
platforms = temp.Platform.unique()
temp = temp.pivot(index=['Train Platform', 'Detector'], columns='Platform', values='AUC ROC').reset_index()
#temp = pd.concat([temp, temp.loc[temp.Category == 'P', :]])
#display(temp)

res_df = pd.DataFrame()
#for (src, trg) in itertools.combinations_with_replacement(temp['Train Platform'].unique(), 2):
#  if src == trg: continue
for lang in platforms[platforms != '{all}']:
   try:
    res = pg.ttest(temp[(temp["Train Platform"] == 'all')][lang], temp[(temp["Train Platform"] != 'all')][lang], paired=True)
    #if (res['p-val'][0] >= 0.05): continue
    print(f"\nTest platform: {lang}")
    display(res.style.apply(lambda _: np.where(res['p-val'] >= 0.05, 'background-color: yellow', '')))
   except:
    pass
# Out:
# Test platform: Twitter
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_a0631_row0_col0, #T_a0631_row0_col1, #T_a0631_row0_col2, #T_a0631_row0_col3, #T_a0631_row0_col4, #T_a0631_row0_col5, #T_a0631_row0_col6, #T_a0631_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a0631">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0631_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_a0631_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_a0631_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_a0631_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_a0631_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_a0631_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_a0631_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_a0631_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0631_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_a0631_row0_col0" class="data row0 col0" >1.336011</td>
#       <td id="T_a0631_row0_col1" class="data row0 col1" >9.961581</td>
#       <td id="T_a0631_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_a0631_row0_col3" class="data row0 col3" >0.211263</td>
#       <td id="T_a0631_row0_col4" class="data row0 col4" >[-0.02  0.1 ]</td>
#       <td id="T_a0631_row0_col5" class="data row0 col5" >0.464185</td>
#       <td id="T_a0631_row0_col6" class="data row0 col6" >0.867</td>
#       <td id="T_a0631_row0_col7" class="data row0 col7" >0.084506</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Telegram
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_857a8_row0_col0, #T_857a8_row0_col1, #T_857a8_row0_col2, #T_857a8_row0_col3, #T_857a8_row0_col4, #T_857a8_row0_col5, #T_857a8_row0_col6, #T_857a8_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_857a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_857a8_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_857a8_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_857a8_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_857a8_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_857a8_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_857a8_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_857a8_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_857a8_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_857a8_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_857a8_row0_col0" class="data row0 col0" >1.465887</td>
#       <td id="T_857a8_row0_col1" class="data row0 col1" >4.973727</td>
#       <td id="T_857a8_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_857a8_row0_col3" class="data row0 col3" >0.202880</td>
#       <td id="T_857a8_row0_col4" class="data row0 col4" >[-0.02  0.07]</td>
#       <td id="T_857a8_row0_col5" class="data row0 col5" >0.626992</td>
#       <td id="T_857a8_row0_col6" class="data row0 col6" >0.946</td>
#       <td id="T_857a8_row0_col7" class="data row0 col7" >0.113668</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: Discord
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_f6348_row0_col0, #T_f6348_row0_col1, #T_f6348_row0_col2, #T_f6348_row0_col3, #T_f6348_row0_col4, #T_f6348_row0_col5, #T_f6348_row0_col6, #T_f6348_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f6348">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6348_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_f6348_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_f6348_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_f6348_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_f6348_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_f6348_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_f6348_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_f6348_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6348_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_f6348_row0_col0" class="data row0 col0" >-0.078218</td>
#       <td id="T_f6348_row0_col1" class="data row0 col1" >1.403998</td>
#       <td id="T_f6348_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_f6348_row0_col3" class="data row0 col3" >0.947306</td>
#       <td id="T_f6348_row0_col4" class="data row0 col4" >[-0.07  0.07]</td>
#       <td id="T_f6348_row0_col5" class="data row0 col5" >0.062077</td>
#       <td id="T_f6348_row0_col6" class="data row0 col6" >0.549</td>
#       <td id="T_f6348_row0_col7" class="data row0 col7" >0.050607</td>
#     </tr>
#   </tbody>
# </table>
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# Test platform: Gab
# <style type="text/css">
# #T_e38b5_row0_col0, #T_e38b5_row0_col1, #T_e38b5_row0_col2, #T_e38b5_row0_col3, #T_e38b5_row0_col4, #T_e38b5_row0_col5, #T_e38b5_row0_col6, #T_e38b5_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e38b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e38b5_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_e38b5_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_e38b5_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_e38b5_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_e38b5_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_e38b5_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_e38b5_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_e38b5_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e38b5_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_e38b5_row0_col0" class="data row0 col0" >1.538056</td>
#       <td id="T_e38b5_row0_col1" class="data row0 col1" >5.411776</td>
#       <td id="T_e38b5_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_e38b5_row0_col3" class="data row0 col3" >0.180243</td>
#       <td id="T_e38b5_row0_col4" class="data row0 col4" >[-0.02  0.08]</td>
#       <td id="T_e38b5_row0_col5" class="data row0 col5" >0.644834</td>
#       <td id="T_e38b5_row0_col6" class="data row0 col6" >0.996</td>
#       <td id="T_e38b5_row0_col7" class="data row0 col7" >0.117428</td>
#     </tr>
#   </tbody>
# </table>
# Test platform: WhatsApp
# /home/kali/anaconda3/lib/python3.9/site-packages/pingouin/parametric.py:228: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to paired == False. Check your data.")
# <style type="text/css">
# #T_b6bc5_row0_col0, #T_b6bc5_row0_col1, #T_b6bc5_row0_col2, #T_b6bc5_row0_col3, #T_b6bc5_row0_col4, #T_b6bc5_row0_col5, #T_b6bc5_row0_col6, #T_b6bc5_row0_col7 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b6bc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6bc5_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_b6bc5_level0_col1" class="col_heading level0 col1" >dof</th>
#       <th id="T_b6bc5_level0_col2" class="col_heading level0 col2" >alternative</th>
#       <th id="T_b6bc5_level0_col3" class="col_heading level0 col3" >p-val</th>
#       <th id="T_b6bc5_level0_col4" class="col_heading level0 col4" >CI95%</th>
#       <th id="T_b6bc5_level0_col5" class="col_heading level0 col5" >cohen-d</th>
#       <th id="T_b6bc5_level0_col6" class="col_heading level0 col6" >BF10</th>
#       <th id="T_b6bc5_level0_col7" class="col_heading level0 col7" >power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6bc5_level0_row0" class="row_heading level0 row0" >T-test</th>
#       <td id="T_b6bc5_row0_col0" class="data row0 col0" >1.698750</td>
#       <td id="T_b6bc5_row0_col1" class="data row0 col1" >9.999679</td>
#       <td id="T_b6bc5_row0_col2" class="data row0 col2" >two-sided</td>
#       <td id="T_b6bc5_row0_col3" class="data row0 col3" >0.120211</td>
#       <td id="T_b6bc5_row0_col4" class="data row0 col4" >[-0.01  0.05]</td>
#       <td id="T_b6bc5_row0_col5" class="data row0 col5" >0.595596</td>
#       <td id="T_b6bc5_row0_col6" class="data row0 col6" >1.124</td>
#       <td id="T_b6bc5_row0_col7" class="data row0 col7" >0.107324</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## News

# %%
#news test data - th calibration for macroF1 based on train data
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    train = data[(data.split == 'train') & (data.domain == 'social_media') & (~data.multi_label.str.contains('gemini'))]
    #print(data[(data.split == 'test') & (data.domain == 'news')].multi_label.unique())
    temp = data[(data.split == 'test') & (data.domain == 'news') & (~data.multi_label.str.contains('lama'))]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)]}#, 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}

  train_labels = [label2id[x] for x in train['label']]
  fpr, tpr, thresholds = roc_curve(train_labels, train['prediction_probs'])
  predictions = [1 if ((x >= thresholds[fpr <= 0.05][-1])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_5'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
  predictions = [1 if ((x >= thresholds[np.argmax(tpr - fpr)])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_o'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': rename_detector(model), 'Category': to_category[model], 'AUC ROC': v['auc'], 'MacroF1@5%FPR': v['cr_5']['macro avg']['f1-score'], 'MacroF1@optim': v['cr_o']['macro avg']['f1-score']}, index=[0])
  results_all = pd.concat([results_all, temp])
results_all = results_all.sort_values(by=['AUC ROC'], ascending=False).reset_index(drop=True)
results_all.index = results_all.index + 1
display(results_all.style.format(na_rep=0, precision=4))
display(results_all.style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1))
print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(
    axis=0).to_latex(convert_css=True))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [01:07<00:00,  1.23it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 2479.16it/s]
# <style type="text/css">
# </style>
# <table id="T_b938c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b938c_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_b938c_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_b938c_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_b938c_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#       <th id="T_b938c_level0_col4" class="col_heading level0 col4" >MacroF1@optim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b938c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b938c_row0_col0" class="data row0 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_b938c_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_b938c_row0_col2" class="data row0 col2" >0.9273</td>
#       <td id="T_b938c_row0_col3" class="data row0 col3" >0.7988</td>
#       <td id="T_b938c_row0_col4" class="data row0 col4" >0.7999</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b938c_row1_col0" class="data row1 col0" >Aya-101-MultiSocial</td>
#       <td id="T_b938c_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_b938c_row1_col2" class="data row1 col2" >0.9262</td>
#       <td id="T_b938c_row1_col3" class="data row1 col3" >0.8008</td>
#       <td id="T_b938c_row1_col4" class="data row1 col4" >0.8010</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b938c_row2_col0" class="data row2 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_b938c_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_b938c_row2_col2" class="data row2 col2" >0.9025</td>
#       <td id="T_b938c_row2_col3" class="data row2 col3" >0.7512</td>
#       <td id="T_b938c_row2_col4" class="data row2 col4" >0.7748</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b938c_row3_col0" class="data row3 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_b938c_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_b938c_row3_col2" class="data row3 col2" >0.8988</td>
#       <td id="T_b938c_row3_col3" class="data row3 col3" >0.7937</td>
#       <td id="T_b938c_row3_col4" class="data row3 col4" >0.7892</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b938c_row4_col0" class="data row4 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_b938c_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_b938c_row4_col2" class="data row4 col2" >0.8309</td>
#       <td id="T_b938c_row4_col3" class="data row4 col3" >0.7306</td>
#       <td id="T_b938c_row4_col4" class="data row4 col4" >0.6840</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b938c_row5_col0" class="data row5 col0" >Binoculars</td>
#       <td id="T_b938c_row5_col1" class="data row5 col1" >S</td>
#       <td id="T_b938c_row5_col2" class="data row5 col2" >0.8303</td>
#       <td id="T_b938c_row5_col3" class="data row5 col3" >0.4041</td>
#       <td id="T_b938c_row5_col4" class="data row5 col4" >0.5539</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b938c_row6_col0" class="data row6 col0" >Fast-Detect-GPT</td>
#       <td id="T_b938c_row6_col1" class="data row6 col1" >S</td>
#       <td id="T_b938c_row6_col2" class="data row6 col2" >0.8104</td>
#       <td id="T_b938c_row6_col3" class="data row6 col3" >0.6361</td>
#       <td id="T_b938c_row6_col4" class="data row6 col4" >0.5961</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b938c_row7_col0" class="data row7 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_b938c_row7_col1" class="data row7 col1" >F</td>
#       <td id="T_b938c_row7_col2" class="data row7 col2" >0.7592</td>
#       <td id="T_b938c_row7_col3" class="data row7 col3" >0.6394</td>
#       <td id="T_b938c_row7_col4" class="data row7 col4" >0.6599</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b938c_row8_col0" class="data row8 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_b938c_row8_col1" class="data row8 col1" >F</td>
#       <td id="T_b938c_row8_col2" class="data row8 col2" >0.7071</td>
#       <td id="T_b938c_row8_col3" class="data row8 col3" >0.5731</td>
#       <td id="T_b938c_row8_col4" class="data row8 col4" >0.5959</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_b938c_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_b938c_row9_col1" class="data row9 col1" >S</td>
#       <td id="T_b938c_row9_col2" class="data row9 col2" >0.6568</td>
#       <td id="T_b938c_row9_col3" class="data row9 col3" >0.3568</td>
#       <td id="T_b938c_row9_col4" class="data row9 col4" >0.4649</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_b938c_row10_col0" class="data row10 col0" >DetectLLM-LRR</td>
#       <td id="T_b938c_row10_col1" class="data row10 col1" >S</td>
#       <td id="T_b938c_row10_col2" class="data row10 col2" >0.6496</td>
#       <td id="T_b938c_row10_col3" class="data row10 col3" >0.4133</td>
#       <td id="T_b938c_row10_col4" class="data row10 col4" >0.4648</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_b938c_row11_col0" class="data row11 col0" >S5</td>
#       <td id="T_b938c_row11_col1" class="data row11 col1" >S</td>
#       <td id="T_b938c_row11_col2" class="data row11 col2" >0.6336</td>
#       <td id="T_b938c_row11_col3" class="data row11 col3" >0.3519</td>
#       <td id="T_b938c_row11_col4" class="data row11 col4" >0.4669</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_b938c_row12_col0" class="data row12 col0" >Longformer Detector</td>
#       <td id="T_b938c_row12_col1" class="data row12 col1" >P</td>
#       <td id="T_b938c_row12_col2" class="data row12 col2" >0.6157</td>
#       <td id="T_b938c_row12_col3" class="data row12 col3" >0.2564</td>
#       <td id="T_b938c_row12_col4" class="data row12 col4" >0.5039</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_b938c_row13_col0" class="data row13 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_b938c_row13_col1" class="data row13 col1" >P</td>
#       <td id="T_b938c_row13_col2" class="data row13 col2" >0.5896</td>
#       <td id="T_b938c_row13_col3" class="data row13 col3" >0.4296</td>
#       <td id="T_b938c_row13_col4" class="data row13 col4" >0.5265</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_b938c_row14_col0" class="data row14 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_b938c_row14_col1" class="data row14 col1" >P</td>
#       <td id="T_b938c_row14_col2" class="data row14 col2" >0.5707</td>
#       <td id="T_b938c_row14_col3" class="data row14 col3" >0.1958</td>
#       <td id="T_b938c_row14_col4" class="data row14 col4" >0.1643</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_b938c_row15_col0" class="data row15 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_b938c_row15_col1" class="data row15 col1" >P</td>
#       <td id="T_b938c_row15_col2" class="data row15 col2" >0.5536</td>
#       <td id="T_b938c_row15_col3" class="data row15 col3" >0.1891</td>
#       <td id="T_b938c_row15_col4" class="data row15 col4" >0.4181</td>
#     </tr>
#     <tr>
#       <th id="T_b938c_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_b938c_row16_col0" class="data row16 col0" >ruRoBERTa-ruatd-binary</td>
# <style type="text/css">
# #T_ca090_row0_col0, #T_ca090_row0_col2, #T_ca090_row0_col3, #T_ca090_row1_col0, #T_ca090_row1_col2, #T_ca090_row1_col3, #T_ca090_row2_col0, #T_ca090_row2_col2, #T_ca090_row2_col3, #T_ca090_row3_col0, #T_ca090_row3_col2, #T_ca090_row3_col3, #T_ca090_row4_col0, #T_ca090_row4_col2, #T_ca090_row4_col3, #T_ca090_row7_col0, #T_ca090_row7_col2, #T_ca090_row7_col3, #T_ca090_row8_col0, #T_ca090_row8_col2, #T_ca090_row8_col3 {
#   background-color: #b6d7a8;
# }
# #T_ca090_row5_col0, #T_ca090_row5_col2, #T_ca090_row5_col3, #T_ca090_row6_col0, #T_ca090_row6_col2, #T_ca090_row6_col3, #T_ca090_row9_col0, #T_ca090_row9_col2, #T_ca090_row9_col3, #T_ca090_row10_col0, #T_ca090_row10_col2, #T_ca090_row10_col3, #T_ca090_row11_col0, #T_ca090_row11_col2, #T_ca090_row11_col3 {
#   background-color: #f9cb9c;
# }
# #T_ca090_row12_col0, #T_ca090_row12_col2, #T_ca090_row12_col3, #T_ca090_row13_col0, #T_ca090_row13_col2, #T_ca090_row13_col3, #T_ca090_row14_col0, #T_ca090_row14_col2, #T_ca090_row14_col3, #T_ca090_row15_col0, #T_ca090_row15_col2, #T_ca090_row15_col3, #T_ca090_row16_col0, #T_ca090_row16_col2, #T_ca090_row16_col3 {
#   background-color: #9fc5e8;
# }
# </style>
# <table id="T_ca090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca090_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_ca090_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_ca090_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca090_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ca090_row0_col0" class="data row0 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_ca090_row0_col2" class="data row0 col2" >0.927322</td>
#       <td id="T_ca090_row0_col3" class="data row0 col3" >0.798831</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ca090_row1_col0" class="data row1 col0" >Aya-101-MultiSocial</td>
#       <td id="T_ca090_row1_col2" class="data row1 col2" >0.926166</td>
#       <td id="T_ca090_row1_col3" class="data row1 col3" >0.800815</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ca090_row2_col0" class="data row2 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_ca090_row2_col2" class="data row2 col2" >0.902500</td>
#       <td id="T_ca090_row2_col3" class="data row2 col3" >0.751232</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ca090_row3_col0" class="data row3 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_ca090_row3_col2" class="data row3 col2" >0.898766</td>
#       <td id="T_ca090_row3_col3" class="data row3 col3" >0.793683</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ca090_row4_col0" class="data row4 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_ca090_row4_col2" class="data row4 col2" >0.830872</td>
#       <td id="T_ca090_row4_col3" class="data row4 col3" >0.730627</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ca090_row5_col0" class="data row5 col0" >Binoculars</td>
#       <td id="T_ca090_row5_col2" class="data row5 col2" >0.830301</td>
#       <td id="T_ca090_row5_col3" class="data row5 col3" >0.404108</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ca090_row6_col0" class="data row6 col0" >Fast-Detect-GPT</td>
#       <td id="T_ca090_row6_col2" class="data row6 col2" >0.810407</td>
#       <td id="T_ca090_row6_col3" class="data row6 col3" >0.636138</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ca090_row7_col0" class="data row7 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_ca090_row7_col2" class="data row7 col2" >0.759205</td>
#       <td id="T_ca090_row7_col3" class="data row7 col3" >0.639355</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_ca090_row8_col0" class="data row8 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_ca090_row8_col2" class="data row8 col2" >0.707063</td>
#       <td id="T_ca090_row8_col3" class="data row8 col3" >0.573052</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_ca090_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_ca090_row9_col2" class="data row9 col2" >0.656790</td>
#       <td id="T_ca090_row9_col3" class="data row9 col3" >0.356787</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_ca090_row10_col0" class="data row10 col0" >DetectLLM-LRR</td>
#       <td id="T_ca090_row10_col2" class="data row10 col2" >0.649570</td>
#       <td id="T_ca090_row10_col3" class="data row10 col3" >0.413276</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_ca090_row11_col0" class="data row11 col0" >S5</td>
#       <td id="T_ca090_row11_col2" class="data row11 col2" >0.633641</td>
#       <td id="T_ca090_row11_col3" class="data row11 col3" >0.351922</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_ca090_row12_col0" class="data row12 col0" >Longformer Detector</td>
#       <td id="T_ca090_row12_col2" class="data row12 col2" >0.615685</td>
#       <td id="T_ca090_row12_col3" class="data row12 col3" >0.256398</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_ca090_row13_col0" class="data row13 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_ca090_row13_col2" class="data row13 col2" >0.589584</td>
#       <td id="T_ca090_row13_col3" class="data row13 col3" >0.429619</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_ca090_row14_col0" class="data row14 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_ca090_row14_col2" class="data row14 col2" >0.570729</td>
#       <td id="T_ca090_row14_col3" class="data row14 col3" >0.195777</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_ca090_row15_col0" class="data row15 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_ca090_row15_col2" class="data row15 col2" >0.553582</td>
#       <td id="T_ca090_row15_col3" class="data row15 col3" >0.189084</td>
#     </tr>
#     <tr>
#       <th id="T_ca090_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_ca090_row16_col0" class="data row16 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_ca090_row16_col2" class="data row16 col2" >0.518611</td>
#       <td id="T_ca090_row16_col3" class="data row16 col3" >0.148528</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{rlrr}
# \bfseries index & \bfseries Detector & \bfseries AUC ROC & \bfseries MacroF1@5%FPR \\
# {\cellcolor[HTML]{B6D7A8}} 1 & {\cellcolor[HTML]{B6D7A8}} Llama-3-8b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9273 & {\cellcolor[HTML]{B6D7A8}} 0.7988 \\
# {\cellcolor[HTML]{B6D7A8}} 2 & {\cellcolor[HTML]{B6D7A8}} Aya-101-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9262 & {\cellcolor[HTML]{B6D7A8}} 0.8008 \\
# {\cellcolor[HTML]{B6D7A8}} 3 & {\cellcolor[HTML]{B6D7A8}} mDeBERTa-v3-base-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.9025 & {\cellcolor[HTML]{B6D7A8}} 0.7512 \\
# {\cellcolor[HTML]{B6D7A8}} 4 & {\cellcolor[HTML]{B6D7A8}} Mistral-7b-v0.1-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8988 & {\cellcolor[HTML]{B6D7A8}} 0.7937 \\
# {\cellcolor[HTML]{B6D7A8}} 5 & {\cellcolor[HTML]{B6D7A8}} XLM-RoBERTa-large-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8309 & {\cellcolor[HTML]{B6D7A8}} 0.7306 \\
# {\cellcolor[HTML]{F9CB9C}} 6 & {\cellcolor[HTML]{F9CB9C}} Binoculars & {\cellcolor[HTML]{F9CB9C}} 0.8303 & {\cellcolor[HTML]{F9CB9C}} 0.4041 \\
# {\cellcolor[HTML]{F9CB9C}} 7 & {\cellcolor[HTML]{F9CB9C}} Fast-Detect-GPT & {\cellcolor[HTML]{F9CB9C}} 0.8104 & {\cellcolor[HTML]{F9CB9C}} 0.6361 \\
# {\cellcolor[HTML]{B6D7A8}} 8 & {\cellcolor[HTML]{B6D7A8}} Falcon-rw-1b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.7592 & {\cellcolor[HTML]{B6D7A8}} 0.6394 \\
# {\cellcolor[HTML]{B6D7A8}} 9 & {\cellcolor[HTML]{B6D7A8}} BLOOMZ-3b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.7071 & {\cellcolor[HTML]{B6D7A8}} 0.5731 \\
# {\cellcolor[HTML]{F9CB9C}} 10 & {\cellcolor[HTML]{F9CB9C}} LLM-Deviation & {\cellcolor[HTML]{F9CB9C}} 0.6568 & {\cellcolor[HTML]{F9CB9C}} 0.3568 \\
# {\cellcolor[HTML]{F9CB9C}} 11 & {\cellcolor[HTML]{F9CB9C}} DetectLLM-LRR & {\cellcolor[HTML]{F9CB9C}} 0.6496 & {\cellcolor[HTML]{F9CB9C}} 0.4133 \\
# {\cellcolor[HTML]{F9CB9C}} 12 & {\cellcolor[HTML]{F9CB9C}} S5 & {\cellcolor[HTML]{F9CB9C}} 0.6336 & {\cellcolor[HTML]{F9CB9C}} 0.3519 \\
# {\cellcolor[HTML]{9FC5E8}} 13 & {\cellcolor[HTML]{9FC5E8}} Longformer Detector & {\cellcolor[HTML]{9FC5E8}} 0.6157 & {\cellcolor[HTML]{9FC5E8}} 0.2564 \\
# {\cellcolor[HTML]{9FC5E8}} 14 & {\cellcolor[HTML]{9FC5E8}} ChatGPT-Detector-RoBERTa-Chinese & {\cellcolor[HTML]{9FC5E8}} 0.5896 & {\cellcolor[HTML]{9FC5E8}} 0.4296 \\
# {\cellcolor[HTML]{9FC5E8}} 15 & {\cellcolor[HTML]{9FC5E8}} RoBERTa-large-OpenAI-Detector & {\cellcolor[HTML]{9FC5E8}} 0.5707 & {\cellcolor[HTML]{9FC5E8}} 0.1958 \\
# {\cellcolor[HTML]{9FC5E8}} 16 & {\cellcolor[HTML]{9FC5E8}} BLOOMZ-3b-mixed-Detector & {\cellcolor[HTML]{9FC5E8}} 0.5536 & {\cellcolor[HTML]{9FC5E8}} 0.1891 \\
# {\cellcolor[HTML]{9FC5E8}} 17 & {\cellcolor[HTML]{9FC5E8}} ruRoBERTa-ruatd-binary & {\cellcolor[HTML]{9FC5E8}} 0.5186 & {\cellcolor[HTML]{9FC5E8}} 0.1485 \\
# \end{tabular}
# /tmp/ipykernel_634/2479829085.py:29: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(

# %%
#(OOD) news test data of Llama-2-70b generator - th calibration for macroF1 based on train data
auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    train = data[(data.split == 'train') & (data.domain == 'social_media') & (~data.multi_label.str.contains('gemini'))]
    #print(data[(data.split == 'test') & (data.domain == 'news')].multi_label.unique())
    temp = data[(data.split == 'test') & (data.domain == 'news') & (data.multi_label.str.contains('lama') | data.multi_label.str.contains('human'))]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)]}#, 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}

  train_labels = [label2id[x] for x in train['label']]
  fpr, tpr, thresholds = roc_curve(train_labels, train['prediction_probs'])
  predictions = [1 if ((x >= thresholds[fpr <= 0.05][-1])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_5'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
  predictions = [1 if ((x >= thresholds[np.argmax(tpr - fpr)])) else 0 for x in temp['prediction_probs']]
  auc_dict[model]['cr_o'] = report_todict(*report_np(np.array(labels), np.array(predictions), 2))
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': rename_detector(model), 'Category': to_category[model], 'AUC ROC': v['auc'], 'MacroF1@5%FPR': v['cr_5']['macro avg']['f1-score'], 'MacroF1@optim': v['cr_o']['macro avg']['f1-score']}, index=[0])
  results_all = pd.concat([results_all, temp])
results_all = results_all.sort_values(by=['AUC ROC'], ascending=False).reset_index(drop=True)
results_all.index = results_all.index + 1
display(results_all.style.format(na_rep=0, precision=4))
display(results_all.style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1))
print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(
    axis=0).to_latex(convert_css=True))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:56<00:00,  1.47it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 1860.24it/s]
# <style type="text/css">
# </style>
# <table id="T_b5a3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5a3e_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_b5a3e_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_b5a3e_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_b5a3e_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#       <th id="T_b5a3e_level0_col4" class="col_heading level0 col4" >MacroF1@optim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5a3e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b5a3e_row0_col0" class="data row0 col0" >Fast-Detect-GPT</td>
#       <td id="T_b5a3e_row0_col1" class="data row0 col1" >S</td>
#       <td id="T_b5a3e_row0_col2" class="data row0 col2" >0.9238</td>
#       <td id="T_b5a3e_row0_col3" class="data row0 col3" >0.8471</td>
#       <td id="T_b5a3e_row0_col4" class="data row0 col4" >0.5841</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b5a3e_row1_col0" class="data row1 col0" >Binoculars</td>
#       <td id="T_b5a3e_row1_col1" class="data row1 col1" >S</td>
#       <td id="T_b5a3e_row1_col2" class="data row1 col2" >0.9048</td>
#       <td id="T_b5a3e_row1_col3" class="data row1 col3" >0.7568</td>
#       <td id="T_b5a3e_row1_col4" class="data row1 col4" >0.4473</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b5a3e_row2_col0" class="data row2 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_b5a3e_row2_col1" class="data row2 col1" >F</td>
#       <td id="T_b5a3e_row2_col2" class="data row2 col2" >0.8871</td>
#       <td id="T_b5a3e_row2_col3" class="data row2 col3" >0.8011</td>
#       <td id="T_b5a3e_row2_col4" class="data row2 col4" >0.7916</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b5a3e_row3_col0" class="data row3 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_b5a3e_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_b5a3e_row3_col2" class="data row3 col2" >0.8614</td>
#       <td id="T_b5a3e_row3_col3" class="data row3 col3" >0.7673</td>
#       <td id="T_b5a3e_row3_col4" class="data row3 col4" >0.7732</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b5a3e_row4_col0" class="data row4 col0" >Aya-101-MultiSocial</td>
#       <td id="T_b5a3e_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_b5a3e_row4_col2" class="data row4 col2" >0.8574</td>
#       <td id="T_b5a3e_row4_col3" class="data row4 col3" >0.7556</td>
#       <td id="T_b5a3e_row4_col4" class="data row4 col4" >0.7562</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b5a3e_row5_col0" class="data row5 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_b5a3e_row5_col1" class="data row5 col1" >F</td>
#       <td id="T_b5a3e_row5_col2" class="data row5 col2" >0.8549</td>
#       <td id="T_b5a3e_row5_col3" class="data row5 col3" >0.7352</td>
#       <td id="T_b5a3e_row5_col4" class="data row5 col4" >0.7451</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b5a3e_row6_col0" class="data row6 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_b5a3e_row6_col1" class="data row6 col1" >F</td>
#       <td id="T_b5a3e_row6_col2" class="data row6 col2" >0.7928</td>
#       <td id="T_b5a3e_row6_col3" class="data row6 col3" >0.7108</td>
#       <td id="T_b5a3e_row6_col4" class="data row6 col4" >0.6032</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b5a3e_row7_col0" class="data row7 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_b5a3e_row7_col1" class="data row7 col1" >F</td>
#       <td id="T_b5a3e_row7_col2" class="data row7 col2" >0.7710</td>
#       <td id="T_b5a3e_row7_col3" class="data row7 col3" >0.6912</td>
#       <td id="T_b5a3e_row7_col4" class="data row7 col4" >0.6707</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b5a3e_row8_col0" class="data row8 col0" >DetectLLM-LRR</td>
#       <td id="T_b5a3e_row8_col1" class="data row8 col1" >S</td>
#       <td id="T_b5a3e_row8_col2" class="data row8 col2" >0.7559</td>
#       <td id="T_b5a3e_row8_col3" class="data row8 col3" >0.7121</td>
#       <td id="T_b5a3e_row8_col4" class="data row8 col4" >0.3320</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_b5a3e_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_b5a3e_row9_col1" class="data row9 col1" >S</td>
#       <td id="T_b5a3e_row9_col2" class="data row9 col2" >0.7257</td>
#       <td id="T_b5a3e_row9_col3" class="data row9 col3" >0.5931</td>
#       <td id="T_b5a3e_row9_col4" class="data row9 col4" >0.3319</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_b5a3e_row10_col0" class="data row10 col0" >Longformer Detector</td>
#       <td id="T_b5a3e_row10_col1" class="data row10 col1" >P</td>
#       <td id="T_b5a3e_row10_col2" class="data row10 col2" >0.7032</td>
#       <td id="T_b5a3e_row10_col3" class="data row10 col3" >0.5018</td>
#       <td id="T_b5a3e_row10_col4" class="data row10 col4" >0.3764</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_b5a3e_row11_col0" class="data row11 col0" >S5</td>
#       <td id="T_b5a3e_row11_col1" class="data row11 col1" >S</td>
#       <td id="T_b5a3e_row11_col2" class="data row11 col2" >0.6849</td>
#       <td id="T_b5a3e_row11_col3" class="data row11 col3" >0.5506</td>
#       <td id="T_b5a3e_row11_col4" class="data row11 col4" >0.3339</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_b5a3e_row12_col0" class="data row12 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_b5a3e_row12_col1" class="data row12 col1" >P</td>
#       <td id="T_b5a3e_row12_col2" class="data row12 col2" >0.6788</td>
#       <td id="T_b5a3e_row12_col3" class="data row12 col3" >0.6161</td>
#       <td id="T_b5a3e_row12_col4" class="data row12 col4" >0.5579</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_b5a3e_row13_col0" class="data row13 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_b5a3e_row13_col1" class="data row13 col1" >F</td>
#       <td id="T_b5a3e_row13_col2" class="data row13 col2" >0.6515</td>
#       <td id="T_b5a3e_row13_col3" class="data row13 col3" >0.6026</td>
#       <td id="T_b5a3e_row13_col4" class="data row13 col4" >0.6078</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_b5a3e_row14_col0" class="data row14 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_b5a3e_row14_col1" class="data row14 col1" >P</td>
#       <td id="T_b5a3e_row14_col2" class="data row14 col2" >0.5596</td>
#       <td id="T_b5a3e_row14_col3" class="data row14 col3" >0.4315</td>
#       <td id="T_b5a3e_row14_col4" class="data row14 col4" >0.3934</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_b5a3e_row15_col0" class="data row15 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_b5a3e_row15_col1" class="data row15 col1" >P</td>
#       <td id="T_b5a3e_row15_col2" class="data row15 col2" >0.5327</td>
#       <td id="T_b5a3e_row15_col3" class="data row15 col3" >0.3473</td>
#       <td id="T_b5a3e_row15_col4" class="data row15 col4" >0.3679</td>
#     </tr>
#     <tr>
#       <th id="T_b5a3e_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_b5a3e_row16_col0" class="data row16 col0" >BLOOMZ-3b-mixed-Detector</td>
# <style type="text/css">
# #T_c6f3d_row0_col0, #T_c6f3d_row0_col2, #T_c6f3d_row0_col3, #T_c6f3d_row1_col0, #T_c6f3d_row1_col2, #T_c6f3d_row1_col3, #T_c6f3d_row8_col0, #T_c6f3d_row8_col2, #T_c6f3d_row8_col3, #T_c6f3d_row9_col0, #T_c6f3d_row9_col2, #T_c6f3d_row9_col3, #T_c6f3d_row11_col0, #T_c6f3d_row11_col2, #T_c6f3d_row11_col3 {
#   background-color: #f9cb9c;
# }
# #T_c6f3d_row2_col0, #T_c6f3d_row2_col2, #T_c6f3d_row2_col3, #T_c6f3d_row3_col0, #T_c6f3d_row3_col2, #T_c6f3d_row3_col3, #T_c6f3d_row4_col0, #T_c6f3d_row4_col2, #T_c6f3d_row4_col3, #T_c6f3d_row5_col0, #T_c6f3d_row5_col2, #T_c6f3d_row5_col3, #T_c6f3d_row6_col0, #T_c6f3d_row6_col2, #T_c6f3d_row6_col3, #T_c6f3d_row7_col0, #T_c6f3d_row7_col2, #T_c6f3d_row7_col3, #T_c6f3d_row13_col0, #T_c6f3d_row13_col2, #T_c6f3d_row13_col3 {
#   background-color: #b6d7a8;
# }
# #T_c6f3d_row10_col0, #T_c6f3d_row10_col2, #T_c6f3d_row10_col3, #T_c6f3d_row12_col0, #T_c6f3d_row12_col2, #T_c6f3d_row12_col3, #T_c6f3d_row14_col0, #T_c6f3d_row14_col2, #T_c6f3d_row14_col3, #T_c6f3d_row15_col0, #T_c6f3d_row15_col2, #T_c6f3d_row15_col3, #T_c6f3d_row16_col0, #T_c6f3d_row16_col2, #T_c6f3d_row16_col3 {
#   background-color: #9fc5e8;
# }
# </style>
# <table id="T_c6f3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6f3d_level0_col0" class="col_heading level0 col0" >Detector</th>
#       <th id="T_c6f3d_level0_col2" class="col_heading level0 col2" >AUC ROC</th>
#       <th id="T_c6f3d_level0_col3" class="col_heading level0 col3" >MacroF1@5%FPR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6f3d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c6f3d_row0_col0" class="data row0 col0" >Fast-Detect-GPT</td>
#       <td id="T_c6f3d_row0_col2" class="data row0 col2" >0.923793</td>
#       <td id="T_c6f3d_row0_col3" class="data row0 col3" >0.847065</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c6f3d_row1_col0" class="data row1 col0" >Binoculars</td>
#       <td id="T_c6f3d_row1_col2" class="data row1 col2" >0.904783</td>
#       <td id="T_c6f3d_row1_col3" class="data row1 col3" >0.756778</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c6f3d_row2_col0" class="data row2 col0" >mDeBERTa-v3-base-MultiSocial</td>
#       <td id="T_c6f3d_row2_col2" class="data row2 col2" >0.887064</td>
#       <td id="T_c6f3d_row2_col3" class="data row2 col3" >0.801123</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c6f3d_row3_col0" class="data row3 col0" >Mistral-7b-v0.1-MultiSocial</td>
#       <td id="T_c6f3d_row3_col2" class="data row3 col2" >0.861438</td>
#       <td id="T_c6f3d_row3_col3" class="data row3 col3" >0.767348</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c6f3d_row4_col0" class="data row4 col0" >Aya-101-MultiSocial</td>
#       <td id="T_c6f3d_row4_col2" class="data row4 col2" >0.857379</td>
#       <td id="T_c6f3d_row4_col3" class="data row4 col3" >0.755611</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c6f3d_row5_col0" class="data row5 col0" >Llama-3-8b-MultiSocial</td>
#       <td id="T_c6f3d_row5_col2" class="data row5 col2" >0.854890</td>
#       <td id="T_c6f3d_row5_col3" class="data row5 col3" >0.735153</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c6f3d_row6_col0" class="data row6 col0" >XLM-RoBERTa-large-MultiSocial</td>
#       <td id="T_c6f3d_row6_col2" class="data row6 col2" >0.792760</td>
#       <td id="T_c6f3d_row6_col3" class="data row6 col3" >0.710824</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_c6f3d_row7_col0" class="data row7 col0" >Falcon-rw-1b-MultiSocial</td>
#       <td id="T_c6f3d_row7_col2" class="data row7 col2" >0.770981</td>
#       <td id="T_c6f3d_row7_col3" class="data row7 col3" >0.691165</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_c6f3d_row8_col0" class="data row8 col0" >DetectLLM-LRR</td>
#       <td id="T_c6f3d_row8_col2" class="data row8 col2" >0.755920</td>
#       <td id="T_c6f3d_row8_col3" class="data row8 col3" >0.712063</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_c6f3d_row9_col0" class="data row9 col0" >LLM-Deviation</td>
#       <td id="T_c6f3d_row9_col2" class="data row9 col2" >0.725709</td>
#       <td id="T_c6f3d_row9_col3" class="data row9 col3" >0.593085</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_c6f3d_row10_col0" class="data row10 col0" >Longformer Detector</td>
#       <td id="T_c6f3d_row10_col2" class="data row10 col2" >0.703166</td>
#       <td id="T_c6f3d_row10_col3" class="data row10 col3" >0.501810</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_c6f3d_row11_col0" class="data row11 col0" >S5</td>
#       <td id="T_c6f3d_row11_col2" class="data row11 col2" >0.684873</td>
#       <td id="T_c6f3d_row11_col3" class="data row11 col3" >0.550642</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_c6f3d_row12_col0" class="data row12 col0" >ChatGPT-Detector-RoBERTa-Chinese</td>
#       <td id="T_c6f3d_row12_col2" class="data row12 col2" >0.678826</td>
#       <td id="T_c6f3d_row12_col3" class="data row12 col3" >0.616093</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_c6f3d_row13_col0" class="data row13 col0" >BLOOMZ-3b-MultiSocial</td>
#       <td id="T_c6f3d_row13_col2" class="data row13 col2" >0.651490</td>
#       <td id="T_c6f3d_row13_col3" class="data row13 col3" >0.602634</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_c6f3d_row14_col0" class="data row14 col0" >RoBERTa-large-OpenAI-Detector</td>
#       <td id="T_c6f3d_row14_col2" class="data row14 col2" >0.559642</td>
#       <td id="T_c6f3d_row14_col3" class="data row14 col3" >0.431490</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_c6f3d_row15_col0" class="data row15 col0" >ruRoBERTa-ruatd-binary</td>
#       <td id="T_c6f3d_row15_col2" class="data row15 col2" >0.532700</td>
#       <td id="T_c6f3d_row15_col3" class="data row15 col3" >0.347324</td>
#     </tr>
#     <tr>
#       <th id="T_c6f3d_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_c6f3d_row16_col0" class="data row16 col0" >BLOOMZ-3b-mixed-Detector</td>
#       <td id="T_c6f3d_row16_col2" class="data row16 col2" >0.521178</td>
#       <td id="T_c6f3d_row16_col3" class="data row16 col3" >0.409596</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{rlrr}
# \bfseries index & \bfseries Detector & \bfseries AUC ROC & \bfseries MacroF1@5%FPR \\
# {\cellcolor[HTML]{F9CB9C}} 1 & {\cellcolor[HTML]{F9CB9C}} Fast-Detect-GPT & {\cellcolor[HTML]{F9CB9C}} 0.9238 & {\cellcolor[HTML]{F9CB9C}} 0.8471 \\
# {\cellcolor[HTML]{F9CB9C}} 2 & {\cellcolor[HTML]{F9CB9C}} Binoculars & {\cellcolor[HTML]{F9CB9C}} 0.9048 & {\cellcolor[HTML]{F9CB9C}} 0.7568 \\
# {\cellcolor[HTML]{B6D7A8}} 3 & {\cellcolor[HTML]{B6D7A8}} mDeBERTa-v3-base-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8871 & {\cellcolor[HTML]{B6D7A8}} 0.8011 \\
# {\cellcolor[HTML]{B6D7A8}} 4 & {\cellcolor[HTML]{B6D7A8}} Mistral-7b-v0.1-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8614 & {\cellcolor[HTML]{B6D7A8}} 0.7673 \\
# {\cellcolor[HTML]{B6D7A8}} 5 & {\cellcolor[HTML]{B6D7A8}} Aya-101-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8574 & {\cellcolor[HTML]{B6D7A8}} 0.7556 \\
# {\cellcolor[HTML]{B6D7A8}} 6 & {\cellcolor[HTML]{B6D7A8}} Llama-3-8b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.8549 & {\cellcolor[HTML]{B6D7A8}} 0.7352 \\
# {\cellcolor[HTML]{B6D7A8}} 7 & {\cellcolor[HTML]{B6D7A8}} XLM-RoBERTa-large-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.7928 & {\cellcolor[HTML]{B6D7A8}} 0.7108 \\
# {\cellcolor[HTML]{B6D7A8}} 8 & {\cellcolor[HTML]{B6D7A8}} Falcon-rw-1b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.7710 & {\cellcolor[HTML]{B6D7A8}} 0.6912 \\
# {\cellcolor[HTML]{F9CB9C}} 9 & {\cellcolor[HTML]{F9CB9C}} DetectLLM-LRR & {\cellcolor[HTML]{F9CB9C}} 0.7559 & {\cellcolor[HTML]{F9CB9C}} 0.7121 \\
# {\cellcolor[HTML]{F9CB9C}} 10 & {\cellcolor[HTML]{F9CB9C}} LLM-Deviation & {\cellcolor[HTML]{F9CB9C}} 0.7257 & {\cellcolor[HTML]{F9CB9C}} 0.5931 \\
# {\cellcolor[HTML]{9FC5E8}} 11 & {\cellcolor[HTML]{9FC5E8}} Longformer Detector & {\cellcolor[HTML]{9FC5E8}} 0.7032 & {\cellcolor[HTML]{9FC5E8}} 0.5018 \\
# {\cellcolor[HTML]{F9CB9C}} 12 & {\cellcolor[HTML]{F9CB9C}} S5 & {\cellcolor[HTML]{F9CB9C}} 0.6849 & {\cellcolor[HTML]{F9CB9C}} 0.5506 \\
# {\cellcolor[HTML]{9FC5E8}} 13 & {\cellcolor[HTML]{9FC5E8}} ChatGPT-Detector-RoBERTa-Chinese & {\cellcolor[HTML]{9FC5E8}} 0.6788 & {\cellcolor[HTML]{9FC5E8}} 0.6161 \\
# {\cellcolor[HTML]{B6D7A8}} 14 & {\cellcolor[HTML]{B6D7A8}} BLOOMZ-3b-MultiSocial & {\cellcolor[HTML]{B6D7A8}} 0.6515 & {\cellcolor[HTML]{B6D7A8}} 0.6026 \\
# {\cellcolor[HTML]{9FC5E8}} 15 & {\cellcolor[HTML]{9FC5E8}} RoBERTa-large-OpenAI-Detector & {\cellcolor[HTML]{9FC5E8}} 0.5596 & {\cellcolor[HTML]{9FC5E8}} 0.4315 \\
# {\cellcolor[HTML]{9FC5E8}} 16 & {\cellcolor[HTML]{9FC5E8}} ruRoBERTa-ruatd-binary & {\cellcolor[HTML]{9FC5E8}} 0.5327 & {\cellcolor[HTML]{9FC5E8}} 0.3473 \\
# {\cellcolor[HTML]{9FC5E8}} 17 & {\cellcolor[HTML]{9FC5E8}} BLOOMZ-3b-mixed-Detector & {\cellcolor[HTML]{9FC5E8}} 0.5212 & {\cellcolor[HTML]{9FC5E8}} 0.4096 \\
# \end{tabular}
# /tmp/ipykernel_634/2866092777.py:29: FutureWarning: Styler.applymap_index has been deprecated. Use Styler.map_index instead.
#   print(results_all.reset_index().style.apply(highlight_categories, axis=1).hide(['Category', 'MacroF1@optim'], axis=1).format(na_rep=0, precision=4).applymap_index(lambda v: "font-weight: bold;", axis=0).applymap_index(lambda v: "font-weight: bold;", axis=1).hide(

# %%
#news test data

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    temp = data[(data.split == 'test') & (data.domain == 'news') & (~data.multi_label.str.contains('lama'))]
    #temp = data[(data.split == 'test') & (data.domain == 'news') & (data.multi_label.str.contains('lama') | data.multi_label.str.contains('human'))]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  temp['prediction_probs']= temp['prediction_probs'].astype(float)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model, 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model, 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
# Out:
#   0%|                                                                                            | 0/83 [00:00<?, ?it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   1%|█                                                                                   | 1/83 [00:00<00:30,  2.68it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   2%|██                                                                                  | 2/83 [00:00<00:28,  2.85it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   4%|███                                                                                 | 3/83 [00:01<00:27,  2.93it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   5%|████                                                                                | 4/83 [00:01<00:27,  2.90it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   6%|█████                                                                               | 5/83 [00:01<00:27,  2.89it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   7%|██████                                                                              | 6/83 [00:02<00:26,  2.95it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   8%|███████                                                                             | 7/83 [00:02<00:25,  2.95it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  10%|████████                                                                            | 8/83 [00:02<00:25,  2.96it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  11%|█████████                                                                           | 9/83 [00:03<00:25,  2.95it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  19%|████████████████                                                                   | 16/83 [00:04<00:14,  4.56it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  28%|███████████████████████                                                            | 23/83 [00:06<00:12,  4.74it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  36%|██████████████████████████████                                                     | 30/83 [00:07<00:11,  4.71it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  54%|█████████████████████████████████████████████                                      | 45/83 [00:11<00:07,  4.75it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  72%|████████████████████████████████████████████████████████████                       | 60/83 [00:14<00:04,  4.75it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  90%|███████████████████████████████████████████████████████████████████████████        | 75/83 [00:17<00:01,  4.66it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  99%|██████████████████████████████████████████████████████████████████████████████████ | 82/83 [00:19<00:00,  4.77it/s]/tmp/ipykernel_634/3409598150.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:19<00:00,  4.25it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 115.34it/s]
# <style type="text/css">
# #T_c9c7c_row0_col0, #T_c9c7c_row0_col3, #T_c9c7c_row0_col4, #T_c9c7c_row0_col5, #T_c9c7c_row0_col18, #T_c9c7c_row0_col20, #T_c9c7c_row0_col21, #T_c9c7c_row0_col22, #T_c9c7c_row1_col1, #T_c9c7c_row1_col8, #T_c9c7c_row1_col9, #T_c9c7c_row1_col10, #T_c9c7c_row1_col11, #T_c9c7c_row1_col12, #T_c9c7c_row1_col14, #T_c9c7c_row1_col16, #T_c9c7c_row1_col19, #T_c9c7c_row3_col17, #T_c9c7c_row5_col6, #T_c9c7c_row5_col7, #T_c9c7c_row5_col13, #T_c9c7c_row5_col15, #T_c9c7c_row6_col2 {
#   background-color: lightyellow;
#   font-weight: bold;
# }
# #T_c9c7c_row0_col1, #T_c9c7c_row0_col2, #T_c9c7c_row0_col6, #T_c9c7c_row0_col7, #T_c9c7c_row0_col8, #T_c9c7c_row0_col9, #T_c9c7c_row0_col10, #T_c9c7c_row0_col11, #T_c9c7c_row0_col12, #T_c9c7c_row0_col13, #T_c9c7c_row0_col14, #T_c9c7c_row0_col15, #T_c9c7c_row0_col16, #T_c9c7c_row0_col17, #T_c9c7c_row0_col19, #T_c9c7c_row1_col0, #T_c9c7c_row1_col2, #T_c9c7c_row1_col3, #T_c9c7c_row1_col4, #T_c9c7c_row1_col5, #T_c9c7c_row1_col6, #T_c9c7c_row1_col7, #T_c9c7c_row1_col13, #T_c9c7c_row1_col15, #T_c9c7c_row1_col17, #T_c9c7c_row1_col18, #T_c9c7c_row1_col20, #T_c9c7c_row1_col21, #T_c9c7c_row1_col22, #T_c9c7c_row2_col0, #T_c9c7c_row2_col1, #T_c9c7c_row2_col2, #T_c9c7c_row2_col3, #T_c9c7c_row2_col4, #T_c9c7c_row2_col5, #T_c9c7c_row2_col6, #T_c9c7c_row2_col7, #T_c9c7c_row2_col8, #T_c9c7c_row2_col9, #T_c9c7c_row2_col10, #T_c9c7c_row2_col11, #T_c9c7c_row2_col12, #T_c9c7c_row2_col13, #T_c9c7c_row2_col14, #T_c9c7c_row2_col15, #T_c9c7c_row2_col16, #T_c9c7c_row2_col17, #T_c9c7c_row2_col18, #T_c9c7c_row2_col19, #T_c9c7c_row2_col20, #T_c9c7c_row2_col21, #T_c9c7c_row2_col22, #T_c9c7c_row3_col0, #T_c9c7c_row3_col1, #T_c9c7c_row3_col2, #T_c9c7c_row3_col3, #T_c9c7c_row3_col4, #T_c9c7c_row3_col5, #T_c9c7c_row3_col6, #T_c9c7c_row3_col7, #T_c9c7c_row3_col8, #T_c9c7c_row3_col9, #T_c9c7c_row3_col10, #T_c9c7c_row3_col11, #T_c9c7c_row3_col12, #T_c9c7c_row3_col13, #T_c9c7c_row3_col14, #T_c9c7c_row3_col15, #T_c9c7c_row3_col16, #T_c9c7c_row3_col18, #T_c9c7c_row3_col19, #T_c9c7c_row3_col20, #T_c9c7c_row3_col21, #T_c9c7c_row3_col22, #T_c9c7c_row4_col0, #T_c9c7c_row4_col1, #T_c9c7c_row4_col2, #T_c9c7c_row4_col3, #T_c9c7c_row4_col4, #T_c9c7c_row4_col5, #T_c9c7c_row4_col6, #T_c9c7c_row4_col7, #T_c9c7c_row4_col8, #T_c9c7c_row4_col9, #T_c9c7c_row4_col10, #T_c9c7c_row4_col11, #T_c9c7c_row4_col12, #T_c9c7c_row4_col13, #T_c9c7c_row4_col14, #T_c9c7c_row4_col15, #T_c9c7c_row4_col16, #T_c9c7c_row4_col17, #T_c9c7c_row4_col18, #T_c9c7c_row4_col19, #T_c9c7c_row4_col20, #T_c9c7c_row4_col21, #T_c9c7c_row4_col22, #T_c9c7c_row5_col0, #T_c9c7c_row5_col1, #T_c9c7c_row5_col2, #T_c9c7c_row5_col3, #T_c9c7c_row5_col4, #T_c9c7c_row5_col5, #T_c9c7c_row5_col8, #T_c9c7c_row5_col9, #T_c9c7c_row5_col10, #T_c9c7c_row5_col11, #T_c9c7c_row5_col12, #T_c9c7c_row5_col14, #T_c9c7c_row5_col16, #T_c9c7c_row5_col17, #T_c9c7c_row5_col18, #T_c9c7c_row5_col19, #T_c9c7c_row5_col20, #T_c9c7c_row5_col21, #T_c9c7c_row5_col22, #T_c9c7c_row6_col0, #T_c9c7c_row6_col1, #T_c9c7c_row6_col3, #T_c9c7c_row6_col4, #T_c9c7c_row6_col6, #T_c9c7c_row6_col7, #T_c9c7c_row6_col8, #T_c9c7c_row6_col9, #T_c9c7c_row6_col10, #T_c9c7c_row6_col11, #T_c9c7c_row6_col12, #T_c9c7c_row6_col13, #T_c9c7c_row6_col14, #T_c9c7c_row6_col15, #T_c9c7c_row6_col16, #T_c9c7c_row6_col17, #T_c9c7c_row6_col18, #T_c9c7c_row6_col19, #T_c9c7c_row6_col20, #T_c9c7c_row6_col21, #T_c9c7c_row6_col22, #T_c9c7c_row7_col0, #T_c9c7c_row7_col1, #T_c9c7c_row7_col2, #T_c9c7c_row7_col3, #T_c9c7c_row7_col4, #T_c9c7c_row7_col5, #T_c9c7c_row7_col6, #T_c9c7c_row7_col7, #T_c9c7c_row7_col8, #T_c9c7c_row7_col9, #T_c9c7c_row7_col10, #T_c9c7c_row7_col11, #T_c9c7c_row7_col12, #T_c9c7c_row7_col13, #T_c9c7c_row7_col14, #T_c9c7c_row7_col15, #T_c9c7c_row7_col16, #T_c9c7c_row7_col17, #T_c9c7c_row7_col18, #T_c9c7c_row7_col19, #T_c9c7c_row7_col20, #T_c9c7c_row7_col21, #T_c9c7c_row7_col22, #T_c9c7c_row8_col0, #T_c9c7c_row8_col1, #T_c9c7c_row8_col2, #T_c9c7c_row8_col3, #T_c9c7c_row8_col4, #T_c9c7c_row8_col5, #T_c9c7c_row8_col6, #T_c9c7c_row8_col7, #T_c9c7c_row8_col8, #T_c9c7c_row8_col9, #T_c9c7c_row8_col10, #T_c9c7c_row8_col11, #T_c9c7c_row8_col12, #T_c9c7c_row8_col13, #T_c9c7c_row8_col14, #T_c9c7c_row8_col15, #T_c9c7c_row8_col16, #T_c9c7c_row8_col17, #T_c9c7c_row8_col18, #T_c9c7c_row8_col19, #T_c9c7c_row8_col20, #T_c9c7c_row8_col21, #T_c9c7c_row8_col22, #T_c9c7c_row9_col0, #T_c9c7c_row9_col1, #T_c9c7c_row9_col2, #T_c9c7c_row9_col3, #T_c9c7c_row9_col4, #T_c9c7c_row9_col6, #T_c9c7c_row9_col7, #T_c9c7c_row9_col8, #T_c9c7c_row9_col9, #T_c9c7c_row9_col10, #T_c9c7c_row9_col11, #T_c9c7c_row9_ ...
#   background-color: lightyellow;
# }
# </style>
# <table id="T_c9c7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9c7c_level0_col0" class="col_heading level0 col0" colspan="23">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_c9c7c_level1_col0" class="col_heading level1 col0" >ar</th>
#       <th id="T_c9c7c_level1_col1" class="col_heading level1 col1" >bg</th>
#       <th id="T_c9c7c_level1_col2" class="col_heading level1 col2" >ca</th>
#       <th id="T_c9c7c_level1_col3" class="col_heading level1 col3" >cs</th>
#       <th id="T_c9c7c_level1_col4" class="col_heading level1 col4" >de</th>
#       <th id="T_c9c7c_level1_col5" class="col_heading level1 col5" >el</th>
#       <th id="T_c9c7c_level1_col6" class="col_heading level1 col6" >en</th>
#       <th id="T_c9c7c_level1_col7" class="col_heading level1 col7" >es</th>
#       <th id="T_c9c7c_level1_col8" class="col_heading level1 col8" >et</th>
#       <th id="T_c9c7c_level1_col9" class="col_heading level1 col9" >ga</th>
#       <th id="T_c9c7c_level1_col10" class="col_heading level1 col10" >gd</th>
#       <th id="T_c9c7c_level1_col11" class="col_heading level1 col11" >hr</th>
#       <th id="T_c9c7c_level1_col12" class="col_heading level1 col12" >hu</th>

# %%
#news test data - OOD

auc_dict = {}
for detector in tqdm(test_results, total=len(test_results)):
  for model,data in detector.items():
    #temp = data[(data.split == 'test') & (data.domain == 'news') & (~data.multi_label.str.contains('lama'))]
    temp = data[(data.split == 'test') & (data.domain == 'news') & (data.multi_label.str.contains('lama') | data.multi_label.str.contains('human'))]
  if (to_category[model] == 'F') and ('social-media' not in model): continue
  #if (temp['prediction_probs'].min() >= 0.5) and (temp['prediction_probs'].max() <= 1.0):
    #temp.loc[temp.predictions == 'human', 'prediction_probs'] = 1 - temp['prediction_probs'] #adjust human prediction prob to be in range <0, 0.5)
  temp['prediction_probs']= temp['prediction_probs'].astype(float)
  labels = [label2id[x] for x in temp['label']]
  fpr, tpr, thresholds = roc_curve(labels, temp['prediction_probs'])
  auc_dict[model] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
  for test_language in temp.language.unique():
    temp2 = temp[temp.language == test_language].reset_index(drop=True)
    labels = [label2id[x] for x in temp2['label']]
    fpr, tpr, thresholds = roc_curve(labels, temp2['prediction_probs'])
    auc_dict[model][test_language] = {'auc':  auc_roc_reliable(fpr, tpr, labels), 'th_optim': thresholds[np.argmax(tpr - fpr)], 'tpr_1%fpr': tpr[fpr <= 0.01][-1], 'tpr_5%fpr': tpr[fpr <= 0.05][-1], 'th_1%fpr': thresholds[fpr <= 0.01][-1], 'th_3%fpr': thresholds[fpr <= 0.03][-1], 'th_5%fpr': thresholds[fpr <= 0.05][-1], 'th_10%fpr': thresholds[fpr <= 0.10][-1], 'th_15%fpr': thresholds[fpr <= 0.15][-1], 'th_20%fpr': thresholds[fpr <= 0.20][-1], 'th_25%fpr': thresholds[fpr <= 0.25][-1], 'th_30%fpr': thresholds[fpr <= 0.30][-1], 'th_40%fpr': thresholds[fpr <= 0.40][-1], 'th_50%fpr': thresholds[fpr <= 0.50][-1]}
results_all = pd.DataFrame()
for model, v in tqdm(auc_dict.items(), total=len(auc_dict)):
  temp = pd.DataFrame({'Detector': model, 'Language': '{all}', 'AUC ROC': v['auc']}, index=[0])
  results_all = pd.concat([results_all, temp])
  for test_language,val in v.items():
    if (test_language == 'auc') or ('_' in test_language): continue
    temp = pd.DataFrame({'Detector': model, 'Language': test_language, 'AUC ROC': val['auc']}, index=[0])
    results_all = pd.concat([results_all, temp])
results_all.set_index(['Detector', 'Language']).unstack().sort_values(by=('AUC ROC','{all}'), ascending=False).style.format(precision=2).apply(lambda x: ["background-color: lightyellow" if v >= 0.6 else "" for v in x], axis = 0, subset='AUC ROC').highlight_max(props='font-weight: bold;', axis=0)
# Out:
#   0%|                                                                                            | 0/83 [00:00<?, ?it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   1%|█                                                                                   | 1/83 [00:00<00:31,  2.64it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   2%|██                                                                                  | 2/83 [00:00<00:30,  2.68it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   4%|███                                                                                 | 3/83 [00:01<00:30,  2.66it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   5%|████                                                                                | 4/83 [00:01<00:29,  2.70it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   6%|█████                                                                               | 5/83 [00:01<00:29,  2.66it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   7%|██████                                                                              | 6/83 [00:02<00:29,  2.63it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#   8%|███████                                                                             | 7/83 [00:02<00:28,  2.66it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  10%|████████                                                                            | 8/83 [00:02<00:27,  2.68it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  11%|█████████                                                                           | 9/83 [00:03<00:27,  2.69it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  19%|████████████████                                                                   | 16/83 [00:05<00:21,  3.06it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  28%|███████████████████████                                                            | 23/83 [00:07<00:19,  3.09it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  36%|██████████████████████████████                                                     | 30/83 [00:10<00:17,  3.10it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  54%|█████████████████████████████████████████████                                      | 45/83 [00:15<00:12,  3.11it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  72%|████████████████████████████████████████████████████████████                       | 60/83 [00:20<00:07,  3.12it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  90%|███████████████████████████████████████████████████████████████████████████        | 75/83 [00:24<00:02,  3.09it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
#  99%|██████████████████████████████████████████████████████████████████████████████████ | 82/83 [00:27<00:00,  3.10it/s]/tmp/ipykernel_634/682490615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['prediction_probs']= temp['prediction_probs'].astype(float)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 83/83 [00:27<00:00,  3.01it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 125.47it/s]
# <style type="text/css">
# #T_342ea_row0_col0, #T_342ea_row0_col1, #T_342ea_row0_col4, #T_342ea_row0_col6, #T_342ea_row0_col7, #T_342ea_row0_col8, #T_342ea_row0_col9, #T_342ea_row0_col10, #T_342ea_row0_col15, #T_342ea_row0_col18, #T_342ea_row0_col20, #T_342ea_row1_col0, #T_342ea_row1_col1, #T_342ea_row1_col2, #T_342ea_row1_col3, #T_342ea_row1_col5, #T_342ea_row1_col9, #T
342ea_row6_col21, #T_342ea_row6_col22, #T_342ea_row7_col0, #T_342ea_row7_col1, #T_342ea_row7_col2, #T_342ea_row7_col3, #T_342ea_row7_col4, #T_342ea_row7_col5, #T_342ea_row7_col6, #T_342ea_row7_col7, #T_342ea_row7_col8, #T_342ea_row7_col9, #T_342ea_row7_col10, #T_342ea_row7_col11, #T_342ea_row7_col12, #T_342ea_row7_col13, #T_342ea_row7_col14, #T_342ea_row7_col15, #T_342ea_row7_col16, #T_342ea_row7_col17, #T_342ea_row7_col18, #T_342ea_row7_col19, #T_342ea_row7_col20, #T_342ea_row7_col21, #T_342ea_row7_col22, #T_342ea_row8_col0, #T_342ea_row8_col1, #T_342ea_row8_col2, #T_342ea_row8_col3, #T_342ea_row8_col4, #T_342ea_row8_col5, #T_342ea_row8_col6, #T_342ea_row8_col7, #T_342ea_row8_col8, #T_342ea_row8_col9, #T_342ea_row8_col10, #T_342ea_row8_col11, #T_342ea_row8_col12, #T_342ea_row8_col13, #T_342ea_row8_col14, #T_342ea_row8_col15, #T_342ea_row8_col16, #T_342ea_row8_col17, #T_342ea_row8_col18, #T_342ea_row8_col19, #T_342ea_row8_col20, #T_342ea_row8_col21, #T_342ea_row8_col22, #T_342ea_row9_col0, #T_342ea_row9_col1, #T_342ea_row9_col2, #T_342ea_row9_col3, #T_342ea_row9_col4, #T_342ea_row9_col5, #T_342ea_row9_col6, #T_342ea_row9_col7, #T_342ea_row9_col8, #T_342ea_row9_col9, #T_342ea_row9_col10, #T_342ea_row9_c ...
#   background-color: lightyellow;
# }
# #T_342ea_row0_col2, #T_342ea_row0_col3, #T_342ea_row0_col11, #T_342ea_row0_col12, #T_342ea_row0_col13, #T_342ea_row0_col14, #T_342ea_row0_col16, #T_342ea_row0_col17, #T_342ea_row0_col19, #T_342ea_row0_col21, #T_342ea_row0_col22, #T_342ea_row1_col4, #T_342ea_row1_col6, #T_342ea_row1_col7, #T_342ea_row1_col8, #T_342ea_row1_col15, #T_342ea_row2_col18, #T_342ea_row3_col1, #T_342ea_row3_col20, #T_342ea_row4_col9, #T_342ea_row4_col10, #T_342ea_row5_col0, #T_342ea_row5_col5 {
#   background-color: lightyellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_342ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_342ea_level0_col0" class="col_heading level0 col0" colspan="23">AUC ROC</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Language</th>
#       <th id="T_342ea_level1_col0" class="col_heading level1 col0" >ar</th>
#       <th id="T_342ea_level1_col1" class="col_heading level1 col1" >bg</th>
#       <th id="T_342ea_level1_col2" class="col_heading level1 col2" >ca</th>
#       <th id="T_342ea_level1_col3" class="col_heading level1 col3" >cs</th>
#       <th id="T_342ea_level1_col4" class="col_heading level1 col4" >de</th>
#       <th id="T_342ea_level1_col5" class="col_heading level1 col5" >el</th>
#       <th id="T_342ea_level1_col6" class="col_heading level1 col6" >en</th>
#       <th id="T_342ea_level1_col7" class="col_heading level1 col7" >es</th>
#       <th id="T_342ea_level1_col8" class="col_heading level1 col8" >et</th>
#       <th id="T_342ea_level1_col9" class="col_heading lev
